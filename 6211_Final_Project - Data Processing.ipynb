# %%
import re
import os
import time
import requests
import pandas as pd
from zipfile import ZipFile
from io import BytesIO
import warnings
warnings.filterwarnings('ignore')

# Configuration
MAX_RETRIES = 10
RETRY_DELAY = 30  # seconds
SURVEY_YEARS = list(range(2011, 2026))  # 2011 to 2025

print("Starting Stack Overflow Survey Data Download...")
print(f"Years to download: {min(SURVEY_YEARS)} to {max(SURVEY_YEARS)}")
print(f"Retry configuration: {MAX_RETRIES} max attempts, {RETRY_DELAY}s delay")
print(f"URL pattern: https://survey.stackoverflow.co/datasets/stack-overflow-developer-survey-{{year}}.zip\n")
# Out:
# Starting Stack Overflow Survey Data Download...
# Years to download: 2011 to 2025
# Retry configuration: 10 max attempts, 30s delay
# URL pattern: https://survey.stackoverflow.co/datasets/stack-overflow-developer-survey-{year}.zip

# %%
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)
pd.set_option('display.max_colwidth', None)

# %%
def get_survey_urls(year):
    """
    Generate URL for a given survey year.
    All years use the same datasets ZIP pattern.
    """
    # All years use the same URL pattern
    url = f"https://survey.stackoverflow.co/datasets/stack-overflow-developer-survey-{year}.zip"
    return [url]

def fix_headers_for_older_years(df, year):
    """
    Fix headers for years 2011-2016 where the first two rows are headers.
    If the second row says "Response", use only the first row value.
    Otherwise, combine the first two rows.
    """
    if year >= 2011 and year <= 2015:
        if df.shape[0] < 2:
            print(f"  Warning: Not enough rows to fix headers for year {year}")
            return df
        
        # Get the first two rows
        first_row = df.iloc[0].astype(str)
        second_row = df.iloc[1].astype(str)
        
        # Create new column names
        new_columns = []
        for i, (first_val, second_val) in enumerate(zip(first_row, second_row)):
            first_val = first_val.strip()
            second_val = second_val.strip()
            
            # If second row is "Response", just use first row value
            if second_val == "Response":
                new_columns.append(first_val)
            else:
                # If both are the same or second is empty, use first
                if first_val == second_val or second_val == "":
                    new_columns.append(first_val)
                else:
                    # Combine both values - first value as primary
                    new_columns.append(f"{first_val} ({second_val})")
        
        # Set new column names
        df.columns = new_columns
        
        # Drop the first two rows (header rows)
        df = df.iloc[2:].reset_index(drop=True)
        
        print(f"  ✓ Fixed headers for year {year} (combined first two rows, removed 2 header rows)")
    
    return df

def download_file(url, year):
    """
    Download a file (single attempt, no retries).
    Returns the content if successful, None otherwise.
    Handles both CSV and ZIP files.
    """
    try:
        print(f"  Trying URL: {url}")
        response = requests.get(url, timeout=60, stream=True)
        response.raise_for_status()
        
        # Check content type
        content_type = response.headers.get('content-type', '').lower()
        
        # Reject HTML responses (likely error pages)
        if 'html' in content_type and response.status_code == 200:
            # Might be an error page, try next URL pattern
            print(f"  Warning: Received HTML instead of data file, may be wrong URL")
            return None
        
        content = response.content
        # Basic validation: check if content looks reasonable
        if len(content) < 100:
            print(f"  Warning: File too small, may be error page")
            return None
        
        # Check if it's a ZIP file by magic bytes
        is_zip = content[:2] == b'PK'  # ZIP files start with PK
        if is_zip:
            print(f"  ✓ Successfully downloaded {year} as ZIP ({len(content):,} bytes)")
        else:
            print(f"  ✓ Successfully downloaded {year} ({len(content):,} bytes)")
        
        return content
        
    except requests.exceptions.RequestException as e:
        print(f"  ✗ Download error: {str(e)}")
        return None

# %%
def validate_url(url):
    """
    Validate if a URL exists without downloading the full content.
    Returns True if the URL is valid and returns proper headers.
    """
    try:
        # Only get headers to check existence
        response = requests.head(url, timeout=10)
        return response.status_code == 200 and 'content-length' in response.headers
    except requests.exceptions.RequestException:
        return False

# %%
def download_and_extract_year(year, max_retries=MAX_RETRIES, delay=RETRY_DELAY, sample_size=None):
    """
    Download and extract survey data for a given year with retry logic.
    Tries multiple URL patterns and handles both CSV and ZIP files.
    Wraps the entire process in retry logic to catch any runtime errors.
    
    Args:
        year: The survey year to download
        max_retries: Maximum number of retry attempts
        delay: Delay between retries in seconds
        sample_size: If provided, only read this many rows from the CSV (for testing/development)
    
    Returns:
        DataFrame if successful, None otherwise.
    """
    print(f"\n{'='*60}")
    print(f"Processing year {year}")
    print(f"{'='*60}")
    
    urls = get_survey_urls(year)
    
    # Outer retry loop for entire download/extract process
    # This will retry the entire process up to max_retries times if a RuntimeError occurs
    for retry_attempt in range(max_retries):
        try:
            # Try each URL pattern
            for url in urls:
                content = download_file(url, year)
                
                if content is None:
                    continue
                
                # Check if content is a ZIP file by magic bytes (ZIP files start with 'PK')
                is_zip = content[:2] == b'PK'
                
                if is_zip:
                    # Try to parse as ZIP
                    try:
                        with ZipFile(BytesIO(content)) as zip_file:
                            # Look for CSV files in the ZIP (exclude macOS metadata)
                            csv_files = [f for f in zip_file.namelist() 
                                       if f.endswith('.csv') and not f.startswith('__MACOSX/')]
                            if csv_files:
                                # Use the first CSV file found
                                csv_file = csv_files[0]
                                print(f"  Found CSV file in ZIP: {csv_file}")
                                with zip_file.open(csv_file) as f:
                                    # For years 2011-2016, read without header to fix manually
                                    read_kwargs = {
                                        'low_memory': False, 
                                        'on_bad_lines': 'skip',
                                        'nrows': sample_size  # Add sample size parameter
                                    }
                                    if year >= 2011 and year <= 2015:
                                        read_kwargs['header'] = None
                                    
                                    try:
                                        df = pd.read_csv(f, encoding='utf-8', **read_kwargs)
                                        print(f"  ✓ Successfully loaded {year} from ZIP ({df.shape[0]:,} rows, {df.shape[1]:,} cols)")
                                        # Fix headers for older years
                                        df = fix_headers_for_older_years(df, year)
                                        return df
                                    except UnicodeDecodeError:
                                        f.seek(0)
                                        df = pd.read_csv(f, encoding='latin-1', **read_kwargs)
                                        print(f"  ✓ Successfully loaded {year} from ZIP with latin-1 encoding ({df.shape[0]:,} rows, {df.shape[1]:,} cols)")
                                        # Fix headers for older years
                                        df = fix_headers_for_older_years(df, year)
                                        return df
                            else:
                                print(f"  No CSV files found in ZIP archive")
                    except Exception as e:
                        print(f"  ZIP parsing failed: {str(e)}")
                        continue
                else:
                    # Try to parse as CSV directly
                    # For years 2011-2016, read without header to fix manually
                    read_kwargs = {
                        'low_memory': False, 
                        'on_bad_lines': 'skip',
                        'nrows': sample_size  # Add sample size parameter
                    }
                    if year >= 2011 and year <= 2016:
                        read_kwargs['header'] = None
                    
                    try:
                        df = pd.read_csv(BytesIO(content), encoding='utf-8', **read_kwargs)
                        print(f"  ✓ Successfully loaded {year} as CSV ({df.shape[0]:,} rows, {df.shape[1]:,} cols)")
                        # Fix headers for older years
                        df = fix_headers_for_older_years(df, year)
                        return df
                    except UnicodeDecodeError:
                        # Try different encoding
                        try:
                            df = pd.read_csv(BytesIO(content), encoding='latin-1', **read_kwargs)
                            print(f"  ✓ Successfully loaded {year} as CSV with latin-1 encoding ({df.shape[0]:,} rows, {df.shape[1]:,} cols)")
                            # Fix headers for older years
                            df = fix_headers_for_older_years(df, year)
                            return df
                        except Exception as e:
                            print(f"  CSV parsing failed: {str(e)}")
                            continue
                    except Exception as e:
                        print(f"  CSV parsing failed: {str(e)}")
                        continue
            
            # If we get here, the URL failed - this triggers a retry if attempts remain
            if retry_attempt < max_retries - 1:
                print(f"  ✗ Download failed for year {year}")
                print(f"  Retrying entire process (attempt {retry_attempt + 2}/{max_retries}) in {delay} seconds...")
                time.sleep(delay)
            else:
                print(f"  ✗ Failed to download and extract data for year {year} after {max_retries} attempts")
                print(f"  URL attempted: {urls[0]}")
                return None
                
        except RuntimeError as e:
            print(f"  ✗ Runtime error on attempt {retry_attempt + 1}: {str(e)}")
            if retry_attempt < max_retries - 1:
                print(f"  Retrying in {delay} seconds...")
                time.sleep(delay)
            else:
                print(f"  ✗ Failed after {max_retries} attempts due to runtime error")
                return None
        except Exception as e:
            # Catch any other unexpected errors and retry
            print(f"  ✗ Unexpected error on attempt {retry_attempt + 1}: {type(e).__name__}: {str(e)}")
            if retry_attempt < max_retries - 1:
                print(f"  Retrying in {delay} seconds...")
                time.sleep(delay)
            else:
                print(f"  ✗ Failed after {max_retries} attempts")
                return None
    
    return None

# %%
# Define sample size for testing (set to None for full dataset)
SAMPLE_SIZE = 1000  # Adjust this value to control how many rows to read from each year

# Download and create dataframes for each year
dataframes = {}

for year in SURVEY_YEARS:
    df = download_and_extract_year(year, max_retries=MAX_RETRIES, delay=RETRY_DELAY)
    if df is not None:
        # Add a year column to track which year the data is from
        df['SurveyYear'] = year
        dataframes[year] = df
    else:
        print(f"⚠ Skipping year {year} - download failed")

print(f"\n{'='*60}")
print(f"Download Summary")
print(f"{'='*60}")
print(f"Successfully downloaded: {len(dataframes)} out of {len(SURVEY_YEARS)} years")
print(f"Years downloaded: {sorted(dataframes.keys())}")
print(f"Years failed: {[y for y in SURVEY_YEARS if y not in dataframes]}")

# Display info for each dataframe
if dataframes:
    print(f"\n{'='*60}")
    print(f"DataFrame Information")
    print(f"{'='*60}")
    for year, df in sorted(dataframes.items()):
        print(f"Year {year}: {df.shape[0]:,} rows × {df.shape[1]:,} columns")
# Out:
# ============================================================
# Processing year 2011
# ============================================================
#   Trying URL: https://survey.stackoverflow.co/datasets/stack-overflow-developer-survey-2011.zip
#   ✓ Successfully downloaded 2011 as ZIP (80,173 bytes)
#   Found CSV file in ZIP: 2011 Stack Overflow Survey Results.csv
#   ✓ Successfully loaded 2011 from ZIP with latin-1 encoding (2,815 rows, 65 cols)
#   ✓ Fixed headers for year 2011 (combined first two rows, removed 2 header rows)
#
# ============================================================
# Processing year 2012
# ============================================================
#   Trying URL: https://survey.stackoverflow.co/datasets/stack-overflow-developer-survey-2012.zip
#   ✓ Successfully downloaded 2012 as ZIP (266,621 bytes)
#   Found CSV file in ZIP: 2012 Stack Overflow Survey Results.csv
#   ✓ Successfully loaded 2012 from ZIP with latin-1 encoding (6,245 rows, 75 cols)
#   ✓ Fixed headers for year 2012 (combined first two rows, removed 2 header rows)
#
# ============================================================
# Processing year 2013
# ============================================================
#   Trying URL: https://survey.stackoverflow.co/datasets/stack-overflow-developer-survey-2013.zip
#   ✓ Successfully downloaded 2013 as ZIP (689,493 bytes)
#   Found CSV file in ZIP: 2013 Stack Overflow Survey Responses.csv
#   ✓ Successfully loaded 2013 from ZIP (9,744 rows, 128 cols)
#   ✓ Fixed headers for year 2013 (combined first two rows, removed 2 header rows)
#
# ============================================================
# Processing year 2014
# ============================================================
#   Trying URL: https://survey.stackoverflow.co/datasets/stack-overflow-developer-survey-2014.zip
#   ✓ Successfully downloaded 2014 as ZIP (549,958 bytes)
#   Found CSV file in ZIP: 2014 Stack Overflow Survey Responses.csv
#   ✓ Successfully loaded 2014 from ZIP (7,645 rows, 120 cols)
#   ✓ Fixed headers for year 2014 (combined first two rows, removed 2 header rows)
#
# ============================================================
# Processing year 2015
# ============================================================
#   Trying URL: https://survey.stackoverflow.co/datasets/stack-overflow-developer-survey-2015.zip
#   ✗ Download error: 429 Client Error: Too Many Requests for url: https://survey.stackoverflow.co/datasets/stack-overflow-developer-survey-2015.zip
#   ✗ Download failed for year 2015
#   Retrying entire process (attempt 2/10) in 30 seconds...
#   Trying URL: https://survey.stackoverflow.co/datasets/stack-overflow-developer-survey-2015.zip
#   ✗ Download error: 429 Client Error: Too Many Requests for url: https://survey.stackoverflow.co/datasets/stack-overflow-developer-survey-2015.zip
#   ✗ Download failed for year 2015
#   Retrying entire process (attempt 3/10) in 30 seconds...
#   Trying URL: https://survey.stackoverflow.co/datasets/stack-overflow-developer-survey-2015.zip
#   ✗ Download error: 429 Client Error: Too Many Requests for url: https://survey.stackoverflow.co/datasets/stack-overflow-developer-survey-2015.zip
#   ✗ Download failed for year 2015
#   Retrying entire process (attempt 4/10) in 30 seconds...
#   Trying URL: https://survey.stackoverflow.co/datasets/stack-overflow-developer-survey-2015.zip
#   ✓ Successfully downloaded 2015 as ZIP (1,915,462 bytes)
#   Found CSV file in ZIP: 2015 Stack Overflow Developer Survey Responses.csv
#   ✓ Successfully loaded 2015 from ZIP (26,088 rows, 222 cols)
#   ✓ Fixed headers for year 2015 (combined first two rows, removed 2 header rows)
#
# ============================================================
# Processing year 2016
# ============================================================
#   Trying URL: https://survey.stackoverflow.co/datasets/stack-overflow-developer-survey-2016.zip
#   ✓ Successfully downloaded 2016 as ZIP (5,855,459 bytes)
#   Found CSV file in ZIP: 2016 Stack Overflow Survey Results/2016 Stack Overflow Survey Responses.csv
#   ✓ Successfully loaded 2016 from ZIP (56,030 rows, 66 cols)
#
# ============================================================
# Processing year 2017
# ============================================================
#   Trying URL: https://survey.stackoverflow.co/datasets/stack-overflow-developer-survey-2017.zip
#   ✗ Download error: 429 Client Error: Too Many Requests for url: https://survey.stackoverflow.co/datasets/stack-overflow-developer-survey-2017.zip
#   ✗ Download failed for year 2017
#   Retrying entire process (attempt 2/10) in 30 seconds...
#   Trying URL: https://survey.stackoverflow.co/datasets/stack-overflow-developer-survey-2017.zip
#   ✗ Download error: 429 Client Error: Too Many Requests for url: https://survey.stackoverflow.co/datasets/stack-overflow-developer-survey-2017.zip
#   ✗ Download failed for year 2017
#   Retrying entire process (attempt 3/10) in 30 seconds...
#   Trying URL: https://survey.stackoverflow.co/datasets/stack-overflow-developer-survey-2017.zip
#   ✓ Successfully downloaded 2017 as ZIP (9,576,818 bytes)
#   Found CSV file in ZIP: survey_results_public.csv
#   ✓ Successfully loaded 2017 from ZIP (51,392 rows, 154 cols)
#
# ============================================================
# Processing year 2018
# ============================================================
#   Trying URL: https://survey.stackoverflow.co/datasets/stack-overflow-developer-survey-2018.zip
#   ✓ Successfully downloaded 2018 as ZIP (20,022,841 bytes)
#   Found CSV file in ZIP: survey_results_public.csv
#   ✓ Successfully loaded 2018 from ZIP (98,855 rows, 129 cols)
#
# ============================================================
# Processing year 2019
# ============================================================
#   Trying URL: https://survey.stackoverflow.co/datasets/stack-overflow-developer-survey-2019.zip
#   ✗ Download error: 429 Client Error: Too Many Requests for url: https://survey.stackoverflow.co/datasets/stack-overflow-developer-survey-2019.zip
#   ✗ Download failed for year 2019
#   Retrying entire process (attempt 2/10) in 30 seconds...
#   Trying URL: https://survey.stackoverflow.co/datasets/stack-overflow-developer-survey-2019.zip
#   ✗ Download error: 429 Client Error: Too Many Requests for url: https://survey.stackoverflow.co/datasets/stack-overflow-developer-survey-2019.zip
#   ✗ Download failed for year 2019
#   Retrying entire process (attempt 3/10) in 30 seconds...
#   Trying URL: https://survey.stackoverflow.co/datasets/stack-overflow-developer-survey-2019.zip
#   ✓ Successfully downloaded 2019 as ZIP (18,681,322 bytes)
#   Found CSV file in ZIP: survey_results_public.csv
#   ✓ Successfully loaded 2019 from ZIP (88,883 rows, 85 cols)
#
# ============================================================
# Processing year 2020
# ============================================================
#   Trying URL: https://survey.stackoverflow.co/datasets/stack-overflow-developer-survey-2020.zip
#   ✓ Successfully downloaded 2020 as ZIP (9,908,290 bytes)
#   Found CSV file in ZIP: survey_results_public.csv
#   ✓ Successfully loaded 2020 from ZIP (64,461 rows, 61 cols)
#
# ============================================================
# Processing year 2021
# ============================================================
#   Trying URL: https://survey.stackoverflow.co/datasets/stack-overflow-developer-survey-2021.zip
#   ✗ Download error: 429 Client Error: Too Many Requests for url: https://survey.stackoverflow.co/datasets/stack-overflow-developer-survey-2021.zip
#   ✗ Download failed for year 2021
#   Retrying entire process (attempt 2/10) in 30 seconds...
#   Trying URL: https://survey.stackoverflow.co/datasets/stack-overflow-developer-survey-2021.zip
#   ✗ Download error: 429 Client Error: Too Many Requests for url: https://survey.stackoverflow.co/datasets/stack-overflow-developer-survey-2021.zip
#   ✗ Download failed for year 2021
#   Retrying entire process (attempt 3/10) in 30 seconds...
#   Trying URL: https://survey.stackoverflow.co/datasets/stack-overflow-developer-survey-2021.zip
#   ✓ Successfully downloaded 2021 as ZIP (8,825,103 bytes)
#   Found CSV file in ZIP: survey_results_public.csv
#   ✓ Successfully loaded 2021 from ZIP (83,439 rows, 48 cols)
#
# ============================================================
# Processing year 2022
# ============================================================
#   Trying URL: https://survey.stackoverflow.co/datasets/stack-overflow-developer-survey-2022.zip
#   ✓ Successfully downloaded 2022 as ZIP (12,089,826 bytes)
#   Found CSV file in ZIP: survey_results_public.csv
#   ✓ Successfully loaded 2022 from ZIP (73,268 rows, 79 cols)
#
# ============================================================
# Processing year 2023
# ============================================================
#   Trying URL: https://survey.stackoverflow.co/datasets/stack-overflow-developer-survey-2023.zip
#   ✗ Download error: 429 Client Error: Too Many Requests for url: https://survey.stackoverflow.co/datasets/stack-overflow-developer-survey-2023.zip
#   ✗ Download failed for year 2023
#   Retrying entire process (attempt 2/10) in 30 seconds...
#   Trying URL: https://survey.stackoverflow.co/datasets/stack-overflow-developer-survey-2023.zip
#   ✗ Download error: 429 Client Error: Too Many Requests for url: https://survey.stackoverflow.co/datasets/stack-overflow-developer-survey-2023.zip
#   ✗ Download failed for year 2023
#   Retrying entire process (attempt 3/10) in 30 seconds...
#   Trying URL: https://survey.stackoverflow.co/datasets/stack-overflow-developer-survey-2023.zip
#   ✓ Successfully downloaded 2023 as ZIP (20,599,404 bytes)
#   Found CSV file in ZIP: survey_results_public.csv
#   ✓ Successfully loaded 2023 from ZIP (89,184 rows, 84 cols)
#
# ============================================================
# Processing year 2024
# ============================================================
#   Trying URL: https://survey.stackoverflow.co/datasets/stack-overflow-developer-survey-2024.zip
#   ✓ Successfully downloaded 2024 as ZIP (17,703,733 bytes)
#   Found CSV file in ZIP: survey_results_public.csv
#   ✓ Successfully loaded 2024 from ZIP (65,437 rows, 114 cols)
#
# ============================================================
# Processing year 2025
# ============================================================
#   Trying URL: https://survey.stackoverflow.co/datasets/stack-overflow-developer-survey-2025.zip
#   ✓ Successfully downloaded 2025 as ZIP (17,368,332 bytes)
#   Found CSV file in ZIP: survey_results_public.csv
#   ✓ Successfully loaded 2025 from ZIP (49,123 rows, 170 cols)
#
# ============================================================
# Download Summary
# ============================================================
# Successfully downloaded: 15 out of 15 years
# Years downloaded: [2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022, 2023, 2024, 2025]
# Years failed: []
#
# ============================================================
# DataFrame Information
# ============================================================
# Year 2011: 2,813 rows × 66 columns
# Year 2012: 6,243 rows × 76 columns
# Year 2013: 9,742 rows × 129 columns
# Year 2014: 7,643 rows × 121 columns
# Year 2015: 26,086 rows × 223 columns
# Year 2016: 56,030 rows × 67 columns
# Year 2017: 51,392 rows × 155 columns
# Year 2018: 98,855 rows × 130 columns
# Year 2019: 88,883 rows × 86 columns
# Year 2020: 64,461 rows × 62 columns
# Year 2021: 83,439 rows × 49 columns
# Year 2022: 73,268 rows × 80 columns
# Year 2023: 89,184 rows × 85 columns
# Year 2024: 65,437 rows × 115 columns
# Year 2025: 49,123 rows × 171 columns

# %% [markdown]
# ### Create Combined Data Frame

# %%
# Create combined dataframe from all years
if dataframes:
    print(f"\n{'='*60}")
    print(f"Creating Combined DataFrame")
    print(f"{'='*60}")
    
    # Ensure all dataframes have unique columns before concatenation
    # Find the union of all columns
    all_columns = set()
    for df in dataframes.values():
        all_columns.update(df.columns)
    all_columns = list(all_columns)

    # Reindex each dataframe to ensure unique columns for concat
    aligned_dfs = []
    for year, df in dataframes.items():
        # Remove duplicate columns if any (can happen on bad CSVs)
        df = df.loc[:,~df.columns.duplicated()]
        aligned_df = df.reindex(columns=all_columns)
        aligned_dfs.append(aligned_df)
    
    combined_df = pd.concat(aligned_dfs, ignore_index=True, sort=False)
    
    print(f"success!")
    print(f"  rows: {combined_df.shape[0]:,}")
    print(f"  columns: {combined_df.shape[1]:,}")
    print(f"  Years: {sorted(combined_df['SurveyYear'].dropna().unique())}")
    
    # Show basic info about the combined dataframe
    print(f"\n{'='*60}")
    print(f"Combined DataFrame Info")
    print(f"{'='*60}")
    print(combined_df.info())
    print(f"{'='*60}")
else:
    print("\n⚠ No dataframes were successfully downloaded. Cannot create combined dataframe.")
    combined_df = None
# Out:
# ============================================================
# Creating Combined DataFrame
# ============================================================
# success!
#   rows: 772,599
#   columns: 1,087
#   Years: [2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022, 2023, 2024, 2025]
#
# ============================================================
# Combined DataFrame Info
# ============================================================
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 772599 entries, 0 to 772598
# Columns: 1087 entries, nan (>$150,000) to StackOverflowAdsDistracting
# dtypes: float64(106), int64(1), object(980)
# memory usage: 6.3+ GB
# None
# ============================================================

# %%
# Access individual year dataframes: dataframes[year]
# Access combined dataframe: combined_df
# Example:
if dataframes:
    print(f"\n{'='*60}")
    print(f"How to Access Your Data")
    print(f"{'='*60}")
    print(f"Individual year dataframes:")
    print(f"  - dataframes[2024]  # Access 2024 data")
    print(f"  - dataframes[2023]  # Access 2023 data")
    print(f"  - etc.")
    print(f"\nCombined dataframe:")
    print(f"  - combined_df  # All years combined")
    print(f"\nAvailable years: {sorted(dataframes.keys())}")
    
    # Quick preview of the combined dataframe
    if combined_df is not None:
        print(f"\n{'='*60}")
        print(f"Combined DataFrame Preview (first 5 rows)")
        print(f"{'='*60}")
        print(combined_df.head())
# Out:
# ============================================================
# How to Access Your Data
# ============================================================
# Individual year dataframes:
#   - dataframes[2024]  # Access 2024 data
#   - dataframes[2023]  # Access 2023 data
#   - etc.
#
# Combined dataframe:
#   - combined_df  # All years combined
#
# Available years: [2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022, 2023, 2024, 2025]
#
# ============================================================
# Combined DataFrame Preview (first 5 rows)
# ============================================================
#   nan (>$150,000)  ExpectedSalary AIToolInterested in Using TrueFalse_1  \
# 0             NaN             NaN                       NaN         NaN
# 1             NaN             NaN                       NaN         NaN
# 2             NaN             NaN                       NaN         NaN
# 3             NaN             NaN                       NaN         NaN
# 4       >$150,000             NaN                       NaN         NaN
#
#   SOTagsHaveWorkedWith ToolsTechWantToWorkWith OfficeStackSyncAdmired  \
# 0                  NaN                     NaN                    NaN
# 1                  NaN                     NaN                    NaN
# 2                  NaN                     NaN                    NaN
# 3                  NaN                     NaN                    NaN
# 4                  NaN                     NaN                    NaN
#
#   NEWCollabToolsDesireNextYear Knowledge_7  \
# 0                          NaN         NaN
# 1                          NaN         NaN
# 2                          NaN         NaN
# 3                          NaN         NaN
# 4                          NaN         NaN
#
#   AINextNeither different nor similar nan (Other tablet)  \
# 0                                 NaN                NaN
# 1                                 NaN                NaN
# 2                                 NaN                NaN
# 3                                 NaN                NaN
# 4                                 NaN                NaN
#
#   nan (Training & Education: Masters in CS)  \
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
#
#   nan (Most important aspect of new job opportunity: Office location)  \
# 0                                                                 NaN
# 1                                                                 NaN
# 2                                                                 NaN
# 3                                                                 NaN
# 4                                                                 NaN
#
#   SexualOrientation  AdsPriorities5 WebframeChoice ImpSyn  \
# 0               NaN             NaN            NaN    NaN
# 1               NaN             NaN            NaN    NaN
# 2               NaN             NaN            NaN    NaN
# 3               NaN             NaN            NaN    NaN
# 4               NaN             NaN            NaN    NaN
#
#   EmbeddedHaveWorkedWith DatabaseChoice agree_legacy OpSys  \
# 0                    NaN            NaN          NaN   NaN
# 1                    NaN            NaN          NaN   NaN
# 2                    NaN            NaN          NaN   NaN
# 3                    NaN            NaN          NaN   NaN
# 4                    NaN            NaN          NaN   NaN
#
#   OfficeStackSyncWantToWorkWith nan (Training & Education: Mentorship)  \
# 0                           NaN                                    NaN
# 1                           NaN                                    NaN
# 2                           NaN                                    NaN
# 3                           NaN                                    NaN
# 4                           NaN                                    NaN
#
#   nan (Excitement About the Company's Products) nan (Go)  \
# 0                                           NaN      NaN
# 1                                           NaN      NaN
# 2                                           NaN      NaN
# 3                                           NaN      NaN
# 4                                           NaN      NaN
#
#   nan (Current Lang & Tech: R) Do you work remotely?  \
# 0                          NaN                   NaN
# 1                          NaN                   NaN
# 2                          NaN                   NaN
# 3                          NaN                   NaN
# 4                          NaN                   NaN
#
#   nan (Why use Stack Overflow: Can't do job without it) BuyNewTool  \
# 0                                                   NaN        NaN
# 1                                                   NaN        NaN
# 2                                                   NaN        NaN
# 3                                                   NaN        NaN
# 4                                                   NaN        NaN
#
#   StackOverflowJobsRecommend LearnCodeAI StackOverflowMetaChat CheckInCode  \
# 0                        NaN         NaN                   NaN         NaN
# 1                        NaN         NaN                   NaN         NaN
# 2                        NaN         NaN                   NaN         NaN
# 3                        NaN         NaN                   NaN         NaN
# 4                        NaN         NaN                   NaN         NaN
#
#    AdsPriorities1 InfluenceWorkstation AssessJobOffice NEWJobHunt Gender  \
# 0             NaN                  NaN             NaN        NaN    NaN
# 1             NaN                  NaN             NaN        NaN    NaN
# 2             NaN                  NaN             NaN        NaN    NaN
# 3             NaN                  NaN             NaN        NaN    NaN
# 4             NaN                  NaN             NaN        NaN    NaN
#
#    JobEmailPriorities4 nan (Remote Status) WebframeWantEntry  \
# 0                  NaN                 NaN               NaN
# 1                  NaN                 NaN               NaN
# 2                  NaN                 NaN               NaN
# 3                  NaN                 NaN               NaN
# 4                  NaN                 NaN               NaN
#
#   nan (Future Lang & Tech: PHP) Which languages are you proficient in? (Java)  \
# 0                           NaN                                           NaN
# 1                           NaN                                          Java
# 2                           NaN                                          Java
# 3                           NaN                                          Java
# 4                           NaN                                          Java
#
#   AnnoyingUI StackOverflowJobListing AIDangerous commit_frequency  \
# 0        NaN                     NaN         NaN              NaN
# 1        NaN                     NaN         NaN              NaN
# 2        NaN                     NaN         NaN              NaN
# 3        NaN                     NaN         NaN              NaN
# 4        NaN                     NaN         NaN              NaN
#
#   agree_loveboss job_satisfaction StackOverflowBetter nan (WinRT)  \
# 0            NaN              NaN                 NaN         NaN
# 1            NaN              NaN                 NaN         NaN
# 2            NaN              NaN                 NaN         NaN
# 3            NaN              NaN                 NaN         NaN
# 4            NaN              NaN                 NaN         NaN
#
#   Do you have a Stack Overflow Careers 2.0 Profile? WantWorkPlatform  \
# 0                                               NaN              NaN
# 1                                               NaN              NaN
# 2                                               NaN              NaN
# 3                                               NaN              NaN
# 4                                               NaN              NaN
#
#   EquipmentSatisfiedRW nan (Current Lang & Tech: Python) EmploymentStatus  \
# 0                  NaN                               NaN              NaN
# 1                  NaN                               NaN              NaN
# 2                  NaN                               NaN              NaN
# 3                  NaN                               NaN              NaN
# 4                  NaN                               NaN              NaN
#
#   WantWorkLanguage  AssessBenefits7 WelcomeChange DifficultCommunication  \
# 0              NaN              NaN           NaN                    NaN
# 1              NaN              NaN           NaN                    NaN
# 2              NaN              NaN           NaN                    NaN
# 3              NaN              NaN           NaN                    NaN
# 4              NaN              NaN           NaN                    NaN
#
#   TechList BuildvsBuy  TechOppose_5 rep_range nan (Redis) AINextNo change  \
# 0      NaN        NaN           NaN       NaN         NaN             NaN
# 1      NaN        NaN           NaN       NaN         NaN             NaN
# 2      NaN        NaN           NaN       NaN         NaN             NaN
# 3      NaN        NaN           NaN       NaN         NaN             NaN
# 4      NaN        NaN           NaN       NaN         NaN             NaN
#
#   ExCoderSkills nan (Why answer: Help future programmers)  \
# 0           NaN                                       NaN
# 1           NaN                                       NaN
# 2           NaN                                       NaN
# 3           NaN                                       NaN
# 4           NaN                                       NaN
#
#   Which desktop operating system do you use the most?  AssessBenefits3  \
# 0                                                 NaN              NaN
# 1                                                 NaN              NaN
# 2                                                 NaN              NaN
# 3                                                 NaN              NaN
# 4                                                 NaN              NaN
#
#   nan (Current Lang & Tech: Java) LearnCodeOnline Frequency_2  \
# 0                             NaN             NaN         NaN
# 1                             NaN             NaN         NaN
# 2                             NaN             NaN         NaN
# 3                             NaN             NaN         NaN
# 4                             NaN             NaN         NaN
#
#   ImportantBenefits open_to_new_job salary_range  \
# 0               NaN             NaN          NaN
# 1               NaN             NaN          NaN
# 2               NaN             NaN          NaN
# 3               NaN             NaN          NaN
# 4               NaN             NaN          NaN
#
#   nan (Why use Stack Overflow: Maintain online presence) InTheZone  \
# 0                                                    NaN       NaN
# 1                                                    NaN       NaN
# 2                                                    NaN       NaN
# 3                                                    NaN       NaN
# 4                                                    NaN       NaN
#
#   why_learn_new_tech CareerSatisfaction Employment NewRole  \
# 0                NaN                NaN        NaN     NaN
# 1                NaN                NaN        NaN     NaN
# 2                NaN                NaN        NaN     NaN
# 3                NaN                NaN        NaN     NaN
# 4                NaN                NaN        NaN     NaN
#
#   InfluenceRecruitment remote nan (Looking for a job)  AssessJob9  \
# 0                  NaN    NaN                     NaN         NaN
# 1                  NaN    NaN                     NaN         NaN
# 2                  NaN    NaN                     NaN         NaN
# 3                  NaN    NaN                     NaN         NaN
# 4                  NaN    NaN                     NaN         NaN
#
#   What Country do you live in?  \
# 0                          NaN
# 1                          NaN
# 2                          NaN
# 3                          NaN
# 4                          NaN
#
#   nan (Most important aspect of new job opportunity: Company reputation)  \
# 0                                                                    NaN
# 1                                                                    NaN
# 2                                                                    NaN
# 3                                                                    NaN
# 4                                                                    NaN
#
#   nan (Why try Stack Overflow Careers: Jobs are on Stack Overflow)  \
# 0                                                              NaN
# 1                                                              NaN
# 2                                                              NaN
# 3                                                              NaN
# 4                                                              NaN
#
#   nan (Employment Status) WebframeAdmired  StackOverflowSatisfaction  WorkExp  \
# 0                     NaN             NaN                        NaN      NaN
# 1                     NaN             NaN                        NaN      NaN
# 2                     NaN             NaN                        NaN      NaN
# 3                     NaN             NaN                        NaN      NaN
# 4                     NaN             NaN                        NaN      NaN
#
#   nan (TypeScript) nan (Future Lang & Tech: C#)  \
# 0              NaN                          NaN
# 1              NaN                          NaN
# 2              NaN                          NaN
# 3              NaN                          NaN
# 4              NaN                          NaN
#
#   nan (Link to a Stack Overflow Careers Company Page or other source of more information about the company (videos, articles, etc))  \
# 0                                                                                                                               NaN
# 1                                                                                                                               NaN
# 2                                                                                                                               NaN
# 3                                                                                                                               NaN
# 4                                                                                                                               NaN
#
#   nan (Who do you want to communicate with about a new job opportunity: Manager)  \
# 0                                                                            NaN
# 1                                                                            NaN
# 2                                                                            NaN
# 3                                                                            NaN
# 4                                                                            NaN
#
#   StackOverflowJobs LastInt NEWDevOpsImpt Frequency_3 SOTagsHaveEntry  \
# 0               NaN     NaN           NaN         NaN             NaN
# 1               NaN     NaN           NaN         NaN             NaN
# 2               NaN     NaN           NaN         NaN             NaN
# 3               NaN     NaN           NaN         NaN             NaN
# 4               NaN     NaN           NaN         NaN             NaN
#
#   AIChallenges AIToolCurrently mostly AI AssessJobProjects AIModelsAdmired  \
# 0          NaN                       NaN               NaN             NaN
# 1          NaN                       NaN               NaN             NaN
# 2          NaN                       NaN               NaN             NaN
# 3          NaN                       NaN               NaN             NaN
# 4          NaN                       NaN               NaN             NaN
#
#   LanguageAdmired JobSatPoints_15_TEXT nan (Current Lang & Tech: Haskell)  \
# 0             NaN                  NaN                                NaN
# 1             NaN                  NaN                                NaN
# 2             NaN                  NaN                                NaN
# 3             NaN                  NaN                                NaN
# 4             NaN                  NaN                                NaN
#
#   PlatformHaveEntry nan (Source control used: CVS) Student  JobSatPoints_14  \
# 0               NaN                            NaN     NaN              NaN
# 1               NaN                            NaN     NaN              NaN
# 2               NaN                            NaN     NaN              NaN
# 3               NaN                            NaN     NaN              NaN
# 4               NaN                            NaN     NaN              NaN
#
#   nan (Why use Stack Overflow: Communicate with others)  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
#
#   nan (Current Lang & Tech: CoffeeScript) nan (Future Lang & Tech: Go)  \
# 0                                     NaN                          NaN
# 1                                     NaN                          NaN
# 2                                     NaN                          NaN
# 3                                     NaN                          NaN
# 4                                     NaN                          NaN
#
#   AIAgentKnowWrite nan (C)  \
# 0              NaN     NaN
# 1              NaN       C
# 2              NaN     NaN
# 3              NaN     NaN
# 4              NaN       C
#
#   How likely is it that a recommendation you make will be acted upon?  \
# 0                                              Not in a million years
# 1                                           It's been known to happen
# 2                                    Unless it's stoopid it gets done
# 3                                           It's been known to happen
# 4                                                    I run this place
#
#   EthicsResponsible nan (Netbook) nan ($41,000 - $75,000)  \
# 0               NaN           NaN                     NaN
# 1               NaN           NaN                     NaN
# 2               NaN           NaN                     NaN
# 3               NaN           NaN                     NaN
# 4               NaN           NaN       $41,000 - $75,000
#
#   If your company has a native mobile app, what platforms do you support? (iPhone)  \
# 0                                                                              NaN
# 1                                                                              NaN
# 2                                                                              NaN
# 3                                                                              NaN
# 4                                                                              NaN
#
#   AIHuman How would you best describe the industry you currently work in?  \
# 0     NaN                                                             NaN
# 1     NaN                                                             NaN
# 2     NaN                                                             NaN
# 3     NaN                                                             NaN
# 4     NaN                                                             NaN
#
#   nan (Office in a Desirable City/Area) InfluenceCommunication nan (Android)  \
# 0                                   NaN                    NaN           NaN
# 1                                   NaN                    NaN           NaN
# 2                                   NaN                    NaN           NaN
# 3                                   NaN                    NaN           NaN
# 4                                   NaN                    NaN       Android
#
#   important_sameend StackOverflowAnswer  \
# 0               NaN                 NaN
# 1               NaN                 NaN
# 2               NaN                 NaN
# 3               NaN                 NaN
# 4               NaN                 NaN
#
#   nan (Who do you want to communicate with about a new job opportunity: Developer)  \
# 0                                                                              NaN
# 1                                                                              NaN
# 2                                                                              NaN
# 3                                                                              NaN
# 4                                                                              NaN
#
#   LearnCodeChoose important_promotion employment_status  \
# 0             NaN                 NaN               NaN
# 1             NaN                 NaN               NaN
# 2             NaN                 NaN               NaN
# 3             NaN                 NaN               NaN
# 4             NaN                 NaN               NaN
#
#   Select all that apply (Current Lang & Tech: Android)  AssessJob4  \
# 0                                                  NaN         NaN
# 1                                                  NaN         NaN
# 2                                                  NaN         NaN
# 3                                                  NaN         NaN
# 4                                                  NaN         NaN
#
#   AIAgentOrchWrite agree_alcohol  \
# 0              NaN           NaN
# 1              NaN           NaN
# 2              NaN           NaN
# 3              NaN           NaN
# 4              NaN           NaN
#
#   What advertisers do you remember seeing on Stack Overflow? (Open-Ended Response)  \
# 0                                                                              NaN
# 1                                                                              NaN
# 2                                                                              NaN
# 3                                                                              NaN
# 4                                                                              NaN
#
#   You answered you don't have a Careers profile, can you elaborate why?  \
# 0                                                                   NaN
# 1                                                                   NaN
# 2                                                                   NaN
# 3                                                                   NaN
# 4                                                                   NaN
#
#   nan (Hadoop) dev_environment dogs_vs_cats OfficeStackWantEntry  \
# 0          NaN             NaN          NaN                  NaN
# 1          NaN             NaN          NaN                  NaN
# 2          NaN             NaN          NaN                  NaN
# 3          NaN             NaN          NaN                  NaN
# 4          NaN             NaN          NaN                  NaN
#
#   nan (Training & Education: Some college, but no CS degree)  \
# 0                                                        NaN
# 1                                                        NaN
# 2                                                        NaN
# 3                                                        NaN
# 4                                                        NaN
#
#   Select all that apply (Why try Stack Overflow Careers: No spam)  \
# 0                                                             NaN
# 1                                                             NaN
# 2                                                             NaN
# 3                                                             NaN
# 4                                                             NaN
#
#    SO_Actions_7 StackOverflowHelpful ProblemSolving  \
# 0           NaN                  NaN            NaN
# 1           NaN                  NaN            NaN
# 2           NaN                  NaN            NaN
# 3           NaN                  NaN            NaN
# 4           NaN                  NaN            NaN
#
#   nan (Current Lang & Tech: Rust) nan (Source control used: TFS)  \
# 0                             NaN                            NaN
# 1                             NaN                            NaN
# 2                             NaN                            NaN
# 3                             NaN                            NaN
# 4                             NaN                            NaN
#
#   DevEnvsAdmired AISearchDevAdmired AIAgentObsWrite AIAgentImpactNeutral  \
# 0            NaN                NaN             NaN                  NaN
# 1            NaN                NaN             NaN                  NaN
# 2            NaN                NaN             NaN                  NaN
# 3            NaN                NaN             NaN                  NaN
# 4            NaN                NaN             NaN                  NaN
#
#   In an average week, how do you spend your time? (Developing new features)  \
# 0                                                                       NaN
# 1                                                                       NaN
# 2                                                                       NaN
# 3                                                                       NaN
# 4                                                                       NaN
#
#   nan (Ask questions to solve problems)  programming_ability LearnedHiring  \
# 0                                   NaN                  NaN           NaN
# 1                                   NaN                  NaN           NaN
# 2                                   NaN                  NaN           NaN
# 3                                   NaN                  NaN           NaN
# 4                                   NaN                  NaN           NaN
#
#   Q120 SOJobs nan (C++) SOFriction nan (Perl) FriendsDevelopers  \
# 0  NaN    NaN       NaN        NaN        NaN               NaN
# 1  NaN    NaN       NaN        NaN        NaN               NaN
# 2  NaN    NaN       NaN        NaN        NaN               NaN
# 3  NaN    NaN       NaN        NaN        NaN               NaN
# 4  NaN    NaN       C++        NaN       Perl               NaN
#
#   nan (Meetings) nan (AngularJS) nan (Finance) University  \
# 0            NaN             NaN           NaN        NaN
# 1            NaN             NaN           NaN        NaN
# 2            NaN             NaN           NaN        NaN
# 3            NaN             NaN           NaN        NaN
# 4            NaN             NaN           NaN        NaN
#
#   StackOverflowAdsRelevant BuildingThings nan (Future Lang & Tech: Haskell)  \
# 0                      NaN            NaN                               NaN
# 1                      NaN            NaN                               NaN
# 2                      NaN            NaN                               NaN
# 3                      NaN            NaN                               NaN
# 4                      NaN            NaN                               NaN
#
#   StackOverflowModeration nan (Industry) SOVisitFreq Ethnicity Onboarding  \
# 0                     NaN            NaN         NaN       NaN        NaN
# 1                     NaN            NaN         NaN       NaN        NaN
# 2                     NaN            NaN         NaN       NaN        NaN
# 3                     NaN            NaN         NaN       NaN        NaN
# 4                     NaN            NaN         NaN       NaN        NaN
#
#    AdsPriorities3 nan (Future Lang & Tech: Matlab) WakeTime  \
# 0             NaN                              NaN      NaN
# 1             NaN                              NaN      NaN
# 2             NaN                              NaN      NaN
# 3             NaN                              NaN      NaN
# 4             NaN                              NaN      NaN
#
#   LearnCodeCoursesCert nan (Learning new skills)  \
# 0                  NaN                       NaN
# 1                  NaN                       NaN
# 2                  NaN                       NaN
# 3                  NaN                       NaN
# 4                  NaN                       NaN
#
#   Select up to 3 (How can companies improve interview process: More live code)  \
# 0                                                                          NaN
# 1                                                                          NaN
# 2                                                                          NaN
# 3                                                                          NaN
# 4                                                                          NaN
#
#   SurveyLength LanguagesWantEntry AssessJobCommute  \
# 0          NaN                NaN              NaN
# 1          NaN                NaN              NaN
# 2          NaN                NaN              NaN
# 3          NaN                NaN              NaN
# 4          NaN                NaN              NaN
#
#   nan (Appealing message traits: Salary information) StackOverflowHasAccount  \
# 0                                                NaN                     NaN
# 1                                                NaN                     NaN
# 2                                                NaN                     NaN
# 3                                                NaN                     NaN
# 4                                                NaN                     NaN
#
#    JobContactPriorities1 nan (Future Lang & Tech: SQL)  \
# 0                    NaN                           NaN
# 1                    NaN                           NaN
# 2                    NaN                           NaN
# 3                    NaN                           NaN
# 4                    NaN                           NaN
#
#   nan (Other Smart Phone) nan (Current Lang & Tech: iOS)  JobEmailPriorities1  \
# 0                     NaN                            NaN                  NaN
# 1                     NaN                            NaN                  NaN
# 2                     NaN                            NaN                  NaN
# 3                     NaN                            NaN                  NaN
# 4                     NaN                            NaN                  NaN
#
#   nan (Most annoying about job search: The Interview) CollaborateRemote  \
# 0                                                 NaN               NaN
# 1                                                 NaN               NaN
# 2                                                 NaN               NaN
# 3                                                 NaN               NaN
# 4                                                 NaN               NaN
#
#   nan (Technical Support) AssessJobTech HaveWorkedLanguage WorkRemote  \
# 0                     NaN           NaN                NaN        NaN
# 1                     NaN           NaN                NaN        NaN
# 2                     NaN           NaN                NaN        NaN
# 3                     NaN           NaN                NaN        NaN
# 4                     NaN           NaN                NaN        NaN
#
#   important_wfh nan (Opportunity to Use/Learn New Technologies)  \
# 0           NaN                                             NaN
# 1           NaN                                             NaN
# 2           NaN                                             NaN
# 3           NaN                                             NaN
# 4           NaN                                             NaN
#
#   nan (Future Lang & Tech: Redis) AIToolCurrently partially AI  \
# 0                             NaN                          NaN
# 1                             NaN                          NaN
# 2                             NaN                          NaN
# 3                             NaN                          NaN
# 4                             NaN                          NaN
#
#   StackOverflowDevices nan (C#)  \
# 0                  NaN      NaN
# 1                  NaN      NaN
# 2                  NaN      NaN
# 3                  NaN      NaN
# 4                  NaN      NaN
#
#   If you make a software product, how does your company make money? (You can choose more than one) (Advertising)  \
# 0                                                                                                            NaN
# 1                                                                                                            NaN
# 2                                                                                                            NaN
# 3                                                                                                            NaN
# 4                                                                                                            NaN
#
#   PurchaseWhat What types of purchases are you involved in? (Hardware)  \
# 0          NaN                                                     NaN
# 1          NaN                                                     NaN
# 2          NaN                                                     NaN
# 3          NaN                                                     NaN
# 4          NaN                                                Hardware
#
#   How would you best describe the industry you work in? UnderstandComputers  \
# 0                                            Consulting                 NaN
# 1                                     Software Products                 NaN
# 2                                     Software Products                 NaN
# 3                               Foundation / Non-Profit                 NaN
# 4                                     Software Products                 NaN
#
#   TrueFalse_3 DatabaseHaveWorkedWith InfluenceTechStack AIInteresting  \
# 0         NaN                    NaN                NaN           NaN
# 1         NaN                    NaN                NaN           NaN
# 2         NaN                    NaN                NaN           NaN
# 3         NaN                    NaN                NaN           NaN
# 4         NaN                    NaN                NaN           NaN
#
#   nan (Source control used: Legacy / Custom) tech_want  AssessJob2  \
# 0                                        NaN       NaN         NaN
# 1                                        NaN       NaN         NaN
# 2                                        NaN       NaN         NaN
# 3                                        NaN       NaN         NaN
# 4                                        NaN       NaN         NaN
#
#   DevEnvWantEntry MajorUndergrad What type of project are you developing?  \
# 0             NaN            NaN                                   Mobile
# 1             NaN            NaN                               Enterprise
# 2             NaN            NaN                                     SaaS
# 3             NaN            NaN                                    Other
# 4             NaN            NaN                               Enterprise
#
#   NonDeveloperType nan (Current Lang & Tech: C++11) Salary NEWOtherComms  \
# 0              NaN                              NaN    NaN           NaN
# 1              NaN                              NaN    NaN           NaN
# 2              NaN                              NaN    NaN           NaN
# 3              NaN                              NaN    NaN           NaN
# 4              NaN                              NaN    NaN           NaN
#
#   BetterLife  SO_Actions_10 MiscTechAdmired InterestedAnswers  AdsPriorities4  \
# 0        NaN            NaN             NaN               NaN             NaN
# 1        NaN            NaN             NaN               NaN             NaN
# 2        NaN            NaN             NaN               NaN             NaN
# 3        NaN            NaN             NaN               NaN             NaN
# 4        NaN            NaN             NaN               NaN             NaN
#
#   ClickyKeys ProgramHobby  \
# 0        NaN          NaN
# 1        NaN          NaN
# 2        NaN          NaN
# 3        NaN          NaN
# 4        NaN          NaN
#
#   nan (Most important aspect of new job opportunity: Equity)  JobSatPoints_7  \
# 0                                                        NaN             NaN
# 1                                                        NaN             NaN
# 2                                                        NaN             NaN
# 3                                                        NaN             NaN
# 4                                                        NaN             NaN
#
#    AdsPriorities6 NEWSOSites AIExplain nan (Software)  \
# 0             NaN        NaN       NaN       Software
# 1             NaN        NaN       NaN            NaN
# 2             NaN        NaN       NaN            NaN
# 3             NaN        NaN       NaN            NaN
# 4             NaN        NaN       NaN       Software
#
#   nan (Current Lang & Tech: MongoDB) nan (HTML5) OtherPeoplesCode AdBlocker  \
# 0                                NaN         NaN              NaN       NaN
# 1                                NaN         NaN              NaN       NaN
# 2                                NaN         NaN              NaN       NaN
# 3                                NaN         NaN              NaN       NaN
# 4                                NaN         NaN              NaN       NaN
#
#    JobSatPoints_10 Knowledge_5 nan (Cordova) EthicsReport nan (Android phone)  \
# 0              NaN         NaN           NaN          NaN                 NaN
# 1              NaN         NaN           NaN          NaN                 NaN
# 2              NaN         NaN           NaN          NaN                 NaN
# 3              NaN         NaN           NaN          NaN                 NaN
# 4              NaN         NaN           NaN          NaN                 NaN
#
#   nan (Source control used: SVN) BlockchainIs  \
# 0                            NaN          NaN
# 1                            NaN          NaN
# 2                            NaN          NaN
# 3                            NaN          NaN
# 4                            NaN          NaN
#
#   nan (How often are Stack Overflow's answers helpful)  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
#
#   Where do you work remotely most of the time? ImportantHiringCompanies  \
# 0                                          NaN                      NaN
# 1                                          NaN                      NaN
# 2                                          NaN                      NaN
# 3                                          NaN                      NaN
# 4                                          NaN                      NaN
#
#   nan ($100,001 - $150,000) nan (Using Stack Exchange) BoringDetails  \
# 0                       NaN                        NaN           NaN
# 1                       NaN                        NaN           NaN
# 2                       NaN                        NaN           NaN
# 3                       NaN                        NaN           NaN
# 4       $100,001 - $150,000                        NaN           NaN
#
#   AdBlockerDisable AdBlockerReasons JobSatisfaction  \
# 0              NaN              NaN             NaN
# 1              NaN              NaN             NaN
# 2              NaN              NaN             NaN
# 3              NaN              NaN             NaN
# 4              NaN              NaN             NaN
#
#   What is your involvement in purchasing products or services for the company you work for? (You can choose more than one) (I can recommend or request products)  \
# 0                                                                                                                                                            NaN
# 1                                                                                                                                                            NaN
# 2                                                                                                                                                            NaN
# 3                                                                                                                                                            NaN
# 4                                                                                                                                                            NaN
#
#   nan (How can companies improve interview process: Remote interviews)  \
# 0                                                                  NaN
# 1                                                                  NaN
# 2                                                                  NaN
# 3                                                                  NaN
# 4                                                                  NaN
#
#   nan (Recruitment Tools & Services)  AssessJob10 JobSecurity AIResponsible  \
# 0                                NaN          NaN         NaN           NaN
# 1                                NaN          NaN         NaN           NaN
# 2                                NaN          NaN         NaN           NaN
# 3                                NaN          NaN         NaN           NaN
# 4                                NaN          NaN         NaN           NaN
#
#   StackOverflowCommunity nan (Training & Education: PhD in CS)  \
# 0                    NaN                                   NaN
# 1                    NaN                                   NaN
# 2                    NaN                                   NaN
# 3                    NaN                                   NaN
# 4                    NaN                                   NaN
#
#   nan (Why use Stack Overflow: Demonstrate expertise)  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
#
#   CommPlatformWantToWorkWith  \
# 0                        NaN
# 1                        NaN
# 2                        NaN
# 3                        NaN
# 4                        NaN
#
#   nan (Most important aspect of new job opportunity: Building something that matters)  \
# 0                                                                                 NaN
# 1                                                                                 NaN
# 2                                                                                 NaN
# 3                                                                                 NaN
# 4                                                                                 NaN
#
#   TabsSpaces nan (Current Lang & Tech: JavaScript) nan (Kindle) OffOn  \
# 0        NaN                                   NaN          NaN   NaN
# 1        NaN                                   NaN          NaN   NaN
# 2        NaN                                   NaN          NaN   NaN
# 3        NaN                                   NaN       Kindle   NaN
# 4        NaN                                   NaN       Kindle   NaN
#
#   nan (Most annoying about job search: Finding interesting job) YearsCodedJob  \
# 0                                                           NaN           NaN
# 1                                                           NaN           NaN
# 2                                                           NaN           NaN
# 3                                                           NaN           NaN
# 4                                                           NaN           NaN
#
#   SeriousWork nan (iPad)  SO_Actions_6  \
# 0         NaN        NaN           NaN
# 1         NaN        NaN           NaN
# 2         NaN        NaN           NaN
# 3         NaN        NaN           NaN
# 4         NaN        NaN           NaN
#
#   Which best describes the size of your company? nan (Node.js)  \
# 0                                Start Up (1-25)           NaN
# 1                 Mature Small Business (25-100)           NaN
# 2                            Mid Sized (100-999)           NaN
# 3                                        Student           NaN
# 4                                Start Up (1-25)           NaN
#
#   nan (Most urgent info about job opportunity: Colleagues)  \
# 0                                                      NaN
# 1                                                      NaN
# 2                                                      NaN
# 3                                                      NaN
# 4                                                      NaN
#
#   StackOverflowMakeMoney MilitaryUS nan (Occupation) visit_frequency  \
# 0                    NaN        NaN              NaN             NaN
# 1                    NaN        NaN              NaN             NaN
# 2                    NaN        NaN              NaN             NaN
# 3                    NaN        NaN              NaN             NaN
# 4                    NaN        NaN              NaN             NaN
#
#   Please rate your job/career satisfaction ExCoder10Years ProjectManagement  \
# 0                                      FML            NaN               NaN
# 1                        So happy it hurts            NaN               NaN
# 2                                      NaN            NaN               NaN
# 3                    I enjoy going to work            NaN               NaN
# 4                        It pays the bills            NaN               NaN
#
#    JobSatPoints_11 AIAgentImpactStrongly agree LastHireDate  \
# 0              NaN                         NaN          NaN
# 1              NaN                         NaN          NaN
# 2              NaN                         NaN          NaN
# 3              NaN                         NaN          NaN
# 4              NaN                         NaN          NaN
#
#   nan (The ads are Informative)  \
# 0                           NaN
# 1                           NaN
# 2                           NaN
# 3                           NaN
# 4                           NaN
#
#   Have you visited / Are you aware of Stack Overflow Careers 2.0?  \
# 0                                                             NaN
# 1                                                             NaN
# 2                                                             NaN
# 3                                                             NaN
# ...
# 2              NaN                     NaN
# 3              NaN                     NaN
# 4              NaN       $25,001 - $40,000
#
#   nan (Current Lang & Tech: Salesforce) AIAgentImpactStrongly disagree  \
# 0                                   NaN                            NaN
# 1                                   NaN                            NaN
# 2                                   NaN                            NaN
# 3                                   NaN                            NaN
# 4                                   NaN                            NaN
#
#   HypotheticalTools1 nan (jQuery) nan (F#) nan (Future Lang & Tech: Swift)  \
# 0                NaN          NaN      NaN                             NaN
# 1                NaN          NaN      NaN                             NaN
# 2                NaN          NaN      NaN                             NaN
# 3                NaN          NaN      NaN                             NaN
# 4                NaN          NaN      NaN                             NaN
#
#   nan (Android Tablet)  \
# 0                  NaN
# 1                  NaN
# 2                  NaN
# 3                  NaN
# 4                  NaN
#
#   nan (How can companies improve interview process: Introduce me to boss)  \
# 0                                                                     NaN
# 1                                                                     NaN
# 2                                                                     NaN
# 3                                                                     NaN
# 4                                                                     NaN
#
#   so_region LanguageChoice nan (Future Lang & Tech: LAMP)  \
# 0       NaN            NaN                            NaN
# 1       NaN            NaN                            NaN
# 2       NaN            NaN                            NaN
# 3       NaN            NaN                            NaN
# 4       NaN            NaN                            NaN
#
#   nan (How can companies improve interview process: Show me workplace)  \
# 0                                                                  NaN
# 1                                                                  NaN
# 2                                                                  NaN
# 3                                                                  NaN
# 4                                                                  NaN
#
#   ProfessionalCloud  TechOppose_3  \
# 0               NaN           NaN
# 1               NaN           NaN
# 2               NaN           NaN
# 3               NaN           NaN
# 4               NaN           NaN
#
#   nan (Most important aspect of new job opportunity: Quality of colleagues)  \
# 0                                                                       NaN
# 1                                                                       NaN
# 2                                                                       NaN
# 3                                                                       NaN
# 4                                                                       NaN
#
#   nan (Future Lang & Tech: R) nan (Current Lang & Tech: Clojure)  \
# 0                         NaN                                NaN
# 1                         NaN                                NaN
# 2                         NaN                                NaN
# 3                         NaN                                NaN
# 4                         NaN                                NaN
#
#   developer_challenges nan (No Involvement) HaveWorkedDatabase Knowledge_6  \
# 0                  NaN                  NaN                NaN         NaN
# 1                  NaN       No Involvement                NaN         NaN
# 2                  NaN                  NaN                NaN         NaN
# 3                  NaN       No Involvement                NaN         NaN
# 4                  NaN                  NaN                NaN         NaN
#
#    JobSatPoints_5 nan (Future Lang & Tech: Dart) nan (Looking for a new job)  \
# 0             NaN                            NaN                         NaN
# 1             NaN                            NaN                         NaN
# 2             NaN                            NaN                         NaN
# 3             NaN                            NaN                         NaN
# 4             NaN                            NaN                         NaN
#
#   YearsCodingProf nan (Objective-C) nan (Consulting) SocialMedia  \
# 0             NaN               NaN              NaN         NaN
# 1             NaN               NaN              NaN         NaN
# 2             NaN               NaN              NaN         NaN
# 3             NaN               NaN              NaN         NaN
# 4             NaN               NaN              NaN         NaN
#
#    SO_Actions_15 nan (Android Phone)  \
# 0            NaN                 NaN
# 1            NaN                 NaN
# 2            NaN                 NaN
# 3            NaN                 NaN
# 4            NaN                 NaN
#
#   nan (Training & Education: Boot camp or night school) HomeRemote  \
# 0                                                   NaN        NaN
# 1                                                   NaN        NaN
# 2                                                   NaN        NaN
# 3                                                   NaN        NaN
# 4                                                   NaN        NaN
#
#   AdsAgreeDisagree1  JobSatPoints_6 industry nan (Wii U) How old are you?  \
# 0               NaN             NaN      NaN         NaN             < 20
# 1               NaN             NaN      NaN         NaN            25-29
# 2               NaN             NaN      NaN         NaN            25-29
# 3               NaN             NaN      NaN         NaN             < 20
# 4               NaN             NaN      NaN         NaN            35-39
#
#    JobSatPoints_1 nan (Source control used: write-in)  \
# 0             NaN                                 NaN
# 1             NaN                                 NaN
# 2             NaN                                 NaN
# 3             NaN                                 NaN
# 4             NaN                                 NaN
#
#   nan (Stock Options/Profit Sharing Program)  JobEmailPriorities5  \
# 0                                        NaN                  NaN
# 1                                        NaN                  NaN
# 2                                        NaN                  NaN
# 3                                        NaN                  NaN
# 4                                        NaN                  NaN
#
#   nan (Android tablet) NEWOnboardGood nan (Perception of contact form: Xing)  \
# 0                  NaN            NaN                                    NaN
# 1                  NaN            NaN                                    NaN
# 2                  NaN            NaN                                    NaN
# 3                  NaN            NaN                                    NaN
# 4                  NaN            NaN                                    NaN
#
#   NEWEdImpt AIBen  \
# 0       NaN   NaN
# 1       NaN   NaN
# 2       NaN   NaN
# 3       NaN   NaN
# 4       NaN   NaN
#
#   nan (Most urgent info about job opportunity: Product details)  \
# 0                                                           NaN
# 1                                                           NaN
# 2                                                           NaN
# 3                                                           NaN
# 4                                                           NaN
#
#   DiversityImportant nan (Current Lang & Tech: Spark)  \
# 0                NaN                              NaN
# 1                NaN                              NaN
# 2                NaN                              NaN
# 3                NaN                              NaN
# 4                NaN                              NaN
#
#   nan (Changed Jobs in last 12 Months)  \
# 0                                  NaN
# 1                                  NaN
# 2                                  NaN
# 3                                  NaN
# 4                                  NaN
#
#   Please rate the advertising you've seen on Stack Overflow (The ads are relevant)  \
# 0                                                                              NaN
# 1                                                                              NaN
# 2                                                                              NaN
# 3                                                                              NaN
# 4                                                                              NaN
#
#   In an average week, how do you spend your time at work? (Developing new features)  \
# 0                                                                               NaN
# 1                                                                               NaN
# 2                                                                               NaN
# 3                                                                               NaN
# 4                                                                               NaN
#
#   nan (How can companies improve interview process: Fewer brainteasers)  \
# 0                                                                   NaN
# 1                                                                   NaN
# 2                                                                   NaN
# 3                                                                   NaN
# 4                                                                   NaN
#
#   ExCoderActive RightWrongWay KinshipDevelopers WebDeveloperType  \
# 0           NaN           NaN               NaN              NaN
# 1           NaN           NaN               NaN              NaN
# 2           NaN           NaN               NaN              NaN
# 3           NaN           NaN               NaN              NaN
# 4           NaN           NaN               NaN              NaN
#
#   nan (Future Lang & Tech: CoffeeScript) NEWCollabToolsAdmired  \
# 0                                    NaN                   NaN
# 1                                    NaN                   NaN
# 2                                    NaN                   NaN
# 3                                    NaN                   NaN
# 4                                    NaN                   NaN
#
#   TechEndorseIntro TimeFullyProductive AssessJobDiversity  \
# 0              NaN                 NaN                NaN
# 1              NaN                 NaN                NaN
# 2              NaN                 NaN                NaN
# 3              NaN                 NaN                NaN
# 4              NaN                 NaN                NaN
#
#   MiscTechDesireNextYear LanguageHaveWorkedWith  JobSatPoints_16 UK_Country  \
# 0                    NaN                    NaN              NaN        NaN
# 1                    NaN                    NaN              NaN        NaN
# 2                    NaN                    NaN              NaN        NaN
# 3                    NaN                    NaN              NaN        NaN
# 4                    NaN                    NaN              NaN        NaN
#
#   nan (Current Lang & Tech: LAMP) agree_notice AIDevWantToWorkWith  \
# 0                             NaN          NaN                 NaN
# 1                             NaN          NaN                 NaN
# 2                             NaN          NaN                 NaN
# 3                             NaN          NaN                 NaN
# 4                             NaN          NaN                 NaN
#
#    JobSatPoints_15 important_buildexisting CodingActivities  \
# 0              NaN                     NaN              NaN
# 1              NaN                     NaN              NaN
# 2              NaN                     NaN              NaN
# 3              NaN                     NaN              NaN
# 4              NaN                     NaN              NaN
#
#    VCHostingPersonal use Do you have a Stack Overflow Careers Profile?  \
# 0                    NaN                                           NaN
# 1                    NaN                                           NaN
# 2                    NaN                                           NaN
# 3                    NaN                                           NaN
# 4                    NaN                                           NaN
#
#   nan (I've taken a trial/purchased a product from ads) Dependents  \
# 0                                                   NaN        NaN
# 1                                                   NaN        NaN
# 2                                                   NaN        NaN
# 3                                                   NaN        NaN
# 4                                                   NaN        NaN
#
#   nan (Most urgent info about job opportunity: Company name) team_size_range  \
# 0                                                        NaN             NaN
# 1                                                        NaN             NaN
# 2                                                        NaN             NaN
# 3                                                        NaN             NaN
# 4                                                        NaN             NaN
#
#   nan (Future Lang & Tech: C++) ChallengeMyself  \
# 0                           NaN             NaN
# 1                           NaN             NaN
# 2                           NaN             NaN
# 3                           NaN             NaN
# 4                           NaN             NaN
#
#   Select all that apply (Training & Education: No formal training)  \
# 0                                                              NaN
# 1                                                              NaN
# 2                                                              NaN
# 3                                                              NaN
# 4                                                              NaN
#
#   nan (Autonomy Over Budget/Expenditures) WebframeWorkedWith nan (Customers)  \
# 0                                     NaN                NaN             NaN
# 1                                     NaN                NaN             NaN
# 2                                     NaN                NaN             NaN
# 3                                     NaN                NaN             NaN
# 4                                     NaN                NaN             NaN
#
#   Knowledge_3  TechEndorse_13  JobContactPriorities2  \
# 0         NaN             NaN                    NaN
# 1         NaN             NaN                    NaN
# 2         NaN             NaN                    NaN
# 3         NaN             NaN                    NaN
# 4         NaN             NaN                    NaN
#
#   nan (Perception of contact form: Email) nan (Product Managers) hobby  \
# 0                                     NaN                    NaN   NaN
# 1                                     NaN                    NaN   NaN
# 2                                     NaN                    NaN   NaN
# 3                                     NaN                    NaN   NaN
# 4                                     NaN                    NaN   NaN
#
#    TechEndorse_3 StackOverflowAdsDistracting
# 0            NaN                         NaN
# 1            NaN                         NaN
# 2            NaN                         NaN
# 3            NaN                         NaN
# 4            NaN                         NaN

# %%
combined_df.head()
# Out:
#   nan (>$150,000)  ExpectedSalary AIToolInterested in Using TrueFalse_1  \
# 0             NaN             NaN                       NaN         NaN
# 1             NaN             NaN                       NaN         NaN
# 2             NaN             NaN                       NaN         NaN
# 3             NaN             NaN                       NaN         NaN
# 4       >$150,000             NaN                       NaN         NaN
#
#   SOTagsHaveWorkedWith ToolsTechWantToWorkWith OfficeStackSyncAdmired  \
# 0                  NaN                     NaN                    NaN
# 1                  NaN                     NaN                    NaN
# 2                  NaN                     NaN                    NaN
# 3                  NaN                     NaN                    NaN
# 4                  NaN                     NaN                    NaN
#
#   NEWCollabToolsDesireNextYear Knowledge_7  \
# 0                          NaN         NaN
# 1                          NaN         NaN
# 2                          NaN         NaN
# 3                          NaN         NaN
# 4                          NaN         NaN
#
#   AINextNeither different nor similar nan (Other tablet)  \
# 0                                 NaN                NaN
# 1                                 NaN                NaN
# 2                                 NaN                NaN
# 3                                 NaN                NaN
# 4                                 NaN                NaN
#
#   nan (Training & Education: Masters in CS)  \
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
#
#   nan (Most important aspect of new job opportunity: Office location)  \
# 0                                                                 NaN
# 1                                                                 NaN
# 2                                                                 NaN
# 3                                                                 NaN
# 4                                                                 NaN
#
#   SexualOrientation  AdsPriorities5 WebframeChoice ImpSyn  \
# 0               NaN             NaN            NaN    NaN
# 1               NaN             NaN            NaN    NaN
# 2               NaN             NaN            NaN    NaN
# 3               NaN             NaN            NaN    NaN
# 4               NaN             NaN            NaN    NaN
#
#   EmbeddedHaveWorkedWith DatabaseChoice agree_legacy OpSys  \
# 0                    NaN            NaN          NaN   NaN
# 1                    NaN            NaN          NaN   NaN
# 2                    NaN            NaN          NaN   NaN
# 3                    NaN            NaN          NaN   NaN
# 4                    NaN            NaN          NaN   NaN
#
#   OfficeStackSyncWantToWorkWith nan (Training & Education: Mentorship)  \
# 0                           NaN                                    NaN
# 1                           NaN                                    NaN
# 2                           NaN                                    NaN
# 3                           NaN                                    NaN
# 4                           NaN                                    NaN
#
#   nan (Excitement About the Company's Products) nan (Go)  \
# 0                                           NaN      NaN
# 1                                           NaN      NaN
# 2                                           NaN      NaN
# 3                                           NaN      NaN
# 4                                           NaN      NaN
#
#   nan (Current Lang & Tech: R) Do you work remotely?  \
# 0                          NaN                   NaN
# 1                          NaN                   NaN
# 2                          NaN                   NaN
# 3                          NaN                   NaN
# 4                          NaN                   NaN
#
#   nan (Why use Stack Overflow: Can't do job without it) BuyNewTool  \
# 0                                                   NaN        NaN
# 1                                                   NaN        NaN
# 2                                                   NaN        NaN
# 3                                                   NaN        NaN
# 4                                                   NaN        NaN
#
#   StackOverflowJobsRecommend LearnCodeAI StackOverflowMetaChat CheckInCode  \
# 0                        NaN         NaN                   NaN         NaN
# 1                        NaN         NaN                   NaN         NaN
# 2                        NaN         NaN                   NaN         NaN
# 3                        NaN         NaN                   NaN         NaN
# 4                        NaN         NaN                   NaN         NaN
#
#    AdsPriorities1 InfluenceWorkstation AssessJobOffice NEWJobHunt Gender  \
# 0             NaN                  NaN             NaN        NaN    NaN
# 1             NaN                  NaN             NaN        NaN    NaN
# 2             NaN                  NaN             NaN        NaN    NaN
# 3             NaN                  NaN             NaN        NaN    NaN
# 4             NaN                  NaN             NaN        NaN    NaN
#
#    JobEmailPriorities4 nan (Remote Status) WebframeWantEntry  \
# 0                  NaN                 NaN               NaN
# 1                  NaN                 NaN               NaN
# 2                  NaN                 NaN               NaN
# 3                  NaN                 NaN               NaN
# 4                  NaN                 NaN               NaN
#
#   nan (Future Lang & Tech: PHP) Which languages are you proficient in? (Java)  \
# 0                           NaN                                           NaN
# 1                           NaN                                          Java
# 2                           NaN                                          Java
# 3                           NaN                                          Java
# 4                           NaN                                          Java
#
#   AnnoyingUI StackOverflowJobListing AIDangerous commit_frequency  \
# 0        NaN                     NaN         NaN              NaN
# 1        NaN                     NaN         NaN              NaN
# 2        NaN                     NaN         NaN              NaN
# 3        NaN                     NaN         NaN              NaN
# 4        NaN                     NaN         NaN              NaN
#
#   agree_loveboss job_satisfaction StackOverflowBetter nan (WinRT)  \
# 0            NaN              NaN                 NaN         NaN
# 1            NaN              NaN                 NaN         NaN
# 2            NaN              NaN                 NaN         NaN
# 3            NaN              NaN                 NaN         NaN
# 4            NaN              NaN                 NaN         NaN
#
#   Do you have a Stack Overflow Careers 2.0 Profile? WantWorkPlatform  \
# 0                                               NaN              NaN
# 1                                               NaN              NaN
# 2                                               NaN              NaN
# 3                                               NaN              NaN
# 4                                               NaN              NaN
#
#   EquipmentSatisfiedRW nan (Current Lang & Tech: Python) EmploymentStatus  \
# 0                  NaN                               NaN              NaN
# 1                  NaN                               NaN              NaN
# 2                  NaN                               NaN              NaN
# 3                  NaN                               NaN              NaN
# 4                  NaN                               NaN              NaN
#
#   WantWorkLanguage  AssessBenefits7 WelcomeChange DifficultCommunication  \
# 0              NaN              NaN           NaN                    NaN
# 1              NaN              NaN           NaN                    NaN
# 2              NaN              NaN           NaN                    NaN
# 3              NaN              NaN           NaN                    NaN
# 4              NaN              NaN           NaN                    NaN
#
#   TechList BuildvsBuy  TechOppose_5 rep_range nan (Redis) AINextNo change  \
# 0      NaN        NaN           NaN       NaN         NaN             NaN
# 1      NaN        NaN           NaN       NaN         NaN             NaN
# 2      NaN        NaN           NaN       NaN         NaN             NaN
# 3      NaN        NaN           NaN       NaN         NaN             NaN
# 4      NaN        NaN           NaN       NaN         NaN             NaN
#
#   ExCoderSkills nan (Why answer: Help future programmers)  \
# 0           NaN                                       NaN
# 1           NaN                                       NaN
# 2           NaN                                       NaN
# 3           NaN                                       NaN
# 4           NaN                                       NaN
#
#   Which desktop operating system do you use the most?  AssessBenefits3  \
# 0                                                 NaN              NaN
# 1                                                 NaN              NaN
# 2                                                 NaN              NaN
# 3                                                 NaN              NaN
# 4                                                 NaN              NaN
#
#   nan (Current Lang & Tech: Java) LearnCodeOnline Frequency_2  \
# 0                             NaN             NaN         NaN
# 1                             NaN             NaN         NaN
# 2                             NaN             NaN         NaN
# 3                             NaN             NaN         NaN
# 4                             NaN             NaN         NaN
#
#   ImportantBenefits open_to_new_job salary_range  \
# 0               NaN             NaN          NaN
# 1               NaN             NaN          NaN
# 2               NaN             NaN          NaN
# 3               NaN             NaN          NaN
# 4               NaN             NaN          NaN
#
#   nan (Why use Stack Overflow: Maintain online presence) InTheZone  \
# 0                                                    NaN       NaN
# 1                                                    NaN       NaN
# 2                                                    NaN       NaN
# 3                                                    NaN       NaN
# 4                                                    NaN       NaN
#
#   why_learn_new_tech CareerSatisfaction Employment NewRole  \
# 0                NaN                NaN        NaN     NaN
# 1                NaN                NaN        NaN     NaN
# 2                NaN                NaN        NaN     NaN
# 3                NaN                NaN        NaN     NaN
# 4                NaN                NaN        NaN     NaN
#
#   InfluenceRecruitment remote nan (Looking for a job)  AssessJob9  \
# 0                  NaN    NaN                     NaN         NaN
# 1                  NaN    NaN                     NaN         NaN
# 2                  NaN    NaN                     NaN         NaN
# 3                  NaN    NaN                     NaN         NaN
# 4                  NaN    NaN                     NaN         NaN
#
#   What Country do you live in?  \
# 0                          NaN
# 1                          NaN
# 2                          NaN
# 3                          NaN
# 4                          NaN
#
#   nan (Most important aspect of new job opportunity: Company reputation)  \
# 0                                                                    NaN
# 1                                                                    NaN
# 2                                                                    NaN
# 3                                                                    NaN
# 4                                                                    NaN
#
#   nan (Why try Stack Overflow Careers: Jobs are on Stack Overflow)  \
# 0                                                              NaN
# 1                                                              NaN
# 2                                                              NaN
# 3                                                              NaN
# 4                                                              NaN
#
#   nan (Employment Status) WebframeAdmired  StackOverflowSatisfaction  WorkExp  \
# 0                     NaN             NaN                        NaN      NaN
# 1                     NaN             NaN                        NaN      NaN
# 2                     NaN             NaN                        NaN      NaN
# 3                     NaN             NaN                        NaN      NaN
# 4                     NaN             NaN                        NaN      NaN
#
#   nan (TypeScript) nan (Future Lang & Tech: C#)  \
# 0              NaN                          NaN
# 1              NaN                          NaN
# 2              NaN                          NaN
# 3              NaN                          NaN
# 4              NaN                          NaN
#
#   nan (Link to a Stack Overflow Careers Company Page or other source of more information about the company (videos, articles, etc))  \
# 0                                                                                                                               NaN
# 1                                                                                                                               NaN
# 2                                                                                                                               NaN
# 3                                                                                                                               NaN
# 4                                                                                                                               NaN
#
#   nan (Who do you want to communicate with about a new job opportunity: Manager)  \
# 0                                                                            NaN
# 1                                                                            NaN
# 2                                                                            NaN
# 3                                                                            NaN
# 4                                                                            NaN
#
#   StackOverflowJobs LastInt NEWDevOpsImpt Frequency_3 SOTagsHaveEntry  \
# 0               NaN     NaN           NaN         NaN             NaN
# 1               NaN     NaN           NaN         NaN             NaN
# 2               NaN     NaN           NaN         NaN             NaN
# 3               NaN     NaN           NaN         NaN             NaN
# 4               NaN     NaN           NaN         NaN             NaN
#
#   AIChallenges AIToolCurrently mostly AI AssessJobProjects AIModelsAdmired  \
# 0          NaN                       NaN               NaN             NaN
# 1          NaN                       NaN               NaN             NaN
# 2          NaN                       NaN               NaN             NaN
# 3          NaN                       NaN               NaN             NaN
# 4          NaN                       NaN               NaN             NaN
#
#   LanguageAdmired JobSatPoints_15_TEXT nan (Current Lang & Tech: Haskell)  \
# 0             NaN                  NaN                                NaN
# 1             NaN                  NaN                                NaN
# 2             NaN                  NaN                                NaN
# 3             NaN                  NaN                                NaN
# 4             NaN                  NaN                                NaN
#
#   PlatformHaveEntry nan (Source control used: CVS) Student  JobSatPoints_14  \
# 0               NaN                            NaN     NaN              NaN
# 1               NaN                            NaN     NaN              NaN
# 2               NaN                            NaN     NaN              NaN
# 3               NaN                            NaN     NaN              NaN
# 4               NaN                            NaN     NaN              NaN
#
#   nan (Why use Stack Overflow: Communicate with others)  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
#
#   nan (Current Lang & Tech: CoffeeScript) nan (Future Lang & Tech: Go)  \
# 0                                     NaN                          NaN
# 1                                     NaN                          NaN
# 2                                     NaN                          NaN
# 3                                     NaN                          NaN
# 4                                     NaN                          NaN
#
#   AIAgentKnowWrite nan (C)  \
# 0              NaN     NaN
# 1              NaN       C
# 2              NaN     NaN
# 3              NaN     NaN
# 4              NaN       C
#
#   How likely is it that a recommendation you make will be acted upon?  \
# 0                                              Not in a million years
# 1                                           It's been known to happen
# 2                                    Unless it's stoopid it gets done
# 3                                           It's been known to happen
# 4                                                    I run this place
#
#   EthicsResponsible nan (Netbook) nan ($41,000 - $75,000)  \
# 0               NaN           NaN                     NaN
# 1               NaN           NaN                     NaN
# 2               NaN           NaN                     NaN
# 3               NaN           NaN                     NaN
# 4               NaN           NaN       $41,000 - $75,000
#
#   If your company has a native mobile app, what platforms do you support? (iPhone)  \
# 0                                                                              NaN
# 1                                                                              NaN
# 2                                                                              NaN
# 3                                                                              NaN
# 4                                                                              NaN
#
#   AIHuman How would you best describe the industry you currently work in?  \
# 0     NaN                                                             NaN
# 1     NaN                                                             NaN
# 2     NaN                                                             NaN
# 3     NaN                                                             NaN
# 4     NaN                                                             NaN
#
#   nan (Office in a Desirable City/Area) InfluenceCommunication nan (Android)  \
# 0                                   NaN                    NaN           NaN
# 1                                   NaN                    NaN           NaN
# 2                                   NaN                    NaN           NaN
# 3                                   NaN                    NaN           NaN
# 4                                   NaN                    NaN       Android
#
#   important_sameend StackOverflowAnswer  \
# 0               NaN                 NaN
# 1               NaN                 NaN
# 2               NaN                 NaN
# 3               NaN                 NaN
# 4               NaN                 NaN
#
#   nan (Who do you want to communicate with about a new job opportunity: Developer)  \
# 0                                                                              NaN
# 1                                                                              NaN
# 2                                                                              NaN
# 3                                                                              NaN
# 4                                                                              NaN
#
#   LearnCodeChoose important_promotion employment_status  \
# 0             NaN                 NaN               NaN
# 1             NaN                 NaN               NaN
# 2             NaN                 NaN               NaN
# 3             NaN                 NaN               NaN
# 4             NaN                 NaN               NaN
#
#   Select all that apply (Current Lang & Tech: Android)  AssessJob4  \
# 0                                                  NaN         NaN
# 1                                                  NaN         NaN
# 2                                                  NaN         NaN
# 3                                                  NaN         NaN
# 4                                                  NaN         NaN
#
#   AIAgentOrchWrite agree_alcohol  \
# 0              NaN           NaN
# 1              NaN           NaN
# 2              NaN           NaN
# 3              NaN           NaN
# 4              NaN           NaN
#
#   What advertisers do you remember seeing on Stack Overflow? (Open-Ended Response)  \
# 0                                                                              NaN
# 1                                                                              NaN
# 2                                                                              NaN
# 3                                                                              NaN
# 4                                                                              NaN
#
#   You answered you don't have a Careers profile, can you elaborate why?  \
# 0                                                                   NaN
# 1                                                                   NaN
# 2                                                                   NaN
# 3                                                                   NaN
# 4                                                                   NaN
#
#   nan (Hadoop) dev_environment dogs_vs_cats OfficeStackWantEntry  \
# 0          NaN             NaN          NaN                  NaN
# 1          NaN             NaN          NaN                  NaN
# 2          NaN             NaN          NaN                  NaN
# 3          NaN             NaN          NaN                  NaN
# 4          NaN             NaN          NaN                  NaN
#
#   nan (Training & Education: Some college, but no CS degree)  \
# 0                                                        NaN
# 1                                                        NaN
# 2                                                        NaN
# 3                                                        NaN
# 4                                                        NaN
#
#   Select all that apply (Why try Stack Overflow Careers: No spam)  \
# 0                                                             NaN
# 1                                                             NaN
# 2                                                             NaN
# 3                                                             NaN
# 4                                                             NaN
#
#    SO_Actions_7 StackOverflowHelpful ProblemSolving  \
# 0           NaN                  NaN            NaN
# 1           NaN                  NaN            NaN
# 2           NaN                  NaN            NaN
# 3           NaN                  NaN            NaN
# 4           NaN                  NaN            NaN
#
#   nan (Current Lang & Tech: Rust) nan (Source control used: TFS)  \
# 0                             NaN                            NaN
# 1                             NaN                            NaN
# 2                             NaN                            NaN
# 3                             NaN                            NaN
# 4                             NaN                            NaN
#
#   DevEnvsAdmired AISearchDevAdmired AIAgentObsWrite AIAgentImpactNeutral  \
# 0            NaN                NaN             NaN                  NaN
# 1            NaN                NaN             NaN                  NaN
# 2            NaN                NaN             NaN                  NaN
# 3            NaN                NaN             NaN                  NaN
# 4            NaN                NaN             NaN                  NaN
#
#   In an average week, how do you spend your time? (Developing new features)  \
# 0                                                                       NaN
# 1                                                                       NaN
# 2                                                                       NaN
# 3                                                                       NaN
# 4                                                                       NaN
#
#   nan (Ask questions to solve problems)  programming_ability LearnedHiring  \
# 0                                   NaN                  NaN           NaN
# 1                                   NaN                  NaN           NaN
# 2                                   NaN                  NaN           NaN
# 3                                   NaN                  NaN           NaN
# 4                                   NaN                  NaN           NaN
#
#   Q120 SOJobs nan (C++) SOFriction nan (Perl) FriendsDevelopers  \
# 0  NaN    NaN       NaN        NaN        NaN               NaN
# 1  NaN    NaN       NaN        NaN        NaN               NaN
# 2  NaN    NaN       NaN        NaN        NaN               NaN
# 3  NaN    NaN       NaN        NaN        NaN               NaN
# 4  NaN    NaN       C++        NaN       Perl               NaN
#
#   nan (Meetings) nan (AngularJS) nan (Finance) University  \
# 0            NaN             NaN           NaN        NaN
# 1            NaN             NaN           NaN        NaN
# 2            NaN             NaN           NaN        NaN
# 3            NaN             NaN           NaN        NaN
# 4            NaN             NaN           NaN        NaN
#
#   StackOverflowAdsRelevant BuildingThings nan (Future Lang & Tech: Haskell)  \
# 0                      NaN            NaN                               NaN
# 1                      NaN            NaN                               NaN
# 2                      NaN            NaN                               NaN
# 3                      NaN            NaN                               NaN
# 4                      NaN            NaN                               NaN
#
#   StackOverflowModeration nan (Industry) SOVisitFreq Ethnicity Onboarding  \
# 0                     NaN            NaN         NaN       NaN        NaN
# 1                     NaN            NaN         NaN       NaN        NaN
# 2                     NaN            NaN         NaN       NaN        NaN
# 3                     NaN            NaN         NaN       NaN        NaN
# 4                     NaN            NaN         NaN       NaN        NaN
#
#    AdsPriorities3 nan (Future Lang & Tech: Matlab) WakeTime  \
# 0             NaN                              NaN      NaN
# 1             NaN                              NaN      NaN
# 2             NaN                              NaN      NaN
# 3             NaN                              NaN      NaN
# 4             NaN                              NaN      NaN
#
#   LearnCodeCoursesCert nan (Learning new skills)  \
# 0                  NaN                       NaN
# 1                  NaN                       NaN
# 2                  NaN                       NaN
# 3                  NaN                       NaN
# 4                  NaN                       NaN
#
#   Select up to 3 (How can companies improve interview process: More live code)  \
# 0                                                                          NaN
# 1                                                                          NaN
# 2                                                                          NaN
# 3                                                                          NaN
# 4                                                                          NaN
#
#   SurveyLength LanguagesWantEntry AssessJobCommute  \
# 0          NaN                NaN              NaN
# 1          NaN                NaN              NaN
# 2          NaN                NaN              NaN
# 3          NaN                NaN              NaN
# 4          NaN                NaN              NaN
#
#   nan (Appealing message traits: Salary information) StackOverflowHasAccount  \
# 0                                                NaN                     NaN
# 1                                                NaN                     NaN
# 2                                                NaN                     NaN
# 3                                                NaN                     NaN
# 4                                                NaN                     NaN
#
#    JobContactPriorities1 nan (Future Lang & Tech: SQL)  \
# 0                    NaN                           NaN
# 1                    NaN                           NaN
# 2                    NaN                           NaN
# 3                    NaN                           NaN
# 4                    NaN                           NaN
#
#   nan (Other Smart Phone) nan (Current Lang & Tech: iOS)  JobEmailPriorities1  \
# 0                     NaN                            NaN                  NaN
# 1                     NaN                            NaN                  NaN
# 2                     NaN                            NaN                  NaN
# 3                     NaN                            NaN                  NaN
# 4                     NaN                            NaN                  NaN
#
#   nan (Most annoying about job search: The Interview) CollaborateRemote  \
# 0                                                 NaN               NaN
# 1                                                 NaN               NaN
# 2                                                 NaN               NaN
# 3                                                 NaN               NaN
# 4                                                 NaN               NaN
#
#   nan (Technical Support) AssessJobTech HaveWorkedLanguage WorkRemote  \
# 0                     NaN           NaN                NaN        NaN
# 1                     NaN           NaN                NaN        NaN
# 2                     NaN           NaN                NaN        NaN
# 3                     NaN           NaN                NaN        NaN
# 4                     NaN           NaN                NaN        NaN
#
#   important_wfh nan (Opportunity to Use/Learn New Technologies)  \
# 0           NaN                                             NaN
# 1           NaN                                             NaN
# 2           NaN                                             NaN
# 3           NaN                                             NaN
# 4           NaN                                             NaN
#
#   nan (Future Lang & Tech: Redis) AIToolCurrently partially AI  \
# 0                             NaN                          NaN
# 1                             NaN                          NaN
# 2                             NaN                          NaN
# 3                             NaN                          NaN
# 4                             NaN                          NaN
#
#   StackOverflowDevices nan (C#)  \
# 0                  NaN      NaN
# 1                  NaN      NaN
# 2                  NaN      NaN
# 3                  NaN      NaN
# 4                  NaN      NaN
#
#   If you make a software product, how does your company make money? (You can choose more than one) (Advertising)  \
# 0                                                                                                            NaN
# 1                                                                                                            NaN
# 2                                                                                                            NaN
# 3                                                                                                            NaN
# 4                                                                                                            NaN
#
#   PurchaseWhat What types of purchases are you involved in? (Hardware)  \
# 0          NaN                                                     NaN
# 1          NaN                                                     NaN
# 2          NaN                                                     NaN
# 3          NaN                                                     NaN
# 4          NaN                                                Hardware
#
#   How would you best describe the industry you work in? UnderstandComputers  \
# 0                                            Consulting                 NaN
# 1                                     Software Products                 NaN
# 2                                     Software Products                 NaN
# 3                               Foundation / Non-Profit                 NaN
# 4                                     Software Products                 NaN
#
#   TrueFalse_3 DatabaseHaveWorkedWith InfluenceTechStack AIInteresting  \
# 0         NaN                    NaN                NaN           NaN
# 1         NaN                    NaN                NaN           NaN
# 2         NaN                    NaN                NaN           NaN
# 3         NaN                    NaN                NaN           NaN
# 4         NaN                    NaN                NaN           NaN
#
#   nan (Source control used: Legacy / Custom) tech_want  AssessJob2  \
# 0                                        NaN       NaN         NaN
# 1                                        NaN       NaN         NaN
# 2                                        NaN       NaN         NaN
# 3                                        NaN       NaN         NaN
# 4                                        NaN       NaN         NaN
#
#   DevEnvWantEntry MajorUndergrad What type of project are you developing?  \
# 0             NaN            NaN                                   Mobile
# 1             NaN            NaN                               Enterprise
# 2             NaN            NaN                                     SaaS
# 3             NaN            NaN                                    Other
# 4             NaN            NaN                               Enterprise
#
#   NonDeveloperType nan (Current Lang & Tech: C++11) Salary NEWOtherComms  \
# 0              NaN                              NaN    NaN           NaN
# 1              NaN                              NaN    NaN           NaN
# 2              NaN                              NaN    NaN           NaN
# 3              NaN                              NaN    NaN           NaN
# 4              NaN                              NaN    NaN           NaN
#
#   BetterLife  SO_Actions_10 MiscTechAdmired InterestedAnswers  AdsPriorities4  \
# 0        NaN            NaN             NaN               NaN             NaN
# 1        NaN            NaN             NaN               NaN             NaN
# 2        NaN            NaN             NaN               NaN             NaN
# 3        NaN            NaN             NaN               NaN             NaN
# 4        NaN            NaN             NaN               NaN             NaN
#
#   ClickyKeys ProgramHobby  \
# 0        NaN          NaN
# 1        NaN          NaN
# 2        NaN          NaN
# 3        NaN          NaN
# 4        NaN          NaN
#
#   nan (Most important aspect of new job opportunity: Equity)  JobSatPoints_7  \
# 0                                                        NaN             NaN
# 1                                                        NaN             NaN
# 2                                                        NaN             NaN
# 3                                                        NaN             NaN
# 4                                                        NaN             NaN
#
#    AdsPriorities6 NEWSOSites AIExplain nan (Software)  \
# 0             NaN        NaN       NaN       Software
# 1             NaN        NaN       NaN            NaN
# 2             NaN        NaN       NaN            NaN
# 3             NaN        NaN       NaN            NaN
# 4             NaN        NaN       NaN       Software
#
#   nan (Current Lang & Tech: MongoDB) nan (HTML5) OtherPeoplesCode AdBlocker  \
# 0                                NaN         NaN              NaN       NaN
# 1                                NaN         NaN              NaN       NaN
# 2                                NaN         NaN              NaN       NaN
# 3                                NaN         NaN              NaN       NaN
# 4                                NaN         NaN              NaN       NaN
#
#    JobSatPoints_10 Knowledge_5 nan (Cordova) EthicsReport nan (Android phone)  \
# 0              NaN         NaN           NaN          NaN                 NaN
# 1              NaN         NaN           NaN          NaN                 NaN
# 2              NaN         NaN           NaN          NaN                 NaN
# 3              NaN         NaN           NaN          NaN                 NaN
# 4              NaN         NaN           NaN          NaN                 NaN
#
#   nan (Source control used: SVN) BlockchainIs  \
# 0                            NaN          NaN
# 1                            NaN          NaN
# 2                            NaN          NaN
# 3                            NaN          NaN
# 4                            NaN          NaN
#
#   nan (How often are Stack Overflow's answers helpful)  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
#
#   Where do you work remotely most of the time? ImportantHiringCompanies  \
# 0                                          NaN                      NaN
# 1                                          NaN                      NaN
# 2                                          NaN                      NaN
# 3                                          NaN                      NaN
# 4                                          NaN                      NaN
#
#   nan ($100,001 - $150,000) nan (Using Stack Exchange) BoringDetails  \
# 0                       NaN                        NaN           NaN
# 1                       NaN                        NaN           NaN
# 2                       NaN                        NaN           NaN
# 3                       NaN                        NaN           NaN
# 4       $100,001 - $150,000                        NaN           NaN
#
#   AdBlockerDisable AdBlockerReasons JobSatisfaction  \
# 0              NaN              NaN             NaN
# 1              NaN              NaN             NaN
# 2              NaN              NaN             NaN
# 3              NaN              NaN             NaN
# 4              NaN              NaN             NaN
#
#   What is your involvement in purchasing products or services for the company you work for? (You can choose more than one) (I can recommend or request products)  \
# 0                                                                                                                                                            NaN
# 1                                                                                                                                                            NaN
# 2                                                                                                                                                            NaN
# 3                                                                                                                                                            NaN
# 4                                                                                                                                                            NaN
#
#   nan (How can companies improve interview process: Remote interviews)  \
# 0                                                                  NaN
# 1                                                                  NaN
# 2                                                                  NaN
# 3                                                                  NaN
# 4                                                                  NaN
#
#   nan (Recruitment Tools & Services)  AssessJob10 JobSecurity AIResponsible  \
# 0                                NaN          NaN         NaN           NaN
# 1                                NaN          NaN         NaN           NaN
# 2                                NaN          NaN         NaN           NaN
# 3                                NaN          NaN         NaN           NaN
# 4                                NaN          NaN         NaN           NaN
#
#   StackOverflowCommunity nan (Training & Education: PhD in CS)  \
# 0                    NaN                                   NaN
# 1                    NaN                                   NaN
# 2                    NaN                                   NaN
# 3                    NaN                                   NaN
# 4                    NaN                                   NaN
#
#   nan (Why use Stack Overflow: Demonstrate expertise)  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
#
#   CommPlatformWantToWorkWith  \
# 0                        NaN
# 1                        NaN
# 2                        NaN
# 3                        NaN
# 4                        NaN
#
#   nan (Most important aspect of new job opportunity: Building something that matters)  \
# 0                                                                                 NaN
# 1                                                                                 NaN
# 2                                                                                 NaN
# 3                                                                                 NaN
# 4                                                                                 NaN
#
#   TabsSpaces nan (Current Lang & Tech: JavaScript) nan (Kindle) OffOn  \
# 0        NaN                                   NaN          NaN   NaN
# 1        NaN                                   NaN          NaN   NaN
# 2        NaN                                   NaN          NaN   NaN
# 3        NaN                                   NaN       Kindle   NaN
# 4        NaN                                   NaN       Kindle   NaN
#
#   nan (Most annoying about job search: Finding interesting job) YearsCodedJob  \
# 0                                                           NaN           NaN
# 1                                                           NaN           NaN
# 2                                                           NaN           NaN
# 3                                                           NaN           NaN
# 4                                                           NaN           NaN
#
#   SeriousWork nan (iPad)  SO_Actions_6  \
# 0         NaN        NaN           NaN
# 1         NaN        NaN           NaN
# 2         NaN        NaN           NaN
# 3         NaN        NaN           NaN
# 4         NaN        NaN           NaN
#
#   Which best describes the size of your company? nan (Node.js)  \
# 0                                Start Up (1-25)           NaN
# 1                 Mature Small Business (25-100)           NaN
# 2                            Mid Sized (100-999)           NaN
# 3                                        Student           NaN
# 4                                Start Up (1-25)           NaN
#
#   nan (Most urgent info about job opportunity: Colleagues)  \
# 0                                                      NaN
# 1                                                      NaN
# 2                                                      NaN
# 3                                                      NaN
# 4                                                      NaN
#
#   StackOverflowMakeMoney MilitaryUS nan (Occupation) visit_frequency  \
# 0                    NaN        NaN              NaN             NaN
# 1                    NaN        NaN              NaN             NaN
# 2                    NaN        NaN              NaN             NaN
# 3                    NaN        NaN              NaN             NaN
# 4                    NaN        NaN              NaN             NaN
#
#   Please rate your job/career satisfaction ExCoder10Years ProjectManagement  \
# 0                                      FML            NaN               NaN
# 1                        So happy it hurts            NaN               NaN
# 2                                      NaN            NaN               NaN
# 3                    I enjoy going to work            NaN               NaN
# 4                        It pays the bills            NaN               NaN
#
#    JobSatPoints_11 AIAgentImpactStrongly agree LastHireDate  \
# 0              NaN                         NaN          NaN
# 1              NaN                         NaN          NaN
# 2              NaN                         NaN          NaN
# 3              NaN                         NaN          NaN
# 4              NaN                         NaN          NaN
#
#   nan (The ads are Informative)  \
# 0                           NaN
# 1                           NaN
# 2                           NaN
# 3                           NaN
# 4                           NaN
#
#   Have you visited / Are you aware of Stack Overflow Careers 2.0?  \
# 0                                                             NaN
# 1                                                             NaN
# 2                                                             NaN
# 3                                                             NaN
# 4                                                             NaN
#
#   AIAgentChallengesStrongly agree nan (Current Lang & Tech: Redis)  \
# 0                             NaN                              NaN
# 1                             NaN                              NaN
# 2                             NaN                              NaN
# 3                             NaN                              NaN
# 4                             NaN                              NaN
#
#   What is your budget for outside expenditures (hardware, software, consulting, etc) for 2014?  \
# ...
# 2              NaN                     NaN
# 3              NaN                     NaN
# 4              NaN       $25,001 - $40,000
#
#   nan (Current Lang & Tech: Salesforce) AIAgentImpactStrongly disagree  \
# 0                                   NaN                            NaN
# 1                                   NaN                            NaN
# 2                                   NaN                            NaN
# 3                                   NaN                            NaN
# 4                                   NaN                            NaN
#
#   HypotheticalTools1 nan (jQuery) nan (F#) nan (Future Lang & Tech: Swift)  \
# 0                NaN          NaN      NaN                             NaN
# 1                NaN          NaN      NaN                             NaN
# 2                NaN          NaN      NaN                             NaN
# 3                NaN          NaN      NaN                             NaN
# 4                NaN          NaN      NaN                             NaN
#
#   nan (Android Tablet)  \
# 0                  NaN
# 1                  NaN
# 2                  NaN
# 3                  NaN
# 4                  NaN
#
#   nan (How can companies improve interview process: Introduce me to boss)  \
# 0                                                                     NaN
# 1                                                                     NaN
# 2                                                                     NaN
# 3                                                                     NaN
# 4                                                                     NaN
#
#   so_region LanguageChoice nan (Future Lang & Tech: LAMP)  \
# 0       NaN            NaN                            NaN
# 1       NaN            NaN                            NaN
# 2       NaN            NaN                            NaN
# 3       NaN            NaN                            NaN
# 4       NaN            NaN                            NaN
#
#   nan (How can companies improve interview process: Show me workplace)  \
# 0                                                                  NaN
# 1                                                                  NaN
# 2                                                                  NaN
# 3                                                                  NaN
# 4                                                                  NaN
#
#   ProfessionalCloud  TechOppose_3  \
# 0               NaN           NaN
# 1               NaN           NaN
# 2               NaN           NaN
# 3               NaN           NaN
# 4               NaN           NaN
#
#   nan (Most important aspect of new job opportunity: Quality of colleagues)  \
# 0                                                                       NaN
# 1                                                                       NaN
# 2                                                                       NaN
# 3                                                                       NaN
# 4                                                                       NaN
#
#   nan (Future Lang & Tech: R) nan (Current Lang & Tech: Clojure)  \
# 0                         NaN                                NaN
# 1                         NaN                                NaN
# 2                         NaN                                NaN
# 3                         NaN                                NaN
# 4                         NaN                                NaN
#
#   developer_challenges nan (No Involvement) HaveWorkedDatabase Knowledge_6  \
# 0                  NaN                  NaN                NaN         NaN
# 1                  NaN       No Involvement                NaN         NaN
# 2                  NaN                  NaN                NaN         NaN
# 3                  NaN       No Involvement                NaN         NaN
# 4                  NaN                  NaN                NaN         NaN
#
#    JobSatPoints_5 nan (Future Lang & Tech: Dart) nan (Looking for a new job)  \
# 0             NaN                            NaN                         NaN
# 1             NaN                            NaN                         NaN
# 2             NaN                            NaN                         NaN
# 3             NaN                            NaN                         NaN
# 4             NaN                            NaN                         NaN
#
#   YearsCodingProf nan (Objective-C) nan (Consulting) SocialMedia  \
# 0             NaN               NaN              NaN         NaN
# 1             NaN               NaN              NaN         NaN
# 2             NaN               NaN              NaN         NaN
# 3             NaN               NaN              NaN         NaN
# 4             NaN               NaN              NaN         NaN
#
#    SO_Actions_15 nan (Android Phone)  \
# 0            NaN                 NaN
# 1            NaN                 NaN
# 2            NaN                 NaN
# 3            NaN                 NaN
# 4            NaN                 NaN
#
#   nan (Training & Education: Boot camp or night school) HomeRemote  \
# 0                                                   NaN        NaN
# 1                                                   NaN        NaN
# 2                                                   NaN        NaN
# 3                                                   NaN        NaN
# 4                                                   NaN        NaN
#
#   AdsAgreeDisagree1  JobSatPoints_6 industry nan (Wii U) How old are you?  \
# 0               NaN             NaN      NaN         NaN             < 20
# 1               NaN             NaN      NaN         NaN            25-29
# 2               NaN             NaN      NaN         NaN            25-29
# 3               NaN             NaN      NaN         NaN             < 20
# 4               NaN             NaN      NaN         NaN            35-39
#
#    JobSatPoints_1 nan (Source control used: write-in)  \
# 0             NaN                                 NaN
# 1             NaN                                 NaN
# 2             NaN                                 NaN
# 3             NaN                                 NaN
# 4             NaN                                 NaN
#
#   nan (Stock Options/Profit Sharing Program)  JobEmailPriorities5  \
# 0                                        NaN                  NaN
# 1                                        NaN                  NaN
# 2                                        NaN                  NaN
# 3                                        NaN                  NaN
# 4                                        NaN                  NaN
#
#   nan (Android tablet) NEWOnboardGood nan (Perception of contact form: Xing)  \
# 0                  NaN            NaN                                    NaN
# 1                  NaN            NaN                                    NaN
# 2                  NaN            NaN                                    NaN
# 3                  NaN            NaN                                    NaN
# 4                  NaN            NaN                                    NaN
#
#   NEWEdImpt AIBen  \
# 0       NaN   NaN
# 1       NaN   NaN
# 2       NaN   NaN
# 3       NaN   NaN
# 4       NaN   NaN
#
#   nan (Most urgent info about job opportunity: Product details)  \
# 0                                                           NaN
# 1                                                           NaN
# 2                                                           NaN
# 3                                                           NaN
# 4                                                           NaN
#
#   DiversityImportant nan (Current Lang & Tech: Spark)  \
# 0                NaN                              NaN
# 1                NaN                              NaN
# 2                NaN                              NaN
# 3                NaN                              NaN
# 4                NaN                              NaN
#
#   nan (Changed Jobs in last 12 Months)  \
# 0                                  NaN
# 1                                  NaN
# 2                                  NaN
# 3                                  NaN
# 4                                  NaN
#
#   Please rate the advertising you've seen on Stack Overflow (The ads are relevant)  \
# 0                                                                              NaN
# 1                                                                              NaN
# 2                                                                              NaN
# 3                                                                              NaN
# 4                                                                              NaN
#
#   In an average week, how do you spend your time at work? (Developing new features)  \
# 0                                                                               NaN
# 1                                                                               NaN
# 2                                                                               NaN
# 3                                                                               NaN
# 4                                                                               NaN
#
#   nan (How can companies improve interview process: Fewer brainteasers)  \
# 0                                                                   NaN
# 1                                                                   NaN
# 2                                                                   NaN
# 3                                                                   NaN
# 4                                                                   NaN
#
#   ExCoderActive RightWrongWay KinshipDevelopers WebDeveloperType  \
# 0           NaN           NaN               NaN              NaN
# 1           NaN           NaN               NaN              NaN
# 2           NaN           NaN               NaN              NaN
# 3           NaN           NaN               NaN              NaN
# 4           NaN           NaN               NaN              NaN
#
#   nan (Future Lang & Tech: CoffeeScript) NEWCollabToolsAdmired  \
# 0                                    NaN                   NaN
# 1                                    NaN                   NaN
# 2                                    NaN                   NaN
# 3                                    NaN                   NaN
# 4                                    NaN                   NaN
#
#   TechEndorseIntro TimeFullyProductive AssessJobDiversity  \
# 0              NaN                 NaN                NaN
# 1              NaN                 NaN                NaN
# 2              NaN                 NaN                NaN
# 3              NaN                 NaN                NaN
# 4              NaN                 NaN                NaN
#
#   MiscTechDesireNextYear LanguageHaveWorkedWith  JobSatPoints_16 UK_Country  \
# 0                    NaN                    NaN              NaN        NaN
# 1                    NaN                    NaN              NaN        NaN
# 2                    NaN                    NaN              NaN        NaN
# 3                    NaN                    NaN              NaN        NaN
# 4                    NaN                    NaN              NaN        NaN
#
#   nan (Current Lang & Tech: LAMP) agree_notice AIDevWantToWorkWith  \
# 0                             NaN          NaN                 NaN
# 1                             NaN          NaN                 NaN
# 2                             NaN          NaN                 NaN
# 3                             NaN          NaN                 NaN
# 4                             NaN          NaN                 NaN
#
#    JobSatPoints_15 important_buildexisting CodingActivities  \
# 0              NaN                     NaN              NaN
# 1              NaN                     NaN              NaN
# 2              NaN                     NaN              NaN
# 3              NaN                     NaN              NaN
# 4              NaN                     NaN              NaN
#
#    VCHostingPersonal use Do you have a Stack Overflow Careers Profile?  \
# 0                    NaN                                           NaN
# 1                    NaN                                           NaN
# 2                    NaN                                           NaN
# 3                    NaN                                           NaN
# 4                    NaN                                           NaN
#
#   nan (I've taken a trial/purchased a product from ads) Dependents  \
# 0                                                   NaN        NaN
# 1                                                   NaN        NaN
# 2                                                   NaN        NaN
# 3                                                   NaN        NaN
# 4                                                   NaN        NaN
#
#   nan (Most urgent info about job opportunity: Company name) team_size_range  \
# 0                                                        NaN             NaN
# 1                                                        NaN             NaN
# 2                                                        NaN             NaN
# 3                                                        NaN             NaN
# 4                                                        NaN             NaN
#
#   nan (Future Lang & Tech: C++) ChallengeMyself  \
# 0                           NaN             NaN
# 1                           NaN             NaN
# 2                           NaN             NaN
# 3                           NaN             NaN
# 4                           NaN             NaN
#
#   Select all that apply (Training & Education: No formal training)  \
# 0                                                              NaN
# 1                                                              NaN
# 2                                                              NaN
# 3                                                              NaN
# 4                                                              NaN
#
#   nan (Autonomy Over Budget/Expenditures) WebframeWorkedWith nan (Customers)  \
# 0                                     NaN                NaN             NaN
# 1                                     NaN                NaN             NaN
# 2                                     NaN                NaN             NaN
# 3                                     NaN                NaN             NaN
# 4                                     NaN                NaN             NaN
#
#   Knowledge_3  TechEndorse_13  JobContactPriorities2  \
# 0         NaN             NaN                    NaN
# 1         NaN             NaN                    NaN
# 2         NaN             NaN                    NaN
# 3         NaN             NaN                    NaN
# 4         NaN             NaN                    NaN
#
#   nan (Perception of contact form: Email) nan (Product Managers) hobby  \
# 0                                     NaN                    NaN   NaN
# 1                                     NaN                    NaN   NaN
# 2                                     NaN                    NaN   NaN
# 3                                     NaN                    NaN   NaN
# 4                                     NaN                    NaN   NaN
#
#    TechEndorse_3 StackOverflowAdsDistracting
# 0            NaN                         NaN
# 1            NaN                         NaN
# 2            NaN                         NaN
# 3            NaN                         NaN
# 4            NaN                         NaN

# %% [markdown]
# ### Sample the dataframe (default - 20%)

# %%
# Create a stratified sample of 20% of the data
if combined_df is not None:
    # Calculate 20% sample size for each year
    sample_size = 0.2
    
    # Perform stratified sampling
    stratified_sample = combined_df.groupby('SurveyYear', group_keys=False).apply(
        lambda x: x.sample(frac=sample_size, random_state=42)
    ).reset_index(drop=True)
    
    # Export to CSV
    output_file = 'stackoverflow_survey_stratified_sample.csv'
    stratified_sample.to_csv(output_file, index=False)
    
    print(f"Original dataset size: {len(combined_df):,} rows")
    print(f"Sampled dataset size: {len(stratified_sample):,} rows")
    print(f"\nSample size by year:")
    print(stratified_sample['SurveyYear'].value_counts().sort_index())
    print(f"\nData exported to: {output_file}")
# Out:
# Original dataset size: 772,599 rows
# Sampled dataset size: 154,521 rows
#
# Sample size by year:
# SurveyYear
# 2011      563
# 2012     1249
# 2013     1948
# 2014     1529
# 2015     5217
# 2016    11206
# 2017    10278
# 2018    19771
# 2019    17777
# 2020    12892
# 2021    16688
# 2022    14654
# 2023    17837
# 2024    13087
# 2025     9825
# Name: count, dtype: int64
#
# Data exported to: stackoverflow_survey_stratified_sample.csv

# %%
stratified_sample.to_csv('stackoverflow_survey_stratified_sample.csv')

# %% [markdown]
# ### Adjust df_use based on the dataframe you want to use (sample_df, stratified_sample, etc)

# %%
sample_df = pd.read_csv('stackoverflow_survey_stratified_sample.csv')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 sample_df = pd.read_csv('stackoverflow_survey_stratified_sample.csv')
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/io/parsers/readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)   1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/io/parsers/readers.py:626, in _read(filepath_or_buffer, kwds)
#     623     return parser
#     625 with parser:
# --> 626     return parser.read(nrows)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/io/parsers/readers.py:1968, in TextFileReader.read(self, nrows)
#    1965     else:
#    1966         new_col_dict = col_dict
# -> 1968     df = DataFrame(
#    1969         new_col_dict,
#    1970         columns=columns,
#    1971         index=index,
#    1972         copy=not using_copy_on_write(),
#    1973     )
#    1975     self._currow += new_rows
#    1976 return df
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/core/frame.py:778, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     772     mgr = self._init_mgr(
#     773         data, axes={"index": index, "columns": columns}, dtype=dtype, copy=copy
#     774     )
#     776 elif isinstance(data, dict):
#     777     # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 778     mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
#     779 elif isinstance(data, ma.MaskedArray):
#     780     from numpy.ma import mrecords
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/core/internals/construction.py:503, in dict_to_mgr(data, index, columns, dtype, typ, copy)
#     499     else:
#     500         # dtype check to exclude e.g. range objects, scalars
#     501         arrays = [x.copy() if hasattr(x, "dtype") else x for x in arrays]
# --> 503 return arrays_to_mgr(arrays, columns, index, dtype=dtype, typ=typ, consolidate=copy)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/core/internals/construction.py:152, in arrays_to_mgr(arrays, columns, index, dtype, verify_integrity, typ, consolidate)
#     149 axes = [columns, index]
#     151 if typ == "block":
# --> 152     return create_block_manager_from_column_arrays(
#     153         arrays, axes, consolidate=consolidate, refs=refs
#     154     )
#     155 elif typ == "array":
#     156     return ArrayManager(arrays, [index, columns])
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/core/internals/managers.py:2139, in create_block_manager_from_column_arrays(arrays, axes, consolidate, refs)
#    2121 def create_block_manager_from_column_arrays(
#    2122     arrays: list[ArrayLike],
#    2123     axes: list[Index],
#    (...)   2135     # These last three are sufficient to allow us to safely pass
#    2136     #  verify_integrity=False below.
#    2138     try:
# -> 2139         blocks = _form_blocks(arrays, consolidate, refs)
#    2140         mgr = BlockManager(blocks, axes, verify_integrity=False)
#    2141     except ValueError as e:
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/core/internals/managers.py:2212, in _form_blocks(arrays, consolidate, refs)
#    2209 if issubclass(dtype.type, (str, bytes)):
#    2210     dtype = np.dtype(object)
# -> 2212 values, placement = _stack_arrays(list(tup_block), dtype)
#    2213 if is_dtlike:
#    2214     values = ensure_wrapped_if_datetimelike(values)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/core/internals/managers.py:2254, in _stack_arrays(tuples, dtype)
#    2252 stacked = np.empty(shape, dtype=dtype)
#    2253 for i, arr in enumerate(arrays):
# -> 2254     stacked[i] = arr
#    2256 return stacked, placement
#
# KeyboardInterrupt:

# %%
df_use = stratified_sample.copy()

# %% [markdown]
# ### Adjust column names for Undefined/NaN

# %%
# Remove any columns with 'Unnamed' in their name from the combined dataframe
if df_use is not None:
    df_use = df_use.loc[:, ~df_use.columns.str.contains('^Unnamed')]

# %%
# Remove columns with 'nan' in their names from combined_df and individual year dataframes
if df_use is not None:
    # For combined dataframe
    nan_columns = df_use.columns[df_use.columns.str.contains('nan', case=False, na=False)]
    if len(nan_columns) > 0:
        print("Removing columns containing 'nan' from combined dataframe:")
        print(list(nan_columns))
        df_use = df_use.drop(columns=nan_columns)

print("\nDone cleaning column names.")
# Out:
# Removing columns containing 'nan' from combined dataframe:
# ['nan (>$150,000)', 'nan (Other tablet)', 'nan (Training & Education: Masters in CS)', 'nan (Most important aspect of new job opportunity: Office location)', 'nan (Training & Education: Mentorship)', "nan (Excitement About the Company's Products)", 'nan (Go)', 'nan (Current Lang & Tech: R)', "nan (Why use Stack Overflow: Can't do job without it)", 'nan (Remote Status)', 'nan (Future Lang & Tech: PHP)', 'nan (WinRT)', 'nan (Current Lang & Tech: Python)', 'nan (Redis)', 'nan (Why answer: Help future programmers)', 'nan (Current Lang & Tech: Java)', 'nan (Why use Stack Overflow: Maintain online presence)', 'nan (Looking for a job)', 'nan (Most important aspect of new job opportunity: Company reputation)', 'nan (Why try Stack Overflow Careers: Jobs are on Stack Overflow)', 'nan (Employment Status)', 'nan (TypeScript)', 'nan (Future Lang & Tech: C#)', 'nan (Link to a Stack Overflow Careers Company Page or other source of more information about the company (videos, articles, etc))', 'nan (Who do you want to communicate with about a new job opportunity: Manager)', 'nan (Current Lang & Tech: Haskell)', 'nan (Source control used: CVS)', 'nan (Why use Stack Overflow: Communicate with others)', 'nan (Current Lang & Tech: CoffeeScript)', 'nan (Future Lang & Tech: Go)', 'nan (C)', 'nan (Netbook)', 'nan ($41,000 - $75,000)', 'nan (Office in a Desirable City/Area)', 'nan (Android)', 'nan (Who do you want to communicate with about a new job opportunity: Developer)', 'nan (Hadoop)', 'nan (Training & Education: Some college, but no CS degree)', 'nan (Current Lang & Tech: Rust)', 'nan (Source control used: TFS)', 'nan (Ask questions to solve problems)', 'nan (C++)', 'nan (Perl)', 'nan (Meetings)', 'nan (AngularJS)', 'nan (Finance)', 'nan (Future Lang & Tech: Haskell)', 'nan (Industry)', 'nan (Future Lang & Tech: Matlab)', 'nan (Learning new skills)', 'nan (Appealing message traits: Salary information)', 'nan (Future Lang & Tech: SQL)', 'nan (Other Smart Phone)', 'nan (Current Lang & Tech: iOS)', 'nan (Most annoying about job search: The Interview)', 'nan (Technical Support)', 'nan (Opportunity to Use/Learn New Technologies)', 'nan (Future Lang & Tech: Redis)', 'nan (C#)', 'nan (Source control used: Legacy / Custom)', 'nan (Current Lang & Tech: C++11)', 'nan (Most important aspect of new job opportunity: Equity)', 'nan (Software)', 'nan (Current Lang & Tech: MongoDB)', 'nan (HTML5)', 'nan (Cordova)', 'nan (Android phone)', 'nan (Source control used: SVN)', "nan (How often are Stack Overflow's answers helpful)", 'nan ($100,001 - $150,000)', 'nan (Using Stack Exchange)', 'nan (How can companies improve interview process: Remote interviews)', 'nan (Recruitment Tools & Services)', 'nan (Training & Education: PhD in CS)', 'nan (Why use Stack Overflow: Demonstrate expertise)', 'nan (Most important aspect of new job opportunity: Building something that matters)', 'nan (Current Lang & Tech: JavaScript)', 'nan (Kindle)', 'nan (Most annoying about job search: Finding interesting job)', 'nan (iPad)', 'nan (Node.js)', 'nan (Most urgent info about job opportunity: Colleagues)', 'nan (Occupation)', 'nan (The ads are Informative)', 'nan (Current Lang & Tech: Redis)', 'nan (Positive Organization Structure (not much bureaucracy, helpful management))', 'nan (Java)', 'nan (Twitter)', 'nan (I can buy anything I want without asking anyone)', 'nan (Current Lang & Tech: Scala)', 'nan (Current Lang & Tech: Node.js)', 'nan (Current Lang & Tech: Cordova)', 'nan (Perception of contact form: Facebook)', 'nan (High Quality Office Space (amenities, lounge space, free food, etc))', 'nan (Gender)', 'nan (Perception of contact form: LinkedIn)', 'nan (Includes salary information)', 'nan (Why answer: Demonstrate expertise)', 'nan (Source control used: Perforce)', 'nan (Future Lang & Tech: Node.js)', 'nan (Future Lang & Tech: AngularJS)', 'nan (Future Lang & Tech: Arduino)', 'nan (Direct sales to consumers)', 'nan (Future Lang & Tech: Rust)', 'nan (How can companies improve intervi ...
#
# Done cleaning column names.

# %% [markdown]
# ### Convert column names to lower case

# %%
# Update all column names in combined_df and each dataframe in dataframes to be lower case
df_use.columns = [col.lower() for col in df_use.columns]

# %%
df_use.head()
# Out:
#    expectedsalary aitoolinterested in using truefalse_1 sotagshaveworkedwith  \
# 0             NaN                       NaN         NaN                  NaN
# 1             NaN                       NaN         NaN                  NaN
# 2             NaN                       NaN         NaN                  NaN
# 3             NaN                       NaN         NaN                  NaN
# 4             NaN                       NaN         NaN                  NaN
#
#   toolstechwanttoworkwith officestacksyncadmired newcollabtoolsdesirenextyear  \
# 0                     NaN                    NaN                          NaN
# 1                     NaN                    NaN                          NaN
# 2                     NaN                    NaN                          NaN
# 3                     NaN                    NaN                          NaN
# 4                     NaN                    NaN                          NaN
#
#   knowledge_7 ainextneither different nor similar sexualorientation  \
# 0         NaN                                 NaN               NaN
# 1         NaN                                 NaN               NaN
# 2         NaN                                 NaN               NaN
# 3         NaN                                 NaN               NaN
# 4         NaN                                 NaN               NaN
#
#    adspriorities5 webframechoice impsyn embeddedhaveworkedwith databasechoice  \
# 0             NaN            NaN    NaN                    NaN            NaN
# 1             NaN            NaN    NaN                    NaN            NaN
# 2             NaN            NaN    NaN                    NaN            NaN
# 3             NaN            NaN    NaN                    NaN            NaN
# 4             NaN            NaN    NaN                    NaN            NaN
#
#   agree_legacy opsys officestacksyncwanttoworkwith do you work remotely?  \
# 0          NaN   NaN                           NaN                   NaN
# 1          NaN   NaN                           NaN                   NaN
# 2          NaN   NaN                           NaN                   NaN
# 3          NaN   NaN                           NaN                   NaN
# 4          NaN   NaN                           NaN                   NaN
#
#   buynewtool stackoverflowjobsrecommend learncodeai stackoverflowmetachat  \
# 0        NaN                        NaN         NaN                   NaN
# 1        NaN                        NaN         NaN                   NaN
# 2        NaN                        NaN         NaN                   NaN
# 3        NaN                        NaN         NaN                   NaN
# 4        NaN                        NaN         NaN                   NaN
#
#   checkincode  adspriorities1 influenceworkstation assessjoboffice newjobhunt  \
# 0         NaN             NaN                  NaN             NaN        NaN
# 1         NaN             NaN                  NaN             NaN        NaN
# 2         NaN             NaN                  NaN             NaN        NaN
# 3         NaN             NaN                  NaN             NaN        NaN
# 4         NaN             NaN                  NaN             NaN        NaN
#
#   gender  jobemailpriorities4 webframewantentry  \
# 0    NaN                  NaN               NaN
# 1    NaN                  NaN               NaN
# 2    NaN                  NaN               NaN
# 3    NaN                  NaN               NaN
# 4    NaN                  NaN               NaN
#
#   which languages are you proficient in? (java) annoyingui  \
# 0                                          Java        NaN
# 1                                          Java        NaN
# 2                                           NaN        NaN
# 3                                           NaN        NaN
# 4                                          Java        NaN
#
#   stackoverflowjoblisting aidangerous commit_frequency agree_loveboss  \
# 0                     NaN         NaN              NaN            NaN
# 1                     NaN         NaN              NaN            NaN
# 2                     NaN         NaN              NaN            NaN
# 3                     NaN         NaN              NaN            NaN
# 4                     NaN         NaN              NaN            NaN
#
#   job_satisfaction stackoverflowbetter  \
# 0              NaN                 NaN
# 1              NaN                 NaN
# 2              NaN                 NaN
# 3              NaN                 NaN
# 4              NaN                 NaN
#
#   do you have a stack overflow careers 2.0 profile? wantworkplatform  \
# 0                                               NaN              NaN
# 1                                               NaN              NaN
# 2                                               NaN              NaN
# 3                                               NaN              NaN
# 4                                               NaN              NaN
#
#   equipmentsatisfiedrw employmentstatus wantworklanguage  assessbenefits7  \
# 0                  NaN              NaN              NaN              NaN
# 1                  NaN              NaN              NaN              NaN
# 2                  NaN              NaN              NaN              NaN
# 3                  NaN              NaN              NaN              NaN
# 4                  NaN              NaN              NaN              NaN
#
#   welcomechange difficultcommunication techlist buildvsbuy  techoppose_5  \
# 0           NaN                    NaN      NaN        NaN           NaN
# 1           NaN                    NaN      NaN        NaN           NaN
# 2           NaN                    NaN      NaN        NaN           NaN
# 3           NaN                    NaN      NaN        NaN           NaN
# 4           NaN                    NaN      NaN        NaN           NaN
#
#   rep_range ainextno change excoderskills  \
# 0       NaN             NaN           NaN
# 1       NaN             NaN           NaN
# 2       NaN             NaN           NaN
# 3       NaN             NaN           NaN
# 4       NaN             NaN           NaN
#
#   which desktop operating system do you use the most?  assessbenefits3  \
# 0                                                 NaN              NaN
# 1                                                 NaN              NaN
# 2                                                 NaN              NaN
# 3                                                 NaN              NaN
# 4                                                 NaN              NaN
#
#   learncodeonline frequency_2 importantbenefits open_to_new_job salary_range  \
# 0             NaN         NaN               NaN             NaN          NaN
# 1             NaN         NaN               NaN             NaN          NaN
# 2             NaN         NaN               NaN             NaN          NaN
# 3             NaN         NaN               NaN             NaN          NaN
# 4             NaN         NaN               NaN             NaN          NaN
#
#   inthezone why_learn_new_tech careersatisfaction employment newrole  \
# 0       NaN                NaN                NaN        NaN     NaN
# 1       NaN                NaN                NaN        NaN     NaN
# 2       NaN                NaN                NaN        NaN     NaN
# 3       NaN                NaN                NaN        NaN     NaN
# 4       NaN                NaN                NaN        NaN     NaN
#
#   influencerecruitment remote  assessjob9 what country do you live in?  \
# 0                  NaN    NaN         NaN                          NaN
# 1                  NaN    NaN         NaN                          NaN
# 2                  NaN    NaN         NaN                          NaN
# 3                  NaN    NaN         NaN                          NaN
# 4                  NaN    NaN         NaN                          NaN
#
#   webframeadmired  stackoverflowsatisfaction  workexp stackoverflowjobs  \
# 0             NaN                        NaN      NaN               NaN
# 1             NaN                        NaN      NaN               NaN
# 2             NaN                        NaN      NaN               NaN
# 3             NaN                        NaN      NaN               NaN
# 4             NaN                        NaN      NaN               NaN
#
#   lastint newdevopsimpt frequency_3 sotagshaveentry aichallenges  \
# 0     NaN           NaN         NaN             NaN          NaN
# 1     NaN           NaN         NaN             NaN          NaN
# 2     NaN           NaN         NaN             NaN          NaN
# 3     NaN           NaN         NaN             NaN          NaN
# 4     NaN           NaN         NaN             NaN          NaN
#
#   aitoolcurrently mostly ai assessjobprojects aimodelsadmired languageadmired  \
# 0                       NaN               NaN             NaN             NaN
# 1                       NaN               NaN             NaN             NaN
# 2                       NaN               NaN             NaN             NaN
# 3                       NaN               NaN             NaN             NaN
# 4                       NaN               NaN             NaN             NaN
#
#   jobsatpoints_15_text platformhaveentry student  jobsatpoints_14  \
# 0                  NaN               NaN     NaN              NaN
# 1                  NaN               NaN     NaN              NaN
# 2                  NaN               NaN     NaN              NaN
# 3                  NaN               NaN     NaN              NaN
# 4                  NaN               NaN     NaN              NaN
#
#   aiagentknowwrite  \
# 0              NaN
# 1              NaN
# 2              NaN
# 3              NaN
# 4              NaN
#
#   how likely is it that a recommendation you make will be acted upon?  \
# 0                                    Unless it's stoopid it gets done
# 1                                           It's been known to happen
# 2                                                 Once in a blue moon
# 3                                              Not in a million years
# 4                                                 Once in a blue moon
#
#   ethicsresponsible  \
# 0               NaN
# 1               NaN
# 2               NaN
# 3               NaN
# 4               NaN
#
#   if your company has a native mobile app, what platforms do you support? (iphone)  \
# 0                                                                              NaN
# 1                                                                              NaN
# 2                                                                              NaN
# 3                                                                              NaN
# 4                                                                              NaN
#
#   aihuman how would you best describe the industry you currently work in?  \
# 0     NaN                                                             NaN
# 1     NaN                                                             NaN
# 2     NaN                                                             NaN
# 3     NaN                                                             NaN
# 4     NaN                                                             NaN
#
#   influencecommunication important_sameend stackoverflowanswer  \
# 0                    NaN               NaN                 NaN
# 1                    NaN               NaN                 NaN
# 2                    NaN               NaN                 NaN
# 3                    NaN               NaN                 NaN
# 4                    NaN               NaN                 NaN
#
#   learncodechoose important_promotion employment_status  \
# 0             NaN                 NaN               NaN
# 1             NaN                 NaN               NaN
# 2             NaN                 NaN               NaN
# 3             NaN                 NaN               NaN
# 4             NaN                 NaN               NaN
#
#   select all that apply (current lang & tech: android)  assessjob4  \
# 0                                                  NaN         NaN
# 1                                                  NaN         NaN
# 2                                                  NaN         NaN
# 3                                                  NaN         NaN
# 4                                                  NaN         NaN
#
#   aiagentorchwrite agree_alcohol  \
# 0              NaN           NaN
# 1              NaN           NaN
# 2              NaN           NaN
# 3              NaN           NaN
# 4              NaN           NaN
#
#   what advertisers do you remember seeing on stack overflow? (open-ended response)  \
# 0                                                                              NaN
# 1                                                                              NaN
# 2                                                                              NaN
# 3                                                                              NaN
# 4                                                                              NaN
#
#   you answered you don't have a careers profile, can you elaborate why?  \
# 0                                                                   NaN
# 1                                                                   NaN
# 2                                                                   NaN
# 3                                                                   NaN
# 4                                                                   NaN
#
#   dev_environment dogs_vs_cats officestackwantentry  \
# 0             NaN          NaN                  NaN
# 1             NaN          NaN                  NaN
# 2             NaN          NaN                  NaN
# 3             NaN          NaN                  NaN
# 4             NaN          NaN                  NaN
#
#   select all that apply (why try stack overflow careers: no spam)  \
# 0                                                             NaN
# 1                                                             NaN
# 2                                                             NaN
# 3                                                             NaN
# 4                                                             NaN
#
#    so_actions_7 stackoverflowhelpful problemsolving devenvsadmired  \
# 0           NaN                  NaN            NaN            NaN
# 1           NaN                  NaN            NaN            NaN
# 2           NaN                  NaN            NaN            NaN
# 3           NaN                  NaN            NaN            NaN
# 4           NaN                  NaN            NaN            NaN
#
#   aisearchdevadmired aiagentobswrite aiagentimpactneutral  \
# 0                NaN             NaN                  NaN
# 1                NaN             NaN                  NaN
# 2                NaN             NaN                  NaN
# 3                NaN             NaN                  NaN
# 4                NaN             NaN                  NaN
#
#   in an average week, how do you spend your time? (developing new features)  \
# 0                                                                       NaN
# 1                                                                       NaN
# 2                                                                       NaN
# 3                                                                       NaN
# 4                                                                       NaN
#
#    programming_ability learnedhiring q120 sojobs sofriction friendsdevelopers  \
# 0                  NaN           NaN  NaN    NaN        NaN               NaN
# 1                  NaN           NaN  NaN    NaN        NaN               NaN
# 2                  NaN           NaN  NaN    NaN        NaN               NaN
# 3                  NaN           NaN  NaN    NaN        NaN               NaN
# 4                  NaN           NaN  NaN    NaN        NaN               NaN
#
#   university stackoverflowadsrelevant buildingthings stackoverflowmoderation  \
# 0        NaN                      NaN            NaN                     NaN
# 1        NaN                      NaN            NaN                     NaN
# 2        NaN                      NaN            NaN                     NaN
# 3        NaN                      NaN            NaN                     NaN
# 4        NaN                      NaN            NaN                     NaN
#
#   sovisitfreq ethnicity onboarding  adspriorities3 waketime  \
# 0         NaN       NaN        NaN             NaN      NaN
# 1         NaN       NaN        NaN             NaN      NaN
# 2         NaN       NaN        NaN             NaN      NaN
# 3         NaN       NaN        NaN             NaN      NaN
# 4         NaN       NaN        NaN             NaN      NaN
#
#   learncodecoursescert  \
# 0                  NaN
# 1                  NaN
# 2                  NaN
# 3                  NaN
# 4                  NaN
#
#   select up to 3 (how can companies improve interview process: more live code)  \
# 0                                                                          NaN
# 1                                                                          NaN
# 2                                                                          NaN
# 3                                                                          NaN
# 4                                                                          NaN
#
#   surveylength languageswantentry assessjobcommute stackoverflowhasaccount  \
# 0          NaN                NaN              NaN                     NaN
# 1          NaN                NaN              NaN                     NaN
# 2          NaN                NaN              NaN                     NaN
# 3          NaN                NaN              NaN                     NaN
# 4          NaN                NaN              NaN                     NaN
#
#    jobcontactpriorities1  jobemailpriorities1 collaborateremote assessjobtech  \
# 0                    NaN                  NaN               NaN           NaN
# 1                    NaN                  NaN               NaN           NaN
# 2                    NaN                  NaN               NaN           NaN
# 3                    NaN                  NaN               NaN           NaN
# 4                    NaN                  NaN               NaN           NaN
#
#   haveworkedlanguage workremote important_wfh aitoolcurrently partially ai  \
# 0                NaN        NaN           NaN                          NaN
# 1                NaN        NaN           NaN                          NaN
# 2                NaN        NaN           NaN                          NaN
# 3                NaN        NaN           NaN                          NaN
# 4                NaN        NaN           NaN                          NaN
#
#   stackoverflowdevices  \
# 0                  NaN
# 1                  NaN
# 2                  NaN
# 3                  NaN
# 4                  NaN
#
#   if you make a software product, how does your company make money? (you can choose more than one) (advertising)  \
# 0                                                                                                            NaN
# 1                                                                                                            NaN
# 2                                                                                                            NaN
# 3                                                                                                            NaN
# 4                                                                                                            NaN
#
#   purchasewhat what types of purchases are you involved in? (hardware)  \
# 0          NaN                                                     NaN
# 1          NaN                                                     NaN
# 2          NaN                                                     NaN
# 3          NaN                                                     NaN
# 4          NaN                                                     NaN
#
#   how would you best describe the industry you work in? understandcomputers  \
# 0                                          Web Services                 NaN
# 1                                     Software Products                 NaN
# 2                                     Software Products                 NaN
# 3                                            Healthcare                 NaN
# 4                                                 Other                 NaN
#
#   truefalse_3 databasehaveworkedwith influencetechstack aiinteresting  \
# 0         NaN                    NaN                NaN           NaN
# 1         NaN                    NaN                NaN           NaN
# 2         NaN                    NaN                NaN           NaN
# 3         NaN                    NaN                NaN           NaN
# 4         NaN                    NaN                NaN           NaN
#
#   tech_want  assessjob2 devenvwantentry majorundergrad  \
# 0       NaN         NaN             NaN            NaN
# 1       NaN         NaN             NaN            NaN
# 2       NaN         NaN             NaN            NaN
# 3       NaN         NaN             NaN            NaN
# 4       NaN         NaN             NaN            NaN
#
#   what type of project are you developing? nondevelopertype salary  \
# 0                             Web Platform              NaN    NaN
# 1                               Enterprise              NaN    NaN
# 2                               Enterprise              NaN    NaN
# 3                                    Other              NaN    NaN
# 4                                    Other              NaN    NaN
#
#   newothercomms betterlife  so_actions_10 misctechadmired interestedanswers  \
# 0           NaN        NaN            NaN             NaN               NaN
# 1           NaN        NaN            NaN             NaN               NaN
# 2           NaN        NaN            NaN             NaN               NaN
# 3           NaN        NaN            NaN             NaN               NaN
# 4           NaN        NaN            NaN             NaN               NaN
#
#    adspriorities4 clickykeys programhobby  jobsatpoints_7  adspriorities6  \
# 0             NaN        NaN          NaN             NaN             NaN
# 1             NaN        NaN          NaN             NaN             NaN
# 2             NaN        NaN          NaN             NaN             NaN
# 3             NaN        NaN          NaN             NaN             NaN
# 4             NaN        NaN          NaN             NaN             NaN
#
#   newsosites aiexplain otherpeoplescode adblocker  jobsatpoints_10  \
# 0        NaN       NaN              NaN       NaN              NaN
# 1        NaN       NaN              NaN       NaN              NaN
# 2        NaN       NaN              NaN       NaN              NaN
# 3        NaN       NaN              NaN       NaN              NaN
# 4        NaN       NaN              NaN       NaN              NaN
#
#   knowledge_5 ethicsreport blockchainis  \
# 0         NaN          NaN          NaN
# 1         NaN          NaN          NaN
# 2         NaN          NaN          NaN
# 3         NaN          NaN          NaN
# 4         NaN          NaN          NaN
#
#   where do you work remotely most of the time? importanthiringcompanies  \
# 0                                          NaN                      NaN
# 1                                          NaN                      NaN
# 2                                          NaN                      NaN
# 3                                          NaN                      NaN
# 4                                          NaN                      NaN
#
#   boringdetails adblockerdisable adblockerreasons jobsatisfaction  \
# 0           NaN              NaN              NaN             NaN
# 1           NaN              NaN              NaN             NaN
# 2           NaN              NaN              NaN             NaN
# 3           NaN              NaN              NaN             NaN
# 4           NaN              NaN              NaN             NaN
#
#   what is your involvement in purchasing products or services for the company you work for? (you can choose more than one) (i can recommend or request products)  \
# 0                                                                                                                                                            NaN
# 1                                                                                                                                                            NaN
# 2                                                                                                                                                            NaN
# 3                                                                                                                                                            NaN
# 4                                                                                                                                                            NaN
#
#    assessjob10 jobsecurity airesponsible stackoverflowcommunity  \
# 0          NaN         NaN           NaN                    NaN
# 1          NaN         NaN           NaN                    NaN
# 2          NaN         NaN           NaN                    NaN
# 3          NaN         NaN           NaN                    NaN
# 4          NaN         NaN           NaN                    NaN
#
#   commplatformwanttoworkwith tabsspaces offon yearscodedjob seriouswork  \
# 0                        NaN        NaN   NaN           NaN         NaN
# 1                        NaN        NaN   NaN           NaN         NaN
# 2                        NaN        NaN   NaN           NaN         NaN
# 3                        NaN        NaN   NaN           NaN         NaN
# 4                        NaN        NaN   NaN           NaN         NaN
#
#    so_actions_6 which best describes the size of your company?  \
# 0           NaN                                Start Up (1-25)
# 1           NaN                                Start Up (1-25)
# 2           NaN                 Mature Small Business (25-100)
# 3           NaN                            Mid Sized (100-999)
# 4           NaN          Other (not working, consultant, etc.)
#
#   stackoverflowmakemoney militaryus visit_frequency  \
# 0                    NaN        NaN             NaN
# 1                    NaN        NaN             NaN
# 2                    NaN        NaN             NaN
# 3                    NaN        NaN             NaN
# 4                    NaN        NaN             NaN
#
#   please rate your job/career satisfaction excoder10years projectmanagement  \
# 0                        So happy it hurts            NaN               NaN
# 1                    I enjoy going to work            NaN               NaN
# 2                        So happy it hurts            NaN               NaN
# 3                                      FML            NaN               NaN
# 4                    I enjoy going to work            NaN               NaN
#
#    jobsatpoints_11 aiagentimpactstrongly agree lasthiredate  \
# 0              NaN                         NaN          NaN
# 1              NaN                         NaN          NaN
# 2              NaN                         NaN          NaN
# 3              NaN                         NaN          NaN
# 4              NaN                         NaN          NaN
#
#   have you visited / are you aware of stack overflow careers 2.0?  \
# 0                                                             NaN
# 1                                                             NaN
# 2                                                             NaN
# 3                                                             NaN
# 4                                                             NaN
#
#   aiagentchallengesstrongly agree  \
# 0                             NaN
# 1                             NaN
# 2                             NaN
# 3                             NaN
# 4                             NaN
#
#   what is your budget for outside expenditures (hardware, software, consulting, etc) for 2014?  \
# 0                                                                                          NaN
# 1                                                                                          NaN
# 2                                                                                          NaN
# 3                                                                                          NaN
# 4                                                                                          NaN
#
#   opensource  \
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN
#
#   how do you prefer to be contacted about job opportunities? (email)  \
# 0                                                                NaN
# 1                                                                NaN
# 2                                                                NaN
# 3                                                                NaN
# 4                                                                NaN
#
#   questionsinteresting salarytype newlearn  techoppose_9  \
# 0                  NaN        NaN      NaN           NaN
# 1                  NaN        NaN      NaN           NaN
# 2                  NaN        NaN      NaN           NaN
# 3                  NaN        NaN      NaN           NaN
# 4                  NaN        NaN      NaN           NaN
#
#   assessjobcompensation databasedesirenextyear hourscomputer  \
# 0                   NaN                    NaN           NaN
# 1                   NaN                    NaN           NaN
# 2                   NaN                    NaN           NaN
# 3                   NaN                    NaN           NaN
# 4                   NaN                    NaN           NaN
#
#    convertedcompyearly aiagentknowledge  \
# 0                  NaN              NaN
# 1                  NaN              NaN
# 2                  NaN              NaN
# 3                  NaN              NaN
# 4                  NaN              NaN
#
#   what is your budget for outside expenditures (hardware, software, consulting, etc) for 2013?  \
# 0                                                                                          NaN
# 1                                                                                          NaN
# 2                                                                                          NaN
# 3                                                                                          NaN
# 4                                                                                          NaN
#
#   have you visited / are you aware of stack overflow careers?  \
# 0                                                         NaN
# 1                                                         NaN
# 2                                                         NaN
# 3                                                         NaN
# 4                                                         NaN
#
#   platformworkedwith aisearchwanttoworkwith frustration  \
# 0                NaN                    NaN         NaN
# 1                NaN                    NaN         NaN
# 2                NaN                    NaN         NaN
# 3                NaN                    NaN         NaN
# 4                NaN                    NaN         NaN
#
#   equipmentsatisfiedstorage webframehaveworkedwith blockchain  \
# 0                       NaN                    NaN        NaN
# 1                       NaN                    NaN        NaN
# 2                       NaN                    NaN        NaN
# 3                       NaN                    NaN        NaN
# 4                       NaN                    NaN        NaN
#
#   educationparents how large is the team that you work on? skipmeals  \
# 0              NaN                                     NaN       NaN
# 1              NaN                                     NaN       NaN
# 2              NaN                                     NaN       NaN
# 3              NaN                                     NaN       NaN
# 4              NaN                                     NaN       NaN
#
#    toolcountpersonal devenviron  \
# 0                NaN        NaN
# 1                NaN        NaN
# 2                NaN        NaN
# 3                NaN        NaN
# 4                NaN        NaN
#
#   what is your involvement in purchasing products or services for the company you work for? (you can choose more than one) (influencer)  \
# 0                                                                                                                                   NaN
# 1                                                                                                                                   NaN
# 2                                                                                                                                   NaN
# 3                                                                                                                                   NaN
# 4                                                                                                                                   NaN
#
#   platformwantentry jobprofile platformwanttoworkwith  \
# 0               NaN        NaN                    NaN
# 1               NaN        NaN                    NaN
# 2               NaN        NaN                    NaN
# 3               NaN        NaN                    NaN
# 4               NaN        NaN                    NaN
#
#   how did you find out about your current job? importanthiringrep  \
# 0                                          NaN                NaN
# 1                                          NaN                NaN
# 2                                          NaN                NaN
# 3                                          NaN                NaN
# 4                                          NaN                NaN
#
#   sotagsadmired soaccount  age ainextvery different mentalhealth  \
# 0           NaN       NaN  NaN                  NaN          NaN
# 1           NaN       NaN  NaN                  NaN          NaN
# 2           NaN       NaN  NaN                  NaN          NaN
# 3           NaN       NaN  NaN                  NaN          NaN
# 4           NaN       NaN  NaN                  NaN          NaN
#
#   stackoverflowvisit  coderevhrs embeddedadmired aisent enjoydebugging  \
# 0                NaN         NaN             NaN    NaN            NaN
# 1                NaN         NaN             NaN    NaN            NaN
# 2                NaN         NaN             NaN    NaN            NaN
# 3                NaN         NaN             NaN    NaN            NaN
# 4                NaN         NaN             NaN    NaN            NaN
#
#   which technologies are you excited about? (node.js) race assessjobleaders  \
# 0                                                 NaN  NaN              NaN
# 1                                                 NaN  NaN              NaN
# 2                                                 NaN  NaN              NaN
# 3                                                 NaN  NaN              NaN
# 4                                                 NaN  NaN              NaN
#
#   please rate how important each of the following characteristics of a company/job offer are to you.    please select a maximum of 3 items as "non-negotiables" to help us identify the most important items, those where you would never consider a company if they didn't meet them. (high base compensation)  \
# 0                                                                                                                                                                                                                                                                                                           NaN
# 1                                                                                                                                                                                                                                                                                                           NaN
# 2                                                                                                                                                                                                                                                                                                           NaN
# 3                                                                                                                                                                                                                                                                                                           NaN
# 4                                                                                                                                                                                                                                                                                                           NaN
#
#   desktop_os mobiledevelopertype importanthiringgettingthingsdone  \
# 0        NaN                 NaN                              NaN
# 1        NaN                 NaN                              NaN
# 2        NaN                 NaN                              NaN
# 3        NaN                 NaN                              NaN
# 4        NaN                 NaN                              NaN
#
#   are you currently looking for a job or open to new opportunities?  \
# 0                                                               NaN
# 1                                                               NaN
# 2                                                               NaN
# 3                                                               NaN
# 4                                                               NaN
#
#   metricassess  \
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
#
#   how often do you find solutions to your programming problems on stack overflow without asking a new question?  \
# 0                                                                                                           NaN
# 1                                                                                                           NaN
# 2                                                                                                           NaN
# 3                                                                                                           NaN
# 4                                                                                                           NaN
#
#   jobseekingstatus ainextsomewhat similar newcollabtoolsworkedwith  \
# 0              NaN                    NaN                      NaN
# 1              NaN                    NaN                      NaN
# 2              NaN                    NaN                      NaN
# 3              NaN                    NaN                      NaN
# 4              NaN                    NaN                      NaN
#
#    assessjob3  techendorse_4  so_actions_3  \
# 0         NaN            NaN           NaN
# 1         NaN            NaN           NaN
# 2         NaN            NaN           NaN
# 3         NaN            NaN           NaN
# 4         NaN            NaN           NaN
#
#   what other departments / roles do you interact with regularly? (system administrators)  \
# 0                                                                                    NaN
# 1                                                                                    NaN
# 2                                                                                    NaN
# 3                                                                                    NaN
# 4                                                                                    NaN
#
#    age_midpoint stackoverflowdescribes  techendorse_6  techoppose_11  \
# 0           NaN                    NaN            NaN            NaN
# 1           NaN                    NaN            NaN            NaN
# 2           NaN                    NaN            NaN            NaN
# 3           NaN                    NaN            NaN            NaN
# 4           NaN                    NaN            NaN            NaN
#
#   excoderwillnotcode were you aware of the apptivate contest?  \
# 0                NaN                                      NaN
# 1                NaN                                      NaN
# 2                NaN                                      NaN
# 3                NaN                                      NaN
# 4                NaN                                      NaN
#
#   aitoolplan to mostly use ai which us state or territory do you live in?  \
# 0                         NaN                                  California
# 1                         NaN                                         NaN
# 2                         NaN                                         NaN
# 3                         NaN                                         NaN
# 4                         NaN                                         NaN
#
#   webframeworkedwith languageworkedwith occupation ergonomicdevices  \
# 0                NaN                NaN        NaN              NaN
# 1                NaN                NaN        NaN              NaN
# 2                NaN                NaN        NaN              NaN
# 3                NaN                NaN        NaN              NaN
# 4                NaN                NaN        NaN              NaN
#
#   equipmentsatisfiedram newofftopic aiagentorchestration important_variety  \
# 0                   NaN         NaN                  NaN               NaN
# 1                   NaN         NaN                  NaN               NaN
# 2                   NaN         NaN                  NaN               NaN
# 3                   NaN         NaN                  NaN               NaN
# 4                   NaN         NaN                  NaN               NaN
#
#   country  jobcontactpriorities3 newovertime platformhaveworkedwith  \
# 0     NaN                    NaN         NaN                    NaN
# 1     NaN                    NaN         NaN                    NaN
# 2     NaN                    NaN         NaN                    NaN
# 3     NaN                    NaN         NaN                    NaN
# 4     NaN                    NaN         NaN                    NaN
#
#   screenname sexuality  hoursperweek  \
# 0        NaN       NaN           NaN
# 1        NaN       NaN           NaN
# 2        NaN       NaN           NaN
# 3        NaN       NaN           NaN
# 4        NaN       NaN           NaN
#
#   what is your current stack overflow reputation? soai devenvswanttoworkwith  \
# 0                                             NaN  NaN                   NaN
# 1                                             NaN  NaN                   NaN
# 2                                             NaN  NaN                   NaN
# 3                                             NaN  NaN                   NaN
# 4                                             NaN  NaN                   NaN
#
#   devtype  vchostingprofessional use officestackasyncadmired  \
# 0     NaN                        NaN                     NaN
# 1     NaN                        NaN                     NaN
# 2     NaN                        NaN                     NaN
# 3     NaN                        NaN                     NaN
# 4     NaN                        NaN                     NaN
#
#   important_newtech assessjobexp country currency overpaid sotagswant entry  \
# 0               NaN          NaN     NaN      NaN      NaN              NaN
# 1               NaN          NaN     NaN      NaN      NaN              NaN
# 2               NaN          NaN     NaN      NaN      NaN              NaN
# 3               NaN          NaN     NaN      NaN      NaN              NaN
# 4               NaN          NaN     NaN      NaN      NaN              NaN
#
#   select all that apply (most urgent info about job opportunity: salary)  \
# 0                                                                    NaN
# 1                                                                    NaN
# 2                                                                    NaN
# 3                                                                    NaN
# 4                                                                    NaN
#
#   importanthiringalgorithms edlevel misctechwanttoworkwith resumeprompted  \
# 0                       NaN     NaN                    NaN            NaN
# 1                       NaN     NaN                    NaN            NaN
# 2                       NaN     NaN                    NaN            NaN
# 3                       NaN     NaN                    NaN            NaN
# 4                       NaN     NaN                    NaN            NaN
#
#   ethicalimplications self_identification  responseid  \
# 0                 NaN                 NaN         NaN
# 1                 NaN                 NaN         NaN
# 2                 NaN                 NaN         NaN
# 3                 NaN                 NaN         NaN
# 4                 NaN                 NaN         NaN
#
#   aisearchdevhaveworkedwith officestackasynchaveworkedwith icorpm collector  \
# 0                       NaN                            NaN    NaN       NaN
# 1                       NaN                            NaN    NaN       NaN
# 2                       NaN                            NaN    NaN       NaN
# 3                       NaN                            NaN    NaN       NaN
# 4                       NaN                            NaN    NaN       NaN
#
#   assessjobdept workloc wantworkdatabase devenvshaveworkedwith  \
# 0           NaN     NaN              NaN                   NaN
# 1           NaN     NaN              NaN                   NaN
# 2           NaN     NaN              NaN                   NaN
# 3           NaN     NaN              NaN                   NaN
# 4           NaN     NaN              NaN                   NaN
#
#   assessjobproduct workchallenge jobsearchstatus importanthiringopensource  \
# 0              NaN           NaN             NaN                       NaN
# 1              NaN           NaN             NaN                       NaN
# 2              NaN           NaN             NaN                       NaN
# 3              NaN           NaN             NaN                       NaN
# 4              NaN           NaN             NaN                       NaN
#
#    so_actions_4 knowledge_8  \
# 0           NaN         NaN
# 1           NaN         NaN
# 2           NaN         NaN
# 3           NaN         NaN
# 4           NaN         NaN
#
# ...
# 0                                                                       Influencer
# 1                                                                              NaN
# 2                                                                       Influencer
# 3                                                                              NaN
# 4                                                                              NaN
#
#   have you changed jobs in the last 12 months? agree_mars  techendorse_5  \
# 0                                          NaN        NaN            NaN
# 1                                          NaN        NaN            NaN
# 2                                          NaN        NaN            NaN
# 3                                          NaN        NaN            NaN
# 4                                          NaN        NaN            NaN
#
#   aiagentexternal  assessbenefits10 aisearchhaveworkedwith tech_do  \
# 0             NaN               NaN                    NaN     NaN
# 1             NaN               NaN                    NaN     NaN
# 2             NaN               NaN                    NaN     NaN
# 3             NaN               NaN                    NaN     NaN
# 4             NaN               NaN                    NaN     NaN
#
#   extraversion so_dev_content ainextless integrated  \
# 0          NaN            NaN                   NaN
# 1          NaN            NaN                   NaN
# 2          NaN            NaN                   NaN
# 3          NaN            NaN                   NaN
# 4          NaN            NaN                   NaN
#
#   newcollabtoolshaveworkedwith officestackhaveentry newdevops jobfactors  \
# 0                          NaN                  NaN       NaN        NaN
# 1                          NaN                  NaN       NaN        NaN
# 2                          NaN                  NaN       NaN        NaN
# 3                          NaN                  NaN       NaN        NaN
# 4                          NaN                  NaN       NaN        NaN
#
#   stackoverflowcompanypage frameworkworkedwith itperson  jobsatpoints_4  \
# 0                      NaN                 NaN      NaN             NaN
# 1                      NaN                 NaN      NaN             NaN
# 2                      NaN                 NaN      NaN             NaN
# 3                      NaN                 NaN      NaN             NaN
# 4                      NaN                 NaN      NaN             NaN
#
#   select up to 3 (most important aspect of new job opportunity: salary)  \
# 0                                                                   NaN
# 1                                                                   NaN
# 2                                                                   NaN
# 3                                                                   NaN
# 4                                                                   NaN
#
#   commplatformhaveworkedwith  assessjob5  assessjob8 educationtypes  \
# 0                        NaN         NaN         NaN            NaN
# 1                        NaN         NaN         NaN            NaN
# 2                        NaN         NaN         NaN            NaN
# 3                        NaN         NaN         NaN            NaN
# 4                        NaN         NaN         NaN            NaN
#
#   how_to_improve_interview_process professionaltech excoderbalance  \
# 0                              NaN              NaN            NaN
# 1                              NaN              NaN            NaN
# 2                              NaN              NaN            NaN
# 3                              NaN              NaN            NaN
# 4                              NaN              NaN            NaN
#
#    jobemailpriorities3 aiagentchallengesneutral  jobemailpriorities6  \
# 0                  NaN                      NaN                  NaN
# 1                  NaN                      NaN                  NaN
# 2                  NaN                      NaN                  NaN
# 3                  NaN                      NaN                  NaN
# 4                  NaN                      NaN                  NaN
#
#   newpurplelink cousineducation orgsize mgridiot exercise  \
# 0           NaN             NaN     NaN      NaN      NaN
# 1           NaN             NaN     NaN      NaN      NaN
# 2           NaN             NaN     NaN      NaN      NaN
# 3           NaN             NaN     NaN      NaN      NaN
# 4           NaN             NaN     NaN      NaN      NaN
#
#   aiagentimpactsomewhat disagree  \
# 0                            NaN
# 1                            NaN
# 2                            NaN
# 3                            NaN
# 4                            NaN
#
#   in receiving an email about a job opportunity, what attributes of the message would make you more likely to respond? (message is personalized to me)  \
# 0                                                                                                                                                  NaN
# 1                                                                                                                                                  NaN
# 2                                                                                                                                                  NaN
# 3                                                                                                                                                  NaN
# 4                                                                                                                                                  NaN
#
#   mgrmoney  workweekhrs sohowmuchtime influencedepttech learncode  \
# 0      NaN          NaN           NaN               NaN       NaN
# 1      NaN          NaN           NaN               NaN       NaN
# 2      NaN          NaN           NaN               NaN       NaN
# 3      NaN          NaN           NaN               NaN       NaN
# 4      NaN          NaN           NaN               NaN       NaN
#
#    jobsatpoints_13 newstuck  \
# 0              NaN      NaN
# 1              NaN      NaN
# 2              NaN      NaN
# 3              NaN      NaN
# 4              NaN      NaN
#
#   select all that apply (future lang & tech: android) highesteducationparents  \
# 0                                                 NaN                     NaN
# 1                                                 NaN                     NaN
# 2                                                 NaN                     NaN
# 3                                                 NaN                     NaN
# 4                                                 NaN                     NaN
#
#   how often are you contacted by recruiters? techendorse_13_text  \
# 0                                        NaN                 NaN
# 1                                        NaN                 NaN
# 2                                        NaN                 NaN
# 3                                        NaN                 NaN
# 4                                        NaN                 NaN
#
#   surveytoolong blockchainorg stackoverflowfoundanswer versioncontrol  \
# 0           NaN           NaN                      NaN            NaN
# 1           NaN           NaN                      NaN            NaN
# 2           NaN           NaN                      NaN            NaN
# 3           NaN           NaN                      NaN            NaN
# 4           NaN           NaN                      NaN            NaN
#
#    techoppose_1 importanthiringtitles sovisitto  \
# 0           NaN                   NaN       NaN
# 1           NaN                   NaN       NaN
# 2           NaN                   NaN       NaN
# 3           NaN                   NaN       NaN
# 4           NaN                   NaN       NaN
#
#   which of our sites do you frequent most?  adspriorities2 vcinteraction  \
# 0                           Stack Overflow             NaN           NaN
# 1                           Stack Overflow             NaN           NaN
# 2                           Stack Overflow             NaN           NaN
# 3               Programmers Stack Exchange             NaN           NaN
# 4                           Stack Overflow             NaN           NaN
#
#   influenceservers aiagentimpactstrongly disagree hypotheticaltools1  \
# 0              NaN                            NaN                NaN
# 1              NaN                            NaN                NaN
# 2              NaN                            NaN                NaN
# 3              NaN                            NaN                NaN
# 4              NaN                            NaN                NaN
#
#   so_region languagechoice professionalcloud  techoppose_3  \
# 0       NaN            NaN               NaN           NaN
# 1       NaN            NaN               NaN           NaN
# 2       NaN            NaN               NaN           NaN
# 3       NaN            NaN               NaN           NaN
# 4       NaN            NaN               NaN           NaN
#
#   developer_challenges haveworkeddatabase knowledge_6  jobsatpoints_5  \
# 0                  NaN                NaN         NaN             NaN
# 1                  NaN                NaN         NaN             NaN
# 2                  NaN                NaN         NaN             NaN
# 3                  NaN                NaN         NaN             NaN
# 4                  NaN                NaN         NaN             NaN
#
#   yearscodingprof socialmedia  so_actions_15 homeremote adsagreedisagree1  \
# 0             NaN         NaN            NaN        NaN               NaN
# 1             NaN         NaN            NaN        NaN               NaN
# 2             NaN         NaN            NaN        NaN               NaN
# 3             NaN         NaN            NaN        NaN               NaN
# 4             NaN         NaN            NaN        NaN               NaN
#
#    jobsatpoints_6 industry how old are you?  jobsatpoints_1  \
# 0             NaN      NaN            30-34             NaN
# 1             NaN      NaN            40-50             NaN
# 2             NaN      NaN            30-34             NaN
# 3             NaN      NaN            30-34             NaN
# 4             NaN      NaN            25-29             NaN
#
#    jobemailpriorities5 newonboardgood newedimpt aiben diversityimportant  \
# 0                  NaN            NaN       NaN   NaN                NaN
# 1                  NaN            NaN       NaN   NaN                NaN
# 2                  NaN            NaN       NaN   NaN                NaN
# 3                  NaN            NaN       NaN   NaN                NaN
# 4                  NaN            NaN       NaN   NaN                NaN
#
#   please rate the advertising you've seen on stack overflow (the ads are relevant)  \
# 0                                                                              NaN
# 1                                                                              NaN
# 2                                                                              NaN
# 3                                                                              NaN
# 4                                                                              NaN
#
#   in an average week, how do you spend your time at work? (developing new features)  \
# 0                                                                               NaN
# 1                                                                               NaN
# 2                                                                               NaN
# 3                                                                               NaN
# 4                                                                               NaN
#
#   excoderactive rightwrongway kinshipdevelopers webdevelopertype  \
# 0           NaN           NaN               NaN              NaN
# 1           NaN           NaN               NaN              NaN
# 2           NaN           NaN               NaN              NaN
# 3           NaN           NaN               NaN              NaN
# 4           NaN           NaN               NaN              NaN
#
#   newcollabtoolsadmired techendorseintro timefullyproductive  \
# 0                   NaN              NaN                 NaN
# 1                   NaN              NaN                 NaN
# 2                   NaN              NaN                 NaN
# 3                   NaN              NaN                 NaN
# 4                   NaN              NaN                 NaN
#
#   assessjobdiversity misctechdesirenextyear languagehaveworkedwith  \
# 0                NaN                    NaN                    NaN
# 1                NaN                    NaN                    NaN
# 2                NaN                    NaN                    NaN
# 3                NaN                    NaN                    NaN
# 4                NaN                    NaN                    NaN
#
#    jobsatpoints_16 uk_country agree_notice aidevwanttoworkwith  \
# 0              NaN        NaN          NaN                 NaN
# 1              NaN        NaN          NaN                 NaN
# 2              NaN        NaN          NaN                 NaN
# 3              NaN        NaN          NaN                 NaN
# 4              NaN        NaN          NaN                 NaN
#
#    jobsatpoints_15 important_buildexisting codingactivities  \
# 0              NaN                     NaN              NaN
# 1              NaN                     NaN              NaN
# 2              NaN                     NaN              NaN
# 3              NaN                     NaN              NaN
# 4              NaN                     NaN              NaN
#
#    vchostingpersonal use do you have a stack overflow careers profile?  \
# 0                    NaN                                           NaN
# 1                    NaN                                           NaN
# 2                    NaN                                           NaN
# 3                    NaN                                           NaN
# 4                    NaN                                           NaN
#
#   dependents team_size_range challengemyself  \
# 0        NaN             NaN             NaN
# 1        NaN             NaN             NaN
# 2        NaN             NaN             NaN
# 3        NaN             NaN             NaN
# 4        NaN             NaN             NaN
#
#   select all that apply (training & education: no formal training)  \
# 0                                                              NaN
# 1                                                              NaN
# 2                                                              NaN
# 3                                                              NaN
# 4                                                              NaN
#
#   webframeworkedwith knowledge_3  techendorse_13  jobcontactpriorities2 hobby  \
# 0                NaN         NaN             NaN                    NaN   NaN
# 1                NaN         NaN             NaN                    NaN   NaN
# 2                NaN         NaN             NaN                    NaN   NaN
# 3                NaN         NaN             NaN                    NaN   NaN
# 4                NaN         NaN             NaN                    NaN   NaN
#
#    techendorse_3 stackoverflowadsdistracting
# 0            NaN                         NaN
# 1            NaN                         NaN
# 2            NaN                         NaN
# 3            NaN                         NaN
# 4            NaN                         NaN

# %% [markdown]
# ### Identify and combine like columns

# %%
# Dictionary of column groups to combine
column_groups = {
    'years_coding': ['yearscode', 'yearscodingprof', 'yearscodepro', 'work_experience', 'yearsprogram', 'yearscodedjob', 'how many years of it/programming experience do you have?'],
    'education': ['edlevel', 'education', 'formaleducation'],
    'employment': ['employment', 'employmentstatus', 'employment_status'],
    'company_size': ['companysize', 'company_size_range', 'orgsize', 'companyemployeesrange', 'how many people work for your company?', 'which best describes the size of your company?'],
    'salary': ['convertedsalary', 'convertedcomp', 'comptotal'],
    'job_satisfaction': ['jobsatisfaction', 'job_satisfaction', 'careersatisfaction', 'please rate your job/career satisfaction'],
    'job_title': ['jobtitle', 'currentjobtitle', 'jobprofile'],
    'developer_type': ['developertype', 'devtype'],
    'industry': ['industry', 'industrytype', 'companytype', 'how would you best describe the industry you work in?', 'how would you best describe the industry you currently work in?'],
    'country': ['country', 'location', 'countrycode', 'what country or region do you live in?', 'what country do you live in?'],
    'programming_experience': ['yearscode', 'yearscoding', 'codingexperience'],
    'database_worked_with': ['databaseworkedwith', 'dbworkedwith'],
    'dev_environment': ['ide', 'developmentenvironment', 'dev_environment', 'devenviron', 'devenvironment'],
    'operating_sys': ['opsys', 'operatingsystem', 'os', 'what operating system do you use the most?', 'which desktop operating system do you use the most?'],
    'dev_methodology': ['methodology', 'devmethodology', 'developmentmethodology'],
    'communication_tools': ['communicationtools', 'collaboration', 'collabtools'],
    'gender': ['gender', 'sex', 'what is your gender?'],
    'age': ['age', 'agerange','age_range','agegrouping', 'how old are you?'],
    'learning': ['learncode', 'learncodehow', 'learningmethod'],
    'work_experience': ['workexp', 'experience', 'yearsexperience'],
    'remote': ['remotework', 'workremote', 'remotestatus', 'do you work remotely?', 'homeremote', 'remote'],
    'team_size': ['teamsize', 'orgteamsize', 'developmentteamsize', 'how large is the team that you work on?'],
    'survey_easy': ['surveyease', 'surveyeasy', 'surveylong', 'surveytoolong', 'surveylength'],
    'version_control_sys': ['versioncontrol', 'versioncontrolsystem', 'vcs'],
    'currency': ['currency', 'currencydesc'],
    'hobby': ['hobby', 'hobbyist'],
    'race': ['race', 'raceethnicity', 'self_identification']
}

# %%
df_use_2 = df_use.copy()

# %%
# Identify and combine duplicate columns
def combine_duplicate_columns(df):
    """
    Identifies columns with the same name (case-insensitive), combines their data
    into a single column by taking the first non-null value, and removes the originals.

    Args:
        df: The input DataFrame.

    Returns:
        A new DataFrame with duplicate columns combined.
    """
    df_combined_duplicates = pd.DataFrame(index=df.index)
    processed_columns = set()

    for col_name in df.columns:
        col_name_lower = col_name.lower()

        if col_name_lower not in processed_columns:
            # Find all columns with this name (case-insensitive)
            duplicate_columns = [col for col in df.columns if col.lower() == col_name_lower]

            if len(duplicate_columns) > 1:
                print(f"Combining duplicate columns for '{col_name_lower}': {duplicate_columns}")
                # Select the duplicate columns
                selected_duplicates = df[duplicate_columns]
                # Combine by taking the first non-null value across rows
                combined_series = selected_duplicates.bfill(axis=1).iloc[:, 0]
                df_combined_duplicates[col_name_lower] = combined_series
                # Add to processed set
                processed_columns.add(col_name_lower)
            else:
                # Not a duplicate, just add the column
                df_combined_duplicates[col_name_lower] = df[col_name]
                processed_columns.add(col_name_lower)

    return df_combined_duplicates

# Apply the function to combine duplicate columns in df_use_2
df_use_combined_duplicates = combine_duplicate_columns(df_use_2)

print("\nOriginal DataFrame shape:", df_use_2.shape)
print("DataFrame shape after combining duplicates:", df_use_combined_duplicates.shape)
# Out:
# Combining duplicate columns for 'gender': ['gender', 'gender']
# Combining duplicate columns for 'webframeworkedwith': ['webframeworkedwith', 'webframeworkedwith']
# Combining duplicate columns for 'country': ['country', 'country']
# Combining duplicate columns for 'industry': ['industry', 'industry']
# Combining duplicate columns for 'hobby': ['hobby', 'hobby']
# Combining duplicate columns for 'webframedesirenextyear': ['webframedesirenextyear', 'webframedesirenextyear']
#
# Original DataFrame shape: (154521, 729)
# DataFrame shape after combining duplicates: (154521, 723)

# %%
def combine_columns(df, column_list):
    """
    Combines data from a list of columns into a single Series,
    taking the first non-null value across the columns for each row.

    Args:
        df: The input pandas DataFrame.
        column_list: A list of column names to combine.

    Returns:
        A pandas Series containing the combined data.
    """
    # Select the specified columns
    selected_columns = df[column_list]

    # Combine columns by taking the first non-null value across rows
    combined_series = selected_columns.bfill(axis=1).iloc[:, 0]

    return combined_series

# %%
# Initialize an empty dictionary to store consolidated columns
consolidated_columns_dict = {}

# Iterate through the column_groups dictionary
for group_name, column_list in column_groups.items():
    # Identify columns in df_use_combined_duplicates that are present in the current group's list
    present_columns = [col for col in column_list if col in df_use_combined_duplicates.columns]

    # If there are columns from the current group present in the DataFrame
    if present_columns:
        print(f"Processing group '{group_name}' with columns: {present_columns}")
        # Call the combine_columns function
        combined_series = combine_columns(df_use_combined_duplicates, present_columns)
        # Store the resulting combined Series in the dictionary
        consolidated_columns_dict[group_name] = combined_series
    else:
        print(f"No columns found for group '{group_name}' in the DataFrame.")

# Create a new DataFrame from the dictionary of consolidated columns
df_consolidated = pd.DataFrame(consolidated_columns_dict)

print("\nConsolidated DataFrame created.")
print(f"Shape of consolidated DataFrame: {df_consolidated.shape}")
df_consolidated.head()
# Out:
# Processing group 'years_coding' with columns: ['yearscode', 'yearscodingprof', 'yearscodepro', 'yearsprogram', 'yearscodedjob', 'how many years of it/programming experience do you have?']
# Processing group 'education' with columns: ['edlevel', 'education', 'formaleducation']
# Processing group 'employment' with columns: ['employment', 'employmentstatus', 'employment_status']
# Processing group 'company_size' with columns: ['companysize', 'company_size_range', 'orgsize', 'how many people work for your company?', 'which best describes the size of your company?']
# Processing group 'salary' with columns: ['convertedsalary', 'convertedcomp', 'comptotal']
# Processing group 'job_satisfaction' with columns: ['jobsatisfaction', 'job_satisfaction', 'careersatisfaction', 'please rate your job/career satisfaction']
# Processing group 'job_title' with columns: ['jobprofile']
# Processing group 'developer_type' with columns: ['developertype', 'devtype']
# Processing group 'industry' with columns: ['industry', 'companytype', 'how would you best describe the industry you work in?', 'how would you best describe the industry you currently work in?']
# Processing group 'country' with columns: ['country', 'what country or region do you live in?', 'what country do you live in?']
# Processing group 'programming_experience' with columns: ['yearscode', 'yearscoding']
# Processing group 'database_worked_with' with columns: ['databaseworkedwith']
# Processing group 'dev_environment' with columns: ['ide', 'dev_environment', 'devenviron']
# Processing group 'operating_sys' with columns: ['opsys', 'operatingsystem', 'what operating system do you use the most?', 'which desktop operating system do you use the most?']
# Processing group 'dev_methodology' with columns: ['methodology']
# Processing group 'communication_tools' with columns: ['communicationtools']
# Processing group 'gender' with columns: ['gender', 'what is your gender?']
# Processing group 'age' with columns: ['age', 'age_range', 'how old are you?']
# Processing group 'learning' with columns: ['learncode']
# Processing group 'work_experience' with columns: ['workexp']
# Processing group 'remote' with columns: ['remotework', 'workremote', 'do you work remotely?', 'homeremote', 'remote']
# Processing group 'team_size' with columns: ['how large is the team that you work on?']
# Processing group 'survey_easy' with columns: ['surveyease', 'surveyeasy', 'surveylong', 'surveytoolong', 'surveylength']
# Processing group 'version_control_sys' with columns: ['versioncontrol', 'versioncontrolsystem']
# Processing group 'currency' with columns: ['currency', 'currencydesc']
# Processing group 'hobby' with columns: ['hobby', 'hobbyist']
# Processing group 'race' with columns: ['race', 'raceethnicity', 'self_identification']
#
# Consolidated DataFrame created.
# Shape of consolidated DataFrame: (154521, 27)
#   years_coding education employment                           company_size  \
# 0           11       NaN        NaN                        Start Up (1-25)
# 1           11       NaN        NaN                        Start Up (1-25)
# 2           11       NaN        NaN         Mature Small Business (25-100)
# 3        41435       NaN        NaN                    Mid Sized (100-999)
# 4        41310       NaN        NaN  Other (not working, consultant, etc.)
#
#    salary       job_satisfaction job_title developer_type           industry  \
# 0     NaN      So happy it hurts       NaN            NaN       Web Services
# 1     NaN  I enjoy going to work       NaN            NaN  Software Products
# 2     NaN      So happy it hurts       NaN            NaN  Software Products
# 3     NaN                    FML       NaN            NaN         Healthcare
# 4     NaN  I enjoy going to work       NaN            NaN              Other
#
#                     country programming_experience database_worked_with  \
# 0  United States of America                    NaN                  NaN
# 1              Other Europe                    NaN                  NaN
# 2             South America                    NaN                  NaN
# 3                Other Asia                    NaN                  NaN
# 4              Other Europe                    NaN                  NaN
#
#   dev_environment operating_sys dev_methodology communication_tools gender  \
# 0             NaN         Linux             NaN                 NaN    NaN
# 1             NaN      Mac OS X             NaN                 NaN    NaN
# 2             NaN     Windows 7             NaN                 NaN    NaN
# 3             NaN      Mac OS X             NaN                 NaN    NaN
# 4             NaN         Linux             NaN                 NaN    NaN
#
#      age learning  work_experience remote team_size survey_easy  \
# 0  30-34      NaN              NaN    NaN       NaN         NaN
# 1  40-50      NaN              NaN    NaN       NaN         NaN
# 2  30-34      NaN              NaN    NaN       NaN         NaN
# 3  30-34      NaN              NaN    NaN       NaN         NaN
# 4  25-29      NaN              NaN    NaN       NaN         NaN
#
#   version_control_sys currency hobby race
# 0                 NaN      NaN   NaN  NaN
# 1                 NaN      NaN   NaN  NaN
# 2                 NaN      NaN   NaN  NaN
# 3                 NaN      NaN   NaN  NaN
# 4                 NaN      NaN   NaN  NaN

# %%
# Create a list of all original column names that were combined
original_columns_to_drop = []
for group_name, column_list in column_groups.items():
    # Identify columns in df_use_combined_duplicates that are present in the current group's list
    present_columns = [col for col in column_list if col in df_use_combined_duplicates.columns]
    original_columns_to_drop.extend(present_columns)

# Remove duplicates from the list of columns to drop
original_columns_to_drop = list(set(original_columns_to_drop))

# Drop these original columns from the df_use_combined_duplicates DataFrame
df_use_combined_duplicates_dropped = df_use_combined_duplicates.drop(columns=original_columns_to_drop, errors='ignore')

print("Original columns that were combined have been dropped.")
print(f"Shape of df_use_combined_duplicates after dropping original columns: {df_use_combined_duplicates_dropped.shape}")
# Out:
# Original columns that were combined have been dropped.
# Shape of df_use_combined_duplicates after dropping original columns: (154521, 651)

# %%
# Concatenate the remaining columns from df_use_combined_duplicates_dropped with the consolidated columns
df_all = pd.concat([df_use_combined_duplicates_dropped, df_consolidated], axis=1)

print("\nFinal DataFrame created by concatenating remaining original columns and consolidated columns.")
print(f"Shape of the final DataFrame: {df_all.shape}")

# Display the first few rows of the final dataframe
print("\nFirst 5 rows of the final DataFrame:")
display(df_all.head())
# Out:
# Final DataFrame created by concatenating remaining original columns and consolidated columns.
# Shape of the final DataFrame: (154521, 678)
#
# First 5 rows of the final DataFrame:
#    expectedsalary aitoolinterested in using truefalse_1 sotagshaveworkedwith  \
# 0             NaN                       NaN         NaN                  NaN
# 1             NaN                       NaN         NaN                  NaN
# 2             NaN                       NaN         NaN                  NaN
# 3             NaN                       NaN         NaN                  NaN
# 4             NaN                       NaN         NaN                  NaN
#
#   toolstechwanttoworkwith officestacksyncadmired newcollabtoolsdesirenextyear  \
# 0                     NaN                    NaN                          NaN
# 1                     NaN                    NaN                          NaN
# 2                     NaN                    NaN                          NaN
# 3                     NaN                    NaN                          NaN
# 4                     NaN                    NaN                          NaN
#
#   knowledge_7 ainextneither different nor similar sexualorientation  \
# 0         NaN                                 NaN               NaN
# 1         NaN                                 NaN               NaN
# 2         NaN                                 NaN               NaN
# 3         NaN                                 NaN               NaN
# 4         NaN                                 NaN               NaN
#
#    adspriorities5 webframechoice impsyn embeddedhaveworkedwith databasechoice  \
# 0             NaN            NaN    NaN                    NaN            NaN
# 1             NaN            NaN    NaN                    NaN            NaN
# 2             NaN            NaN    NaN                    NaN            NaN
# 3             NaN            NaN    NaN                    NaN            NaN
# 4             NaN            NaN    NaN                    NaN            NaN
#
#   agree_legacy officestacksyncwanttoworkwith buynewtool  \
# 0          NaN                           NaN        NaN
# 1          NaN                           NaN        NaN
# 2          NaN                           NaN        NaN
# 3          NaN                           NaN        NaN
# 4          NaN                           NaN        NaN
#
#   stackoverflowjobsrecommend learncodeai stackoverflowmetachat checkincode  \
# 0                        NaN         NaN                   NaN         NaN
# 1                        NaN         NaN                   NaN         NaN
# 2                        NaN         NaN                   NaN         NaN
# 3                        NaN         NaN                   NaN         NaN
# 4                        NaN         NaN                   NaN         NaN
#
#    adspriorities1 influenceworkstation assessjoboffice newjobhunt  \
# 0             NaN                  NaN             NaN        NaN
# 1             NaN                  NaN             NaN        NaN
# 2             NaN                  NaN             NaN        NaN
# 3             NaN                  NaN             NaN        NaN
# 4             NaN                  NaN             NaN        NaN
#
#    jobemailpriorities4 webframewantentry  \
# 0                  NaN               NaN
# 1                  NaN               NaN
# 2                  NaN               NaN
# 3                  NaN               NaN
# 4                  NaN               NaN
#
#   which languages are you proficient in? (java) annoyingui  \
# 0                                          Java        NaN
# 1                                          Java        NaN
# 2                                           NaN        NaN
# 3                                           NaN        NaN
# 4                                          Java        NaN
#
#   stackoverflowjoblisting aidangerous commit_frequency agree_loveboss  \
# 0                     NaN         NaN              NaN            NaN
# 1                     NaN         NaN              NaN            NaN
# 2                     NaN         NaN              NaN            NaN
# 3                     NaN         NaN              NaN            NaN
# 4                     NaN         NaN              NaN            NaN
#
#   stackoverflowbetter do you have a stack overflow careers 2.0 profile?  \
# 0                 NaN                                               NaN
# 1                 NaN                                               NaN
# 2                 NaN                                               NaN
# 3                 NaN                                               NaN
# 4                 NaN                                               NaN
#
#   wantworkplatform equipmentsatisfiedrw wantworklanguage  assessbenefits7  \
# 0              NaN                  NaN              NaN              NaN
# 1              NaN                  NaN              NaN              NaN
# 2              NaN                  NaN              NaN              NaN
# 3              NaN                  NaN              NaN              NaN
# 4              NaN                  NaN              NaN              NaN
#
#   welcomechange difficultcommunication techlist buildvsbuy  techoppose_5  \
# 0           NaN                    NaN      NaN        NaN           NaN
# 1           NaN                    NaN      NaN        NaN           NaN
# 2           NaN                    NaN      NaN        NaN           NaN
# 3           NaN                    NaN      NaN        NaN           NaN
# 4           NaN                    NaN      NaN        NaN           NaN
#
#   rep_range ainextno change excoderskills  assessbenefits3 learncodeonline  \
# 0       NaN             NaN           NaN              NaN             NaN
# 1       NaN             NaN           NaN              NaN             NaN
# 2       NaN             NaN           NaN              NaN             NaN
# 3       NaN             NaN           NaN              NaN             NaN
# 4       NaN             NaN           NaN              NaN             NaN
#
#   frequency_2 importantbenefits open_to_new_job salary_range inthezone  \
# 0         NaN               NaN             NaN          NaN       NaN
# 1         NaN               NaN             NaN          NaN       NaN
# 2         NaN               NaN             NaN          NaN       NaN
# 3         NaN               NaN             NaN          NaN       NaN
# 4         NaN               NaN             NaN          NaN       NaN
#
#   why_learn_new_tech newrole influencerecruitment  assessjob9 webframeadmired  \
# 0                NaN     NaN                  NaN         NaN             NaN
# 1                NaN     NaN                  NaN         NaN             NaN
# 2                NaN     NaN                  NaN         NaN             NaN
# 3                NaN     NaN                  NaN         NaN             NaN
# 4                NaN     NaN                  NaN         NaN             NaN
#
#    stackoverflowsatisfaction stackoverflowjobs lastint newdevopsimpt  \
# 0                        NaN               NaN     NaN           NaN
# 1                        NaN               NaN     NaN           NaN
# 2                        NaN               NaN     NaN           NaN
# 3                        NaN               NaN     NaN           NaN
# 4                        NaN               NaN     NaN           NaN
#
#   frequency_3 sotagshaveentry aichallenges aitoolcurrently mostly ai  \
# 0         NaN             NaN          NaN                       NaN
# 1         NaN             NaN          NaN                       NaN
# 2         NaN             NaN          NaN                       NaN
# 3         NaN             NaN          NaN                       NaN
# 4         NaN             NaN          NaN                       NaN
#
#   assessjobprojects aimodelsadmired languageadmired jobsatpoints_15_text  \
# 0               NaN             NaN             NaN                  NaN
# 1               NaN             NaN             NaN                  NaN
# 2               NaN             NaN             NaN                  NaN
# 3               NaN             NaN             NaN                  NaN
# 4               NaN             NaN             NaN                  NaN
#
#   platformhaveentry student  jobsatpoints_14 aiagentknowwrite  \
# 0               NaN     NaN              NaN              NaN
# 1               NaN     NaN              NaN              NaN
# 2               NaN     NaN              NaN              NaN
# 3               NaN     NaN              NaN              NaN
# 4               NaN     NaN              NaN              NaN
#
#   how likely is it that a recommendation you make will be acted upon?  \
# 0                                    Unless it's stoopid it gets done
# 1                                           It's been known to happen
# 2                                                 Once in a blue moon
# 3                                              Not in a million years
# 4                                                 Once in a blue moon
#
#   ethicsresponsible  \
# 0               NaN
# 1               NaN
# 2               NaN
# 3               NaN
# 4               NaN
#
#   if your company has a native mobile app, what platforms do you support? (iphone)  \
# 0                                                                              NaN
# 1                                                                              NaN
# 2                                                                              NaN
# 3                                                                              NaN
# 4                                                                              NaN
#
#   aihuman influencecommunication important_sameend stackoverflowanswer  \
# 0     NaN                    NaN               NaN                 NaN
# 1     NaN                    NaN               NaN                 NaN
# 2     NaN                    NaN               NaN                 NaN
# 3     NaN                    NaN               NaN                 NaN
# 4     NaN                    NaN               NaN                 NaN
#
#   learncodechoose important_promotion  \
# 0             NaN                 NaN
# 1             NaN                 NaN
# 2             NaN                 NaN
# 3             NaN                 NaN
# 4             NaN                 NaN
#
#   select all that apply (current lang & tech: android)  assessjob4  \
# 0                                                  NaN         NaN
# 1                                                  NaN         NaN
# 2                                                  NaN         NaN
# 3                                                  NaN         NaN
# 4                                                  NaN         NaN
#
#   aiagentorchwrite agree_alcohol  \
# 0              NaN           NaN
# 1              NaN           NaN
# 2              NaN           NaN
# 3              NaN           NaN
# 4              NaN           NaN
#
#   what advertisers do you remember seeing on stack overflow? (open-ended response)  \
# 0                                                                              NaN
# 1                                                                              NaN
# 2                                                                              NaN
# 3                                                                              NaN
# 4                                                                              NaN
#
#   you answered you don't have a careers profile, can you elaborate why?  \
# 0                                                                   NaN
# 1                                                                   NaN
# 2                                                                   NaN
# 3                                                                   NaN
# 4                                                                   NaN
#
#   dogs_vs_cats officestackwantentry  \
# 0          NaN                  NaN
# 1          NaN                  NaN
# 2          NaN                  NaN
# 3          NaN                  NaN
# 4          NaN                  NaN
#
#   select all that apply (why try stack overflow careers: no spam)  \
# 0                                                             NaN
# 1                                                             NaN
# 2                                                             NaN
# 3                                                             NaN
# 4                                                             NaN
#
#    so_actions_7 stackoverflowhelpful problemsolving devenvsadmired  \
# 0           NaN                  NaN            NaN            NaN
# 1           NaN                  NaN            NaN            NaN
# 2           NaN                  NaN            NaN            NaN
# 3           NaN                  NaN            NaN            NaN
# 4           NaN                  NaN            NaN            NaN
#
#   aisearchdevadmired aiagentobswrite aiagentimpactneutral  \
# 0                NaN             NaN                  NaN
# 1                NaN             NaN                  NaN
# 2                NaN             NaN                  NaN
# 3                NaN             NaN                  NaN
# 4                NaN             NaN                  NaN
#
#   in an average week, how do you spend your time? (developing new features)  \
# 0                                                                       NaN
# 1                                                                       NaN
# 2                                                                       NaN
# 3                                                                       NaN
# 4                                                                       NaN
#
#    programming_ability learnedhiring q120 sojobs sofriction friendsdevelopers  \
# 0                  NaN           NaN  NaN    NaN        NaN               NaN
# 1                  NaN           NaN  NaN    NaN        NaN               NaN
# 2                  NaN           NaN  NaN    NaN        NaN               NaN
# 3                  NaN           NaN  NaN    NaN        NaN               NaN
# 4                  NaN           NaN  NaN    NaN        NaN               NaN
#
#   university stackoverflowadsrelevant buildingthings stackoverflowmoderation  \
# 0        NaN                      NaN            NaN                     NaN
# 1        NaN                      NaN            NaN                     NaN
# 2        NaN                      NaN            NaN                     NaN
# 3        NaN                      NaN            NaN                     NaN
# 4        NaN                      NaN            NaN                     NaN
#
#   sovisitfreq ethnicity onboarding  adspriorities3 waketime  \
# 0         NaN       NaN        NaN             NaN      NaN
# 1         NaN       NaN        NaN             NaN      NaN
# 2         NaN       NaN        NaN             NaN      NaN
# 3         NaN       NaN        NaN             NaN      NaN
# 4         NaN       NaN        NaN             NaN      NaN
#
#   learncodecoursescert  \
# 0                  NaN
# 1                  NaN
# 2                  NaN
# 3                  NaN
# 4                  NaN
#
#   select up to 3 (how can companies improve interview process: more live code)  \
# 0                                                                          NaN
# 1                                                                          NaN
# 2                                                                          NaN
# 3                                                                          NaN
# 4                                                                          NaN
#
#   languageswantentry assessjobcommute stackoverflowhasaccount  \
# 0                NaN              NaN                     NaN
# 1                NaN              NaN                     NaN
# 2                NaN              NaN                     NaN
# 3                NaN              NaN                     NaN
# 4                NaN              NaN                     NaN
#
#    jobcontactpriorities1  jobemailpriorities1 collaborateremote assessjobtech  \
# 0                    NaN                  NaN               NaN           NaN
# 1                    NaN                  NaN               NaN           NaN
# 2                    NaN                  NaN               NaN           NaN
# 3                    NaN                  NaN               NaN           NaN
# 4                    NaN                  NaN               NaN           NaN
#
#   haveworkedlanguage important_wfh aitoolcurrently partially ai  \
# 0                NaN           NaN                          NaN
# 1                NaN           NaN                          NaN
# 2                NaN           NaN                          NaN
# 3                NaN           NaN                          NaN
# 4                NaN           NaN                          NaN
#
#   stackoverflowdevices  \
# 0                  NaN
# 1                  NaN
# 2                  NaN
# 3                  NaN
# 4                  NaN
#
#   if you make a software product, how does your company make money? (you can choose more than one) (advertising)  \
# 0                                                                                                            NaN
# 1                                                                                                            NaN
# 2                                                                                                            NaN
# 3                                                                                                            NaN
# 4                                                                                                            NaN
#
#   purchasewhat what types of purchases are you involved in? (hardware)  \
# 0          NaN                                                     NaN
# 1          NaN                                                     NaN
# 2          NaN                                                     NaN
# 3          NaN                                                     NaN
# 4          NaN                                                     NaN
#
#   understandcomputers truefalse_3 databasehaveworkedwith influencetechstack  \
# 0                 NaN         NaN                    NaN                NaN
# 1                 NaN         NaN                    NaN                NaN
# 2                 NaN         NaN                    NaN                NaN
# 3                 NaN         NaN                    NaN                NaN
# 4                 NaN         NaN                    NaN                NaN
#
#   aiinteresting tech_want  assessjob2 devenvwantentry majorundergrad  \
# 0           NaN       NaN         NaN             NaN            NaN
# 1           NaN       NaN         NaN             NaN            NaN
# 2           NaN       NaN         NaN             NaN            NaN
# 3           NaN       NaN         NaN             NaN            NaN
# 4           NaN       NaN         NaN             NaN            NaN
#
#   what type of project are you developing? nondevelopertype  salary  \
# 0                             Web Platform              NaN     NaN
# 1                               Enterprise              NaN     NaN
# 2                               Enterprise              NaN     NaN
# 3                                    Other              NaN     NaN
# 4                                    Other              NaN     NaN
#
#   newothercomms betterlife  so_actions_10 misctechadmired interestedanswers  \
# 0           NaN        NaN            NaN             NaN               NaN
# 1           NaN        NaN            NaN             NaN               NaN
# 2           NaN        NaN            NaN             NaN               NaN
# 3           NaN        NaN            NaN             NaN               NaN
# 4           NaN        NaN            NaN             NaN               NaN
#
#    adspriorities4 clickykeys programhobby  jobsatpoints_7  adspriorities6  \
# 0             NaN        NaN          NaN             NaN             NaN
# 1             NaN        NaN          NaN             NaN             NaN
# 2             NaN        NaN          NaN             NaN             NaN
# 3             NaN        NaN          NaN             NaN             NaN
# 4             NaN        NaN          NaN             NaN             NaN
#
#   newsosites aiexplain otherpeoplescode adblocker  jobsatpoints_10  \
# 0        NaN       NaN              NaN       NaN              NaN
# 1        NaN       NaN              NaN       NaN              NaN
# 2        NaN       NaN              NaN       NaN              NaN
# 3        NaN       NaN              NaN       NaN              NaN
# 4        NaN       NaN              NaN       NaN              NaN
#
#   knowledge_5 ethicsreport blockchainis  \
# 0         NaN          NaN          NaN
# 1         NaN          NaN          NaN
# 2         NaN          NaN          NaN
# 3         NaN          NaN          NaN
# 4         NaN          NaN          NaN
#
#   where do you work remotely most of the time? importanthiringcompanies  \
# 0                                          NaN                      NaN
# 1                                          NaN                      NaN
# 2                                          NaN                      NaN
# 3                                          NaN                      NaN
# 4                                          NaN                      NaN
#
#   boringdetails adblockerdisable adblockerreasons  \
# 0           NaN              NaN              NaN
# 1           NaN              NaN              NaN
# 2           NaN              NaN              NaN
# 3           NaN              NaN              NaN
# 4           NaN              NaN              NaN
#
#   what is your involvement in purchasing products or services for the company you work for? (you can choose more than one) (i can recommend or request products)  \
# 0                                                                                                                                                            NaN
# 1                                                                                                                                                            NaN
# 2                                                                                                                                                            NaN
# 3                                                                                                                                                            NaN
# 4                                                                                                                                                            NaN
#
#    assessjob10 jobsecurity airesponsible stackoverflowcommunity  \
# 0          NaN         NaN           NaN                    NaN
# 1          NaN         NaN           NaN                    NaN
# 2          NaN         NaN           NaN                    NaN
# 3          NaN         NaN           NaN                    NaN
# 4          NaN         NaN           NaN                    NaN
#
#   commplatformwanttoworkwith tabsspaces offon seriouswork  so_actions_6  \
# 0                        NaN        NaN   NaN         NaN           NaN
# 1                        NaN        NaN   NaN         NaN           NaN
# 2                        NaN        NaN   NaN         NaN           NaN
# 3                        NaN        NaN   NaN         NaN           NaN
# 4                        NaN        NaN   NaN         NaN           NaN
#
#   stackoverflowmakemoney militaryus visit_frequency excoder10years  \
# 0                    NaN        NaN             NaN            NaN
# 1                    NaN        NaN             NaN            NaN
# 2                    NaN        NaN             NaN            NaN
# 3                    NaN        NaN             NaN            NaN
# 4                    NaN        NaN             NaN            NaN
#
#   projectmanagement  jobsatpoints_11 aiagentimpactstrongly agree lasthiredate  \
# 0               NaN              NaN                         NaN          NaN
# 1               NaN              NaN                         NaN          NaN
# 2               NaN              NaN                         NaN          NaN
# 3               NaN              NaN                         NaN          NaN
# 4               NaN              NaN                         NaN          NaN
#
#   have you visited / are you aware of stack overflow careers 2.0?  \
# 0                                                             NaN
# 1                                                             NaN
# 2                                                             NaN
# 3                                                             NaN
# 4                                                             NaN
#
#   aiagentchallengesstrongly agree  \
# 0                             NaN
# 1                             NaN
# 2                             NaN
# 3                             NaN
# 4                             NaN
#
#   what is your budget for outside expenditures (hardware, software, consulting, etc) for 2014?  \
# 0                                                                                          NaN
# 1                                                                                          NaN
# 2                                                                                          NaN
# 3                                                                                          NaN
# 4                                                                                          NaN
#
#   opensource  \
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN
#
#   how do you prefer to be contacted about job opportunities? (email)  \
# 0                                                                NaN
# 1                                                                NaN
# 2                                                                NaN
# 3                                                                NaN
# 4                                                                NaN
#
#   questionsinteresting salarytype newlearn  techoppose_9  \
# 0                  NaN        NaN      NaN           NaN
# 1                  NaN        NaN      NaN           NaN
# 2                  NaN        NaN      NaN           NaN
# 3                  NaN        NaN      NaN           NaN
# 4                  NaN        NaN      NaN           NaN
#
#   assessjobcompensation databasedesirenextyear hourscomputer  \
# 0                   NaN                    NaN           NaN
# 1                   NaN                    NaN           NaN
# 2                   NaN                    NaN           NaN
# 3                   NaN                    NaN           NaN
# 4                   NaN                    NaN           NaN
#
#    convertedcompyearly aiagentknowledge  \
# 0                  NaN              NaN
# 1                  NaN              NaN
# 2                  NaN              NaN
# 3                  NaN              NaN
# 4                  NaN              NaN
#
#   what is your budget for outside expenditures (hardware, software, consulting, etc) for 2013?  \
# 0                                                                                          NaN
# 1                                                                                          NaN
# 2                                                                                          NaN
# 3                                                                                          NaN
# 4                                                                                          NaN
#
#   have you visited / are you aware of stack overflow careers?  \
# 0                                                         NaN
# 1                                                         NaN
# 2                                                         NaN
# 3                                                         NaN
# 4                                                         NaN
#
#   platformworkedwith aisearchwanttoworkwith frustration  \
# 0                NaN                    NaN         NaN
# 1                NaN                    NaN         NaN
# 2                NaN                    NaN         NaN
# 3                NaN                    NaN         NaN
# 4                NaN                    NaN         NaN
#
#   equipmentsatisfiedstorage webframehaveworkedwith blockchain  \
# 0                       NaN                    NaN        NaN
# 1                       NaN                    NaN        NaN
# 2                       NaN                    NaN        NaN
# 3                       NaN                    NaN        NaN
# 4                       NaN                    NaN        NaN
#
#   educationparents skipmeals  toolcountpersonal  \
# 0              NaN       NaN                NaN
# 1              NaN       NaN                NaN
# 2              NaN       NaN                NaN
# 3              NaN       NaN                NaN
# 4              NaN       NaN                NaN
#
#   what is your involvement in purchasing products or services for the company you work for? (you can choose more than one) (influencer)  \
# 0                                                                                                                                   NaN
# 1                                                                                                                                   NaN
# 2                                                                                                                                   NaN
# 3                                                                                                                                   NaN
# 4                                                                                                                                   NaN
#
#   platformwantentry platformwanttoworkwith  \
# 0               NaN                    NaN
# 1               NaN                    NaN
# 2               NaN                    NaN
# 3               NaN                    NaN
# 4               NaN                    NaN
#
#   how did you find out about your current job? importanthiringrep  \
# 0                                          NaN                NaN
# 1                                          NaN                NaN
# 2                                          NaN                NaN
# 3                                          NaN                NaN
# 4                                          NaN                NaN
#
#   sotagsadmired soaccount ainextvery different mentalhealth  \
# 0           NaN       NaN                  NaN          NaN
# 1           NaN       NaN                  NaN          NaN
# 2           NaN       NaN                  NaN          NaN
# 3           NaN       NaN                  NaN          NaN
# 4           NaN       NaN                  NaN          NaN
#
#   stackoverflowvisit  coderevhrs embeddedadmired aisent enjoydebugging  \
# 0                NaN         NaN             NaN    NaN            NaN
# 1                NaN         NaN             NaN    NaN            NaN
# 2                NaN         NaN             NaN    NaN            NaN
# 3                NaN         NaN             NaN    NaN            NaN
# 4                NaN         NaN             NaN    NaN            NaN
#
#   which technologies are you excited about? (node.js) assessjobleaders  \
# 0                                                 NaN              NaN
# 1                                                 NaN              NaN
# 2                                                 NaN              NaN
# 3                                                 NaN              NaN
# 4                                                 NaN              NaN
#
#   please rate how important each of the following characteristics of a company/job offer are to you.    please select a maximum of 3 items as "non-negotiables" to help us identify the most important items, those where you would never consider a company if they didn't meet them. (high base compensation)  \
# 0                                                                                                                                                                                                                                                                                                           NaN
# 1                                                                                                                                                                                                                                                                                                           NaN
# 2                                                                                                                                                                                                                                                                                                           NaN
# 3                                                                                                                                                                                                                                                                                                           NaN
# 4                                                                                                                                                                                                                                                                                                           NaN
#
#   desktop_os mobiledevelopertype importanthiringgettingthingsdone  \
# 0        NaN                 NaN                              NaN
# 1        NaN                 NaN                              NaN
# 2        NaN                 NaN                              NaN
# 3        NaN                 NaN                              NaN
# 4        NaN                 NaN                              NaN
#
#   are you currently looking for a job or open to new opportunities?  \
# 0                                                               NaN
# 1                                                               NaN
# 2                                                               NaN
# 3                                                               NaN
# 4                                                               NaN
#
#   metricassess  \
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
#
#   how often do you find solutions to your programming problems on stack overflow without asking a new question?  \
# 0                                                                                                           NaN
# 1                                                                                                           NaN
# 2                                                                                                           NaN
# 3                                                                                                           NaN
# 4                                                                                                           NaN
#
#   jobseekingstatus ainextsomewhat similar newcollabtoolsworkedwith  \
# 0              NaN                    NaN                      NaN
# 1              NaN                    NaN                      NaN
# 2              NaN                    NaN                      NaN
# 3              NaN                    NaN                      NaN
# 4              NaN                    NaN                      NaN
#
#    assessjob3  techendorse_4  so_actions_3  \
# 0         NaN            NaN           NaN
# 1         NaN            NaN           NaN
# 2         NaN            NaN           NaN
# 3         NaN            NaN           NaN
# 4         NaN            NaN           NaN
#
#   what other departments / roles do you interact with regularly? (system administrators)  \
# 0                                                                                    NaN
# 1                                                                                    NaN
# 2                                                                                    NaN
# 3                                                                                    NaN
# 4                                                                                    NaN
#
#    age_midpoint stackoverflowdescribes  techendorse_6  techoppose_11  \
# 0           NaN                    NaN            NaN            NaN
# 1           NaN                    NaN            NaN            NaN
# 2           NaN                    NaN            NaN            NaN
# 3           NaN                    NaN            NaN            NaN
# 4           NaN                    NaN            NaN            NaN
#
#   excoderwillnotcode were you aware of the apptivate contest?  \
# 0                NaN                                      NaN
# 1                NaN                                      NaN
# 2                NaN                                      NaN
# 3                NaN                                      NaN
# 4                NaN                                      NaN
#
#   aitoolplan to mostly use ai which us state or territory do you live in?  \
# 0                         NaN                                  California
# 1                         NaN                                         NaN
# 2                         NaN                                         NaN
# 3                         NaN                                         NaN
# 4                         NaN                                         NaN
#
#   webframeworkedwith languageworkedwith occupation ergonomicdevices  \
# 0                NaN                NaN        NaN              NaN
# 1                NaN                NaN        NaN              NaN
# 2                NaN                NaN        NaN              NaN
# 3                NaN                NaN        NaN              NaN
# 4                NaN                NaN        NaN              NaN
#
#   equipmentsatisfiedram newofftopic aiagentorchestration important_variety  \
# 0                   NaN         NaN                  NaN               NaN
# 1                   NaN         NaN                  NaN               NaN
# 2                   NaN         NaN                  NaN               NaN
# 3                   NaN         NaN                  NaN               NaN
# 4                   NaN         NaN                  NaN               NaN
#
#    jobcontactpriorities3 newovertime platformhaveworkedwith screenname  \
# 0                    NaN         NaN                    NaN        NaN
# 1                    NaN         NaN                    NaN        NaN
# 2                    NaN         NaN                    NaN        NaN
# 3                    NaN         NaN                    NaN        NaN
# 4                    NaN         NaN                    NaN        NaN
#
#   sexuality  hoursperweek what is your current stack overflow reputation?  \
# 0       NaN           NaN                                             NaN
# 1       NaN           NaN                                             NaN
# 2       NaN           NaN                                             NaN
# 3       NaN           NaN                                             NaN
# 4       NaN           NaN                                             NaN
#
#   soai devenvswanttoworkwith  vchostingprofessional use  \
# 0  NaN                   NaN                        NaN
# 1  NaN                   NaN                        NaN
# 2  NaN                   NaN                        NaN
# 3  NaN                   NaN                        NaN
# 4  NaN                   NaN                        NaN
#
#   officestackasyncadmired important_newtech assessjobexp overpaid  \
# 0                     NaN               NaN          NaN      NaN
# 1                     NaN               NaN          NaN      NaN
# 2                     NaN               NaN          NaN      NaN
# 3                     NaN               NaN          NaN      NaN
# 4                     NaN               NaN          NaN      NaN
#
#   sotagswant entry  \
# 0              NaN
# 1              NaN
# 2              NaN
# 3              NaN
# 4              NaN
#
#   select all that apply (most urgent info about job opportunity: salary)  \
# 0                                                                    NaN
# 1                                                                    NaN
# 2                                                                    NaN
# 3                                                                    NaN
# 4                                                                    NaN
#
#   importanthiringalgorithms misctechwanttoworkwith resumeprompted  \
# 0                       NaN                    NaN            NaN
# 1                       NaN                    NaN            NaN
# 2                       NaN                    NaN            NaN
# 3                       NaN                    NaN            NaN
# 4                       NaN                    NaN            NaN
#
#   ethicalimplications  responseid aisearchdevhaveworkedwith  \
# 0                 NaN         NaN                       NaN
# 1                 NaN         NaN                       NaN
# 2                 NaN         NaN                       NaN
# 3                 NaN         NaN                       NaN
# 4                 NaN         NaN                       NaN
#
#   officestackasynchaveworkedwith icorpm collector assessjobdept workloc  \
# 0                            NaN    NaN       NaN           NaN     NaN
# 1                            NaN    NaN       NaN           NaN     NaN
# 2                            NaN    NaN       NaN           NaN     NaN
# 3                            NaN    NaN       NaN           NaN     NaN
# 4                            NaN    NaN       NaN           NaN     NaN
#
#   wantworkdatabase devenvshaveworkedwith assessjobproduct workchallenge  \
# 0              NaN                   NaN              NaN           NaN
# 1              NaN                   NaN              NaN           NaN
# 2              NaN                   NaN              NaN           NaN
# 3              NaN                   NaN              NaN           NaN
# 4              NaN                   NaN              NaN           NaN
#
#   jobsearchstatus importanthiringopensource  so_actions_4 knowledge_8  \
# 0             NaN                       NaN           NaN         NaN
# 1             NaN                       NaN           NaN         NaN
# 2             NaN                       NaN           NaN         NaN
# 3             NaN                       NaN           NaN         NaN
# 4             NaN                       NaN           NaN         NaN
#
#   select up to 3 (appealing message traits: message is personalized)  \
# 0                                                                NaN
# 1                                                                NaN
# 2                                                                NaN
# 3                                                                NaN
# 4                                                                NaN
#
#   in the last 12 months, how much money have you spent on personal technology-related purchases?  \
# 0                                                                                        >$3,000
# 1                                                                                  $2,001-$3,000
# 2                                                                                    $501-$1,000
# 3                                                                                        >$3,000
# 4                                                                                      $251-$500
#
#   aifrustration  jobemailpriorities2 importanthiringpmexp assessjobrole  \
# 0           NaN                  NaN                  NaN           NaN
# 1           NaN                  NaN                  NaN           NaN
# 2           NaN                  NaN                  NaN           NaN
# 3           NaN                  NaN                  NaN           NaN
# 4           NaN                  NaN                  NaN           NaN
#
#   select all that apply (source control used: git) sovisit1st  \
# 0                                              NaN        NaN
# 1                                              NaN        NaN
# 2                                              NaN        NaN
# 3                                              NaN        NaN
# 4                                              NaN        NaN
#
#   experience_range why_stack_overflow yearscodedjobpast aithreat  \
# 0              NaN                NaN               NaN      NaN
# 1              NaN                NaN               NaN      NaN
# 2              NaN                NaN               NaN      NaN
# 3              NaN                NaN               NaN      NaN
# 4              NaN                NaN               NaN      NaN
#
#    assessbenefits8 stackoverflowdevstory aiagentchallengessomewhat disagree  \
# 0              NaN                   NaN                                NaN
# 1              NaN                   NaN                                NaN
# 2              NaN                   NaN                                NaN
# 3              NaN                   NaN                                NaN
# 4              NaN                   NaN                                NaN
#
#   jobseek aiopen lastnewjob agreedisagree1  \
# 0     NaN    NaN        NaN            NaN
# 1     NaN    NaN        NaN            NaN
# 2     NaN    NaN        NaN            NaN
# 3     NaN    NaN        NaN            NaN
# 4     NaN    NaN        NaN            NaN
#
#   which of the following best describes your occupation? commplatformadmired  \
# 0                                      Server Programmer                 NaN
# 1                              Web Application Developer                 NaN
# 2                          Desktop Application Developer                 NaN
# 3                          Desktop Application Developer                 NaN
# 4                                                Student                 NaN
#
#    assessjob7  jobsatpoints_9  assessbenefits4 influenceviztools sotimesaved  \
# 0         NaN             NaN              NaN               NaN         NaN
# 1         NaN             NaN              NaN               NaN         NaN
# 2         NaN             NaN              NaN               NaN         NaN
# ...
# 0                          NaN                  NaN       NaN        NaN
# 1                          NaN                  NaN       NaN        NaN
# 2                          NaN                  NaN       NaN        NaN
# 3                          NaN                  NaN       NaN        NaN
# 4                          NaN                  NaN       NaN        NaN
#
#   stackoverflowcompanypage frameworkworkedwith itperson  jobsatpoints_4  \
# 0                      NaN                 NaN      NaN             NaN
# 1                      NaN                 NaN      NaN             NaN
# 2                      NaN                 NaN      NaN             NaN
# 3                      NaN                 NaN      NaN             NaN
# 4                      NaN                 NaN      NaN             NaN
#
#   select up to 3 (most important aspect of new job opportunity: salary)  \
# 0                                                                   NaN
# 1                                                                   NaN
# 2                                                                   NaN
# 3                                                                   NaN
# 4                                                                   NaN
#
#   commplatformhaveworkedwith  assessjob5  assessjob8 educationtypes  \
# 0                        NaN         NaN         NaN            NaN
# 1                        NaN         NaN         NaN            NaN
# 2                        NaN         NaN         NaN            NaN
# 3                        NaN         NaN         NaN            NaN
# 4                        NaN         NaN         NaN            NaN
#
#   how_to_improve_interview_process professionaltech excoderbalance  \
# 0                              NaN              NaN            NaN
# 1                              NaN              NaN            NaN
# 2                              NaN              NaN            NaN
# 3                              NaN              NaN            NaN
# 4                              NaN              NaN            NaN
#
#    jobemailpriorities3 aiagentchallengesneutral  jobemailpriorities6  \
# 0                  NaN                      NaN                  NaN
# 1                  NaN                      NaN                  NaN
# 2                  NaN                      NaN                  NaN
# 3                  NaN                      NaN                  NaN
# 4                  NaN                      NaN                  NaN
#
#   newpurplelink cousineducation mgridiot exercise  \
# 0           NaN             NaN      NaN      NaN
# 1           NaN             NaN      NaN      NaN
# 2           NaN             NaN      NaN      NaN
# 3           NaN             NaN      NaN      NaN
# 4           NaN             NaN      NaN      NaN
#
#   aiagentimpactsomewhat disagree  \
# 0                            NaN
# 1                            NaN
# 2                            NaN
# 3                            NaN
# 4                            NaN
#
#   in receiving an email about a job opportunity, what attributes of the message would make you more likely to respond? (message is personalized to me)  \
# 0                                                                                                                                                  NaN
# 1                                                                                                                                                  NaN
# 2                                                                                                                                                  NaN
# 3                                                                                                                                                  NaN
# 4                                                                                                                                                  NaN
#
#   mgrmoney  workweekhrs sohowmuchtime influencedepttech  jobsatpoints_13  \
# 0      NaN          NaN           NaN               NaN              NaN
# 1      NaN          NaN           NaN               NaN              NaN
# 2      NaN          NaN           NaN               NaN              NaN
# 3      NaN          NaN           NaN               NaN              NaN
# 4      NaN          NaN           NaN               NaN              NaN
#
#   newstuck select all that apply (future lang & tech: android)  \
# 0      NaN                                                 NaN
# 1      NaN                                                 NaN
# 2      NaN                                                 NaN
# 3      NaN                                                 NaN
# 4      NaN                                                 NaN
#
#   highesteducationparents how often are you contacted by recruiters?  \
# 0                     NaN                                        NaN
# 1                     NaN                                        NaN
# 2                     NaN                                        NaN
# 3                     NaN                                        NaN
# 4                     NaN                                        NaN
#
#   techendorse_13_text blockchainorg stackoverflowfoundanswer  techoppose_1  \
# 0                 NaN           NaN                      NaN           NaN
# 1                 NaN           NaN                      NaN           NaN
# 2                 NaN           NaN                      NaN           NaN
# 3                 NaN           NaN                      NaN           NaN
# 4                 NaN           NaN                      NaN           NaN
#
#   importanthiringtitles sovisitto which of our sites do you frequent most?  \
# 0                   NaN       NaN                           Stack Overflow
# 1                   NaN       NaN                           Stack Overflow
# 2                   NaN       NaN                           Stack Overflow
# 3                   NaN       NaN               Programmers Stack Exchange
# 4                   NaN       NaN                           Stack Overflow
#
#    adspriorities2 vcinteraction influenceservers  \
# 0             NaN           NaN              NaN
# 1             NaN           NaN              NaN
# 2             NaN           NaN              NaN
# 3             NaN           NaN              NaN
# 4             NaN           NaN              NaN
#
#   aiagentimpactstrongly disagree hypotheticaltools1 so_region languagechoice  \
# 0                            NaN                NaN       NaN            NaN
# 1                            NaN                NaN       NaN            NaN
# 2                            NaN                NaN       NaN            NaN
# 3                            NaN                NaN       NaN            NaN
# 4                            NaN                NaN       NaN            NaN
#
#   professionalcloud  techoppose_3 developer_challenges haveworkeddatabase  \
# 0               NaN           NaN                  NaN                NaN
# 1               NaN           NaN                  NaN                NaN
# 2               NaN           NaN                  NaN                NaN
# 3               NaN           NaN                  NaN                NaN
# 4               NaN           NaN                  NaN                NaN
#
#   knowledge_6  jobsatpoints_5 socialmedia  so_actions_15 adsagreedisagree1  \
# 0         NaN             NaN         NaN            NaN               NaN
# 1         NaN             NaN         NaN            NaN               NaN
# 2         NaN             NaN         NaN            NaN               NaN
# 3         NaN             NaN         NaN            NaN               NaN
# 4         NaN             NaN         NaN            NaN               NaN
#
#    jobsatpoints_6  jobsatpoints_1  jobemailpriorities5 newonboardgood  \
# 0             NaN             NaN                  NaN            NaN
# 1             NaN             NaN                  NaN            NaN
# 2             NaN             NaN                  NaN            NaN
# 3             NaN             NaN                  NaN            NaN
# 4             NaN             NaN                  NaN            NaN
#
#   newedimpt aiben diversityimportant  \
# 0       NaN   NaN                NaN
# 1       NaN   NaN                NaN
# 2       NaN   NaN                NaN
# 3       NaN   NaN                NaN
# 4       NaN   NaN                NaN
#
#   please rate the advertising you've seen on stack overflow (the ads are relevant)  \
# 0                                                                              NaN
# 1                                                                              NaN
# 2                                                                              NaN
# 3                                                                              NaN
# 4                                                                              NaN
#
#   in an average week, how do you spend your time at work? (developing new features)  \
# 0                                                                               NaN
# 1                                                                               NaN
# 2                                                                               NaN
# 3                                                                               NaN
# 4                                                                               NaN
#
#   excoderactive rightwrongway kinshipdevelopers webdevelopertype  \
# 0           NaN           NaN               NaN              NaN
# 1           NaN           NaN               NaN              NaN
# 2           NaN           NaN               NaN              NaN
# 3           NaN           NaN               NaN              NaN
# 4           NaN           NaN               NaN              NaN
#
#   newcollabtoolsadmired techendorseintro timefullyproductive  \
# 0                   NaN              NaN                 NaN
# 1                   NaN              NaN                 NaN
# 2                   NaN              NaN                 NaN
# 3                   NaN              NaN                 NaN
# 4                   NaN              NaN                 NaN
#
#   assessjobdiversity misctechdesirenextyear languagehaveworkedwith  \
# 0                NaN                    NaN                    NaN
# 1                NaN                    NaN                    NaN
# 2                NaN                    NaN                    NaN
# 3                NaN                    NaN                    NaN
# 4                NaN                    NaN                    NaN
#
#    jobsatpoints_16 uk_country agree_notice aidevwanttoworkwith  \
# 0              NaN        NaN          NaN                 NaN
# 1              NaN        NaN          NaN                 NaN
# 2              NaN        NaN          NaN                 NaN
# 3              NaN        NaN          NaN                 NaN
# 4              NaN        NaN          NaN                 NaN
#
#    jobsatpoints_15 important_buildexisting codingactivities  \
# 0              NaN                     NaN              NaN
# 1              NaN                     NaN              NaN
# 2              NaN                     NaN              NaN
# 3              NaN                     NaN              NaN
# 4              NaN                     NaN              NaN
#
#    vchostingpersonal use do you have a stack overflow careers profile?  \
# 0                    NaN                                           NaN
# 1                    NaN                                           NaN
# 2                    NaN                                           NaN
# 3                    NaN                                           NaN
# 4                    NaN                                           NaN
#
#   dependents team_size_range challengemyself  \
# 0        NaN             NaN             NaN
# 1        NaN             NaN             NaN
# 2        NaN             NaN             NaN
# 3        NaN             NaN             NaN
# 4        NaN             NaN             NaN
#
#   select all that apply (training & education: no formal training)  \
# 0                                                              NaN
# 1                                                              NaN
# 2                                                              NaN
# 3                                                              NaN
# 4                                                              NaN
#
#   knowledge_3  techendorse_13  jobcontactpriorities2  techendorse_3  \
# 0         NaN             NaN                    NaN            NaN
# 1         NaN             NaN                    NaN            NaN
# 2         NaN             NaN                    NaN            NaN
# 3         NaN             NaN                    NaN            NaN
# 4         NaN             NaN                    NaN            NaN
#
#   stackoverflowadsdistracting years_coding education employment  \
# 0                         NaN           11       NaN        NaN
# 1                         NaN           11       NaN        NaN
# 2                         NaN           11       NaN        NaN
# 3                         NaN        41435       NaN        NaN
# 4                         NaN        41310       NaN        NaN
#
#                             company_size  salary       job_satisfaction  \
# 0                        Start Up (1-25)     NaN      So happy it hurts
# 1                        Start Up (1-25)     NaN  I enjoy going to work
# 2         Mature Small Business (25-100)     NaN      So happy it hurts
# 3                    Mid Sized (100-999)     NaN                    FML
# 4  Other (not working, consultant, etc.)     NaN  I enjoy going to work
#
#   job_title developer_type           industry                   country  \
# 0       NaN            NaN       Web Services  United States of America
# 1       NaN            NaN  Software Products              Other Europe
# 2       NaN            NaN  Software Products             South America
# 3       NaN            NaN         Healthcare                Other Asia
# 4       NaN            NaN              Other              Other Europe
#
#   programming_experience database_worked_with dev_environment operating_sys  \
# 0                    NaN                  NaN             NaN         Linux
# 1                    NaN                  NaN             NaN      Mac OS X
# 2                    NaN                  NaN             NaN     Windows 7
# 3                    NaN                  NaN             NaN      Mac OS X
# 4                    NaN                  NaN             NaN         Linux
#
#   dev_methodology communication_tools gender    age learning  work_experience  \
# 0             NaN                 NaN    NaN  30-34      NaN              NaN
# 1             NaN                 NaN    NaN  40-50      NaN              NaN
# 2             NaN                 NaN    NaN  30-34      NaN              NaN
# 3             NaN                 NaN    NaN  30-34      NaN              NaN
# 4             NaN                 NaN    NaN  25-29      NaN              NaN
#
#   remote team_size survey_easy version_control_sys currency hobby race
# 0    NaN       NaN         NaN                 NaN      NaN   NaN  NaN
# 1    NaN       NaN         NaN                 NaN      NaN   NaN  NaN
# 2    NaN       NaN         NaN                 NaN      NaN   NaN  NaN
# 3    NaN       NaN         NaN                 NaN      NaN   NaN  NaN
# 4    NaN       NaN         NaN                 NaN      NaN   NaN  NaN

# %%
combined_consolidated_df = df_all.copy()

# %% [markdown]
# ### Consolidate values for country

# %%
# Find columns containing 'country'
country_columns = [col for col in df_use.columns if 'country' in str(col).lower()]

print("Columns containing 'country':")
for col in country_columns:
    try:
        # Select the column(s). If multiple columns share the same name this returns a DataFrame.
        selected = df_use.loc[:, col]
        # If a DataFrame is returned (duplicate column names), collapse to a single Series by taking
        # the first non-null value across duplicates for each row.
        if isinstance(selected, pd.DataFrame):
            if selected.shape[1] > 1:
                print(f"\nWarning: column name '{col}' is duplicated ({selected.shape[1]} columns). Combining duplicates by taking first non-null value.")
            series = selected.bfill(axis=1).iloc[:, 0]
        else:
            series = selected.squeeze()

        print(f"\nColumn: {col}")
        print("Top 5 most common values and their counts:")
        counts = series.fillna('NULL').value_counts().head()
        print(counts)

        # Get unique count excluding nulls
        unique_count = series.dropna().nunique()
        print(f"\nTotal unique values (excluding nulls): {unique_count}")
        print(f"Number of null values: {series.isnull().sum()}")
        print("-" * 50)
    except Exception as e:
        print(f"\nError processing column {col}: {str(e)}")
        print("-" * 50)
# Out:
# Columns containing 'country':
#
# Column: what country do you live in?
# Top 5 most common values and their counts:
# what country do you live in?
# NULL              152992
# United States        400
# India                166
# United Kingdom       143
# Germany               85
# Name: count, dtype: int64
#
# Total unique values (excluding nulls): 80
# Number of null values: 152992
# --------------------------------------------------
#
# Warning: column name 'country' is duplicated (2 columns). Combining duplicates by taking first non-null value.
#
# Column: country
# Top 5 most common values and their counts:
# country
# United States               15827
# NULL                        15330
# India                       14075
# United States of America    13283
# Germany                     10046
# Name: count, dtype: int64
#
# Total unique values (excluding nulls): 235
# Number of null values: 15330
# --------------------------------------------------
#
# Warning: column name 'country' is duplicated (2 columns). Combining duplicates by taking first non-null value.
#
# Column: country
# Top 5 most common values and their counts:
# country
# United States               15827
# NULL                        15330
# India                       14075
# United States of America    13283
# Germany                     10046
# Name: count, dtype: int64
#
# Total unique values (excluding nulls): 235
# Number of null values: 15330
# --------------------------------------------------
#
# Column: what country or region do you live in?
# Top 5 most common values and their counts:
# what country or region do you live in?
# NULL                        150762
# United States of America      1189
# Other Europe                   637
# United Kingdom                 386
# India                          292
# Name: count, dtype: int64
#
# Total unique values (excluding nulls): 20
# Number of null values: 150762
# --------------------------------------------------
#
# Column: uk_country
# Top 5 most common values and their counts:
# uk_country
# NULL                153633
# England                795
# Scotland                66
# Wales                   15
# Northern Ireland        12
# Name: count, dtype: int64
#
# Total unique values (excluding nulls): 4
# Number of null values: 153633
# --------------------------------------------------

# %%
# Mapping of variants -> canonical names (lowercased keys for matching)
country_map = {
    'united states': 'United States',
    'united states of america': 'United States',
    'united kingdom of great britain and northern ireland': 'United Kingdom',
    'united kingdom': 'United Kingdom',
    'trinidad and tobago': 'Trinidad and Tobago',
    'trinidad & tobago': 'Trinidad and Tobago',
    'syrian arab republic': 'Syria',
    'syria': 'Syria',
    'other country (not listed above)': 'Other',
    'other (please specify)': 'Other',
    'myanmar, {burma}': 'Myanmar',
    'myanmar': 'Myanmar',
    'libyan arab jamahiriya': 'Libya',
    'libya': 'Libya',
    'laos': 'Laos',
    "lao people's democratic republic": 'Laos',
    'korea south': 'South Korea',
    'republic of korea': 'South Korea',
    'south korea': 'South Korea',
    'korea north': 'North Korea',
    'north korea': 'North Korea',
    'ireland': 'Ireland',
    'ireland {republic}': 'Ireland',
    'hong kong (s.a.r.)': 'Hong Kong',
    'hong kong': 'Hong Kong',
    'guinea-bissau': 'Guinea',
    'guinea': 'Guinea',
    'bosnia herzegovina': 'Bosnia and Herzegovina',
    'bosnia and herzegovina': 'Bosnia and Herzegovina',
    'bosnia-herzegovina': 'Bosnia and Herzegovina',
    'vatican city state': 'Vatican',
    'vatican': 'Vatican',
    'viet nam': 'Vietnam',
    'vietnam': 'Vietnam'
}

# %%
# Standardize and map 'country' values in combined_consolidated_df
def standardize_country(val):
    # Preserve NaN/None as-is
    if pd.isna(val):
        return val
    # Normalize to lower-case stripped string for lookup
    key = str(val).strip().lower()
    # Return mapped canonical name if available, otherwise return original (preserve original casing)
    return country_map.get(key, val)

# Apply mapping (overwrites 'country' column if present)
if 'country' in combined_consolidated_df.columns:
    combined_consolidated_df['country'] = combined_consolidated_df['country'].apply(standardize_country)
    print("Mapped 'country' values using country_map. Sample counts:")
    # Print the top values (including NaN) to give a quick check
    print(combined_consolidated_df['country'].value_counts(dropna=False).head(20))
else:
    print("Warning: 'country' column not found in combined_consolidated_df")
# Out:
# Mapped 'country' values using country_map. Sample counts:
# country
# United States         30699
# India                 14533
# Germany               10309
# NaN                   10042
# United Kingdom         9382
# Canada                 5367
# France                 4451
# Brazil                 3344
# Poland                 3312
# Netherlands            3184
# Australia              3017
# Italy                  2742
# Spain                  2682
# Russian Federation     2564
# Sweden                 2163
# Ukraine                2019
# Switzerland            1672
# Israel                 1467
# Austria                1443
# Turkey                 1429
# Name: count, dtype: int64

# %%
# Remove columns from combined_consolidated_df with >70% null values
threshold = 0.7
null_pct = combined_consolidated_df.isna().mean()
cols_to_drop = null_pct[null_pct > threshold].index.tolist()
print(f"Dropping {len(cols_to_drop)} columns with >70% null values:")
print(cols_to_drop)
combined_consolidated_df.drop(columns=cols_to_drop, inplace=True)
print(f"New shape of combined_consolidated_df: {combined_consolidated_df.shape}")
# Out:
# Dropping 639 columns with >70% null values:
# ['expectedsalary', 'aitoolinterested in using', 'truefalse_1', 'sotagshaveworkedwith', 'toolstechwanttoworkwith', 'officestacksyncadmired', 'newcollabtoolsdesirenextyear', 'knowledge_7', 'ainextneither different nor similar', 'sexualorientation', 'adspriorities5', 'webframechoice', 'impsyn', 'embeddedhaveworkedwith', 'databasechoice', 'agree_legacy', 'officestacksyncwanttoworkwith', 'buynewtool', 'stackoverflowjobsrecommend', 'learncodeai', 'stackoverflowmetachat', 'checkincode', 'adspriorities1', 'influenceworkstation', 'assessjoboffice', 'newjobhunt', 'jobemailpriorities4', 'webframewantentry', 'which languages are you proficient in? (java)', 'annoyingui', 'stackoverflowjoblisting', 'aidangerous', 'commit_frequency', 'agree_loveboss', 'stackoverflowbetter', 'do you have a stack overflow careers 2.0 profile?', 'wantworkplatform', 'equipmentsatisfiedrw', 'wantworklanguage', 'assessbenefits7', 'welcomechange', 'difficultcommunication', 'techlist', 'buildvsbuy', 'techoppose_5', 'rep_range', 'ainextno change', 'excoderskills', 'assessbenefits3', 'learncodeonline', 'frequency_2', 'importantbenefits', 'open_to_new_job', 'salary_range', 'inthezone', 'why_learn_new_tech', 'newrole', 'influencerecruitment', 'assessjob9', 'webframeadmired', 'stackoverflowsatisfaction', 'stackoverflowjobs', 'lastint', 'newdevopsimpt', 'frequency_3', 'sotagshaveentry', 'aichallenges', 'aitoolcurrently mostly ai', 'assessjobprojects', 'aimodelsadmired', 'languageadmired', 'jobsatpoints_15_text', 'platformhaveentry', 'student', 'jobsatpoints_14', 'aiagentknowwrite', 'how likely is it that a recommendation you make will be acted upon?', 'ethicsresponsible', 'if your company has a native mobile app, what platforms do you support? (iphone)', 'aihuman', 'influencecommunication', 'important_sameend', 'stackoverflowanswer', 'learncodechoose', 'important_promotion', 'select all that apply (current lang & tech: android)', 'assessjob4', 'aiagentorchwrite', 'agree_alcohol', 'what advertisers do you remember seeing on stack overflow? (open-ended response)', "you answered you don't have a careers profile, can you elaborate why?", 'dogs_vs_cats', 'officestackwantentry', 'select all that apply (why try stack overflow careers: no spam)', 'so_actions_7', 'stackoverflowhelpful', 'problemsolving', 'devenvsadmired', 'aisearchdevadmired', 'aiagentobswrite', 'aiagentimpactneutral', 'in an average week, how do you spend your time? (developing new features)', 'programming_ability', 'learnedhiring', 'q120', 'sojobs', 'sofriction', 'friendsdevelopers', 'university', 'stackoverflowadsrelevant', 'buildingthings', 'stackoverflowmoderation', 'onboarding', 'adspriorities3', 'waketime', 'learncodecoursescert', 'select up to 3 (how can companies improve interview process: more live code)', 'languageswantentry', 'assessjobcommute', 'stackoverflowhasaccount', 'jobcontactpriorities1', 'jobemailpriorities1', 'collaborateremote', 'assessjobtech', 'haveworkedlanguage', 'important_wfh', 'aitoolcurrently partially ai', 'stackoverflowdevices', 'if you make a software product, how does your company make money? (you can choose more than one) (advertising)', 'purchasewhat', 'what types of purchases are you involved in? (hardware)', 'understandcomputers', 'truefalse_3', 'influencetechstack', 'aiinteresting', 'tech_want', 'assessjob2', 'devenvwantentry', 'majorundergrad', 'what type of project are you developing?', 'nondevelopertype', 'salary', 'newothercomms', 'betterlife', 'so_actions_10', 'misctechadmired', 'interestedanswers', 'adspriorities4', 'clickykeys', 'programhobby', 'jobsatpoints_7', 'adspriorities6', 'aiexplain', 'otherpeoplescode', 'adblocker', 'jobsatpoints_10', 'knowledge_5', 'ethicsreport', 'blockchainis', 'where do you work remotely most of the time?', 'importanthiringcompanies', 'boringdetails', 'adblockerdisable', 'adblockerreasons', 'what is your involvement in purchasing products or services for the company you work for? (you can choose more than one) (i can recommend or request  ...
# New shape of combined_consolidated_df: (154521, 38)

# %%
# Detailed column stats sorted by non-null count (descending)
col_stats = pd.DataFrame({
    'non_null_count': combined_consolidated_df.notna().sum(),
    'null_count': combined_consolidated_df.isna().sum(),
    'unique_count': combined_consolidated_df.nunique(dropna=True)
}).sort_values('non_null_count', ascending=False)

# %%
# Add percent of total rows for nulls (rounded to 2 decimals)
total_rows = combined_consolidated_df.shape[0]
col_stats['null_pct'] = (col_stats['null_count'] / total_rows * 100).round(2)

# %%
col_stats
# Out:
#                               non_null_count  null_count  unique_count  \
# surveyyear                            154521           0            15
# country                               144479       10042           229
# employment                            140846       13675           151
# education                             137278       17243           554
# years_coding                          128780       25741           156
# age                                   125492       29029           121
# programming_experience                116643       37878           126
# developer_type                        113405       41116         14745
# company_size                          108436       46085            38
# survey_easy                           107361       47160            18
# mainbranch                            102584       51937             9
# soaccount                              95864       58657             4
# sovisitfreq                            95671       58850             8
# socomm                                 95425       59096             6
# currency                               92126       62395           301
# gender                                 90288       64233            50
# sopartfreq                             78453       76068             8
# remote                                 76487       78034            22
# newsosites                             72161       82360           100
# responseid                             72091       82430         42533
# learning                               67363       87158          3180
# languagehaveworkedwith                 66353       88168         27756
# operating_sys                          65228       89293            18
# languagewanttoworkwith                 61468       93053         25635
# respondent                             60718       93803         47730
# newcollabtoolshaveworkedwith           59030       95491         15531
# hobby                                  58530       95991             8
# trans                                  56849       97672             4
# databasehaveworkedwith                 55898       98623          8418
# ethnicity                              54384      100137           755
# newcollabtoolswanttoworkwith           53188      101333         10150
# sexuality                              52130      102391            38
# toolstechhaveworkedwith                51599      102922         13512
# webframehaveworkedwith                 50199      104322         12271
# opsyspersonal use                      49431      105090          2522
# dev_environment                        48894      105627          7735
# platformhaveworkedwith                 46681      107840          8024
# databasewanttoworkwith                 46496      108025          8066
#
#                               null_pct
# surveyyear                        0.00
# country                           6.50
# employment                        8.85
# education                        11.16
# years_coding                     16.66
# age                              18.79
# programming_experience           24.51
# developer_type                   26.61
# company_size                     29.82
# survey_easy                      30.52
# mainbranch                       33.61
# soaccount                        37.96
# sovisitfreq                      38.09
# socomm                           38.24
# currency                         40.38
# gender                           41.57
# sopartfreq                       49.23
# remote                           50.50
# newsosites                       53.30
# responseid                       53.35
# learning                         56.41
# languagehaveworkedwith           57.06
# operating_sys                    57.79
# languagewanttoworkwith           60.22
# respondent                       60.71
# newcollabtoolshaveworkedwith     61.80
# hobby                            62.12
# trans                            63.21
# databasehaveworkedwith           63.82
# ethnicity                        64.80
# newcollabtoolswanttoworkwith     65.58
# sexuality                        66.26
# toolstechhaveworkedwith          66.61
# webframehaveworkedwith           67.51
# opsyspersonal use                68.01
# dev_environment                  68.36
# platformhaveworkedwith           69.79
# databasewanttoworkwith           69.91

# %% [markdown]
# ### Consolidate values for 'gender'

# %%
combined_consolidated_df['gender'].value_counts()
# Out:
# gender
# Man                                                                                   52647
# Male                                                                                  29939
# Woman                                                                                  3561
# Female                                                                                 1947
# Non-binary, genderqueer, or gender non-conforming                                       544
# Prefer not to say                                                                       507
# Prefer not to disclose                                                                  176
# Man;Non-binary, genderqueer, or gender non-conforming                                   136
# Woman;Non-binary, genderqueer, or gender non-conforming                                 135
# Or, in your own words:                                                                  133
# Other                                                                                   111
# Man;Or, in your own words:                                                               96
# Woman;Man                                                                                35
# Transgender                                                                              31
# Female;Transgender                                                                       30
# Male; Other                                                                              28
# Gender non-conforming                                                                    27
# Male;Non-binary, genderqueer, or gender non-conforming                                   26
# Woman;Man;Non-binary, genderqueer, or gender non-conforming                              24
# Male; Gender non-conforming                                                              16
# Female;Male                                                                              12
# Man;Woman;Non-binary, genderqueer, or gender non-conforming                              12
# Transgender;Non-binary, genderqueer, or gender non-conforming                            11
# Female;Male;Transgender;Non-binary, genderqueer, or gender non-conforming                10
# Female; Transgender                                                                      10
# Female;Non-binary, genderqueer, or gender non-conforming                                  9
# Man;Woman                                                                                 9
# Female;Transgender;Non-binary, genderqueer, or gender non-conforming                      8
# Female; Gender non-conforming                                                             7
# Non-binary, genderqueer, or gender non-conforming;Or, in your own words:                  6
# Man;Or, in your own words:;Woman;Non-binary, genderqueer, or gender non-conforming        5
# Transgender; Gender non-conforming                                                        5
# Man;Or, in your own words:;Non-binary, genderqueer, or gender non-conforming              4
# Male;Transgender                                                                          4
# Woman;Or, in your own words:                                                              3
# Male; Female                                                                              3
# Male; Transgender                                                                         3
# Male; Female; Transgender; Gender non-conforming; Other                                   3
# Man;Non-binary, genderqueer, or gender non-conforming;Or, in your own words:              2
# Or, in your own words:;Woman                                                              2
# Female;Male;Transgender                                                                   2
# Male; Gender non-conforming; Other                                                        1
# Male; Female; Gender non-conforming                                                       1
# Male; Female; Transgender                                                                 1
# Male; Female; Transgender; Gender non-conforming                                          1
# Male; Female; Other                                                                       1
# Woman;Non-binary, genderqueer, or gender non-conforming;Or, in your own words:            1
# Male; Transgender; Gender non-conforming                                                  1
# Or, in your own words:;Non-binary, genderqueer, or gender non-conforming                  1
# Or, in your own words:;Woman;Non-binary, genderqueer, or gender non-conforming            1
# Name: count, dtype: int64

# %%
# Keep the portion before the first semicolon in df_final['gender'] and convert to lower case
def keep_before_semicolon(val):
    if pd.isna(val):
        return val
    if isinstance(val, str):
        return val.split(';', 1)[0].strip()
    return val

combined_consolidated_df['gender_raw'] = combined_consolidated_df['gender'].apply(keep_before_semicolon)
combined_consolidated_df['gender_raw'] = combined_consolidated_df['gender_raw'].str.lower()

# Quick check
print(combined_consolidated_df['gender_raw'].value_counts(dropna=False).head(20))
# Out:
# gender_raw
# NaN                                                  64233
# man                                                  52911
# male                                                 30028
# woman                                                 3759
# female                                                2035
# non-binary, genderqueer, or gender non-conforming      550
# prefer not to say                                      507
# prefer not to disclose                                 176
# or, in your own words:                                 137
# other                                                  111
# transgender                                             47
# gender non-conforming                                   27
# Name: count, dtype: int64

# %%
# Exact mapping for common raw values (keys are lowercased/stripped)
exact_map = {
    'nan': None,  # placeholder, handled below
    'man': 'man',
    'male': 'man',
    'woman': 'woman',
    'female': 'woman',
    'non-binary, genderqueer, or gender non-conforming': 'non-binary',
    'gender non-conforming': 'non-binary',
    'transgender': 'transgender',
    'prefer not to say': 'prefer_not_to_say',
    'prefer not to disclose': 'prefer_not_to_say',
    'or, in your own words:': 'other',
    'other': 'other'
}

def apply_exact_map(val):
    # Preserve NaN as unknown
    if pd.isna(val):
        return 'unknown'
    key = str(val).strip().lower()
    return exact_map.get(key, None)  # None if no exact mapping

# Create exact mapping column
combined_consolidated_df['gender_update'] = combined_consolidated_df['gender_raw'].apply(apply_exact_map)

# Quick summary counts
print("Exact-mapped counts:")
print(combined_consolidated_df['gender_update'].value_counts(dropna=False))
# Out:
# Exact-mapped counts:
# gender_update
# man                  82939
# unknown              64233
# woman                 5794
# prefer_not_to_say      683
# non-binary             577
# other                  248
# transgender             47
# Name: count, dtype: int64

# %%
# extract surveyyear and country and make a counts matrix
cols = ['surveyyear', 'gender_update']
df_sub = combined_consolidated_df[cols].copy()

# drop rows missing either value
#df_sub = df_sub.dropna(subset=['surveyyear', 'country'])

# ensure surveyyear is treated consistently (optional)
# df_sub['surveyyear'] = df_sub['surveyyear'].astype(str)

# Create matrix: rows = surveyyear, cols = country, values = counts
matrix_df = pd.crosstab(df_sub['surveyyear'], df_sub['gender_update']).sort_index()

# display and optionally save
display(matrix_df)
matrix_df.to_csv('surveyyear_by_gender_mapped_final_matrix.csv')
# Out:
# gender_update    man  non-binary  other  prefer_not_to_say  transgender  \
# surveyyear
# 2011               0           0      0                  0            0
# 2012               0           0      0                  0            0
# 2013               0           0      0                  0            0
# 2014            1364           0      0                 23            0
# 2015               0           0      0                  0            0
# 2016           10291           0     58                153            0
# 2017            6357          27     53                  0           17
# 2018           12016          53      0                  0           30
# 2019           15598         115      0                  0            0
# 2020            9219          72      0                  0            0
# 2021           15098         140     80                282            0
# 2022           12996         170     57                225            0
# 2023               0           0      0                  0            0
# 2024               0           0      0                  0            0
# 2025               0           0      0                  0            0
#
# gender_update  unknown  woman
# surveyyear
# 2011               563      0
# 2012              1249      0
# 2013              1948      0
# 2014                74     68
# 2015              5217      0
# 2016                85    619
# 2017              3294    530
# 2018              6854    818
# 2019               695   1369
# 2020              2771    830
# 2021               212    876
# 2022               522    684
# 2023             17837      0
# 2024             13087      0
# 2025              9825      0

# %%
# Clean up gender columns: drop old versions and rename gender_update to gender
columns_to_drop = ['gender', 'gender_raw', 'gender_mapped_exact']
existing_cols = [col for col in columns_to_drop if col in combined_consolidated_df.columns]

if existing_cols:
    combined_consolidated_df = combined_consolidated_df.drop(columns=existing_cols)
    print(f"Dropped columns: {existing_cols}")

if 'gender_update' in combined_consolidated_df.columns:
    combined_consolidated_df = combined_consolidated_df.rename(columns={'gender_update': 'gender'})
    print("Renamed 'gender_update' to 'gender'")

print(f"Final shape: {combined_consolidated_df.shape}")

# %% [markdown]
# ### years_coding

# %%
def clean_years_coding(val):
    """
    Clean years_coding values:
    - Convert ranges (e.g., '9-11 years') to median
    - Extract single numeric values
    - Drop values >100
    - Return NaN for non-numeric values
    """
    if pd.isna(val):
        return None
    
    val_str = str(val).strip().lower()
    
    # Extract numbers from ranges (e.g., "9-11 years" or "9-11")
    range_match = re.search(r'(\d+)\s*[-–—to]\s*(\d+)', val_str)
    if range_match:
        start = float(range_match.group(1))
        end = float(range_match.group(2))
        median_val = (start + end) / 2
        return median_val if median_val <= 100 else None
    
    # Extract single number (e.g., "5 years" or "5")
    single_match = re.search(r'(\d+(?:\.\d+)?)', val_str)
    if single_match:
        num_val = float(single_match.group(1))
        return num_val if num_val <= 100 else None
    
    # No numeric value found
    return None

# Apply cleaning function
combined_consolidated_df['years_coding_clean'] = combined_consolidated_df['years_coding'].apply(clean_years_coding)

# Show comparison
print(f"Min: {combined_consolidated_df['years_coding_clean'].min()}")
print(f"Max: {combined_consolidated_df['years_coding_clean'].max()}")
print(f"Mean: {combined_consolidated_df['years_coding_clean'].mean():.2f}")
print(f"Median: {combined_consolidated_df['years_coding_clean'].median()}")
# Out:
# Min: 1.0
# Max: 100.0
# Mean: 12.04
# Median: 10.0

# %%
# Drop the old years_coding column and rename years_coding_clean
combined_consolidated_df = combined_consolidated_df.drop(columns=['years_coding'])
combined_consolidated_df = combined_consolidated_df.rename(columns={'years_coding_clean': 'years_coding'})

print(f"Updated columns. New shape: {combined_consolidated_df.shape}")
print(f"\nYears coding column summary:")
print(f"  Non-null count: {combined_consolidated_df['years_coding'].notna().sum()}")
print(f"  Min: {combined_consolidated_df['years_coding'].min()}")
print(f"  Max: {combined_consolidated_df['years_coding'].max()}")
print(f"  Mean: {combined_consolidated_df['years_coding'].mean():.2f}")
# Out:
# Updated columns. New shape: (151564, 47)
#
# Years coding column summary:
#   Non-null count: 125509
#   Min: 1.0
#   Max: 100.0
#   Mean: 12.04

# %% [markdown]
# ### Consolidate Education

# %%
def standardize_education(val):
    """
    Standardize education values:
    - bachelor's -> bachelors
    - master's -> masters
    - on-the-job training variations -> on_the_job_training
    """
    if pd.isna(val):
        return val
    
    val_str = str(val).strip().lower()
    
    # Check for bachelor's variations
    if "bachelor" in val_str or "b.a" in val_str or "b.s." in val_str or "b.s" in val_str:
        return "bachelors"
    
    # Check for master's variations
    if "master" in val_str:
        return "masters"
    
    # Check for on-the-job training variations
    if "self-taught" in val_str or "online class" in val_str or "self taught" in val_str:
        return "self-taught"

    # Check for on-the-job training variations
    if "on-the-job" in val_str or "on the job" in val_str or "job training" in val_str:
        return "on the job training"

    # Check for on-the-job training variations
    if "some college" in val_str:
        return "some college"
    
    # Check for on-the-job training variations
    if "primary" in val_str or "secondary" in val_str:
        return "less than college"

    # Check for on-the-job training variations
    if "associate" in val_str:
        return "associate degree"
    
    # Check for on-the-job training variations
    if "md" in val_str or "doctor" in val_str or "phd" in val_str or "doctoral" in val_str or "jd" in val_str:
        return "doctoral degree"
    
    # Check for on-the-job training variations
    if "full-time, intensive" in val_str or "part-time program" in val_str or "industry certification" in val_str or "mentorship program" in val_str or "something else" in val_str or "other" in val_str:
        return "other program"
    
    # Check for on-the-job training variations
    if "i prefer not to say" in val_str or "i prefer not to answer" in val_str:
        return "i prefer not to say"
    
    # Check for on-the-job training variations
    if "i never completed any formal education" in val_str:
        return "none"
    
    # Return original value if no match
    return val

# Apply standardization to education column
combined_consolidated_df['education_clean'] = combined_consolidated_df['education'].apply(standardize_education)

# Create a pivot-style DataFrame from education value counts
education_counts = combined_consolidated_df['education_clean'].value_counts().reset_index()
education_counts.columns = ['Education Level', 'Count']

# Add percentage column
total = education_counts['Count'].sum()
education_counts['Percentage'] = (education_counts['Count'] / total * 100).round(2)

# Display the formatted table
display(education_counts)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[34], line 61
#      58     return val
#      60 # Apply standardization to education column
# ---> 61 combined_consolidated_df['education_clean'] = combined_consolidated_df['education'].apply(standardize_education)
#      63 # Create a pivot-style DataFrame from education value counts
#      64 education_counts = combined_consolidated_df['education_clean'].value_counts().reset_index()
#
# NameError: name 'combined_consolidated_df' is not defined

# %%
# Drop the old education column and rename education_clean to education
combined_consolidated_df = combined_consolidated_df.drop(columns=['education'])
combined_consolidated_df = combined_consolidated_df.rename(columns={'education_clean': 'education'})

print(f"Updated columns. New shape: {combined_consolidated_df.shape}")
print(f"\nEducation column summary:")
print(f"  Non-null count: {combined_consolidated_df['education'].notna().sum()}")
print(f"\nValue counts:")
print(combined_consolidated_df['education'].value_counts())
# Out:
# Updated columns. New shape: (151564, 46)
#
# Education column summary:
#   Non-null count: 137278
#
# Value counts:
# education
# bachelors              61140
# masters                30519
# less than college      15207
# some college           15080
# doctoral degree         5710
# associate degree        3675
# self-taught             3672
# other program           1271
# none                     432
# i prefer not to say      243
# on the job training      192
# Professional degree      137
# Name: count, dtype: int64

# %% [markdown]
# ### Consolidate age

# %%
combined_consolidated_df['age'].value_counts()
# Out:
# age
# 25-34 years old      26873
# 18-24 years old      15779
# 35-44 years old      15633
# 25 - 34 years old     6420
# 45-54 years old       6242
#                      ...
# 21.5                     1
# 3.0                      1
# 37.5                     1
# 16.9                     1
# 76.0                     1
# Name: count, Length: 191, dtype: int64

# %%
def clean_age(val):
    """
    Clean age values:
    - Convert ranges (e.g., '25-34 years old') to median
    - Extract single numeric values
    - Handle special cases like 'Under 18' or '65 or older'
    - Force any values under 12 to be 12
    - Return NaN for non-numeric values
    """
    if pd.isna(val):
        return None
    
    val_str = str(val).strip().lower()
    result = None
    
    # Handle special cases
    if 'under' in val_str or 'less than' in val_str:
        # Extract the number after 'under' or 'less than'
        match = re.search(r'(\d+)', val_str)
        if match:
            result = float(match.group(1)) - 1  # e.g., "Under 18" -> 17
    
    elif 'older' in val_str or 'over' in val_str or 'above' in val_str:
        # Extract the number before 'older', 'over', or 'above'
        match = re.search(r'(\d+)', val_str)
        if match:
            result = float(match.group(1))  # e.g., "65 or older" -> 65
    
    # Extract numbers from ranges (e.g., "25-34" or "25 - 34")
    elif (range_match := re.search(r'(\d+)\s*[-–—to]\s*(\d+)', val_str)):
        start = float(range_match.group(1))
        end = float(range_match.group(2))
        result = (start + end) / 2
    
    # Extract single number (e.g., "25 years old" or "25")
    elif (single_match := re.search(r'(\d+)', val_str)):
        result = float(single_match.group(1))
    
    # Force minimum age of 12
    if result is not None and result < 12:
        result = 12
    
    return result

# Apply cleaning function to combined_consolidated_df
combined_consolidated_df['age_clean'] = combined_consolidated_df['age'].apply(clean_age)

# Show statistics
print(f"Age Statistics:")
print(f"Min: {combined_consolidated_df['age_clean'].min()}")
print(f"Max: {combined_consolidated_df['age_clean'].max()}")
print(f"Mean: {combined_consolidated_df['age_clean'].mean():.2f}")
print(f"Median: {combined_consolidated_df['age_clean'].median()}")
print(f"\nValue counts:")
print(combined_consolidated_df['age_clean'].value_counts().sort_index().head(50))
# Out:
# Age Statistics:
# Min: 12.0
# Max: 99.0
# Mean: 31.65
# Median: 29.5
#
# Value counts:
# age_clean
# 12.0       23
# 13.0       44
# 14.0       62
# 15.0      132
# 16.0      174
# 17.0     3748
# 18.0      388
# 19.0      484
# 20.0     1533
# 21.0    19600
# 22.0     3985
# 23.0     1244
# 24.0     1389
# 25.0     1451
# 26.0     1383
# 27.0     4740
# 28.0     1332
# 29.0     1258
# 29.5    33293
# 30.0     1292
# 31.0      954
# 32.0     3426
# 33.0      893
# 34.0      756
# 35.0      787
# 36.0      583
# 37.0     2154
# 38.0      569
# 39.0      416
# 39.5    17957
# 40.0      451
# 41.0      296
# 42.0      362
# 43.0      288
# 44.0      231
# 44.5     1019
# 45.0      639
# 46.0      191
# 47.0      163
# 48.0      156
# 49.0      143
# 49.5     6942
# 50.0      141
# 51.0      103
# 52.0      103
# 53.0       90
# 54.0       82
# 54.5      307
# 55.0       78
# 55.5       93
# Name: count, dtype: int64

# %%
# Drop the old age column and rename age_clean to age
combined_consolidated_df = combined_consolidated_df.drop(columns=['age'])
combined_consolidated_df = combined_consolidated_df.rename(columns={'age_clean': 'age'})

print(f"Updated columns. New shape: {combined_consolidated_df.shape}")
print(f"\nAge column summary:")
print(f"  Non-null count: {combined_consolidated_df['age'].notna().sum()}")
print(f"  Min: {combined_consolidated_df['age'].min()}")
print(f"  Max: {combined_consolidated_df['age'].max()}")
print(f"  Mean: {combined_consolidated_df['age'].mean():.2f}")
print(f"  Median: {combined_consolidated_df['age'].median()}")

# %% [markdown]
# ### Consolidate Developer Type

# %%
df['developer_type'].value_counts()
# Out:
# developer_type
# Developer, full-stack                                                                                                                                       17062
# Developer, back-end                                                                                                                                          9755
# Developer, front-end                                                                                                                                         3772
# Student                                                                                                                                                      3292
# Developer, mobile                                                                                                                                            2539
#                                                                                                                                                             ...
# Developer, back-end;Developer, desktop or enterprise applications;Developer, front-end;Engineer, site reliability                                               1
# Developer, mobile;Educator;Product manager                                                                                                                      1
# Database administrator;Developer, back-end;Developer, embedded applications or devices;DevOps specialist;Engineer, site reliability;System administrator        1
# Developer, QA or test;Product manager;Student                                                                                                                   1
# Data or business analyst;Developer, back-end;Developer, desktop or enterprise applications;Developer, front-end;Educator;Engineering manager                    1
# Name: count, Length: 14745, dtype: int64

# %%
# Keep only the portion before the first semicolon in developer_type and standardize values
def clean_developer_type(val):
    """
    Extract the first developer type before semicolon and standardize common variations.
    E.g., 'Full-stack developer;Back-end developer' -> 'full-stack developer'
    E.g., 'Developer, full-stack' -> 'full-stack developer'
    """
    if pd.isna(val):
        return val
    if isinstance(val, str):
        # Take only the first value before semicolon
        first_type = val.split(';', 1)[0].strip().lower()
        
        # Standardize full-stack variations
        if 'full-stack' in first_type or 'full stack' in first_type:
            return 'full-stack developer'

        if 'front-end' in first_type or 'front end' in first_type:
            return 'front-end developer'

        if 'back-end' in first_type or 'back end' in first_type:
            return 'back-end developer'
        
        if 'mobile' in first_type or 'architect' in first_type or 'graphics' in first_type or 'devops' in first_type or 'web' in first_type or 'developer' in first_type:
            return 'other developer'

        if 'data scien' in first_type or 'machine learning' in first_type or 'ML' in first_type or 'DS' in first_type :
            return 'data scientist'

        if 'data' in first_type :
            return 'data role'

        if 'engineer' in first_type :
            return 'engineering role'
        
        if 'research' in first_type or 'scientist' in first_type:
            return 'research role'
        
        if 'systems administrator' in first_type or 'system administrator' in first_type:
            return 'systems administrator'
        
        if 'executive' in first_type :
            return 'executive'
        
        if 'design' in first_type :
            return 'design'
        
        if 'security' in first_type or 'blockchain' in first_type:
            return 'cyber security'

        if 'product manager' in first_type or 'project manager' in first_type:
            return 'product/project manager'
        
        if 'other' in first_type :
            return 'other role'

        # Return the cleaned value
        return first_type
    return val

# Apply cleaning to df (which should be combined_consolidated_df based on context)
combined_consolidated_df['developer_type_clean'] = combined_consolidated_df['developer_type'].apply(clean_developer_type)

# Show value counts
print("Developer Type (cleaned) - Top 20:")
print(combined_consolidated_df['developer_type_clean'].value_counts().head(50))
# Out:
# Developer Type (cleaned) - Top 20:
# developer_type_clean
# back-end developer                 29209
# full-stack developer               23102
# other developer                    22286
# front-end developer                10418
# data role                           6844
# research role                       3964
# student                             3488
# data scientist                      3362
# engineering role                    2701
# other role                          2573
# design                              2308
# executive                           1011
# product/project manager              646
# systems administrator                635
# cyber security                       358
# educator                             290
# marketing or sales professional      121
# retired                               89
# Name: count, dtype: int64

# %% [markdown]
# ### Export df_final

# %%
df_final = combined_consolidated_df.copy()

# %%
df_final.to_csv('df_final.csv')

# %%
#df = pd.read_csv('df_final.csv')
