# %%
import os
import time
import requests
import pandas as pd
from zipfile import ZipFile
from io import BytesIO
import warnings
warnings.filterwarnings('ignore')

# Configuration
MAX_RETRIES = 10
RETRY_DELAY = 30  # seconds
SURVEY_YEARS = list(range(2011, 2026))  # 2011 to 2025

print("Starting Stack Overflow Survey Data Download...")
print(f"Years to download: {min(SURVEY_YEARS)} to {max(SURVEY_YEARS)}")
print(f"Retry configuration: {MAX_RETRIES} max attempts, {RETRY_DELAY}s delay")
print(f"URL pattern: https://survey.stackoverflow.co/datasets/stack-overflow-developer-survey-{{year}}.zip\n")
# Out:
# Starting Stack Overflow Survey Data Download...
# Years to download: 2011 to 2025
# Retry configuration: 10 max attempts, 30s delay
# URL pattern: https://survey.stackoverflow.co/datasets/stack-overflow-developer-survey-{year}.zip

# %%
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)
pd.set_option('display.max_colwidth', None)

# %%
def get_survey_urls(year):
    """
    Generate URL for a given survey year.
    All years use the same datasets ZIP pattern.
    """
    # All years use the same URL pattern
    url = f"https://survey.stackoverflow.co/datasets/stack-overflow-developer-survey-{year}.zip"
    return [url]

def fix_headers_for_older_years(df, year):
    """
    Fix headers for years 2011-2016 where the first two rows are headers.
    If the second row says "Response", use only the first row value.
    Otherwise, combine the first two rows.
    """
    if year >= 2011 and year <= 2015:
        if df.shape[0] < 2:
            print(f"  Warning: Not enough rows to fix headers for year {year}")
            return df
        
        # Get the first two rows
        first_row = df.iloc[0].astype(str)
        second_row = df.iloc[1].astype(str)
        
        # Create new column names
        new_columns = []
        for i, (first_val, second_val) in enumerate(zip(first_row, second_row)):
            first_val = first_val.strip()
            second_val = second_val.strip()
            
            # If second row is "Response", just use first row value
            if second_val == "Response":
                new_columns.append(first_val)
            else:
                # If both are the same or second is empty, use first
                if first_val == second_val or second_val == "":
                    new_columns.append(first_val)
                else:
                    # Combine both values - first value as primary
                    new_columns.append(f"{first_val} ({second_val})")
        
        # Set new column names
        df.columns = new_columns
        
        # Drop the first two rows (header rows)
        df = df.iloc[2:].reset_index(drop=True)
        
        print(f"  ✓ Fixed headers for year {year} (combined first two rows, removed 2 header rows)")
    
    return df

def download_file(url, year):
    """
    Download a file (single attempt, no retries).
    Returns the content if successful, None otherwise.
    Handles both CSV and ZIP files.
    """
    try:
        print(f"  Trying URL: {url}")
        response = requests.get(url, timeout=60, stream=True)
        response.raise_for_status()
        
        # Check content type
        content_type = response.headers.get('content-type', '').lower()
        
        # Reject HTML responses (likely error pages)
        if 'html' in content_type and response.status_code == 200:
            # Might be an error page, try next URL pattern
            print(f"  Warning: Received HTML instead of data file, may be wrong URL")
            return None
        
        content = response.content
        # Basic validation: check if content looks reasonable
        if len(content) < 100:
            print(f"  Warning: File too small, may be error page")
            return None
        
        # Check if it's a ZIP file by magic bytes
        is_zip = content[:2] == b'PK'  # ZIP files start with PK
        if is_zip:
            print(f"  ✓ Successfully downloaded {year} as ZIP ({len(content):,} bytes)")
        else:
            print(f"  ✓ Successfully downloaded {year} ({len(content):,} bytes)")
        
        return content
        
    except requests.exceptions.RequestException as e:
        print(f"  ✗ Download error: {str(e)}")
        return None

# %%
def validate_url(url):
    """
    Validate if a URL exists without downloading the full content.
    Returns True if the URL is valid and returns proper headers.
    """
    try:
        # Only get headers to check existence
        response = requests.head(url, timeout=10)
        return response.status_code == 200 and 'content-length' in response.headers
    except requests.exceptions.RequestException:
        return False

# %%
def download_and_extract_year(year, max_retries=MAX_RETRIES, delay=RETRY_DELAY, sample_size=None):
    """
    Download and extract survey data for a given year with retry logic.
    Tries multiple URL patterns and handles both CSV and ZIP files.
    Wraps the entire process in retry logic to catch any runtime errors.
    
    Args:
        year: The survey year to download
        max_retries: Maximum number of retry attempts
        delay: Delay between retries in seconds
        sample_size: If provided, only read this many rows from the CSV (for testing/development)
    
    Returns:
        DataFrame if successful, None otherwise.
    """
    print(f"\n{'='*60}")
    print(f"Processing year {year}")
    print(f"{'='*60}")
    
    urls = get_survey_urls(year)
    
    # Outer retry loop for entire download/extract process
    # This will retry the entire process up to max_retries times if a RuntimeError occurs
    for retry_attempt in range(max_retries):
        try:
            # Try each URL pattern
            for url in urls:
                content = download_file(url, year)
                
                if content is None:
                    continue
                
                # Check if content is a ZIP file by magic bytes (ZIP files start with 'PK')
                is_zip = content[:2] == b'PK'
                
                if is_zip:
                    # Try to parse as ZIP
                    try:
                        with ZipFile(BytesIO(content)) as zip_file:
                            # Look for CSV files in the ZIP (exclude macOS metadata)
                            csv_files = [f for f in zip_file.namelist() 
                                       if f.endswith('.csv') and not f.startswith('__MACOSX/')]
                            if csv_files:
                                # Use the first CSV file found
                                csv_file = csv_files[0]
                                print(f"  Found CSV file in ZIP: {csv_file}")
                                with zip_file.open(csv_file) as f:
                                    # For years 2011-2016, read without header to fix manually
                                    read_kwargs = {
                                        'low_memory': False, 
                                        'on_bad_lines': 'skip',
                                        'nrows': sample_size  # Add sample size parameter
                                    }
                                    if year >= 2011 and year <= 2015:
                                        read_kwargs['header'] = None
                                    
                                    try:
                                        df = pd.read_csv(f, encoding='utf-8', **read_kwargs)
                                        print(f"  ✓ Successfully loaded {year} from ZIP ({df.shape[0]:,} rows, {df.shape[1]:,} cols)")
                                        # Fix headers for older years
                                        df = fix_headers_for_older_years(df, year)
                                        return df
                                    except UnicodeDecodeError:
                                        f.seek(0)
                                        df = pd.read_csv(f, encoding='latin-1', **read_kwargs)
                                        print(f"  ✓ Successfully loaded {year} from ZIP with latin-1 encoding ({df.shape[0]:,} rows, {df.shape[1]:,} cols)")
                                        # Fix headers for older years
                                        df = fix_headers_for_older_years(df, year)
                                        return df
                            else:
                                print(f"  No CSV files found in ZIP archive")
                    except Exception as e:
                        print(f"  ZIP parsing failed: {str(e)}")
                        continue
                else:
                    # Try to parse as CSV directly
                    # For years 2011-2016, read without header to fix manually
                    read_kwargs = {
                        'low_memory': False, 
                        'on_bad_lines': 'skip',
                        'nrows': sample_size  # Add sample size parameter
                    }
                    if year >= 2011 and year <= 2016:
                        read_kwargs['header'] = None
                    
                    try:
                        df = pd.read_csv(BytesIO(content), encoding='utf-8', **read_kwargs)
                        print(f"  ✓ Successfully loaded {year} as CSV ({df.shape[0]:,} rows, {df.shape[1]:,} cols)")
                        # Fix headers for older years
                        df = fix_headers_for_older_years(df, year)
                        return df
                    except UnicodeDecodeError:
                        # Try different encoding
                        try:
                            df = pd.read_csv(BytesIO(content), encoding='latin-1', **read_kwargs)
                            print(f"  ✓ Successfully loaded {year} as CSV with latin-1 encoding ({df.shape[0]:,} rows, {df.shape[1]:,} cols)")
                            # Fix headers for older years
                            df = fix_headers_for_older_years(df, year)
                            return df
                        except Exception as e:
                            print(f"  CSV parsing failed: {str(e)}")
                            continue
                    except Exception as e:
                        print(f"  CSV parsing failed: {str(e)}")
                        continue
            
            # If we get here, the URL failed - this triggers a retry if attempts remain
            if retry_attempt < max_retries - 1:
                print(f"  ✗ Download failed for year {year}")
                print(f"  Retrying entire process (attempt {retry_attempt + 2}/{max_retries}) in {delay} seconds...")
                time.sleep(delay)
            else:
                print(f"  ✗ Failed to download and extract data for year {year} after {max_retries} attempts")
                print(f"  URL attempted: {urls[0]}")
                return None
                
        except RuntimeError as e:
            print(f"  ✗ Runtime error on attempt {retry_attempt + 1}: {str(e)}")
            if retry_attempt < max_retries - 1:
                print(f"  Retrying in {delay} seconds...")
                time.sleep(delay)
            else:
                print(f"  ✗ Failed after {max_retries} attempts due to runtime error")
                return None
        except Exception as e:
            # Catch any other unexpected errors and retry
            print(f"  ✗ Unexpected error on attempt {retry_attempt + 1}: {type(e).__name__}: {str(e)}")
            if retry_attempt < max_retries - 1:
                print(f"  Retrying in {delay} seconds...")
                time.sleep(delay)
            else:
                print(f"  ✗ Failed after {max_retries} attempts")
                return None
    
    return None

# %%
# Define sample size for testing (set to None for full dataset)
SAMPLE_SIZE = 1000  # Adjust this value to control how many rows to read from each year

# Download and create dataframes for each year
dataframes = {}

for year in SURVEY_YEARS:
    df = download_and_extract_year(year, max_retries=MAX_RETRIES, delay=RETRY_DELAY)
    if df is not None:
        # Add a year column to track which year the data is from
        df['SurveyYear'] = year
        dataframes[year] = df
    else:
        print(f"⚠ Skipping year {year} - download failed")

print(f"\n{'='*60}")
print(f"Download Summary")
print(f"{'='*60}")
print(f"Successfully downloaded: {len(dataframes)} out of {len(SURVEY_YEARS)} years")
print(f"Years downloaded: {sorted(dataframes.keys())}")
print(f"Years failed: {[y for y in SURVEY_YEARS if y not in dataframes]}")

# Display info for each dataframe
if dataframes:
    print(f"\n{'='*60}")
    print(f"DataFrame Information")
    print(f"{'='*60}")
    for year, df in sorted(dataframes.items()):
        print(f"Year {year}: {df.shape[0]:,} rows × {df.shape[1]:,} columns")
# Out:
# ============================================================
# Processing year 2011
# ============================================================
#   Trying URL: https://survey.stackoverflow.co/datasets/stack-overflow-developer-survey-2011.zip
#   ✓ Successfully downloaded 2011 as ZIP (80,173 bytes)
#   Found CSV file in ZIP: 2011 Stack Overflow Survey Results.csv
#   ✓ Successfully loaded 2011 from ZIP with latin-1 encoding (2,815 rows, 65 cols)
#   ✓ Fixed headers for year 2011 (combined first two rows, removed 2 header rows)
#
# ============================================================
# Processing year 2012
# ============================================================
#   Trying URL: https://survey.stackoverflow.co/datasets/stack-overflow-developer-survey-2012.zip
#   ✓ Successfully downloaded 2012 as ZIP (266,621 bytes)
#   Found CSV file in ZIP: 2012 Stack Overflow Survey Results.csv
#   ✓ Successfully loaded 2012 from ZIP with latin-1 encoding (6,245 rows, 75 cols)
#   ✓ Fixed headers for year 2012 (combined first two rows, removed 2 header rows)
#
# ============================================================
# Processing year 2013
# ============================================================
#   Trying URL: https://survey.stackoverflow.co/datasets/stack-overflow-developer-survey-2013.zip
#   ✓ Successfully downloaded 2013 as ZIP (689,493 bytes)
#   Found CSV file in ZIP: 2013 Stack Overflow Survey Responses.csv
#   ✓ Successfully loaded 2013 from ZIP (9,744 rows, 128 cols)
#   ✓ Fixed headers for year 2013 (combined first two rows, removed 2 header rows)
#
# ============================================================
# Processing year 2014
# ============================================================
#   Trying URL: https://survey.stackoverflow.co/datasets/stack-overflow-developer-survey-2014.zip
#   ✗ Download error: 429 Client Error: Too Many Requests for url: https://survey.stackoverflow.co/datasets/stack-overflow-developer-survey-2014.zip
#   ✗ Download failed for year 2014
#   Retrying entire process (attempt 2/10) in 30 seconds...
#   Trying URL: https://survey.stackoverflow.co/datasets/stack-overflow-developer-survey-2014.zip
#   ✗ Download error: 429 Client Error: Too Many Requests for url: https://survey.stackoverflow.co/datasets/stack-overflow-developer-survey-2014.zip
#   ✗ Download failed for year 2014
#   Retrying entire process (attempt 3/10) in 30 seconds...
#   Trying URL: https://survey.stackoverflow.co/datasets/stack-overflow-developer-survey-2014.zip
#   ✓ Successfully downloaded 2014 as ZIP (549,958 bytes)
#   Found CSV file in ZIP: 2014 Stack Overflow Survey Responses.csv
#   ✓ Successfully loaded 2014 from ZIP (7,645 rows, 120 cols)
#   ✓ Fixed headers for year 2014 (combined first two rows, removed 2 header rows)
#
# ============================================================
# Processing year 2015
# ============================================================
#   Trying URL: https://survey.stackoverflow.co/datasets/stack-overflow-developer-survey-2015.zip
#   ✓ Successfully downloaded 2015 as ZIP (1,915,462 bytes)
#   Found CSV file in ZIP: 2015 Stack Overflow Developer Survey Responses.csv
#   ✓ Successfully loaded 2015 from ZIP (26,088 rows, 222 cols)
#   ✓ Fixed headers for year 2015 (combined first two rows, removed 2 header rows)
#
# ============================================================
# Processing year 2016
# ============================================================
#   Trying URL: https://survey.stackoverflow.co/datasets/stack-overflow-developer-survey-2016.zip
#   ✓ Successfully downloaded 2016 as ZIP (5,855,459 bytes)
#   Found CSV file in ZIP: 2016 Stack Overflow Survey Results/2016 Stack Overflow Survey Responses.csv
#   ✓ Successfully loaded 2016 from ZIP (56,030 rows, 66 cols)
#
# ============================================================
# Processing year 2017
# ============================================================
#   Trying URL: https://survey.stackoverflow.co/datasets/stack-overflow-developer-survey-2017.zip
#   ✗ Download error: 429 Client Error: Too Many Requests for url: https://survey.stackoverflow.co/datasets/stack-overflow-developer-survey-2017.zip
#   ✗ Download failed for year 2017
#   Retrying entire process (attempt 2/10) in 30 seconds...
#   Trying URL: https://survey.stackoverflow.co/datasets/stack-overflow-developer-survey-2017.zip
#   ✗ Download error: 429 Client Error: Too Many Requests for url: https://survey.stackoverflow.co/datasets/stack-overflow-developer-survey-2017.zip
#   ✗ Download failed for year 2017
#   Retrying entire process (attempt 3/10) in 30 seconds...
#   Trying URL: https://survey.stackoverflow.co/datasets/stack-overflow-developer-survey-2017.zip
#   ✓ Successfully downloaded 2017 as ZIP (9,576,818 bytes)
#   Found CSV file in ZIP: survey_results_public.csv
#   ✓ Successfully loaded 2017 from ZIP (51,392 rows, 154 cols)
#
# ============================================================
# Processing year 2018
# ============================================================
#   Trying URL: https://survey.stackoverflow.co/datasets/stack-overflow-developer-survey-2018.zip
#   ✓ Successfully downloaded 2018 as ZIP (20,022,841 bytes)
#   Found CSV file in ZIP: survey_results_public.csv
#   ✓ Successfully loaded 2018 from ZIP (98,855 rows, 129 cols)
#
# ============================================================
# Processing year 2019
# ============================================================
#   Trying URL: https://survey.stackoverflow.co/datasets/stack-overflow-developer-survey-2019.zip
#   ✗ Download error: 429 Client Error: Too Many Requests for url: https://survey.stackoverflow.co/datasets/stack-overflow-developer-survey-2019.zip
#   ✗ Download failed for year 2019
#   Retrying entire process (attempt 2/10) in 30 seconds...
#   Trying URL: https://survey.stackoverflow.co/datasets/stack-overflow-developer-survey-2019.zip
#   ✗ Download error: 429 Client Error: Too Many Requests for url: https://survey.stackoverflow.co/datasets/stack-overflow-developer-survey-2019.zip
#   ✗ Download failed for year 2019
#   Retrying entire process (attempt 3/10) in 30 seconds...
#   Trying URL: https://survey.stackoverflow.co/datasets/stack-overflow-developer-survey-2019.zip
#   ✓ Successfully downloaded 2019 as ZIP (18,681,322 bytes)
#   Found CSV file in ZIP: survey_results_public.csv
#   ✓ Successfully loaded 2019 from ZIP (88,883 rows, 85 cols)
#
# ============================================================
# Processing year 2020
# ============================================================
#   Trying URL: https://survey.stackoverflow.co/datasets/stack-overflow-developer-survey-2020.zip
#   ✓ Successfully downloaded 2020 as ZIP (9,908,290 bytes)
#   Found CSV file in ZIP: survey_results_public.csv
#   ✓ Successfully loaded 2020 from ZIP (64,461 rows, 61 cols)
#
# ============================================================
# Processing year 2021
# ============================================================
#   Trying URL: https://survey.stackoverflow.co/datasets/stack-overflow-developer-survey-2021.zip
#   ✗ Download error: 429 Client Error: Too Many Requests for url: https://survey.stackoverflow.co/datasets/stack-overflow-developer-survey-2021.zip
#   ✗ Download failed for year 2021
#   Retrying entire process (attempt 2/10) in 30 seconds...
#   Trying URL: https://survey.stackoverflow.co/datasets/stack-overflow-developer-survey-2021.zip
#   ✗ Download error: 429 Client Error: Too Many Requests for url: https://survey.stackoverflow.co/datasets/stack-overflow-developer-survey-2021.zip
#   ✗ Download failed for year 2021
#   Retrying entire process (attempt 3/10) in 30 seconds...
#   Trying URL: https://survey.stackoverflow.co/datasets/stack-overflow-developer-survey-2021.zip
#   ✓ Successfully downloaded 2021 as ZIP (8,825,103 bytes)
#   Found CSV file in ZIP: survey_results_public.csv
#   ✓ Successfully loaded 2021 from ZIP (83,439 rows, 48 cols)
#
# ============================================================
# Processing year 2022
# ============================================================
#   Trying URL: https://survey.stackoverflow.co/datasets/stack-overflow-developer-survey-2022.zip
#   ✓ Successfully downloaded 2022 as ZIP (12,089,826 bytes)
#   Found CSV file in ZIP: survey_results_public.csv
#   ✓ Successfully loaded 2022 from ZIP (73,268 rows, 79 cols)
#
# ============================================================
# Processing year 2023
# ============================================================
#   Trying URL: https://survey.stackoverflow.co/datasets/stack-overflow-developer-survey-2023.zip
#   ✗ Download error: 429 Client Error: Too Many Requests for url: https://survey.stackoverflow.co/datasets/stack-overflow-developer-survey-2023.zip
#   ✗ Download failed for year 2023
#   Retrying entire process (attempt 2/10) in 30 seconds...
#   Trying URL: https://survey.stackoverflow.co/datasets/stack-overflow-developer-survey-2023.zip
#   ✗ Download error: 429 Client Error: Too Many Requests for url: https://survey.stackoverflow.co/datasets/stack-overflow-developer-survey-2023.zip
#   ✗ Download failed for year 2023
#   Retrying entire process (attempt 3/10) in 30 seconds...
#   Trying URL: https://survey.stackoverflow.co/datasets/stack-overflow-developer-survey-2023.zip
#   ✓ Successfully downloaded 2023 as ZIP (20,599,404 bytes)
#   Found CSV file in ZIP: survey_results_public.csv
#   ✓ Successfully loaded 2023 from ZIP (89,184 rows, 84 cols)
#
# ============================================================
# Processing year 2024
# ============================================================
#   Trying URL: https://survey.stackoverflow.co/datasets/stack-overflow-developer-survey-2024.zip
#   ✓ Successfully downloaded 2024 as ZIP (17,703,733 bytes)
#   Found CSV file in ZIP: survey_results_public.csv
#   ✓ Successfully loaded 2024 from ZIP (65,437 rows, 114 cols)
#
# ============================================================
# Processing year 2025
# ============================================================
#   Trying URL: https://survey.stackoverflow.co/datasets/stack-overflow-developer-survey-2025.zip
#   ✗ Download error: 429 Client Error: Too Many Requests for url: https://survey.stackoverflow.co/datasets/stack-overflow-developer-survey-2025.zip
#   ✗ Download failed for year 2025
#   Retrying entire process (attempt 2/10) in 30 seconds...
#   Trying URL: https://survey.stackoverflow.co/datasets/stack-overflow-developer-survey-2025.zip
#   ✗ Download error: 429 Client Error: Too Many Requests for url: https://survey.stackoverflow.co/datasets/stack-overflow-developer-survey-2025.zip
#   ✗ Download failed for year 2025
#   Retrying entire process (attempt 3/10) in 30 seconds...
#   Trying URL: https://survey.stackoverflow.co/datasets/stack-overflow-developer-survey-2025.zip
#   ✓ Successfully downloaded 2025 as ZIP (16,835,700 bytes)
#   Found CSV file in ZIP: survey_results_public.csv
#   ✓ Successfully loaded 2025 from ZIP (49,123 rows, 170 cols)
#
# ============================================================
# Download Summary
# ============================================================
# Successfully downloaded: 15 out of 15 years
# Years downloaded: [2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022, 2023, 2024, 2025]
# Years failed: []
#
# ============================================================
# DataFrame Information
# ============================================================
# Year 2011: 2,813 rows × 66 columns
# Year 2012: 6,243 rows × 76 columns
# Year 2013: 9,742 rows × 129 columns
# Year 2014: 7,643 rows × 121 columns
# Year 2015: 26,086 rows × 223 columns
# Year 2016: 56,030 rows × 67 columns
# Year 2017: 51,392 rows × 155 columns
# Year 2018: 98,855 rows × 130 columns
# Year 2019: 88,883 rows × 86 columns
# Year 2020: 64,461 rows × 62 columns
# Year 2021: 83,439 rows × 49 columns
# Year 2022: 73,268 rows × 80 columns
# Year 2023: 89,184 rows × 85 columns
# Year 2024: 65,437 rows × 115 columns
# Year 2025: 49,123 rows × 171 columns

# %%
# Create combined dataframe from all years
if dataframes:
    print(f"\n{'='*60}")
    print(f"Creating Combined DataFrame")
    print(f"{'='*60}")
    
    # Ensure all dataframes have unique columns before concatenation
    # Find the union of all columns
    all_columns = set()
    for df in dataframes.values():
        all_columns.update(df.columns)
    all_columns = list(all_columns)

    # Reindex each dataframe to ensure unique columns for concat
    aligned_dfs = []
    for year, df in dataframes.items():
        # Remove duplicate columns if any (can happen on bad CSVs)
        df = df.loc[:,~df.columns.duplicated()]
        aligned_df = df.reindex(columns=all_columns)
        aligned_dfs.append(aligned_df)
    
    combined_df = pd.concat(aligned_dfs, ignore_index=True, sort=False)
    
    print(f"success!")
    print(f"  rows: {combined_df.shape[0]:,}")
    print(f"  columns: {combined_df.shape[1]:,}")
    print(f"  Years: {sorted(combined_df['SurveyYear'].dropna().unique())}")
    
    # Show basic info about the combined dataframe
    print(f"\n{'='*60}")
    print(f"Combined DataFrame Info")
    print(f"{'='*60}")
    print(combined_df.info())
    print(f"{'='*60}")
else:
    print("\n⚠ No dataframes were successfully downloaded. Cannot create combined dataframe.")
    combined_df = None
# Out:
# ============================================================
# Creating Combined DataFrame
# ============================================================
# success!
#   rows: 772,599
#   columns: 1,087
#   Years: [2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022, 2023, 2024, 2025]
#
# ============================================================
# Combined DataFrame Info
# ============================================================
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 772599 entries, 0 to 772598
# Columns: 1087 entries, ImportantHiringRep to ProgramHobby
# dtypes: float64(106), int64(1), object(980)
# memory usage: 6.3+ GB
# None
# ============================================================

# %%
# Access individual year dataframes: dataframes[year]
# Access combined dataframe: combined_df
# Example:
if dataframes:
    print(f"\n{'='*60}")
    print(f"How to Access Your Data")
    print(f"{'='*60}")
    print(f"Individual year dataframes:")
    print(f"  - dataframes[2024]  # Access 2024 data")
    print(f"  - dataframes[2023]  # Access 2023 data")
    print(f"  - etc.")
    print(f"\nCombined dataframe:")
    print(f"  - combined_df  # All years combined")
    print(f"\nAvailable years: {sorted(dataframes.keys())}")
    
    # Quick preview of the combined dataframe
    if combined_df is not None:
        print(f"\n{'='*60}")
        print(f"Combined DataFrame Preview (first 5 rows)")
        print(f"{'='*60}")
        print(combined_df.head())
# Out:
# ============================================================
# How to Access Your Data
# ============================================================
# Individual year dataframes:
#   - dataframes[2024]  # Access 2024 data
#   - dataframes[2023]  # Access 2023 data
#   - etc.
#
# Combined dataframe:
#   - combined_df  # All years combined
#
# Available years: [2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022, 2023, 2024, 2025]
#
# ============================================================
# Combined DataFrame Preview (first 5 rows)
# ============================================================
#   ImportantHiringRep EquipmentSatisfiedRAM EduOther  HoursPerWeek LearnCodeAI  \
# 0                NaN                   NaN      NaN           NaN         NaN
# 1                NaN                   NaN      NaN           NaN         NaN
# 2                NaN                   NaN      NaN           NaN         NaN
# 3                NaN                   NaN      NaN           NaN         NaN
# 4                NaN                   NaN      NaN           NaN         NaN
#
#    JobSatPoints_16 company_size_range WebframeWantEntry AssessJobCompensation  \
# 0              NaN                NaN               NaN                   NaN
# 1              NaN                NaN               NaN                   NaN
# 2              NaN                NaN               NaN                   NaN
# 3              NaN                NaN               NaN                   NaN
# 4              NaN                NaN               NaN                   NaN
#
#    TechOppose_2 nan (Training & Education: Other) why_stack_overflow  \
# 0           NaN                               NaN                NaN
# 1           NaN                               NaN                NaN
# 2           NaN                               NaN                NaN
# 3           NaN                               NaN                NaN
# 4           NaN                               NaN                NaN
#
#   LanguageDesireNextYear EthicalImplications  CompTotal Knowledge_6  \
# 0                    NaN                 NaN        NaN         NaN
# 1                    NaN                 NaN        NaN         NaN
# 2                    NaN                 NaN        NaN         NaN
# 3                    NaN                 NaN        NaN         NaN
# 4                    NaN                 NaN        NaN         NaN
#
#   nan (Training & Education: Masters in CS) nan (Fixing bugs)  \
# 0                                       NaN               NaN
# 1                                       NaN               NaN
# 2                                       NaN               NaN
# 3                                       NaN               NaN
# 4                                       NaN               NaN
#
#   nan (Future Lang & Tech: R) YearsCodePro nan (Desktop Operating System)  \
# 0                         NaN          NaN                            NaN
# 1                         NaN          NaN                            NaN
# 2                         NaN          NaN                            NaN
# 3                         NaN          NaN                            NaN
# 4                         NaN          NaN                            NaN
#
#   nan (Why try Stack Overflow Careers: Selection of revelant jobs)  \
# 0                                                              NaN
# 1                                                              NaN
# 2                                                              NaN
# 3                                                              NaN
# 4                                                              NaN
#
#   AIToolDon't plan to use AI for this task PurchaseHow dogs_vs_cats  \
# 0                                      NaN         NaN          NaN
# 1                                      NaN         NaN          NaN
# 2                                      NaN         NaN          NaN
# 3                                      NaN         NaN          NaN
# 4                                      NaN         NaN          NaN
#
#   nan (TypeScript) AgreeDisagree2 EquipmentSatisfiedMonitors nan (Servers)  \
# 0              NaN            NaN                        NaN           NaN
# 1              NaN            NaN                        NaN           NaN
# 2              NaN            NaN                        NaN           NaN
# 3              NaN            NaN                        NaN           NaN
# 4              NaN            NaN                        NaN       Servers
#
#   nan (Perception of contact form: Twitter)  \
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
#
#   nan (Current Lang & Tech: Cordova)  \
# 0                                NaN
# 1                                NaN
# 2                                NaN
# 3                                NaN
# 4                                NaN
#
#   Please rate the advertising you've seen on Stack Overflow (The ads are relevant)  \
# 0                                                                              NaN
# 1                                                                              NaN
# 2                                                                              NaN
# 3                                                                              NaN
# 4                                                                              NaN
#
#   nan (Link to a Stack Overflow Careers Company Page or other source of more information about the company (videos, articles, etc))  \
# 0                                                                                                                               NaN
# 1                                                                                                                               NaN
# 2                                                                                                                               NaN
# 3                                                                                                                               NaN
# 4                                                                                                                               NaN
#
#   FizzBuzz InfluenceVizTools StackOverflowModeration  \
# 0      NaN               NaN                     NaN
# 1      NaN               NaN                     NaN
# 2      NaN               NaN                     NaN
# 3      NaN               NaN                     NaN
# 4      NaN               NaN                     NaN
#
#   nan (How frequently land on or read Stack Overflow)  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
#
#   nan (Current Lang & Tech: SQL Server) HaveWorkedPlatform employment_status  \
# 0                                   NaN                NaN               NaN
# 1                                   NaN                NaN               NaN
# 2                                   NaN                NaN               NaN
# 3                                   NaN                NaN               NaN
# 4                                   NaN                NaN               NaN
#
#   interview_likelihood EquipmentSatisfiedRW SOVisit1st  \
# 0                  NaN                  NaN        NaN
# 1                  NaN                  NaN        NaN
# 2                  NaN                  NaN        NaN
# 3                  NaN                  NaN        NaN
# 4                  NaN                  NaN        NaN
#
#   nan (Future Lang & Tech: Redis) job_discovery nan (Commuting)  \
# 0                             NaN           NaN             NaN
# 1                             NaN           NaN             NaN
# 2                             NaN           NaN             NaN
# 3                             NaN           NaN             NaN
# 4                             NaN           NaN             NaN
#
#   nan (Limited night / weekend work)  \
# 0                                NaN
# 1                                NaN
# 2                                NaN
# 3                                NaN
# 4                                NaN
#
#   What types of purchases are you involved in? (Hardware)  \
# 0                                                     NaN
# 1                                                     NaN
# 2                                                     NaN
# 3                                                     NaN
# 4                                                Hardware
#
#   nan (Future Lang & Tech: Scala) DatabaseDesireNextYear CurrencyDesc  \
# 0                             NaN                    NaN          NaN
# 1                             NaN                    NaN          NaN
# 2                             NaN                    NaN          NaN
# 3                             NaN                    NaN          NaN
# 4                             NaN                    NaN          NaN
#
#   nan (Current Lang & Tech: Redis)  \
# 0                              NaN
# 1                              NaN
# 2                              NaN
# 3                              NaN
# 4                              NaN
#
#   nan (Appealing message traits: Stack Overflow Company Page)  \
# 0                                                         NaN
# 1                                                         NaN
# 2                                                         NaN
# 3                                                         NaN
# 4                                                         NaN
#
#   DatabaseWantToWorkWith WorkChallenge ICorPM  \
# 0                    NaN           NaN    NaN
# 1                    NaN           NaN    NaN
# 2                    NaN           NaN    NaN
# 3                    NaN           NaN    NaN
# 4                    NaN           NaN    NaN
#
#   How likely is it that a recommendation you make will be acted upon?  \
# 0                                              Not in a million years
# 1                                           It's been known to happen
# 2                                    Unless it's stoopid it gets done
# 3                                           It's been known to happen
# 4                                                    I run this place
#
#   nan (Most urgent info about job opportunity: Job title) WebframeAdmired  \
# 0                                                     NaN             NaN
# 1                                                     NaN             NaN
# 2                                                     NaN             NaN
# 3                                                     NaN             NaN
# 4                                                     NaN             NaN
#
#   AssessJobDiversity EmploymentStatus Knowledge_8 Methodology nan (Node.js)  \
# 0                NaN              NaN         NaN         NaN           NaN
# 1                NaN              NaN         NaN         NaN           NaN
# 2                NaN              NaN         NaN         NaN           NaN
# 3                NaN              NaN         NaN         NaN           NaN
# 4                NaN              NaN         NaN         NaN           NaN
#
#    AdsPriorities2 nan (Recommender) nan (Other tablet) SOComm  nan  \
# 0             NaN               NaN                NaN    NaN  NaN
# 1             NaN               NaN                NaN    NaN  NaN
# 2             NaN               NaN                NaN    NaN  NaN
# 3             NaN               NaN                NaN    NaN  NaN
# 4             NaN               NaN                NaN    NaN  NaN
#
#   AIAgentChallengesNeutral AISelect  \
# 0                      NaN      NaN
# 1                      NaN      NaN
# 2                      NaN      NaN
# 3                      NaN      NaN
# 4                      NaN      NaN
#
#   Which best describes the size of your company? How old are you?  \
# 0                                Start Up (1-25)             < 20
# 1                 Mature Small Business (25-100)            25-29
# 2                            Mid Sized (100-999)            25-29
# 3                                        Student             < 20
# 4                                Start Up (1-25)            35-39
#
#   ProblemSolving Frustration nan (Current Lang & Tech: Hadoop)  \
# 0            NaN         NaN                               NaN
# 1            NaN         NaN                               NaN
# 2            NaN         NaN                               NaN
# 3            NaN         NaN                               NaN
# 4            NaN         NaN                               NaN
#
#   PlatformWorkedWith CurrencySymbol AdsAgreeDisagree2 nan (Consultants)  \
# 0                NaN            NaN               NaN               NaN
# 1                NaN            NaN               NaN               NaN
# 2                NaN            NaN               NaN               NaN
# 3                NaN            NaN               NaN               NaN
# 4                NaN            NaN               NaN               NaN
#
#   Accessibility  \
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN
#
#   You answered you don't have a Careers profile, can you elaborate why?  \
# 0                                                                   NaN
# 1                                                                   NaN
# 2                                                                   NaN
# 3                                                                   NaN
# 4                                                                   NaN
#
#   nan (Current Lang & Tech: Cassandra) WantWorkDatabase  \
# 0                                  NaN              NaN
# 1                                  NaN              NaN
# 2                                  NaN              NaN
# 3                                  NaN              NaN
# 4                                  NaN              NaN
#
#   Which of our sites do you frequent most? nan (CSS)  \
# 0                                      NaN       NaN
# 1                           Stack Overflow       NaN
# 2                                      NaN       NaN
# 3                           Stack Overflow       NaN
# 4                           Stack Overflow       CSS
#
#   nan (Future Lang & Tech: Java) StackOverflowDevices QuestionsConfusing  \
# 0                            NaN                  NaN                NaN
# 1                            NaN                  NaN                NaN
# 2                            NaN                  NaN                NaN
# 3                            NaN                  NaN                NaN
# 4                            NaN                  NaN                NaN
#
#   How many people work for your company?  \
# 0                                    NaN
# 1                                    NaN
# 2                                    NaN
# 3                                    NaN
# 4                                    NaN
#
#   nan (Most important aspect of new job opportunity: Company size)  \
# 0                                                              NaN
# 1                                                              NaN
# 2                                                              NaN
# 3                                                              NaN
# 4                                                              NaN
#
#   BlockchainOrg  salary_midpoint PurchaseInfluence  \
# 0           NaN              NaN               NaN
# 1           NaN              NaN               NaN
# 2           NaN              NaN               NaN
# 3           NaN              NaN               NaN
# 4           NaN              NaN               NaN
#
#   How often do you find solutions to your programming problems on Stack Overflow without asking a new question?  \
# 0                                                                                                           NaN
# 1                                                                                                           NaN
# 2                                                                                                           NaN
# 3                                                                                                           NaN
# 4                                                                                                           NaN
#
#    big_mac_index remote  JobEmailPriorities1 TechEndorse  TechEndorse_1  \
# 0            NaN    NaN                  NaN         NaN            NaN
# 1            NaN    NaN                  NaN         NaN            NaN
# 2            NaN    NaN                  NaN         NaN            NaN
# 3            NaN    NaN                  NaN         NaN            NaN
# 4            NaN    NaN                  NaN         NaN            NaN
#
#   LanguageChoice HighestEducationParents nan (Blackberry) TabsSpaces  \
# 0            NaN                     NaN              NaN        NaN
# 1            NaN                     NaN              NaN        NaN
# 2            NaN                     NaN              NaN        NaN
# 3            NaN                     NaN              NaN        NaN
# 4            NaN                     NaN              NaN        NaN
#
#   CompanySize nan (Most important aspect of new job opportunity: Tech stack)  \
# 0         NaN                                                            NaN
# 1         NaN                                                            NaN
# 2         NaN                                                            NaN
# 3         NaN                                                            NaN
# 4         NaN                                                            NaN
#
#   FormalEducation StackOverflowRecommend SkipMeals Employment  \
# 0             NaN                    NaN       NaN        NaN
# 1             NaN                    NaN       NaN        NaN
# 2             NaN                    NaN       NaN        NaN
# 3             NaN                    NaN       NaN        NaN
# 4             NaN                    NaN       NaN        NaN
#
#   nan (Future Lang & Tech: C++) DeveloperType  \
# 0                           NaN           NaN
# 1                           NaN           NaN
# 2                           NaN           NaN
# 3                           NaN           NaN
# 4                           NaN           NaN
#
#   How do you prefer to be contacted about job opportunities? (Email)  \
# 0                                                                NaN
# 1                                                                NaN
# 2                                                                NaN
# 3                                                                NaN
# 4                                                                NaN
#
#   Ethnicity TimeSearching country AssessJobIndustry DifficultCommunication  \
# 0       NaN           NaN     NaN               NaN                    NaN
# 1       NaN           NaN     NaN               NaN                    NaN
# 2       NaN           NaN     NaN               NaN                    NaN
# 3       NaN           NaN     NaN               NaN                    NaN
# 4       NaN           NaN     NaN               NaN                    NaN
#
#   LanguageWorkedWith AISent nan (Check Writer) PlatformWantToWorkWith  \
# 0                NaN    NaN                NaN                    NaN
# 1                NaN    NaN                NaN                    NaN
# 2                NaN    NaN                NaN                    NaN
# 3                NaN    NaN                NaN                    NaN
# 4                NaN    NaN                NaN                    NaN
#
#   CousinEducation SOTimeSaved CommPlatformHaveEntr agree_adblocker  \
# 0             NaN         NaN                  NaN             NaN
# 1             NaN         NaN                  NaN             NaN
# 2             NaN         NaN                  NaN             NaN
# 3             NaN         NaN                  NaN             NaN
# 4             NaN         NaN                  NaN             NaN
#
#   nan ($10,001 - $25,000) SOJobs StackOverflowAdsRelevant  \
# 0                     NaN    NaN                      NaN
# 1                     NaN    NaN                      NaN
# 2                     NaN    NaN                      NaN
# 3                     NaN    NaN                      NaN
# 4       $10,001 - $25,000    NaN                      NaN
#
#   nan (Most urgent info about job opportunity: Company name)  \
# 0                                                        NaN
# 1                                                        NaN
# 2                                                        NaN
# 3                                                        NaN
# 4                                                        NaN
#
#   HypotheticalTools1 InTheZone SurveyEasy WebframeHaveEntry  \
# 0                NaN       NaN        NaN               NaN
# 1                NaN       NaN        NaN               NaN
# 2                NaN       NaN        NaN               NaN
# 3                NaN       NaN        NaN               NaN
# 4                NaN       NaN        NaN               NaN
#
#   nan (Future Lang & Tech: Cassandra) Knowledge_5  \
# 0                                 NaN         NaN
# 1                                 NaN         NaN
# 2                                 NaN         NaN
# 3                                 NaN         NaN
# 4                                 NaN         NaN
#
#   nan (Appealing message traits: Salary information) WebFrameDesireNextYear  \
# 0                                                NaN                    NaN
# 1                                                NaN                    NaN
# 2                                                NaN                    NaN
# 3                                                NaN                    NaN
# 4                                                NaN                    NaN
#
#   nan (Most important aspect of new job opportunity: Health insurance)  \
# 0                                                                  NaN
# 1                                                                  NaN
# 2                                                                  NaN
# 3                                                                  NaN
# 4                                                                  NaN
#
#    JobSatPoints_1 nan (>$150,000)  \
# 0             NaN             NaN
# 1             NaN             NaN
# 2             NaN             NaN
# 3             NaN             NaN
# 4             NaN       >$150,000
#
#   Do you have a Stack Overflow Careers Profile?  \
# 0                                           NaN
# 1                                           NaN
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN
#
#   nan (I like that I can indicate ads I want to see less of) Exercise  \
# 0                                                        NaN      NaN
# 1                                                        NaN      NaN
# 2                                                        NaN      NaN
# 3                                                        NaN      NaN
# 4                                                        NaN      NaN
#
#   How often do you visit job boards? nan (Training & Education: Online Class)  \
# 0                                NaN                                      NaN
# 1                                NaN                                      NaN
# 2                                NaN                                      NaN
# 3                                NaN                                      NaN
# 4                                NaN                                      NaN
#
#    JobEmailPriorities7  AssessJob5 AnnoyingUI DatabaseWantEntry  \
# 0                  NaN         NaN        NaN               NaN
# 1                  NaN         NaN        NaN               NaN
# 2                  NaN         NaN        NaN               NaN
# 3                  NaN         NaN        NaN               NaN
# 4                  NaN         NaN        NaN               NaN
#
#   nan (Future Lang & Tech: iOS) nan (Current Lang & Tech: C++)  \
# 0                           NaN                            NaN
# 1                           NaN                            NaN
# 2                           NaN                            NaN
# 3                           NaN                            NaN
# 4                           NaN                            NaN
#
#   nan (Purchasing Power) nan (Prefered Source Control: write-in) TBranch  \
# 0                    NaN                                     NaN     NaN
# 1                    NaN                                     NaN     NaN
# 2                    NaN                                     NaN     NaN
# 3                    NaN                                     NaN     NaN
# 4                    NaN                                     NaN     NaN
#
#   AIDevHaveWorkedWith AIBen  AssessJob8  \
# 0                 NaN   NaN         NaN
# 1                 NaN   NaN         NaN
# 2                 NaN   NaN         NaN
# 3                 NaN   NaN         NaN
# 4                 NaN   NaN         NaN
#
#   nan (Most urgent info about job opportunity: Benefits)  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
#
#   nan (Current Lang & Tech: C#) nan (Technical support)  \
# 0                           NaN                     NaN
# 1                           NaN                     NaN
# 2                           NaN                     NaN
# 3                           NaN                     NaN
# 4                           NaN                     NaN
#
#   nan (How can companies improve interview process: Gimme coffee)  \
# 0                                                             NaN
# 1                                                             NaN
# 2                                                             NaN
# 3                                                             NaN
# 4                                                             NaN
#
#   nan ($100,001 - $150,000) nan (Identification With the Company/Goals)  \
# 0                       NaN                                         NaN
# 1                       NaN                                         NaN
# 2                       NaN                                         NaN
# 3                       NaN                                         NaN
# 4       $100,001 - $150,000                                         NaN
#
#    AssessJob4 WebframeWorkedWith nan (Future Lang & Tech: PHP)  \
# 0         NaN                NaN                           NaN
# 1         NaN                NaN                           NaN
# 2         NaN                NaN                           NaN
# 3         NaN                NaN                           NaN
# 4         NaN                NaN                           NaN
#
#   InfluenceConsultants nan (Source control used: SVN) Knowledge_4  \
# 0                  NaN                            NaN         NaN
# 1                  NaN                            NaN         NaN
# 2                  NaN                            NaN         NaN
# 3                  NaN                            NaN         NaN
# 4                  NaN                            NaN         NaN
#
#    JobEmailPriorities2 nan (Current Lang & Tech: Ruby) WakeTime education  \
# 0                  NaN                             NaN      NaN       NaN
# 1                  NaN                             NaN      NaN       NaN
# 2                  NaN                             NaN      NaN       NaN
# 3                  NaN                             NaN      NaN       NaN
# 4                  NaN                             NaN      NaN       NaN
#
#   nan (Future Lang & Tech: Objective-C) AIExplain  \
# 0                                   NaN       NaN
# 1                                   NaN       NaN
# 2                                   NaN       NaN
# 3                                   NaN       NaN
# 4                                   NaN       NaN
#
#   nan (Future Lang & Tech: Python) nan (Autonomy Over Budget/Expenditures)  \
# 0                              NaN                                     NaN
# 1                              NaN                                     NaN
# 2                              NaN                                     NaN
# 3                              NaN                                     NaN
# 4                              NaN                                     NaN
#
#   nan (Current Lang & Tech: Python)  \
# 0                               NaN
# 1                               NaN
# 2                               NaN
# 3                               NaN
# 4                               NaN
#
#   What is your budget for outside expenditures (hardware, software, consulting, etc) for 2014?  \
# 0                                                                                          NaN
# 1                                                                                          NaN
# 2                                                                                          NaN
# 3                                                                                          NaN
# 4                                                                                          NaN
#
#   AIAgentOrchWrite AIHuman StackOverflowCompanyPage  \
# 0              NaN     NaN                      NaN
# 1              NaN     NaN                      NaN
# 2              NaN     NaN                      NaN
# 3              NaN     NaN                      NaN
# 4              NaN     NaN                      NaN
#
#   OfficeStackSyncWantToWorkWith UpdateCV important_wfh NumberMonitors  \
# 0                           NaN      NaN           NaN            NaN
# 1                           NaN      NaN           NaN            NaN
# 2                           NaN      NaN           NaN            NaN
# 3                           NaN      NaN           NaN            NaN
# 4                           NaN      NaN           NaN            NaN
#
#   ResumeUpdate Which US State or Territory do you live in?  \
# 0          NaN                                         NaN
# 1          NaN                                         NaN
# 2          NaN                                         NaN
# 3          NaN                                         NaN
# 4          NaN                                         NaN
#
#   nan (Who do you want to communicate with about a new job opportunity: In-house tech recruiter)  \
# 0                                                                                            NaN
# 1                                                                                            NaN
# 2                                                                                            NaN
# 3                                                                                            NaN
# 4                                                                                            NaN
#
#   nan (Xbox) StackOverflowAdsDistracting  \
# 0        NaN                         NaN
# 1        NaN                         NaN
# 2        NaN                         NaN
# 3        NaN                         NaN
# 4       Xbox                         NaN
#
#   nan (I influence purchasing decisions, but don't have final approval)  \
# 0                                                                   NaN
# 1                                                                   NaN
# 2                                                                   NaN
# 3                                                                   NaN
# 4                                                                   NaN
#
#   LanguageAdmired ImportantHiringPMExp  AssessBenefits4 Hobbyist  \
# 0             NaN                  NaN              NaN      NaN
# 1             NaN                  NaN              NaN      NaN
# 2             NaN                  NaN              NaN      NaN
# 3             NaN                  NaN              NaN      NaN
# 4             NaN                  NaN              NaN      NaN
#
#   YearsCodingProf  \
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN
#
#   nan (How can companies improve interview process: Flexible interview schedule)  \
# 0                                                                            NaN
# 1                                                                            NaN
# 2                                                                            NaN
# 3                                                                            NaN
# 4                                                                            NaN
#
#   EmbeddedHaveWorkedWith  TechOppose_7 AIAgentChallengesSomewhat agree  \
# 0                    NaN           NaN                             NaN
# 1                    NaN           NaN                             NaN
# 2                    NaN           NaN                             NaN
# 3                    NaN           NaN                             NaN
# 4                    NaN           NaN                             NaN
#
#    AdsPriorities1 Which of the following best describes your occupation?  \
# 0             NaN                              Web Application Developer
# 1             NaN                                      Server Programmer
# 2             NaN                                      Server Programmer
# 3             NaN                                                Student
# 4             NaN                  Executive (VP of Eng, CTO, CIO, etc.)
#
#   MainBranch  JobSatPoints_13  Respondent  \
# 0        NaN              NaN         NaN
# 1        NaN              NaN         NaN
# 2        NaN              NaN         NaN
# 3        NaN              NaN         NaN
# 4        NaN              NaN         NaN
#
#   nan (Most annoying about job search: Finding interesting job)  \
# 0                                                           NaN
# 1                                                           NaN
# 2                                                           NaN
# 3                                                           NaN
# 4                                                           NaN
#
#   important_ownoffice InfluenceCloud AIModelsWantEntry team_size_range  \
# 0                 NaN            NaN               NaN             NaN
# 1                 NaN            NaN               NaN             NaN
# 2                 NaN            NaN               NaN             NaN
# 3                 NaN            NaN               NaN             NaN
# 4                 NaN            NaN               NaN             NaN
#
#   nan (I can buy anything I want without asking anyone) AIDangerous  \
# 0                                                   NaN         NaN
# 1                                                   NaN         NaN
# 2                                                   NaN         NaN
# 3                                                   NaN         NaN
# 4                                                   NaN         NaN
#
#   EmbeddedAdmired nan (CoffeeScript) AssessJobTech HopeFiveYears  \
# 0             NaN                NaN           NaN           NaN
# 1             NaN                NaN           NaN           NaN
# 2             NaN                NaN           NaN           NaN
# 3             NaN                NaN           NaN           NaN
# 4             NaN                NaN           NaN           NaN
#
#   nan (Xbox 360) nan (Includes salary information) AIToolInterested in Using  \
# 0            NaN                               NaN                       NaN
# 1            NaN                               NaN                       NaN
# 2            NaN                               NaN                       NaN
# 3            NaN                               NaN                       NaN
# 4            NaN                               NaN                       NaN
#
#   AINextLess integrated nan (Appealing message traits: Team described)  \
# 0                   NaN                                            NaN
# 1                   NaN                                            NaN
# 2                   NaN                                            NaN
# 3                   NaN                                            NaN
# 4                   NaN                                            NaN
#
#   DevEnvsHaveWorkedWith  JobSatPoints_10 nan (Python)  \
# 0                   NaN              NaN          NaN
# 1                   NaN              NaN          NaN
# 2                   NaN              NaN          NaN
# 3                   NaN              NaN          NaN
# 4                   NaN              NaN          NaN
#
#   nan (Future Lang & Tech: Write-In) nan (How often contacted by recruiters)  \
# 0                                NaN                                     NaN
# 1                                NaN                                     NaN
# 2                                NaN                                     NaN
# 3                                NaN                                     NaN
# 4                                NaN                                     NaN
#
#   AssessJobProduct occupation_group important_promotion  TechOppose_16  \
# 0              NaN              NaN                 NaN            NaN
# 1              NaN              NaN                 NaN            NaN
# 2              NaN              NaN                 NaN            NaN
# 3              NaN              NaN                 NaN            NaN
# 4              NaN              NaN                 NaN            NaN
#
#   so_region DatabaseChoice nan (Open to new job opportunities)  \
# 0       NaN            NaN                                 NaN
# 1       NaN            NaN                                 NaN
# 2       NaN            NaN                                 NaN
# 3       NaN            NaN                                 NaN
# 4       NaN            NaN                                 NaN
#
#   ExCoderWillNotCode WelcomeChange new_job_value  \
# 0                NaN           NaN           NaN
# 1                NaN           NaN           NaN
# 2                NaN           NaN           NaN
# 3                NaN           NaN           NaN
# 4                NaN           NaN           NaN
#
#   How would you best describe the industry you currently work in?  \
# 0                                                             NaN
# 1                                                             NaN
# 2                                                             NaN
# 3                                                             NaN
# 4                                                             NaN
#
#   CompetePeers nan (User Equipment: Monitors, PCs, Laptops)  \
# 0          NaN                                          NaN
# 1          NaN                                          NaN
# 2          NaN                                          NaN
# 3          NaN       User Equipment: Monitors, PCs, Laptops
# 4          NaN       User Equipment: Monitors, PCs, Laptops
#
#   nan (Future Lang & Tech: Dart) nan (Future Lang & Tech: Haskell) AIEthics  \
# 0                            NaN                               NaN      NaN
# 1                            NaN                               NaN      NaN
# 2                            NaN                               NaN      NaN
# 3                            NaN                               NaN      NaN
# 4                            NaN                               NaN      NaN
#
#   nan (Human Resources)  TechOppose_13 nan (Grants / outside fund-raising)  \
# 0                   NaN            NaN                                 NaN
# 1                   NaN            NaN                                 NaN
# 2                   NaN            NaN                                 NaN
# 3                   NaN            NaN                                 NaN
# 4                   NaN            NaN                                 NaN
#
#   NEWOvertime  \
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
#
#   What other departments / roles do you interact with regularly? (System Administrators)  \
# 0                                                                                    NaN
# 1                                                                                    NaN
# 2                                                                                    NaN
# 3                                                                                    NaN
# 4                                                                                    NaN
#
#   nan (Describes benefits / perks of the work environment) nan (Wii)  \
# 0                                                      NaN       NaN
# 1                                                      NaN       NaN
# 2                                                      NaN       NaN
# 3                                                      NaN       Wii
# 4                                                      NaN       NaN
#
#   nan (Most important aspect of new job opportunity: Office location)  \
# 0                                                                 NaN
# 1                                                                 NaN
# 2                                                                 NaN
# 3                                                                 NaN
# 4                                                                 NaN
#
#   ToolsTechHaveWorkedWith US_State  SO_Actions_10 StackOverflowDescribes  \
# 0                     NaN      NaN            NaN                    NaN
# 1                     NaN      NaN            NaN                    NaN
# 2                     NaN      NaN            NaN                    NaN
# 3                     NaN      NaN            NaN                    NaN
# 4                     NaN      NaN            NaN                    NaN
#
#   nan (Future Lang & Tech: C++11) AIModelsHaveEntry ExCoderBelonged  \
# 0                             NaN               NaN             NaN
# 1                             NaN               NaN             NaN
# 2                             NaN               NaN             NaN
# 3                             NaN               NaN             NaN
# 4                             NaN               NaN             NaN
#
#   nan (Most important aspect of new job opportunity: Remote working)  \
# 0                                                                NaN
# 1                                                                NaN
# 2                                                                NaN
# 3                                                                NaN
# 4                                                                NaN
#
#    AssessJob2 nan (Future Lang & Tech: Hadoop) important_control agree_notice  \
# 0         NaN                              NaN               NaN          NaN
# 1         NaN                              NaN               NaN          NaN
# 2         NaN                              NaN               NaN          NaN
# 3         NaN                              NaN               NaN          NaN
# 4         NaN                              NaN               NaN          NaN
#
#    AssessJob6 Select up to 3 (Most annoying about job search: Finding time)  \
# 0         NaN                                                           NaN
# 1         NaN                                                           NaN
# 2         NaN                                                           NaN
# 3         NaN                                                           NaN
# 4         NaN                                                           NaN
#
#   ToolsTechAdmired  JobEmailPriorities4 DevEnvsWantToWorkWith  \
# 0              NaN                  NaN                   NaN
# 1              NaN                  NaN                   NaN
# 2              NaN                  NaN                   NaN
# 3              NaN                  NaN                   NaN
# 4              NaN                  NaN                   NaN
#
#   ImportantHiringTechExp CollaborateRemote ImportantHiringGettingThingsDone  \
# 0                    NaN               NaN                              NaN
# 1                    NaN               NaN                              NaN
# 2                    NaN               NaN                              NaN
# 3                    NaN               NaN                              NaN
# 4                    NaN               NaN                              NaN
#
#   nan (Xbox One) nan (Current Lang & Tech: PHP) nan (jQuery) agree_nightcode  \
# 0            NaN                            NaN          NaN             NaN
# 1            NaN                            NaN          NaN             NaN
# 2            NaN                            NaN          NaN             NaN
# 3            NaN                            NaN          NaN             NaN
# 4            NaN                            NaN          NaN             NaN
#
#   MetricAssess DiversityImportant  VCHostingProfessional use  \
# 0          NaN                NaN                        NaN
# 1          NaN                NaN                        NaN
# 2          NaN                NaN                        NaN
# 3          NaN                NaN                        NaN
# 4          NaN                NaN                        NaN
#
#   VersionControlSystem nan (Other) nan (Learning new skills)  \
# 0                  NaN         NaN                       NaN
# 1                  NaN         NaN                       NaN
# 2                  NaN         NaN                       NaN
# 3                  NaN         NaN                       NaN
# 4                  NaN         NaN                       NaN
#
#   nan (I have a discretionary budget at my disposal) NEWStuck  \
# 0                                                NaN      NaN
# 1                                                NaN      NaN
# 2                                                NaN      NaN
# 3                                                NaN      NaN
# 4                                                NaN      NaN
#
# ...
# 3                              NaN         NaN                    NaN
# 4                              NaN         NaN                    NaN
#
#   OpenSource BlockchainIs WorkPlan nan (Perception of recruiter contact)  \
# 0        NaN          NaN      NaN                                   NaN
# 1        NaN          NaN      NaN                                   NaN
# 2        NaN          NaN      NaN                                   NaN
# 3        NaN          NaN      NaN                                   NaN
# 4        NaN          NaN      NaN                                   NaN
#
#   EducationTypes AIAgentChallengesSomewhat disagree  \
# 0            NaN                                NaN
# 1            NaN                                NaN
# 2            NaN                                NaN
# 3            NaN                                NaN
# 4            NaN                                NaN
#
#   nan (Answer questions I know the answer to) StackOverflowWhatDo  \
# 0                                         NaN                 NaN
# 1                                         NaN                 NaN
# 2                                         NaN                 NaN
# 3                                         NaN                 NaN
# 4                                         NaN                 NaN
#
#   ErgonomicDevices AdsAgreeDisagree3 LearnCodeCoursesCert  \
# 0              NaN               NaN                  NaN
# 1              NaN               NaN                  NaN
# 2              NaN               NaN                  NaN
# 3              NaN               NaN                  NaN
# 4              NaN               NaN                  NaN
#
#   Please rate your job/career satisfaction HypotheticalTools2  \
# 0                                      FML                NaN
# 1                        So happy it hurts                NaN
# 2                                      NaN                NaN
# 3                    I enjoy going to work                NaN
# 4                        It pays the bills                NaN
#
#   StackOverflowHasAccount AIAgentKnowWrite nan (Remote Status)  \
# 0                     NaN              NaN                 NaN
# 1                     NaN              NaN                 NaN
# 2                     NaN              NaN                 NaN
# 3                     NaN              NaN                 NaN
# 4                     NaN              NaN                 NaN
#
#   nan (Source control used: CVS) nan (Current Lang & Tech: Salesforce)  \
# 0                            NaN                                   NaN
# 1                            NaN                                   NaN
# 2                            NaN                                   NaN
# 3                            NaN                                   NaN
# 4                            NaN                                   NaN
#
#   ImportantHiringEducation Industry visit_frequency  \
# 0                      NaN      NaN             NaN
# 1                      NaN      NaN             NaN
# 2                      NaN      NaN             NaN
# 3                      NaN      NaN             NaN
# 4                      NaN      NaN             NaN
#
#   Select all that apply (Future Lang & Tech: Android) HaveWorkedLanguage  \
# 0                                                 NaN                NaN
# 1                                                 NaN                NaN
# 2                                                 NaN                NaN
# 3                                                 NaN                NaN
# 4                                                 NaN                NaN
#
#   nan (Most annoying about job search: The Interview) JobFactors  \
# 0                                                 NaN        NaN
# 1                                                 NaN        NaN
# 2                                                 NaN        NaN
# 3                                                 NaN        NaN
# 4                                                 NaN        NaN
#
#   In receiving an email about a job opportunity, what attributes of the message would make you more likely to respond? (Message is personalized to me)  \
# 0                                                                                                                                                  NaN
# 1                                                                                                                                                  NaN
# 2                                                                                                                                                  NaN
# 3                                                                                                                                                  NaN
# 4                                                                                                                                                  NaN
#
#   nan (I've taken a trial/purchased a product from ads)  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
#
#   nan (How many caffeinated beverages per day?) nan (AppleTV)  \
# 0                                           NaN           NaN
# 1                                           NaN           NaN
# 2                                           NaN           NaN
# 3                                           NaN           NaN
# 4                                           NaN           NaN
#
#   nan (Windows Phone) WorkLoc Containers AINextMuch less integrated  \
# 0                 NaN     NaN        NaN                        NaN
# 1                 NaN     NaN        NaN                        NaN
# 2                 NaN     NaN        NaN                        NaN
# 3                 NaN     NaN        NaN                        NaN
# 4                 NaN     NaN        NaN                        NaN
#
#   DevEnvWantEntry nan (Future Lang & Tech: Swift) LastNewJob  \
# 0             NaN                             NaN        NaN
# 1             NaN                             NaN        NaN
# 2             NaN                             NaN        NaN
# 3             NaN                             NaN        NaN
# 4             NaN                             NaN        NaN
#
#    JobContactPriorities5 StackOverflowJobSearch nan (Wii U)  \
# 0                    NaN                    NaN         NaN
# 1                    NaN                    NaN         NaN
# 2                    NaN                    NaN         NaN
# 3                    NaN                    NaN         NaN
# 4                    NaN                    NaN         NaN
#
#   nan (Future Lang & Tech: Clojure) ProfessionalCloud AssessJobFinances  \
# 0                               NaN               NaN               NaN
# 1                               NaN               NaN               NaN
# 2                               NaN               NaN               NaN
# 3                               NaN               NaN               NaN
# 4                               NaN               NaN               NaN
#
#   MgrIdiot BuildvsBuy OpSysProfessional use StackOverflowHelpful  \
# 0      NaN        NaN                   NaN                  NaN
# 1      NaN        NaN                   NaN                  NaN
# 2      NaN        NaN                   NaN                  NaN
# 3      NaN        NaN                   NaN                  NaN
# 4      NaN        NaN                   NaN                  NaN
#
#   How many years of IT/Programming experience do you have? ResumePrompted  \
# 0                                                       <2            NaN
# 1                                                    41310            NaN
# 2                                                    41435            NaN
# 3                                                    41310            NaN
# 4                                                       11            NaN
#
#   DatabaseWorkedWith important_variety MajorUndergrad  \
# 0                NaN               NaN            NaN
# 1                NaN               NaN            NaN
# 2                NaN               NaN            NaN
# 3                NaN               NaN            NaN
# 4                NaN               NaN            NaN
#
#   What is your involvement in purchasing products or services for the company you work for? (You can choose more than one) (Influencer)  \
# 0                                                                                                                                   NaN
# 1                                                                                                                                   NaN
# 2                                                                                                                                   NaN
# 3                                                                                                                                   NaN
# 4                                                                                                                                   NaN
#
#   AIToolCurrently partially AI nan (Other Stack Exchange (please specify))  \
# 0                          NaN                                         NaN
# 1                          NaN                                         NaN
# 2                          NaN                                         NaN
# 3                          NaN                                         NaN
# 4                          NaN                                         NaN
#
#   OfficeStackHaveEntry  \
# 0                  NaN
# 1                  NaN
# 2                  NaN
# 3                  NaN
# 4                  NaN
#
#   nan (Positive Organization Structure (not much bureaucracy, helpful management))  \
# 0                                                                              NaN
# 1                                                                              NaN
# 2                                                                              NaN
# 3                                                                              NaN
# 4                                                                              NaN
#
#   nan (No Involvement)  \
# 0                  NaN
# 1       No Involvement
# 2                  NaN
# 3       No Involvement
# 4                  NaN
#
#   nan (Quality of Workstation (dream machine, 30inch monitors, etc))  \
# 0                                                                NaN
# 1                                                                NaN
# 2                                                                NaN
# 3                                                                NaN
# 4                                                                NaN
#
#   KinshipDevelopers EnjoyDebugging SO_Actions_15_TEXT nan (MongoDB)  \
# 0               NaN            NaN                NaN           NaN
# 1               NaN            NaN                NaN           NaN
# 2               NaN            NaN                NaN           NaN
# 3               NaN            NaN                NaN           NaN
# 4               NaN            NaN                NaN           NaN
#
#   nan (Perl) StackOverflowNewQuestion nan (Android Phone) HoursComputer  \
# 0        NaN                      NaN                 NaN           NaN
# 1        NaN                      NaN                 NaN           NaN
# 2        NaN                      NaN                 NaN           NaN
# 3        NaN                      NaN                 NaN           NaN
# 4       Perl                      NaN                 NaN           NaN
#
#   Select all that apply (Why answer: Help a programmer in need)  \
# 0                                                           NaN
# 1                                                           NaN
# 2                                                           NaN
# 3                                                           NaN
# 4                                                           NaN
#
#   InfluenceDeptTech SOVisitFreq nan (I'm a Seller)  \
# 0               NaN         NaN                NaN
# 1               NaN         NaN                NaN
# 2               NaN         NaN       I'm a Seller
# 3               NaN         NaN                NaN
# 4               NaN         NaN                NaN
#
#   nan (Appealing message traits: Stack Overflow activity mentioned)  \
# 0                                                               NaN
# 1                                                               NaN
# 2                                                               NaN
# 3                                                               NaN
# 4                                                               NaN
#
#    TechEndorse_9 ImportantBenefits nan (Recruitment Tools & Services)  \
# 0            NaN               NaN                                NaN
# 1            NaN               NaN                                NaN
# 2            NaN               NaN                                NaN
# 3            NaN               NaN                                NaN
# 4            NaN               NaN                                NaN
#
#    TechEndorse_4  \
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
#
#   nan (Most important aspect of new job opportunity: Important decisions)  \
# 0                                                                     NaN
# 1                                                                     NaN
# 2                                                                     NaN
# 3                                                                     NaN
# 4                                                                     NaN
#
#   ImportantHiringCommunication Student nan (Source control used: Mercurial)  \
# 0                          NaN     NaN                                  NaN
# 1                          NaN     NaN                                  NaN
# 2                          NaN     NaN                                  NaN
# 3                          NaN     NaN                                  NaN
# 4                          NaN     NaN                                  NaN
#
#   TechOppose_15_TEXT  TechEndorse_6  \
# 0                NaN            NaN
# 1                NaN            NaN
# 2                NaN            NaN
# 3                NaN            NaN
# 4                NaN            NaN
#
#   nan (Why answer: I don't answer but I want to)  \
# 0                                            NaN
# 1                                            NaN
# 2                                            NaN
# 3                                            NaN
# 4                                            NaN
#
#   nan (Source control used: Legacy / Custom)  \
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4                                        NaN
#
#   nan (Software as a service / recurring billing) ProgramHobby
# 0                                             NaN          NaN
# 1                                             NaN          NaN
# 2                                             NaN          NaN
# 3                                             NaN          NaN
# 4                                             NaN          NaN

# %%
combined_df.head()
# Out:
#   ImportantHiringRep EquipmentSatisfiedRAM EduOther  HoursPerWeek LearnCodeAI  \
# 0                NaN                   NaN      NaN           NaN         NaN
# 1                NaN                   NaN      NaN           NaN         NaN
# 2                NaN                   NaN      NaN           NaN         NaN
# 3                NaN                   NaN      NaN           NaN         NaN
# 4                NaN                   NaN      NaN           NaN         NaN
#
#    JobSatPoints_16 company_size_range WebframeWantEntry AssessJobCompensation  \
# 0              NaN                NaN               NaN                   NaN
# 1              NaN                NaN               NaN                   NaN
# 2              NaN                NaN               NaN                   NaN
# 3              NaN                NaN               NaN                   NaN
# 4              NaN                NaN               NaN                   NaN
#
#    TechOppose_2 nan (Training & Education: Other) why_stack_overflow  \
# 0           NaN                               NaN                NaN
# 1           NaN                               NaN                NaN
# 2           NaN                               NaN                NaN
# 3           NaN                               NaN                NaN
# 4           NaN                               NaN                NaN
#
#   LanguageDesireNextYear EthicalImplications  CompTotal Knowledge_6  \
# 0                    NaN                 NaN        NaN         NaN
# 1                    NaN                 NaN        NaN         NaN
# 2                    NaN                 NaN        NaN         NaN
# 3                    NaN                 NaN        NaN         NaN
# 4                    NaN                 NaN        NaN         NaN
#
#   nan (Training & Education: Masters in CS) nan (Fixing bugs)  \
# 0                                       NaN               NaN
# 1                                       NaN               NaN
# 2                                       NaN               NaN
# 3                                       NaN               NaN
# 4                                       NaN               NaN
#
#   nan (Future Lang & Tech: R) YearsCodePro nan (Desktop Operating System)  \
# 0                         NaN          NaN                            NaN
# 1                         NaN          NaN                            NaN
# 2                         NaN          NaN                            NaN
# 3                         NaN          NaN                            NaN
# 4                         NaN          NaN                            NaN
#
#   nan (Why try Stack Overflow Careers: Selection of revelant jobs)  \
# 0                                                              NaN
# 1                                                              NaN
# 2                                                              NaN
# 3                                                              NaN
# 4                                                              NaN
#
#   AIToolDon't plan to use AI for this task PurchaseHow dogs_vs_cats  \
# 0                                      NaN         NaN          NaN
# 1                                      NaN         NaN          NaN
# 2                                      NaN         NaN          NaN
# 3                                      NaN         NaN          NaN
# 4                                      NaN         NaN          NaN
#
#   nan (TypeScript) AgreeDisagree2 EquipmentSatisfiedMonitors nan (Servers)  \
# 0              NaN            NaN                        NaN           NaN
# 1              NaN            NaN                        NaN           NaN
# 2              NaN            NaN                        NaN           NaN
# 3              NaN            NaN                        NaN           NaN
# 4              NaN            NaN                        NaN       Servers
#
#   nan (Perception of contact form: Twitter)  \
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
#
#   nan (Current Lang & Tech: Cordova)  \
# 0                                NaN
# 1                                NaN
# 2                                NaN
# 3                                NaN
# 4                                NaN
#
#   Please rate the advertising you've seen on Stack Overflow (The ads are relevant)  \
# 0                                                                              NaN
# 1                                                                              NaN
# 2                                                                              NaN
# 3                                                                              NaN
# 4                                                                              NaN
#
#   nan (Link to a Stack Overflow Careers Company Page or other source of more information about the company (videos, articles, etc))  \
# 0                                                                                                                               NaN
# 1                                                                                                                               NaN
# 2                                                                                                                               NaN
# 3                                                                                                                               NaN
# 4                                                                                                                               NaN
#
#   FizzBuzz InfluenceVizTools StackOverflowModeration  \
# 0      NaN               NaN                     NaN
# 1      NaN               NaN                     NaN
# 2      NaN               NaN                     NaN
# 3      NaN               NaN                     NaN
# 4      NaN               NaN                     NaN
#
#   nan (How frequently land on or read Stack Overflow)  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
#
#   nan (Current Lang & Tech: SQL Server) HaveWorkedPlatform employment_status  \
# 0                                   NaN                NaN               NaN
# 1                                   NaN                NaN               NaN
# 2                                   NaN                NaN               NaN
# 3                                   NaN                NaN               NaN
# 4                                   NaN                NaN               NaN
#
#   interview_likelihood EquipmentSatisfiedRW SOVisit1st  \
# 0                  NaN                  NaN        NaN
# 1                  NaN                  NaN        NaN
# 2                  NaN                  NaN        NaN
# 3                  NaN                  NaN        NaN
# 4                  NaN                  NaN        NaN
#
#   nan (Future Lang & Tech: Redis) job_discovery nan (Commuting)  \
# 0                             NaN           NaN             NaN
# 1                             NaN           NaN             NaN
# 2                             NaN           NaN             NaN
# 3                             NaN           NaN             NaN
# 4                             NaN           NaN             NaN
#
#   nan (Limited night / weekend work)  \
# 0                                NaN
# 1                                NaN
# 2                                NaN
# 3                                NaN
# 4                                NaN
#
#   What types of purchases are you involved in? (Hardware)  \
# 0                                                     NaN
# 1                                                     NaN
# 2                                                     NaN
# 3                                                     NaN
# 4                                                Hardware
#
#   nan (Future Lang & Tech: Scala) DatabaseDesireNextYear CurrencyDesc  \
# 0                             NaN                    NaN          NaN
# 1                             NaN                    NaN          NaN
# 2                             NaN                    NaN          NaN
# 3                             NaN                    NaN          NaN
# 4                             NaN                    NaN          NaN
#
#   nan (Current Lang & Tech: Redis)  \
# 0                              NaN
# 1                              NaN
# 2                              NaN
# 3                              NaN
# 4                              NaN
#
#   nan (Appealing message traits: Stack Overflow Company Page)  \
# 0                                                         NaN
# 1                                                         NaN
# 2                                                         NaN
# 3                                                         NaN
# 4                                                         NaN
#
#   DatabaseWantToWorkWith WorkChallenge ICorPM  \
# 0                    NaN           NaN    NaN
# 1                    NaN           NaN    NaN
# 2                    NaN           NaN    NaN
# 3                    NaN           NaN    NaN
# 4                    NaN           NaN    NaN
#
#   How likely is it that a recommendation you make will be acted upon?  \
# 0                                              Not in a million years
# 1                                           It's been known to happen
# 2                                    Unless it's stoopid it gets done
# 3                                           It's been known to happen
# 4                                                    I run this place
#
#   nan (Most urgent info about job opportunity: Job title) WebframeAdmired  \
# 0                                                     NaN             NaN
# 1                                                     NaN             NaN
# 2                                                     NaN             NaN
# 3                                                     NaN             NaN
# 4                                                     NaN             NaN
#
#   AssessJobDiversity EmploymentStatus Knowledge_8 Methodology nan (Node.js)  \
# 0                NaN              NaN         NaN         NaN           NaN
# 1                NaN              NaN         NaN         NaN           NaN
# 2                NaN              NaN         NaN         NaN           NaN
# 3                NaN              NaN         NaN         NaN           NaN
# 4                NaN              NaN         NaN         NaN           NaN
#
#    AdsPriorities2 nan (Recommender) nan (Other tablet) SOComm  nan  \
# 0             NaN               NaN                NaN    NaN  NaN
# 1             NaN               NaN                NaN    NaN  NaN
# 2             NaN               NaN                NaN    NaN  NaN
# 3             NaN               NaN                NaN    NaN  NaN
# 4             NaN               NaN                NaN    NaN  NaN
#
#   AIAgentChallengesNeutral AISelect  \
# 0                      NaN      NaN
# 1                      NaN      NaN
# 2                      NaN      NaN
# 3                      NaN      NaN
# 4                      NaN      NaN
#
#   Which best describes the size of your company? How old are you?  \
# 0                                Start Up (1-25)             < 20
# 1                 Mature Small Business (25-100)            25-29
# 2                            Mid Sized (100-999)            25-29
# 3                                        Student             < 20
# 4                                Start Up (1-25)            35-39
#
#   ProblemSolving Frustration nan (Current Lang & Tech: Hadoop)  \
# 0            NaN         NaN                               NaN
# 1            NaN         NaN                               NaN
# 2            NaN         NaN                               NaN
# 3            NaN         NaN                               NaN
# 4            NaN         NaN                               NaN
#
#   PlatformWorkedWith CurrencySymbol AdsAgreeDisagree2 nan (Consultants)  \
# 0                NaN            NaN               NaN               NaN
# 1                NaN            NaN               NaN               NaN
# 2                NaN            NaN               NaN               NaN
# 3                NaN            NaN               NaN               NaN
# 4                NaN            NaN               NaN               NaN
#
#   Accessibility  \
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN
#
#   You answered you don't have a Careers profile, can you elaborate why?  \
# 0                                                                   NaN
# 1                                                                   NaN
# 2                                                                   NaN
# 3                                                                   NaN
# 4                                                                   NaN
#
#   nan (Current Lang & Tech: Cassandra) WantWorkDatabase  \
# 0                                  NaN              NaN
# 1                                  NaN              NaN
# 2                                  NaN              NaN
# 3                                  NaN              NaN
# 4                                  NaN              NaN
#
#   Which of our sites do you frequent most? nan (CSS)  \
# 0                                      NaN       NaN
# 1                           Stack Overflow       NaN
# 2                                      NaN       NaN
# 3                           Stack Overflow       NaN
# 4                           Stack Overflow       CSS
#
#   nan (Future Lang & Tech: Java) StackOverflowDevices QuestionsConfusing  \
# 0                            NaN                  NaN                NaN
# 1                            NaN                  NaN                NaN
# 2                            NaN                  NaN                NaN
# 3                            NaN                  NaN                NaN
# 4                            NaN                  NaN                NaN
#
#   How many people work for your company?  \
# 0                                    NaN
# 1                                    NaN
# 2                                    NaN
# 3                                    NaN
# 4                                    NaN
#
#   nan (Most important aspect of new job opportunity: Company size)  \
# 0                                                              NaN
# 1                                                              NaN
# 2                                                              NaN
# 3                                                              NaN
# 4                                                              NaN
#
#   BlockchainOrg  salary_midpoint PurchaseInfluence  \
# 0           NaN              NaN               NaN
# 1           NaN              NaN               NaN
# 2           NaN              NaN               NaN
# 3           NaN              NaN               NaN
# 4           NaN              NaN               NaN
#
#   How often do you find solutions to your programming problems on Stack Overflow without asking a new question?  \
# 0                                                                                                           NaN
# 1                                                                                                           NaN
# 2                                                                                                           NaN
# 3                                                                                                           NaN
# 4                                                                                                           NaN
#
#    big_mac_index remote  JobEmailPriorities1 TechEndorse  TechEndorse_1  \
# 0            NaN    NaN                  NaN         NaN            NaN
# 1            NaN    NaN                  NaN         NaN            NaN
# 2            NaN    NaN                  NaN         NaN            NaN
# 3            NaN    NaN                  NaN         NaN            NaN
# 4            NaN    NaN                  NaN         NaN            NaN
#
#   LanguageChoice HighestEducationParents nan (Blackberry) TabsSpaces  \
# 0            NaN                     NaN              NaN        NaN
# 1            NaN                     NaN              NaN        NaN
# 2            NaN                     NaN              NaN        NaN
# 3            NaN                     NaN              NaN        NaN
# 4            NaN                     NaN              NaN        NaN
#
#   CompanySize nan (Most important aspect of new job opportunity: Tech stack)  \
# 0         NaN                                                            NaN
# 1         NaN                                                            NaN
# 2         NaN                                                            NaN
# 3         NaN                                                            NaN
# 4         NaN                                                            NaN
#
#   FormalEducation StackOverflowRecommend SkipMeals Employment  \
# 0             NaN                    NaN       NaN        NaN
# 1             NaN                    NaN       NaN        NaN
# 2             NaN                    NaN       NaN        NaN
# 3             NaN                    NaN       NaN        NaN
# 4             NaN                    NaN       NaN        NaN
#
#   nan (Future Lang & Tech: C++) DeveloperType  \
# 0                           NaN           NaN
# 1                           NaN           NaN
# 2                           NaN           NaN
# 3                           NaN           NaN
# 4                           NaN           NaN
#
#   How do you prefer to be contacted about job opportunities? (Email)  \
# 0                                                                NaN
# 1                                                                NaN
# 2                                                                NaN
# 3                                                                NaN
# 4                                                                NaN
#
#   Ethnicity TimeSearching country AssessJobIndustry DifficultCommunication  \
# 0       NaN           NaN     NaN               NaN                    NaN
# 1       NaN           NaN     NaN               NaN                    NaN
# 2       NaN           NaN     NaN               NaN                    NaN
# 3       NaN           NaN     NaN               NaN                    NaN
# 4       NaN           NaN     NaN               NaN                    NaN
#
#   LanguageWorkedWith AISent nan (Check Writer) PlatformWantToWorkWith  \
# 0                NaN    NaN                NaN                    NaN
# 1                NaN    NaN                NaN                    NaN
# 2                NaN    NaN                NaN                    NaN
# 3                NaN    NaN                NaN                    NaN
# 4                NaN    NaN                NaN                    NaN
#
#   CousinEducation SOTimeSaved CommPlatformHaveEntr agree_adblocker  \
# 0             NaN         NaN                  NaN             NaN
# 1             NaN         NaN                  NaN             NaN
# 2             NaN         NaN                  NaN             NaN
# 3             NaN         NaN                  NaN             NaN
# 4             NaN         NaN                  NaN             NaN
#
#   nan ($10,001 - $25,000) SOJobs StackOverflowAdsRelevant  \
# 0                     NaN    NaN                      NaN
# 1                     NaN    NaN                      NaN
# 2                     NaN    NaN                      NaN
# 3                     NaN    NaN                      NaN
# 4       $10,001 - $25,000    NaN                      NaN
#
#   nan (Most urgent info about job opportunity: Company name)  \
# 0                                                        NaN
# 1                                                        NaN
# 2                                                        NaN
# 3                                                        NaN
# 4                                                        NaN
#
#   HypotheticalTools1 InTheZone SurveyEasy WebframeHaveEntry  \
# 0                NaN       NaN        NaN               NaN
# 1                NaN       NaN        NaN               NaN
# 2                NaN       NaN        NaN               NaN
# 3                NaN       NaN        NaN               NaN
# 4                NaN       NaN        NaN               NaN
#
#   nan (Future Lang & Tech: Cassandra) Knowledge_5  \
# 0                                 NaN         NaN
# 1                                 NaN         NaN
# 2                                 NaN         NaN
# 3                                 NaN         NaN
# 4                                 NaN         NaN
#
#   nan (Appealing message traits: Salary information) WebFrameDesireNextYear  \
# 0                                                NaN                    NaN
# 1                                                NaN                    NaN
# 2                                                NaN                    NaN
# 3                                                NaN                    NaN
# 4                                                NaN                    NaN
#
#   nan (Most important aspect of new job opportunity: Health insurance)  \
# 0                                                                  NaN
# 1                                                                  NaN
# 2                                                                  NaN
# 3                                                                  NaN
# 4                                                                  NaN
#
#    JobSatPoints_1 nan (>$150,000)  \
# 0             NaN             NaN
# 1             NaN             NaN
# 2             NaN             NaN
# 3             NaN             NaN
# 4             NaN       >$150,000
#
#   Do you have a Stack Overflow Careers Profile?  \
# 0                                           NaN
# 1                                           NaN
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN
#
#   nan (I like that I can indicate ads I want to see less of) Exercise  \
# 0                                                        NaN      NaN
# 1                                                        NaN      NaN
# 2                                                        NaN      NaN
# 3                                                        NaN      NaN
# 4                                                        NaN      NaN
#
#   How often do you visit job boards? nan (Training & Education: Online Class)  \
# 0                                NaN                                      NaN
# 1                                NaN                                      NaN
# 2                                NaN                                      NaN
# 3                                NaN                                      NaN
# 4                                NaN                                      NaN
#
#    JobEmailPriorities7  AssessJob5 AnnoyingUI DatabaseWantEntry  \
# 0                  NaN         NaN        NaN               NaN
# 1                  NaN         NaN        NaN               NaN
# 2                  NaN         NaN        NaN               NaN
# 3                  NaN         NaN        NaN               NaN
# 4                  NaN         NaN        NaN               NaN
#
#   nan (Future Lang & Tech: iOS) nan (Current Lang & Tech: C++)  \
# 0                           NaN                            NaN
# 1                           NaN                            NaN
# 2                           NaN                            NaN
# 3                           NaN                            NaN
# 4                           NaN                            NaN
#
#   nan (Purchasing Power) nan (Prefered Source Control: write-in) TBranch  \
# 0                    NaN                                     NaN     NaN
# 1                    NaN                                     NaN     NaN
# 2                    NaN                                     NaN     NaN
# 3                    NaN                                     NaN     NaN
# 4                    NaN                                     NaN     NaN
#
#   AIDevHaveWorkedWith AIBen  AssessJob8  \
# 0                 NaN   NaN         NaN
# 1                 NaN   NaN         NaN
# 2                 NaN   NaN         NaN
# 3                 NaN   NaN         NaN
# 4                 NaN   NaN         NaN
#
#   nan (Most urgent info about job opportunity: Benefits)  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
#
#   nan (Current Lang & Tech: C#) nan (Technical support)  \
# 0                           NaN                     NaN
# 1                           NaN                     NaN
# 2                           NaN                     NaN
# 3                           NaN                     NaN
# 4                           NaN                     NaN
#
#   nan (How can companies improve interview process: Gimme coffee)  \
# 0                                                             NaN
# 1                                                             NaN
# 2                                                             NaN
# 3                                                             NaN
# 4                                                             NaN
#
#   nan ($100,001 - $150,000) nan (Identification With the Company/Goals)  \
# 0                       NaN                                         NaN
# 1                       NaN                                         NaN
# 2                       NaN                                         NaN
# 3                       NaN                                         NaN
# 4       $100,001 - $150,000                                         NaN
#
#    AssessJob4 WebframeWorkedWith nan (Future Lang & Tech: PHP)  \
# 0         NaN                NaN                           NaN
# 1         NaN                NaN                           NaN
# 2         NaN                NaN                           NaN
# 3         NaN                NaN                           NaN
# 4         NaN                NaN                           NaN
#
#   InfluenceConsultants nan (Source control used: SVN) Knowledge_4  \
# 0                  NaN                            NaN         NaN
# 1                  NaN                            NaN         NaN
# 2                  NaN                            NaN         NaN
# 3                  NaN                            NaN         NaN
# 4                  NaN                            NaN         NaN
#
#    JobEmailPriorities2 nan (Current Lang & Tech: Ruby) WakeTime education  \
# 0                  NaN                             NaN      NaN       NaN
# 1                  NaN                             NaN      NaN       NaN
# 2                  NaN                             NaN      NaN       NaN
# 3                  NaN                             NaN      NaN       NaN
# 4                  NaN                             NaN      NaN       NaN
#
#   nan (Future Lang & Tech: Objective-C) AIExplain  \
# 0                                   NaN       NaN
# 1                                   NaN       NaN
# 2                                   NaN       NaN
# 3                                   NaN       NaN
# 4                                   NaN       NaN
#
#   nan (Future Lang & Tech: Python) nan (Autonomy Over Budget/Expenditures)  \
# 0                              NaN                                     NaN
# 1                              NaN                                     NaN
# 2                              NaN                                     NaN
# 3                              NaN                                     NaN
# 4                              NaN                                     NaN
#
#   nan (Current Lang & Tech: Python)  \
# 0                               NaN
# 1                               NaN
# 2                               NaN
# 3                               NaN
# 4                               NaN
#
#   What is your budget for outside expenditures (hardware, software, consulting, etc) for 2014?  \
# 0                                                                                          NaN
# 1                                                                                          NaN
# 2                                                                                          NaN
# 3                                                                                          NaN
# 4                                                                                          NaN
#
#   AIAgentOrchWrite AIHuman StackOverflowCompanyPage  \
# 0              NaN     NaN                      NaN
# 1              NaN     NaN                      NaN
# 2              NaN     NaN                      NaN
# 3              NaN     NaN                      NaN
# 4              NaN     NaN                      NaN
#
#   OfficeStackSyncWantToWorkWith UpdateCV important_wfh NumberMonitors  \
# 0                           NaN      NaN           NaN            NaN
# 1                           NaN      NaN           NaN            NaN
# 2                           NaN      NaN           NaN            NaN
# 3                           NaN      NaN           NaN            NaN
# 4                           NaN      NaN           NaN            NaN
#
#   ResumeUpdate Which US State or Territory do you live in?  \
# 0          NaN                                         NaN
# 1          NaN                                         NaN
# 2          NaN                                         NaN
# 3          NaN                                         NaN
# 4          NaN                                         NaN
#
#   nan (Who do you want to communicate with about a new job opportunity: In-house tech recruiter)  \
# 0                                                                                            NaN
# 1                                                                                            NaN
# 2                                                                                            NaN
# 3                                                                                            NaN
# 4                                                                                            NaN
#
#   nan (Xbox) StackOverflowAdsDistracting  \
# 0        NaN                         NaN
# 1        NaN                         NaN
# 2        NaN                         NaN
# 3        NaN                         NaN
# 4       Xbox                         NaN
#
#   nan (I influence purchasing decisions, but don't have final approval)  \
# 0                                                                   NaN
# 1                                                                   NaN
# 2                                                                   NaN
# 3                                                                   NaN
# 4                                                                   NaN
#
#   LanguageAdmired ImportantHiringPMExp  AssessBenefits4 Hobbyist  \
# 0             NaN                  NaN              NaN      NaN
# 1             NaN                  NaN              NaN      NaN
# 2             NaN                  NaN              NaN      NaN
# 3             NaN                  NaN              NaN      NaN
# 4             NaN                  NaN              NaN      NaN
#
#   YearsCodingProf  \
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN
#
#   nan (How can companies improve interview process: Flexible interview schedule)  \
# 0                                                                            NaN
# 1                                                                            NaN
# 2                                                                            NaN
# 3                                                                            NaN
# 4                                                                            NaN
#
#   EmbeddedHaveWorkedWith  TechOppose_7 AIAgentChallengesSomewhat agree  \
# 0                    NaN           NaN                             NaN
# 1                    NaN           NaN                             NaN
# 2                    NaN           NaN                             NaN
# 3                    NaN           NaN                             NaN
# 4                    NaN           NaN                             NaN
#
#    AdsPriorities1 Which of the following best describes your occupation?  \
# 0             NaN                              Web Application Developer
# 1             NaN                                      Server Programmer
# 2             NaN                                      Server Programmer
# 3             NaN                                                Student
# 4             NaN                  Executive (VP of Eng, CTO, CIO, etc.)
#
#   MainBranch  JobSatPoints_13  Respondent  \
# 0        NaN              NaN         NaN
# 1        NaN              NaN         NaN
# 2        NaN              NaN         NaN
# 3        NaN              NaN         NaN
# 4        NaN              NaN         NaN
#
#   nan (Most annoying about job search: Finding interesting job)  \
# 0                                                           NaN
# 1                                                           NaN
# 2                                                           NaN
# 3                                                           NaN
# 4                                                           NaN
#
#   important_ownoffice InfluenceCloud AIModelsWantEntry team_size_range  \
# 0                 NaN            NaN               NaN             NaN
# 1                 NaN            NaN               NaN             NaN
# 2                 NaN            NaN               NaN             NaN
# 3                 NaN            NaN               NaN             NaN
# 4                 NaN            NaN               NaN             NaN
#
#   nan (I can buy anything I want without asking anyone) AIDangerous  \
# 0                                                   NaN         NaN
# 1                                                   NaN         NaN
# 2                                                   NaN         NaN
# 3                                                   NaN         NaN
# 4                                                   NaN         NaN
#
#   EmbeddedAdmired nan (CoffeeScript) AssessJobTech HopeFiveYears  \
# 0             NaN                NaN           NaN           NaN
# 1             NaN                NaN           NaN           NaN
# 2             NaN                NaN           NaN           NaN
# 3             NaN                NaN           NaN           NaN
# 4             NaN                NaN           NaN           NaN
#
#   nan (Xbox 360) nan (Includes salary information) AIToolInterested in Using  \
# 0            NaN                               NaN                       NaN
# 1            NaN                               NaN                       NaN
# 2            NaN                               NaN                       NaN
# 3            NaN                               NaN                       NaN
# 4            NaN                               NaN                       NaN
#
#   AINextLess integrated nan (Appealing message traits: Team described)  \
# 0                   NaN                                            NaN
# 1                   NaN                                            NaN
# 2                   NaN                                            NaN
# 3                   NaN                                            NaN
# 4                   NaN                                            NaN
#
#   DevEnvsHaveWorkedWith  JobSatPoints_10 nan (Python)  \
# 0                   NaN              NaN          NaN
# 1                   NaN              NaN          NaN
# 2                   NaN              NaN          NaN
# 3                   NaN              NaN          NaN
# 4                   NaN              NaN          NaN
#
#   nan (Future Lang & Tech: Write-In) nan (How often contacted by recruiters)  \
# 0                                NaN                                     NaN
# 1                                NaN                                     NaN
# 2                                NaN                                     NaN
# 3                                NaN                                     NaN
# 4                                NaN                                     NaN
#
#   AssessJobProduct occupation_group important_promotion  TechOppose_16  \
# 0              NaN              NaN                 NaN            NaN
# 1              NaN              NaN                 NaN            NaN
# 2              NaN              NaN                 NaN            NaN
# 3              NaN              NaN                 NaN            NaN
# 4              NaN              NaN                 NaN            NaN
#
#   so_region DatabaseChoice nan (Open to new job opportunities)  \
# 0       NaN            NaN                                 NaN
# 1       NaN            NaN                                 NaN
# 2       NaN            NaN                                 NaN
# 3       NaN            NaN                                 NaN
# 4       NaN            NaN                                 NaN
#
#   ExCoderWillNotCode WelcomeChange new_job_value  \
# 0                NaN           NaN           NaN
# 1                NaN           NaN           NaN
# 2                NaN           NaN           NaN
# 3                NaN           NaN           NaN
# 4                NaN           NaN           NaN
#
#   How would you best describe the industry you currently work in?  \
# 0                                                             NaN
# 1                                                             NaN
# 2                                                             NaN
# 3                                                             NaN
# 4                                                             NaN
#
#   CompetePeers nan (User Equipment: Monitors, PCs, Laptops)  \
# 0          NaN                                          NaN
# 1          NaN                                          NaN
# 2          NaN                                          NaN
# 3          NaN       User Equipment: Monitors, PCs, Laptops
# 4          NaN       User Equipment: Monitors, PCs, Laptops
#
#   nan (Future Lang & Tech: Dart) nan (Future Lang & Tech: Haskell) AIEthics  \
# 0                            NaN                               NaN      NaN
# 1                            NaN                               NaN      NaN
# 2                            NaN                               NaN      NaN
# 3                            NaN                               NaN      NaN
# 4                            NaN                               NaN      NaN
#
#   nan (Human Resources)  TechOppose_13 nan (Grants / outside fund-raising)  \
# 0                   NaN            NaN                                 NaN
# 1                   NaN            NaN                                 NaN
# 2                   NaN            NaN                                 NaN
# 3                   NaN            NaN                                 NaN
# 4                   NaN            NaN                                 NaN
#
#   NEWOvertime  \
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
#
#   What other departments / roles do you interact with regularly? (System Administrators)  \
# 0                                                                                    NaN
# 1                                                                                    NaN
# 2                                                                                    NaN
# 3                                                                                    NaN
# 4                                                                                    NaN
#
#   nan (Describes benefits / perks of the work environment) nan (Wii)  \
# 0                                                      NaN       NaN
# 1                                                      NaN       NaN
# 2                                                      NaN       NaN
# 3                                                      NaN       Wii
# 4                                                      NaN       NaN
#
#   nan (Most important aspect of new job opportunity: Office location)  \
# 0                                                                 NaN
# 1                                                                 NaN
# 2                                                                 NaN
# 3                                                                 NaN
# 4                                                                 NaN
#
#   ToolsTechHaveWorkedWith US_State  SO_Actions_10 StackOverflowDescribes  \
# 0                     NaN      NaN            NaN                    NaN
# 1                     NaN      NaN            NaN                    NaN
# 2                     NaN      NaN            NaN                    NaN
# 3                     NaN      NaN            NaN                    NaN
# 4                     NaN      NaN            NaN                    NaN
#
#   nan (Future Lang & Tech: C++11) AIModelsHaveEntry ExCoderBelonged  \
# 0                             NaN               NaN             NaN
# 1                             NaN               NaN             NaN
# 2                             NaN               NaN             NaN
# 3                             NaN               NaN             NaN
# 4                             NaN               NaN             NaN
#
#   nan (Most important aspect of new job opportunity: Remote working)  \
# 0                                                                NaN
# 1                                                                NaN
# 2                                                                NaN
# 3                                                                NaN
# 4                                                                NaN
#
#    AssessJob2 nan (Future Lang & Tech: Hadoop) important_control agree_notice  \
# 0         NaN                              NaN               NaN          NaN
# 1         NaN                              NaN               NaN          NaN
# 2         NaN                              NaN               NaN          NaN
# 3         NaN                              NaN               NaN          NaN
# 4         NaN                              NaN               NaN          NaN
#
#    AssessJob6 Select up to 3 (Most annoying about job search: Finding time)  \
# 0         NaN                                                           NaN
# 1         NaN                                                           NaN
# 2         NaN                                                           NaN
# 3         NaN                                                           NaN
# 4         NaN                                                           NaN
#
#   ToolsTechAdmired  JobEmailPriorities4 DevEnvsWantToWorkWith  \
# 0              NaN                  NaN                   NaN
# 1              NaN                  NaN                   NaN
# 2              NaN                  NaN                   NaN
# 3              NaN                  NaN                   NaN
# 4              NaN                  NaN                   NaN
#
#   ImportantHiringTechExp CollaborateRemote ImportantHiringGettingThingsDone  \
# 0                    NaN               NaN                              NaN
# 1                    NaN               NaN                              NaN
# 2                    NaN               NaN                              NaN
# 3                    NaN               NaN                              NaN
# 4                    NaN               NaN                              NaN
#
#   nan (Xbox One) nan (Current Lang & Tech: PHP) nan (jQuery) agree_nightcode  \
# 0            NaN                            NaN          NaN             NaN
# 1            NaN                            NaN          NaN             NaN
# 2            NaN                            NaN          NaN             NaN
# 3            NaN                            NaN          NaN             NaN
# 4            NaN                            NaN          NaN             NaN
#
#   MetricAssess DiversityImportant  VCHostingProfessional use  \
# 0          NaN                NaN                        NaN
# 1          NaN                NaN                        NaN
# 2          NaN                NaN                        NaN
# 3          NaN                NaN                        NaN
# 4          NaN                NaN                        NaN
#
#   VersionControlSystem nan (Other) nan (Learning new skills)  \
# 0                  NaN         NaN                       NaN
# 1                  NaN         NaN                       NaN
# 2                  NaN         NaN                       NaN
# 3                  NaN         NaN                       NaN
# 4                  NaN         NaN                       NaN
#
#   nan (I have a discretionary budget at my disposal) NEWStuck  \
# 0                                                NaN      NaN
# 1                                                NaN      NaN
# 2                                                NaN      NaN
# 3                                                NaN      NaN
# 4                                                NaN      NaN
#
#   nan (Android Tablet) nan (Current Lang & Tech: AngularJS)  \
# 0                  NaN                                  NaN
# 1                  NaN                                  NaN
# 2                  NaN                                  NaN
# 3                  NaN                                  NaN
# 4                  NaN                                  NaN
#
#   nan (Why answer: Help future programmers) nan (Testers / Quality Assurance)  \
# 0                                       NaN                               NaN
# ...
# 3                              NaN         NaN                    NaN
# 4                              NaN         NaN                    NaN
#
#   OpenSource BlockchainIs WorkPlan nan (Perception of recruiter contact)  \
# 0        NaN          NaN      NaN                                   NaN
# 1        NaN          NaN      NaN                                   NaN
# 2        NaN          NaN      NaN                                   NaN
# 3        NaN          NaN      NaN                                   NaN
# 4        NaN          NaN      NaN                                   NaN
#
#   EducationTypes AIAgentChallengesSomewhat disagree  \
# 0            NaN                                NaN
# 1            NaN                                NaN
# 2            NaN                                NaN
# 3            NaN                                NaN
# 4            NaN                                NaN
#
#   nan (Answer questions I know the answer to) StackOverflowWhatDo  \
# 0                                         NaN                 NaN
# 1                                         NaN                 NaN
# 2                                         NaN                 NaN
# 3                                         NaN                 NaN
# 4                                         NaN                 NaN
#
#   ErgonomicDevices AdsAgreeDisagree3 LearnCodeCoursesCert  \
# 0              NaN               NaN                  NaN
# 1              NaN               NaN                  NaN
# 2              NaN               NaN                  NaN
# 3              NaN               NaN                  NaN
# 4              NaN               NaN                  NaN
#
#   Please rate your job/career satisfaction HypotheticalTools2  \
# 0                                      FML                NaN
# 1                        So happy it hurts                NaN
# 2                                      NaN                NaN
# 3                    I enjoy going to work                NaN
# 4                        It pays the bills                NaN
#
#   StackOverflowHasAccount AIAgentKnowWrite nan (Remote Status)  \
# 0                     NaN              NaN                 NaN
# 1                     NaN              NaN                 NaN
# 2                     NaN              NaN                 NaN
# 3                     NaN              NaN                 NaN
# 4                     NaN              NaN                 NaN
#
#   nan (Source control used: CVS) nan (Current Lang & Tech: Salesforce)  \
# 0                            NaN                                   NaN
# 1                            NaN                                   NaN
# 2                            NaN                                   NaN
# 3                            NaN                                   NaN
# 4                            NaN                                   NaN
#
#   ImportantHiringEducation Industry visit_frequency  \
# 0                      NaN      NaN             NaN
# 1                      NaN      NaN             NaN
# 2                      NaN      NaN             NaN
# 3                      NaN      NaN             NaN
# 4                      NaN      NaN             NaN
#
#   Select all that apply (Future Lang & Tech: Android) HaveWorkedLanguage  \
# 0                                                 NaN                NaN
# 1                                                 NaN                NaN
# 2                                                 NaN                NaN
# 3                                                 NaN                NaN
# 4                                                 NaN                NaN
#
#   nan (Most annoying about job search: The Interview) JobFactors  \
# 0                                                 NaN        NaN
# 1                                                 NaN        NaN
# 2                                                 NaN        NaN
# 3                                                 NaN        NaN
# 4                                                 NaN        NaN
#
#   In receiving an email about a job opportunity, what attributes of the message would make you more likely to respond? (Message is personalized to me)  \
# 0                                                                                                                                                  NaN
# 1                                                                                                                                                  NaN
# 2                                                                                                                                                  NaN
# 3                                                                                                                                                  NaN
# 4                                                                                                                                                  NaN
#
#   nan (I've taken a trial/purchased a product from ads)  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
#
#   nan (How many caffeinated beverages per day?) nan (AppleTV)  \
# 0                                           NaN           NaN
# 1                                           NaN           NaN
# 2                                           NaN           NaN
# 3                                           NaN           NaN
# 4                                           NaN           NaN
#
#   nan (Windows Phone) WorkLoc Containers AINextMuch less integrated  \
# 0                 NaN     NaN        NaN                        NaN
# 1                 NaN     NaN        NaN                        NaN
# 2                 NaN     NaN        NaN                        NaN
# 3                 NaN     NaN        NaN                        NaN
# 4                 NaN     NaN        NaN                        NaN
#
#   DevEnvWantEntry nan (Future Lang & Tech: Swift) LastNewJob  \
# 0             NaN                             NaN        NaN
# 1             NaN                             NaN        NaN
# 2             NaN                             NaN        NaN
# 3             NaN                             NaN        NaN
# 4             NaN                             NaN        NaN
#
#    JobContactPriorities5 StackOverflowJobSearch nan (Wii U)  \
# 0                    NaN                    NaN         NaN
# 1                    NaN                    NaN         NaN
# 2                    NaN                    NaN         NaN
# 3                    NaN                    NaN         NaN
# 4                    NaN                    NaN         NaN
#
#   nan (Future Lang & Tech: Clojure) ProfessionalCloud AssessJobFinances  \
# 0                               NaN               NaN               NaN
# 1                               NaN               NaN               NaN
# 2                               NaN               NaN               NaN
# 3                               NaN               NaN               NaN
# 4                               NaN               NaN               NaN
#
#   MgrIdiot BuildvsBuy OpSysProfessional use StackOverflowHelpful  \
# 0      NaN        NaN                   NaN                  NaN
# 1      NaN        NaN                   NaN                  NaN
# 2      NaN        NaN                   NaN                  NaN
# 3      NaN        NaN                   NaN                  NaN
# 4      NaN        NaN                   NaN                  NaN
#
#   How many years of IT/Programming experience do you have? ResumePrompted  \
# 0                                                       <2            NaN
# 1                                                    41310            NaN
# 2                                                    41435            NaN
# 3                                                    41310            NaN
# 4                                                       11            NaN
#
#   DatabaseWorkedWith important_variety MajorUndergrad  \
# 0                NaN               NaN            NaN
# 1                NaN               NaN            NaN
# 2                NaN               NaN            NaN
# 3                NaN               NaN            NaN
# 4                NaN               NaN            NaN
#
#   What is your involvement in purchasing products or services for the company you work for? (You can choose more than one) (Influencer)  \
# 0                                                                                                                                   NaN
# 1                                                                                                                                   NaN
# 2                                                                                                                                   NaN
# 3                                                                                                                                   NaN
# 4                                                                                                                                   NaN
#
#   AIToolCurrently partially AI nan (Other Stack Exchange (please specify))  \
# 0                          NaN                                         NaN
# 1                          NaN                                         NaN
# 2                          NaN                                         NaN
# 3                          NaN                                         NaN
# 4                          NaN                                         NaN
#
#   OfficeStackHaveEntry  \
# 0                  NaN
# 1                  NaN
# 2                  NaN
# 3                  NaN
# 4                  NaN
#
#   nan (Positive Organization Structure (not much bureaucracy, helpful management))  \
# 0                                                                              NaN
# 1                                                                              NaN
# 2                                                                              NaN
# 3                                                                              NaN
# 4                                                                              NaN
#
#   nan (No Involvement)  \
# 0                  NaN
# 1       No Involvement
# 2                  NaN
# 3       No Involvement
# 4                  NaN
#
#   nan (Quality of Workstation (dream machine, 30inch monitors, etc))  \
# 0                                                                NaN
# 1                                                                NaN
# 2                                                                NaN
# 3                                                                NaN
# 4                                                                NaN
#
#   KinshipDevelopers EnjoyDebugging SO_Actions_15_TEXT nan (MongoDB)  \
# 0               NaN            NaN                NaN           NaN
# 1               NaN            NaN                NaN           NaN
# 2               NaN            NaN                NaN           NaN
# 3               NaN            NaN                NaN           NaN
# 4               NaN            NaN                NaN           NaN
#
#   nan (Perl) StackOverflowNewQuestion nan (Android Phone) HoursComputer  \
# 0        NaN                      NaN                 NaN           NaN
# 1        NaN                      NaN                 NaN           NaN
# 2        NaN                      NaN                 NaN           NaN
# 3        NaN                      NaN                 NaN           NaN
# 4       Perl                      NaN                 NaN           NaN
#
#   Select all that apply (Why answer: Help a programmer in need)  \
# 0                                                           NaN
# 1                                                           NaN
# 2                                                           NaN
# 3                                                           NaN
# 4                                                           NaN
#
#   InfluenceDeptTech SOVisitFreq nan (I'm a Seller)  \
# 0               NaN         NaN                NaN
# 1               NaN         NaN                NaN
# 2               NaN         NaN       I'm a Seller
# 3               NaN         NaN                NaN
# 4               NaN         NaN                NaN
#
#   nan (Appealing message traits: Stack Overflow activity mentioned)  \
# 0                                                               NaN
# 1                                                               NaN
# 2                                                               NaN
# 3                                                               NaN
# 4                                                               NaN
#
#    TechEndorse_9 ImportantBenefits nan (Recruitment Tools & Services)  \
# 0            NaN               NaN                                NaN
# 1            NaN               NaN                                NaN
# 2            NaN               NaN                                NaN
# 3            NaN               NaN                                NaN
# 4            NaN               NaN                                NaN
#
#    TechEndorse_4  \
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
#
#   nan (Most important aspect of new job opportunity: Important decisions)  \
# 0                                                                     NaN
# 1                                                                     NaN
# 2                                                                     NaN
# 3                                                                     NaN
# 4                                                                     NaN
#
#   ImportantHiringCommunication Student nan (Source control used: Mercurial)  \
# 0                          NaN     NaN                                  NaN
# 1                          NaN     NaN                                  NaN
# 2                          NaN     NaN                                  NaN
# 3                          NaN     NaN                                  NaN
# 4                          NaN     NaN                                  NaN
#
#   TechOppose_15_TEXT  TechEndorse_6  \
# 0                NaN            NaN
# 1                NaN            NaN
# 2                NaN            NaN
# 3                NaN            NaN
# 4                NaN            NaN
#
#   nan (Why answer: I don't answer but I want to)  \
# 0                                            NaN
# 1                                            NaN
# 2                                            NaN
# 3                                            NaN
# 4                                            NaN
#
#   nan (Source control used: Legacy / Custom)  \
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4                                        NaN
#
#   nan (Software as a service / recurring billing) ProgramHobby
# 0                                             NaN          NaN
# 1                                             NaN          NaN
# 2                                             NaN          NaN
# 3                                             NaN          NaN
# 4                                             NaN          NaN

# %%
# Create a stratified sample of 20% of the data
if combined_df is not None:
    # Calculate 20% sample size for each year
    sample_size = 0.2
    
    # Perform stratified sampling
    stratified_sample = combined_df.groupby('SurveyYear', group_keys=False).apply(
        lambda x: x.sample(frac=sample_size, random_state=42)
    ).reset_index(drop=True)
    
    # Export to CSV
    output_file = 'stackoverflow_survey_stratified_sample.csv'
    stratified_sample.to_csv(output_file, index=False)
    
    print(f"Original dataset size: {len(combined_df):,} rows")
    print(f"Sampled dataset size: {len(stratified_sample):,} rows")
    print(f"\nSample size by year:")
    print(stratified_sample['SurveyYear'].value_counts().sort_index())
    print(f"\nData exported to: {output_file}")
# Out:
# Original dataset size: 772,599 rows
# Sampled dataset size: 154,521 rows
#
# Sample size by year:
# SurveyYear
# 2011      563
# 2012     1249
# 2013     1948
# 2014     1529
# 2015     5217
# 2016    11206
# 2017    10278
# 2018    19771
# 2019    17777
# 2020    12892
# 2021    16688
# 2022    14654
# 2023    17837
# 2024    13087
# 2025     9825
# Name: count, dtype: int64
#
# Data exported to: stackoverflow_survey_stratified_sample.csv

# %%
stratified_sample.to_csv('stackoverflow_survey_stratified_sample.csv')

# %% [markdown]
# ## Adjust df_use based on the dataframe you wwant to use (sample_df, stratified_sample, etc)

# %%
sample_df = pd.read_csv('stackoverflow_survey_stratified_sample.csv')

# %%
df_use = sample_df.copy()

# %%
# Remove any columns with 'Unnamed' in their name from the combined dataframe
if df_use is not None:
    df_use = df_use.loc[:, ~df_use.columns.str.contains('^Unnamed')]

# %%
# Remove columns with 'nan' in their names from combined_df and individual year dataframes
if df_use is not None:
    # For combined dataframe
    nan_columns = df_use.columns[df_use.columns.str.contains('nan', case=False, na=False)]
    if len(nan_columns) > 0:
        print("Removing columns containing 'nan' from combined dataframe:")
        print(list(nan_columns))
        df_use = df_use.drop(columns=nan_columns)

print("\nDone cleaning column names.")
# Out:
# Removing columns containing 'nan' from combined dataframe:
# ['nan (Training & Education: Other)', 'nan (Training & Education: Masters in CS)', 'nan (Fixing bugs)', 'nan (Future Lang & Tech: R)', 'nan (Desktop Operating System)', 'nan (Why try Stack Overflow Careers: Selection of revelant jobs)', 'nan (TypeScript)', 'nan (Servers)', 'nan (Perception of contact form: Twitter)', 'nan (Current Lang & Tech: Cordova)', 'nan (Link to a Stack Overflow Careers Company Page or other source of more information about the company (videos, articles, etc))', 'nan (How frequently land on or read Stack Overflow)', 'nan (Current Lang & Tech: SQL Server)', 'nan (Future Lang & Tech: Redis)', 'nan (Commuting)', 'nan (Limited night / weekend work)', 'nan (Future Lang & Tech: Scala)', 'nan (Current Lang & Tech: Redis)', 'nan (Appealing message traits: Stack Overflow Company Page)', 'nan (Most urgent info about job opportunity: Job title)', 'nan (Node.js)', 'nan (Recommender)', 'nan (Other tablet)', 'nan', 'nan (Current Lang & Tech: Hadoop)', 'nan (Consultants)', 'nan (Current Lang & Tech: Cassandra)', 'nan (CSS)', 'nan (Future Lang & Tech: Java)', 'nan (Most important aspect of new job opportunity: Company size)', 'nan (Blackberry)', 'nan (Most important aspect of new job opportunity: Tech stack)', 'nan (Future Lang & Tech: C++)', 'nan (Check Writer)', 'nan ($10,001 - $25,000)', 'nan (Most urgent info about job opportunity: Company name)', 'nan (Future Lang & Tech: Cassandra)', 'nan (Appealing message traits: Salary information)', 'nan (Most important aspect of new job opportunity: Health insurance)', 'nan (>$150,000)', 'nan (I like that I can indicate ads I want to see less of)', 'nan (Training & Education: Online Class)', 'nan (Future Lang & Tech: iOS)', 'nan (Current Lang & Tech: C++)', 'nan (Purchasing Power)', 'nan (Prefered Source Control: write-in)', 'nan (Most urgent info about job opportunity: Benefits)', 'nan (Current Lang & Tech: C#)', 'nan (Technical support)', 'nan (How can companies improve interview process: Gimme coffee)', 'nan ($100,001 - $150,000)', 'nan (Identification With the Company/Goals)', 'nan (Future Lang & Tech: PHP)', 'nan (Source control used: SVN)', 'nan (Current Lang & Tech: Ruby)', 'nan (Future Lang & Tech: Objective-C)', 'nan (Future Lang & Tech: Python)', 'nan (Autonomy Over Budget/Expenditures)', 'nan (Current Lang & Tech: Python)', 'nan (Who do you want to communicate with about a new job opportunity: In-house tech recruiter)', 'nan (Xbox)', "nan (I influence purchasing decisions, but don't have final approval)", 'nan (How can companies improve interview process: Flexible interview schedule)', 'nan (Most annoying about job search: Finding interesting job)', 'nan (I can buy anything I want without asking anyone)', 'nan (CoffeeScript)', 'nan (Xbox 360)', 'nan (Includes salary information)', 'nan (Appealing message traits: Team described)', 'nan (Python)', 'nan (Future Lang & Tech: Write-In)', 'nan (How often contacted by recruiters)', 'nan (Open to new job opportunities)', 'nan (User Equipment: Monitors, PCs, Laptops)', 'nan (Future Lang & Tech: Dart)', 'nan (Future Lang & Tech: Haskell)', 'nan (Human Resources)', 'nan (Grants / outside fund-raising)', 'nan (Describes benefits / perks of the work environment)', 'nan (Wii)', 'nan (Most important aspect of new job opportunity: Office location)', 'nan (Future Lang & Tech: C++11)', 'nan (Most important aspect of new job opportunity: Remote working)', 'nan (Future Lang & Tech: Hadoop)', 'nan (Xbox One)', 'nan (Current Lang & Tech: PHP)', 'nan (jQuery)', 'nan (Other)', 'nan (Learning new skills)', 'nan (I have a discretionary budget at my disposal)', 'nan (Android Tablet)', 'nan (Current Lang & Tech: AngularJS)', 'nan (Why answer: Help future programmers)', 'nan (Testers / Quality Assurance)', 'nan (Other media streaming device)', 'nan (Employment Status)', 'nan (Technical Support)', 'nan (Describes company culture)', 'nan (Why use Stack Overflow: Receive help on personal projects)', 'nan (What ads? I use an ad blocker)', 'nan (Co ...
#
# Done cleaning column names.

# %%
# Update all column names in combined_df and each dataframe in dataframes to be lower case
df_use.columns = [col.lower() for col in df_use.columns]

# %%
df_use.head()
# Out:
#   importanthiringrep equipmentsatisfiedram eduother  hoursperweek learncodeai  \
# 0                NaN                   NaN      NaN           NaN         NaN
# 1                NaN                   NaN      NaN           NaN         NaN
# 2                NaN                   NaN      NaN           NaN         NaN
# 3                NaN                   NaN      NaN           NaN         NaN
# 4                NaN                   NaN      NaN           NaN         NaN
#
#    jobsatpoints_16 company_size_range webframewantentry assessjobcompensation  \
# 0              NaN                NaN               NaN                   NaN
# 1              NaN                NaN               NaN                   NaN
# 2              NaN                NaN               NaN                   NaN
# 3              NaN                NaN               NaN                   NaN
# 4              NaN                NaN               NaN                   NaN
#
#    techoppose_2 why_stack_overflow languagedesirenextyear ethicalimplications  \
# 0           NaN                NaN                    NaN                 NaN
# 1           NaN                NaN                    NaN                 NaN
# 2           NaN                NaN                    NaN                 NaN
# 3           NaN                NaN                    NaN                 NaN
# 4           NaN                NaN                    NaN                 NaN
#
#    comptotal knowledge_6 yearscodepro  \
# 0        NaN         NaN          NaN
# 1        NaN         NaN          NaN
# 2        NaN         NaN          NaN
# 3        NaN         NaN          NaN
# 4        NaN         NaN          NaN
#
#   aitooldon't plan to use ai for this task purchasehow dogs_vs_cats  \
# 0                                      NaN         NaN          NaN
# 1                                      NaN         NaN          NaN
# 2                                      NaN         NaN          NaN
# 3                                      NaN         NaN          NaN
# 4                                      NaN         NaN          NaN
#
#   agreedisagree2 equipmentsatisfiedmonitors  \
# 0            NaN                        NaN
# 1            NaN                        NaN
# 2            NaN                        NaN
# 3            NaN                        NaN
# 4            NaN                        NaN
#
#   please rate the advertising you've seen on stack overflow (the ads are relevant)  \
# 0                                                                              NaN
# 1                                                                              NaN
# 2                                                                              NaN
# 3                                                                              NaN
# 4                                                                              NaN
#
#   fizzbuzz influenceviztools stackoverflowmoderation haveworkedplatform  \
# 0      NaN               NaN                     NaN                NaN
# 1      NaN               NaN                     NaN                NaN
# 2      NaN               NaN                     NaN                NaN
# 3      NaN               NaN                     NaN                NaN
# 4      NaN               NaN                     NaN                NaN
#
#   employment_status interview_likelihood equipmentsatisfiedrw sovisit1st  \
# 0               NaN                  NaN                  NaN        NaN
# 1               NaN                  NaN                  NaN        NaN
# 2               NaN                  NaN                  NaN        NaN
# 3               NaN                  NaN                  NaN        NaN
# 4               NaN                  NaN                  NaN        NaN
#
#   job_discovery what types of purchases are you involved in? (hardware)  \
# 0           NaN                                                     NaN
# 1           NaN                                                     NaN
# 2           NaN                                                     NaN
# 3           NaN                                                     NaN
# 4           NaN                                                     NaN
#
#   databasedesirenextyear currencydesc databasewanttoworkwith workchallenge  \
# 0                    NaN          NaN                    NaN           NaN
# 1                    NaN          NaN                    NaN           NaN
# 2                    NaN          NaN                    NaN           NaN
# 3                    NaN          NaN                    NaN           NaN
# 4                    NaN          NaN                    NaN           NaN
#
#   icorpm how likely is it that a recommendation you make will be acted upon?  \
# 0    NaN                                    Unless it's stoopid it gets done
# 1    NaN                                           It's been known to happen
# 2    NaN                                                 Once in a blue moon
# 3    NaN                                              Not in a million years
# 4    NaN                                                 Once in a blue moon
#
#   webframeadmired assessjobdiversity employmentstatus knowledge_8 methodology  \
# 0             NaN                NaN              NaN         NaN         NaN
# 1             NaN                NaN              NaN         NaN         NaN
# 2             NaN                NaN              NaN         NaN         NaN
# 3             NaN                NaN              NaN         NaN         NaN
# 4             NaN                NaN              NaN         NaN         NaN
#
#    adspriorities2 socomm aiagentchallengesneutral aiselect  \
# 0             NaN    NaN                      NaN      NaN
# 1             NaN    NaN                      NaN      NaN
# 2             NaN    NaN                      NaN      NaN
# 3             NaN    NaN                      NaN      NaN
# 4             NaN    NaN                      NaN      NaN
#
#   which best describes the size of your company? how old are you?  \
# 0                                Start Up (1-25)            30-34
# 1                                Start Up (1-25)            40-50
# 2                 Mature Small Business (25-100)            30-34
# 3                            Mid Sized (100-999)            30-34
# 4          Other (not working, consultant, etc.)            25-29
#
#   problemsolving frustration platformworkedwith currencysymbol  \
# 0            NaN         NaN                NaN            NaN
# 1            NaN         NaN                NaN            NaN
# 2            NaN         NaN                NaN            NaN
# 3            NaN         NaN                NaN            NaN
# 4            NaN         NaN                NaN            NaN
#
#   adsagreedisagree2 accessibility  \
# 0               NaN           NaN
# 1               NaN           NaN
# 2               NaN           NaN
# 3               NaN           NaN
# 4               NaN           NaN
#
#   you answered you don't have a careers profile, can you elaborate why?  \
# 0                                                                   NaN
# 1                                                                   NaN
# 2                                                                   NaN
# 3                                                                   NaN
# 4                                                                   NaN
#
#   wantworkdatabase which of our sites do you frequent most?  \
# 0              NaN                           Stack Overflow
# 1              NaN                           Stack Overflow
# 2              NaN                           Stack Overflow
# 3              NaN               Programmers Stack Exchange
# 4              NaN                           Stack Overflow
#
#   stackoverflowdevices questionsconfusing  \
# 0                  NaN                NaN
# 1                  NaN                NaN
# 2                  NaN                NaN
# 3                  NaN                NaN
# 4                  NaN                NaN
#
#   how many people work for your company? blockchainorg  salary_midpoint  \
# 0                                    NaN           NaN              NaN
# 1                                    NaN           NaN              NaN
# 2                                    NaN           NaN              NaN
# 3                                    NaN           NaN              NaN
# 4                                    NaN           NaN              NaN
#
#   purchaseinfluence  \
# 0               NaN
# 1               NaN
# 2               NaN
# 3               NaN
# 4               NaN
#
#   how often do you find solutions to your programming problems on stack overflow without asking a new question?  \
# 0                                                                                                           NaN
# 1                                                                                                           NaN
# 2                                                                                                           NaN
# 3                                                                                                           NaN
# 4                                                                                                           NaN
#
#    big_mac_index remote  jobemailpriorities1 techendorse  techendorse_1  \
# 0            NaN    NaN                  NaN         NaN            NaN
# 1            NaN    NaN                  NaN         NaN            NaN
# 2            NaN    NaN                  NaN         NaN            NaN
# 3            NaN    NaN                  NaN         NaN            NaN
# 4            NaN    NaN                  NaN         NaN            NaN
#
#   languagechoice highesteducationparents tabsspaces companysize  \
# 0            NaN                     NaN        NaN         NaN
# 1            NaN                     NaN        NaN         NaN
# 2            NaN                     NaN        NaN         NaN
# 3            NaN                     NaN        NaN         NaN
# 4            NaN                     NaN        NaN         NaN
#
#   formaleducation stackoverflowrecommend skipmeals employment developertype  \
# 0             NaN                    NaN       NaN        NaN           NaN
# 1             NaN                    NaN       NaN        NaN           NaN
# 2             NaN                    NaN       NaN        NaN           NaN
# 3             NaN                    NaN       NaN        NaN           NaN
# 4             NaN                    NaN       NaN        NaN           NaN
#
#   how do you prefer to be contacted about job opportunities? (email)  \
# 0                                                                NaN
# 1                                                                NaN
# 2                                                                NaN
# 3                                                                NaN
# 4                                                                NaN
#
#   ethnicity timesearching country assessjobindustry difficultcommunication  \
# 0       NaN           NaN     NaN               NaN                    NaN
# 1       NaN           NaN     NaN               NaN                    NaN
# 2       NaN           NaN     NaN               NaN                    NaN
# 3       NaN           NaN     NaN               NaN                    NaN
# 4       NaN           NaN     NaN               NaN                    NaN
#
#   languageworkedwith aisent platformwanttoworkwith cousineducation  \
# 0                NaN    NaN                    NaN             NaN
# 1                NaN    NaN                    NaN             NaN
# 2                NaN    NaN                    NaN             NaN
# 3                NaN    NaN                    NaN             NaN
# 4                NaN    NaN                    NaN             NaN
#
#   sotimesaved commplatformhaveentr agree_adblocker sojobs  \
# 0         NaN                  NaN             NaN    NaN
# 1         NaN                  NaN             NaN    NaN
# 2         NaN                  NaN             NaN    NaN
# 3         NaN                  NaN             NaN    NaN
# 4         NaN                  NaN             NaN    NaN
#
#   stackoverflowadsrelevant hypotheticaltools1 inthezone surveyeasy  \
# 0                      NaN                NaN       NaN        NaN
# 1                      NaN                NaN       NaN        NaN
# 2                      NaN                NaN       NaN        NaN
# 3                      NaN                NaN       NaN        NaN
# 4                      NaN                NaN       NaN        NaN
#
#   webframehaveentry knowledge_5 webframedesirenextyear  jobsatpoints_1  \
# 0               NaN         NaN                    NaN             NaN
# 1               NaN         NaN                    NaN             NaN
# 2               NaN         NaN                    NaN             NaN
# 3               NaN         NaN                    NaN             NaN
# 4               NaN         NaN                    NaN             NaN
#
#   do you have a stack overflow careers profile? exercise  \
# 0                                           NaN      NaN
# 1                                           NaN      NaN
# 2                                           NaN      NaN
# 3                                           NaN      NaN
# 4                                           NaN      NaN
#
#   how often do you visit job boards?  jobemailpriorities7  assessjob5  \
# 0                                NaN                  NaN         NaN
# 1                                NaN                  NaN         NaN
# 2                                NaN                  NaN         NaN
# 3                                NaN                  NaN         NaN
# 4                                NaN                  NaN         NaN
#
#   annoyingui databasewantentry tbranch aidevhaveworkedwith aiben  assessjob8  \
# 0        NaN               NaN     NaN                 NaN   NaN         NaN
# 1        NaN               NaN     NaN                 NaN   NaN         NaN
# 2        NaN               NaN     NaN                 NaN   NaN         NaN
# 3        NaN               NaN     NaN                 NaN   NaN         NaN
# 4        NaN               NaN     NaN                 NaN   NaN         NaN
#
#    assessjob4 webframeworkedwith influenceconsultants knowledge_4  \
# 0         NaN                NaN                  NaN         NaN
# 1         NaN                NaN                  NaN         NaN
# 2         NaN                NaN                  NaN         NaN
# 3         NaN                NaN                  NaN         NaN
# 4         NaN                NaN                  NaN         NaN
#
#    jobemailpriorities2 waketime education aiexplain  \
# 0                  NaN      NaN       NaN       NaN
# 1                  NaN      NaN       NaN       NaN
# 2                  NaN      NaN       NaN       NaN
# 3                  NaN      NaN       NaN       NaN
# 4                  NaN      NaN       NaN       NaN
#
#   what is your budget for outside expenditures (hardware, software, consulting, etc) for 2014?  \
# 0                                                                                          NaN
# 1                                                                                          NaN
# 2                                                                                          NaN
# 3                                                                                          NaN
# 4                                                                                          NaN
#
#   aiagentorchwrite aihuman stackoverflowcompanypage  \
# 0              NaN     NaN                      NaN
# 1              NaN     NaN                      NaN
# 2              NaN     NaN                      NaN
# 3              NaN     NaN                      NaN
# 4              NaN     NaN                      NaN
#
#   officestacksyncwanttoworkwith updatecv important_wfh numbermonitors  \
# 0                           NaN      NaN           NaN            NaN
# 1                           NaN      NaN           NaN            NaN
# 2                           NaN      NaN           NaN            NaN
# 3                           NaN      NaN           NaN            NaN
# 4                           NaN      NaN           NaN            NaN
#
#   resumeupdate which us state or territory do you live in?  \
# 0          NaN                                  California
# 1          NaN                                         NaN
# 2          NaN                                         NaN
# 3          NaN                                         NaN
# 4          NaN                                         NaN
#
#   stackoverflowadsdistracting languageadmired importanthiringpmexp  \
# 0                         NaN             NaN                  NaN
# 1                         NaN             NaN                  NaN
# 2                         NaN             NaN                  NaN
# 3                         NaN             NaN                  NaN
# 4                         NaN             NaN                  NaN
#
#    assessbenefits4 hobbyist yearscodingprof embeddedhaveworkedwith  \
# 0              NaN      NaN             NaN                    NaN
# 1              NaN      NaN             NaN                    NaN
# 2              NaN      NaN             NaN                    NaN
# 3              NaN      NaN             NaN                    NaN
# 4              NaN      NaN             NaN                    NaN
#
#    techoppose_7 aiagentchallengessomewhat agree  adspriorities1  \
# 0           NaN                             NaN             NaN
# 1           NaN                             NaN             NaN
# 2           NaN                             NaN             NaN
# 3           NaN                             NaN             NaN
# 4           NaN                             NaN             NaN
#
#   which of the following best describes your occupation? mainbranch  \
# 0                                      Server Programmer        NaN
# 1                              Web Application Developer        NaN
# 2                          Desktop Application Developer        NaN
# 3                          Desktop Application Developer        NaN
# 4                                                Student        NaN
#
#    jobsatpoints_13  respondent important_ownoffice influencecloud  \
# 0              NaN         NaN                 NaN            NaN
# 1              NaN         NaN                 NaN            NaN
# 2              NaN         NaN                 NaN            NaN
# 3              NaN         NaN                 NaN            NaN
# 4              NaN         NaN                 NaN            NaN
#
#   aimodelswantentry team_size_range aidangerous embeddedadmired assessjobtech  \
# 0               NaN             NaN         NaN             NaN           NaN
# 1               NaN             NaN         NaN             NaN           NaN
# 2               NaN             NaN         NaN             NaN           NaN
# 3               NaN             NaN         NaN             NaN           NaN
# 4               NaN             NaN         NaN             NaN           NaN
#
#   hopefiveyears aitoolinterested in using ainextless integrated  \
# 0           NaN                       NaN                   NaN
# 1           NaN                       NaN                   NaN
# 2           NaN                       NaN                   NaN
# 3           NaN                       NaN                   NaN
# 4           NaN                       NaN                   NaN
#
#   devenvshaveworkedwith  jobsatpoints_10 assessjobproduct occupation_group  \
# 0                   NaN              NaN              NaN              NaN
# 1                   NaN              NaN              NaN              NaN
# 2                   NaN              NaN              NaN              NaN
# 3                   NaN              NaN              NaN              NaN
# 4                   NaN              NaN              NaN              NaN
#
#   important_promotion  techoppose_16 so_region databasechoice  \
# 0                 NaN            NaN       NaN            NaN
# 1                 NaN            NaN       NaN            NaN
# 2                 NaN            NaN       NaN            NaN
# 3                 NaN            NaN       NaN            NaN
# 4                 NaN            NaN       NaN            NaN
#
#   excoderwillnotcode welcomechange new_job_value  \
# 0                NaN           NaN           NaN
# 1                NaN           NaN           NaN
# 2                NaN           NaN           NaN
# 3                NaN           NaN           NaN
# 4                NaN           NaN           NaN
#
#   how would you best describe the industry you currently work in?  \
# 0                                                             NaN
# 1                                                             NaN
# 2                                                             NaN
# 3                                                             NaN
# 4                                                             NaN
#
#   competepeers aiethics  techoppose_13 newovertime  \
# 0          NaN      NaN            NaN         NaN
# 1          NaN      NaN            NaN         NaN
# 2          NaN      NaN            NaN         NaN
# 3          NaN      NaN            NaN         NaN
# 4          NaN      NaN            NaN         NaN
#
#   what other departments / roles do you interact with regularly? (system administrators)  \
# 0                                                                                    NaN
# 1                                                                                    NaN
# 2                                                                                    NaN
# 3                                                                                    NaN
# 4                                                                                    NaN
#
#   toolstechhaveworkedwith us_state  so_actions_10 stackoverflowdescribes  \
# 0                     NaN      NaN            NaN                    NaN
# 1                     NaN      NaN            NaN                    NaN
# 2                     NaN      NaN            NaN                    NaN
# 3                     NaN      NaN            NaN                    NaN
# 4                     NaN      NaN            NaN                    NaN
#
#   aimodelshaveentry excoderbelonged  assessjob2 important_control  \
# 0               NaN             NaN         NaN               NaN
# 1               NaN             NaN         NaN               NaN
# 2               NaN             NaN         NaN               NaN
# 3               NaN             NaN         NaN               NaN
# 4               NaN             NaN         NaN               NaN
#
#   agree_notice  assessjob6  \
# 0          NaN         NaN
# 1          NaN         NaN
# 2          NaN         NaN
# 3          NaN         NaN
# 4          NaN         NaN
#
#   select up to 3 (most annoying about job search: finding time)  \
# 0                                                           NaN
# 1                                                           NaN
# 2                                                           NaN
# 3                                                           NaN
# 4                                                           NaN
#
#   toolstechadmired  jobemailpriorities4 devenvswanttoworkwith  \
# 0              NaN                  NaN                   NaN
# 1              NaN                  NaN                   NaN
# 2              NaN                  NaN                   NaN
# 3              NaN                  NaN                   NaN
# 4              NaN                  NaN                   NaN
#
#   importanthiringtechexp collaborateremote importanthiringgettingthingsdone  \
# 0                    NaN               NaN                              NaN
# 1                    NaN               NaN                              NaN
# 2                    NaN               NaN                              NaN
# 3                    NaN               NaN                              NaN
# 4                    NaN               NaN                              NaN
#
#   agree_nightcode metricassess diversityimportant  vchostingprofessional use  \
# 0             NaN          NaN                NaN                        NaN
# 1             NaN          NaN                NaN                        NaN
# 2             NaN          NaN                NaN                        NaN
# 3             NaN          NaN                NaN                        NaN
# 4             NaN          NaN                NaN                        NaN
#
#   versioncontrolsystem newstuck how large is the team that you work on?  \
# 0                  NaN      NaN                                     NaN
# 1                  NaN      NaN                                     NaN
# 2                  NaN      NaN                                     NaN
# 3                  NaN      NaN                                     NaN
# 4                  NaN      NaN                                     NaN
#
#   importanthiringopensource sohowmuchtime excoderskills  \
# 0                       NaN           NaN           NaN
# 1                       NaN           NaN           NaN
# 2                       NaN           NaN           NaN
# 3                       NaN           NaN           NaN
# 4                       NaN           NaN           NaN
#
#   what is your current stack overflow reputation? frequency_3 sotagshaveentry  \
# 0                                             NaN         NaN             NaN
# 1                                             NaN         NaN             NaN
# 2                                             NaN         NaN             NaN
# 3                                             NaN         NaN             NaN
# 4                                             NaN         NaN             NaN
#
#   purchasewhat which technologies are you excited about? (node.js)  \
# 0          NaN                                                 NaN
# 1          NaN                                                 NaN
# 2          NaN                                                 NaN
# 3          NaN                                                 NaN
# 4          NaN                                                 NaN
#
#   what type of project are you developing?  assessjob10  \
# 0                             Web Platform          NaN
# 1                               Enterprise          NaN
# 2                               Enterprise          NaN
# 3                                    Other          NaN
# 4                                    Other          NaN
#
#   webframehaveworkedwith sofindanswer yearscodedjob influencetechstack  \
# 0                    NaN          NaN           NaN                NaN
# 1                    NaN          NaN           NaN                NaN
# 2                    NaN          NaN           NaN                NaN
# 3                    NaN          NaN           NaN                NaN
# 4                    NaN          NaN           NaN                NaN
#
#    techendorse_3 newcollabtoolshaveworkedwith remotework  \
# 0            NaN                          NaN        NaN
# 1            NaN                          NaN        NaN
# 2            NaN                          NaN        NaN
# 3            NaN                          NaN        NaN
# 4            NaN                          NaN        NaN
#
#   officestacksynchaveworkedwith languageshaveentry  techendorse_7 aiagents  \
# 0                           NaN                NaN            NaN      NaN
# 1                           NaN                NaN            NaN      NaN
# 2                           NaN                NaN            NaN      NaN
# 3                           NaN                NaN            NaN      NaN
# 4                           NaN                NaN            NaN      NaN
#
#   stackoverflowparticipate compfreq  vchostingpersonal use open_to_new_job  \
# 0                      NaN      NaN                    NaN             NaN
# 1                      NaN      NaN                    NaN             NaN
# 2                      NaN      NaN                    NaN             NaN
# 3                      NaN      NaN                    NaN             NaN
# 4                      NaN      NaN                    NaN             NaN
#
#   workstart race trans  workexp newofftopic stackoverflowcommunity  \
# 0       NaN  NaN   NaN      NaN         NaN                    NaN
# 1       NaN  NaN   NaN      NaN         NaN                    NaN
# 2       NaN  NaN   NaN      NaN         NaN                    NaN
# 3       NaN  NaN   NaN      NaN         NaN                    NaN
# 4       NaN  NaN   NaN      NaN         NaN                    NaN
#
#   surveylength desktop_os jobprofile developer_challenges why_learn_new_tech  \
# 0          NaN        NaN        NaN                  NaN                NaN
# 1          NaN        NaN        NaN                  NaN                NaN
# 2          NaN        NaN        NaN                  NaN                NaN
# 3          NaN        NaN        NaN                  NaN                NaN
# 4          NaN        NaN        NaN                  NaN                NaN
#
#   aisearchdevadmired aiagentchange age_range buildingthings assessjoboffice  \
# 0                NaN           NaN       NaN            NaN             NaN
# 1                NaN           NaN       NaN            NaN             NaN
# 2                NaN           NaN       NaN            NaN             NaN
# 3                NaN           NaN       NaN            NaN             NaN
# 4                NaN           NaN       NaN            NaN             NaN
#
#    jobemailpriorities3 aiagentimpactstrongly disagree  \
# 0                  NaN                            NaN
# 1                  NaN                            NaN
# 2                  NaN                            NaN
# 3                  NaN                            NaN
# 4                  NaN                            NaN
#
#   aitoolplan to partially use ai  responseid  \
# 0                            NaN         NaN
# 1                            NaN         NaN
# 2                            NaN         NaN
# 3                            NaN         NaN
# 4                            NaN         NaN
#
#   what operating system do you use the most?  \
# 0                                      Linux
# 1                                   Mac OS X
# 2                                  Windows 7
# 3                                   Mac OS X
# 4                                      Linux
#
#   what advertisers do you remember seeing on stack overflow? (open-ended response)  \
# 0                                                                              NaN
# 1                                                                              NaN
# 2                                                                              NaN
# 3                                                                              NaN
# 4                                                                              NaN
#
#   socialmedia platformhaveentry  surveyyear  jobsatpoints_8  \
# 0         NaN               NaN        2011             NaN
# 1         NaN               NaN        2011             NaN
# 2         NaN               NaN        2011             NaN
# 3         NaN               NaN        2011             NaN
# 4         NaN               NaN        2011             NaN
#
#   importanthiringalgorithms ethicsresponsible officestackasynchaveworkedwith  \
# 0                       NaN               NaN                            NaN
# 1                       NaN               NaN                            NaN
# 2                       NaN               NaN                            NaN
# 3                       NaN               NaN                            NaN
# 4                       NaN               NaN                            NaN
#
#   officestackasyncadmired officestackwantentry equipmentsatisfiedstorage  \
# 0                     NaN                  NaN                       NaN
# 1                     NaN                  NaN                       NaN
# 2                     NaN                  NaN                       NaN
# 3                     NaN                  NaN                       NaN
# 4                     NaN                  NaN                       NaN
#
#   buynewtool  so_actions_4 blockchain agree_tech unittests betterlife  \
# 0        NaN           NaN        NaN        NaN       NaN        NaN
# 1        NaN           NaN        NaN        NaN       NaN        NaN
# 2        NaN           NaN        NaN        NaN       NaN        NaN
# 3        NaN           NaN        NaN        NaN       NaN        NaN
# 4        NaN           NaN        NaN        NaN       NaN        NaN
#
#   hoursoutside  workweekhrs  adspriorities6 newjobhunt  \
# 0          NaN          NaN             NaN        NaN
# 1          NaN          NaN             NaN        NaN
# 2          NaN          NaN             NaN        NaN
# 3          NaN          NaN             NaN        NaN
# 4          NaN          NaN             NaN        NaN
#
#   commplatformwanttoworkwith sexualorientation knowledge_2 jobsecurity  \
# 0                        NaN               NaN         NaN         NaN
# 1                        NaN               NaN         NaN         NaN
# 2                        NaN               NaN         NaN         NaN
# 3                        NaN               NaN         NaN         NaN
# 4                        NaN               NaN         NaN         NaN
#
#   influenceservers stackoverflowanswer sopartfreq job_satisfaction  \
# 0              NaN                 NaN        NaN              NaN
# 1              NaN                 NaN        NaN              NaN
# 2              NaN                 NaN        NaN              NaN
# 3              NaN                 NaN        NaN              NaN
# 4              NaN                 NaN        NaN              NaN
#
#    assessbenefits7 devtype commit_frequency newcollabtoolsworkedwith  age  \
# 0              NaN     NaN              NaN                      NaN  NaN
# 1              NaN     NaN              NaN                      NaN  NaN
# 2              NaN     NaN              NaN                      NaN  NaN
# 3              NaN     NaN              NaN                      NaN  NaN
# 4              NaN     NaN              NaN                      NaN  NaN
#
#   newdevopsimpt jobseek commplatformhaveworkedwith  \
# 0           NaN     NaN                        NaN
# 1           NaN     NaN                        NaN
# 2           NaN     NaN                        NaN
# 3           NaN     NaN                        NaN
# 4           NaN     NaN                        NaN
#
#   select up to 3 (how can companies improve interview process: more live code)  \
# 0                                                                          NaN
# 1                                                                          NaN
# 2                                                                          NaN
# 3                                                                          NaN
# 4                                                                          NaN
#
#   learncodeonline adsactions misctechadmired importanthiringcompanies  \
# 0             NaN        NaN             NaN                      NaN
# 1             NaN        NaN             NaN                      NaN
# 2             NaN        NaN             NaN                      NaN
# 3             NaN        NaN             NaN                      NaN
# 4             NaN        NaN             NaN                      NaN
#
#    so_actions_16 commplatformwantentr understandcomputers  \
# 0            NaN                  NaN                 NaN
# 1            NaN                  NaN                 NaN
# 2            NaN                  NaN                 NaN
# 3            NaN                  NaN                 NaN
# 4            NaN                  NaN                 NaN
#
#   which desktop operating system do you use the most? assessjobremote  \
# 0                                                 NaN             NaN
# 1                                                 NaN             NaN
# 2                                                 NaN             NaN
# 3                                                 NaN             NaN
# 4                                                 NaN             NaN
#
#   aifrustration aimodelschoice sotagswanttoworkwith salary_range  \
# 0           NaN            NaN                  NaN          NaN
# 1           NaN            NaN                  NaN          NaN
# 2           NaN            NaN                  NaN          NaN
# 3           NaN            NaN                  NaN          NaN
# 4           NaN            NaN                  NaN          NaN
#
#   challengemyself frequency_2  ide  assessbenefits5  \
# 0             NaN         NaN  NaN              NaN
# 1             NaN         NaN  NaN              NaN
# 2             NaN         NaN  NaN              NaN
# 3             NaN         NaN  NaN              NaN
# 4             NaN         NaN  NaN              NaN
#
#   in an average week, how do you spend your time at work? (developing new features)  \
# 0                                                                               NaN
# 1                                                                               NaN
# 2                                                                               NaN
# 3                                                                               NaN
# 4                                                                               NaN
#
#   clickykeys stackoverflowdevstory assessjobexp techlist ainextvery similar  \
# 0        NaN                   NaN          NaN      NaN                NaN
# 1        NaN                   NaN          NaN      NaN                NaN
# 2        NaN                   NaN          NaN      NaN                NaN
# 3        NaN                   NaN          NaN      NaN                NaN
# 4        NaN                   NaN          NaN      NaN                NaN
#
#    so_actions_5 knowledge_7  stackoverflowsatisfaction  \
# 0           NaN         NaN                        NaN
# 1           NaN         NaN                        NaN
# 2           NaN         NaN                        NaN
# 3           NaN         NaN                        NaN
# 4           NaN         NaN                        NaN
#
#   what best describes your career / job satisfaction? stackoverflowbetter  \
# 0                                                 NaN                 NaN
# 1                                                 NaN                 NaN
# 2                                                 NaN                 NaN
# 3                                                 NaN                 NaN
# 4                                                 NaN                 NaN
#
#   stackoverflowvisit  assessbenefits8 jobsat influencedatabase surveyease  \
# 0                NaN              NaN    NaN               NaN        NaN
# 1                NaN              NaN    NaN               NaN        NaN
# 2                NaN              NaN    NaN               NaN        NaN
# 3                NaN              NaN    NaN               NaN        NaN
# 4                NaN              NaN    NaN               NaN        NaN
#
#   how often are you contacted by recruiters?  adspriorities4 coderev  \
# 0                                        NaN             NaN     NaN
# 1                                        NaN             NaN     NaN
# 2                                        NaN             NaN     NaN
# 3                                        NaN             NaN     NaN
# 4                                        NaN             NaN     NaN
#
#    assessbenefits3 newothercomms embeddedwanttoworkwith commplatformadmired  \
# 0              NaN           NaN                    NaN                 NaN
# 1              NaN           NaN                    NaN                 NaN
# 2              NaN           NaN                    NaN                 NaN
# 3              NaN           NaN                    NaN                 NaN
# 4              NaN           NaN                    NaN                 NaN
#
#   aimodelsadmired excodernotforme careersatisfaction devenvschoice  \
# 0             NaN             NaN                NaN           NaN
# 1             NaN             NaN                NaN           NaN
# 2             NaN             NaN                NaN           NaN
# 3             NaN             NaN                NaN           NaN
# 4             NaN             NaN                NaN           NaN
#
#   sonewcontent aithreat platformadmired aimodelswanttoworkwith boringdetails  \
# 0          NaN      NaN             NaN                    NaN           NaN
# 1          NaN      NaN             NaN                    NaN           NaN
# 2          NaN      NaN             NaN                    NaN           NaN
# 3          NaN      NaN             NaN                    NaN           NaN
# 4          NaN      NaN             NaN                    NaN           NaN
#
#   sexuality  adspriorities3 what country do you live in? haveworkeddatabase  \
# 0       NaN             NaN                          NaN                NaN
# 1       NaN             NaN                          NaN                NaN
# 2       NaN             NaN                          NaN                NaN
# 3       NaN             NaN                          NaN                NaN
# 4       NaN             NaN                          NaN                NaN
#
#   how did you find out about your current job? misctechhaveworkedwith  \
# 0                                          NaN                    NaN
# 1                                          NaN                    NaN
# 2                                          NaN                    NaN
# 3                                          NaN                    NaN
# 4                                          NaN                    NaN
#
#   salarytype important_buildexisting truefalse_3 adblockerdisable  \
# 0        NaN                     NaN         NaN              NaN
# 1        NaN                     NaN         NaN              NaN
# 2        NaN                     NaN         NaN              NaN
# 3        NaN                     NaN         NaN              NaN
# 4        NaN                     NaN         NaN              NaN
#
#   jobsatisfaction  \
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN
#
#   are you currently looking for a job or open to new opportunities?  \
# 0                                                               NaN
# 1                                                               NaN
# 2                                                               NaN
# 3                                                               NaN
# 4                                                               NaN
#
#   including bonus, what is your annual compensation in usd? assessjobleaders  \
# 0                                                       NaN              NaN
# 1                                         $40,000 - $60,000              NaN
# 2                                         $20,000 - $40,000              NaN
# 3                                         $60,000 - $80,000              NaN
# 4                                                  <$20,000              NaN
#
#    jobemailpriorities5  \
# 0                  NaN
# 1                  NaN
# 2                  NaN
# 3                  NaN
# 4                  NaN
#
#   select all that apply (training & education: no formal training) yearscode  \
# 0                                                              NaN       NaN
# 1                                                              NaN       NaN
# 2                                                              NaN       NaN
# 3                                                              NaN       NaN
# 4                                                              NaN       NaN
#
#   aiacc haveworkedframework self_identification platformchoice sohow  \
# 0   NaN                 NaN                 NaN            NaN   NaN
# 1   NaN                 NaN                 NaN            NaN   NaN
# 2   NaN                 NaN                 NaN            NaN   NaN
# 3   NaN                 NaN                 NaN            NaN   NaN
# 4   NaN                 NaN                 NaN            NaN   NaN
#
#   important_sameend webframechoice  so_actions_3 newcollabtoolsdesirenextyear  \
# 0               NaN            NaN           NaN                          NaN
# 1               NaN            NaN           NaN                          NaN
# 2               NaN            NaN           NaN                          NaN
# 3               NaN            NaN           NaN                          NaN
# 4               NaN            NaN           NaN                          NaN
#
#   databasehaveworkedwith misctechworkedwith timeanswering languageswantentry  \
# 0                    NaN                NaN           NaN                NaN
# 1                    NaN                NaN           NaN                NaN
# 2                    NaN                NaN           NaN                NaN
# 3                    NaN                NaN           NaN                NaN
# 4                    NaN                NaN           NaN                NaN
#
#   stackoverflowjoblisting occupation webdevelopertype  jobcontactpriorities3  \
# 0                     NaN        NaN              NaN                    NaN
# 1                     NaN        NaN              NaN                    NaN
# 2                     NaN        NaN              NaN                    NaN
# 3                     NaN        NaN              NaN                    NaN
# 4                     NaN        NaN              NaN                    NaN
#
#   ainextsomewhat similar sotagshaveworkedwith assessjobprojects  \
# 0                    NaN                  NaN               NaN
# 1                    NaN                  NaN               NaN
# 2                    NaN                  NaN               NaN
# 3                    NaN                  NaN               NaN
# 4                    NaN                  NaN               NaN
#
#   aisearchdevwanttoworkwith  techoppose_5 women_on_team currency  \
# 0                       NaN           NaN           NaN      NaN
# 1                       NaN           NaN           NaN      NaN
# 2                       NaN           NaN           NaN      NaN
# 3                       NaN           NaN           NaN      NaN
# ...
#
#   how do you use stack overflow? (read other people's questions to solve my problems)  \
# 0                                                                                 NaN
# 1                                                                                 NaN
# 2                                                                                 NaN
# 3                                                                                 NaN
# 4                                                                                 NaN
#
#    programming_ability versioncontrol toolstechwanttoworkwith  \
# 0                  NaN            NaN                     NaN
# 1                  NaN            NaN                     NaN
# 2                  NaN            NaN                     NaN
# 3                  NaN            NaN                     NaN
# 4                  NaN            NaN                     NaN
#
#   what is your budget for outside expenditures (hardware, software, consulting, etc) for 2011?  \
# 0                                                                                          NaN
# 1                                                                                          NaN
# 2                                                                                          NaN
# 3                                                                                          NaN
# 4                                                                                          NaN
#
#   hackathonreasons  toolcountwork aitoolcurrently using aiopen  \
# 0              NaN            NaN                   NaN    NaN
# 1              NaN            NaN                   NaN    NaN
# 2              NaN            NaN                   NaN    NaN
# 3              NaN            NaN                   NaN    NaN
# 4              NaN            NaN                   NaN    NaN
#
#   questionsinteresting sofriction  techoppose_11  so_actions_1  \
# 0                  NaN        NaN            NaN           NaN
# 1                  NaN        NaN            NaN           NaN
# 2                  NaN        NaN            NaN           NaN
# 3                  NaN        NaN            NaN           NaN
# 4                  NaN        NaN            NaN           NaN
#
#   equipmentsatisfiedcpu  experience_midpoint databaseadmired  \
# 0                   NaN                  NaN             NaN
# 1                   NaN                  NaN             NaN
# 2                   NaN                  NaN             NaN
# 3                   NaN                  NaN             NaN
# 4                   NaN                  NaN             NaN
#
#   aiagentimpactsomewhat disagree investtimetools mobiledevelopertype  \
# 0                            NaN             NaN                 NaN
# 1                            NaN             NaN                 NaN
# 2                            NaN             NaN                 NaN
# 3                            NaN             NaN                 NaN
# 4                            NaN             NaN                 NaN
#
#   workpaycare  techendorse_2 influenceworkstation influencecommunication  \
# 0         NaN            NaN                  NaN                    NaN
# 1         NaN            NaN                  NaN                    NaN
# 2         NaN            NaN                  NaN                    NaN
# 3         NaN            NaN                  NaN                    NaN
# 4         NaN            NaN                  NaN                    NaN
#
#   ainextsomewhat different jobsatpoints_15_text  so_actions_6  \
# 0                      NaN                  NaN           NaN
# 1                      NaN                  NaN           NaN
# 2                      NaN                  NaN           NaN
# 3                      NaN                  NaN           NaN
# 4                      NaN                  NaN           NaN
#
#   projectmanagement gender educationparents  jobsatpoints_7  age_midpoint  \
# 0               NaN    NaN              NaN             NaN           NaN
# 1               NaN    NaN              NaN             NaN           NaN
# 2               NaN    NaN              NaN             NaN           NaN
# 3               NaN    NaN              NaN             NaN           NaN
# 4               NaN    NaN              NaN             NaN           NaN
#
#    toolcountpersonal collector stackoverflowmetachat surveylong  \
# 0                NaN       NaN                   NaN        NaN
# 1                NaN       NaN                   NaN        NaN
# 2                NaN       NaN                   NaN        NaN
# 3                NaN       NaN                   NaN        NaN
# 4                NaN       NaN                   NaN        NaN
#
#    convertedsalary age1stcode stackoverflowcopiedcode newlearn  \
# 0              NaN        NaN                     NaN      NaN
# 1              NaN        NaN                     NaN      NaN
# 2              NaN        NaN                     NaN      NaN
# 3              NaN        NaN                     NaN      NaN
# 4              NaN        NaN                     NaN      NaN
#
#   important_companymission how many developers are employed at your company?  \
# 0                      NaN                                               NaN
# 1                      NaN                                               NaN
# 2                      NaN                                               NaN
# 3                      NaN                                               NaN
# 4                      NaN                                               NaN
#
#   stackoverflowconsidermember offon entteams platformhaveworkedwith  \
# 0                         NaN   NaN      NaN                    NaN
# 1                         NaN   NaN      NaN                    NaN
# 2                         NaN   NaN      NaN                    NaN
# 3                         NaN   NaN      NaN                    NaN
# 4                         NaN   NaN      NaN                    NaN
#
#   select all that apply (source control used: git)  \
# 0                                              NaN
# 1                                              NaN
# 2                                              NaN
# 3                                              NaN
# 4                                              NaN
#
#   which technology products do you own? (you can choose more than one) (iphone)  \
# 0                                                                        iPhone
# 1                                                                        iPhone
# 2                                                                        iPhone
# 3                                                                           NaN
# 4                                                                           NaN
#
#    assessjob7  jobcontactpriorities2 opensource blockchainis workplan  \
# 0         NaN                    NaN        NaN          NaN      NaN
# 1         NaN                    NaN        NaN          NaN      NaN
# 2         NaN                    NaN        NaN          NaN      NaN
# 3         NaN                    NaN        NaN          NaN      NaN
# 4         NaN                    NaN        NaN          NaN      NaN
#
#   educationtypes aiagentchallengessomewhat disagree stackoverflowwhatdo  \
# 0            NaN                                NaN                 NaN
# 1            NaN                                NaN                 NaN
# 2            NaN                                NaN                 NaN
# 3            NaN                                NaN                 NaN
# 4            NaN                                NaN                 NaN
#
#   ergonomicdevices adsagreedisagree3 learncodecoursescert  \
# 0              NaN               NaN                  NaN
# 1              NaN               NaN                  NaN
# 2              NaN               NaN                  NaN
# 3              NaN               NaN                  NaN
# 4              NaN               NaN                  NaN
#
#   please rate your job/career satisfaction hypotheticaltools2  \
# 0                        So happy it hurts                NaN
# 1                    I enjoy going to work                NaN
# 2                        So happy it hurts                NaN
# 3                                      FML                NaN
# 4                    I enjoy going to work                NaN
#
#   stackoverflowhasaccount aiagentknowwrite importanthiringeducation industry  \
# 0                     NaN              NaN                      NaN      NaN
# 1                     NaN              NaN                      NaN      NaN
# 2                     NaN              NaN                      NaN      NaN
# 3                     NaN              NaN                      NaN      NaN
# 4                     NaN              NaN                      NaN      NaN
#
#   visit_frequency select all that apply (future lang & tech: android)  \
# 0             NaN                                                 NaN
# 1             NaN                                                 NaN
# 2             NaN                                                 NaN
# 3             NaN                                                 NaN
# 4             NaN                                                 NaN
#
#   haveworkedlanguage jobfactors  \
# 0                NaN        NaN
# 1                NaN        NaN
# 2                NaN        NaN
# 3                NaN        NaN
# 4                NaN        NaN
#
#   in receiving an email about a job opportunity, what attributes of the message would make you more likely to respond? (message is personalized to me)  \
# 0                                                                                                                                                  NaN
# 1                                                                                                                                                  NaN
# 2                                                                                                                                                  NaN
# 3                                                                                                                                                  NaN
# 4                                                                                                                                                  NaN
#
#   workloc containers ainextmuch less integrated devenvwantentry lastnewjob  \
# 0     NaN        NaN                        NaN             NaN        NaN
# 1     NaN        NaN                        NaN             NaN        NaN
# 2     NaN        NaN                        NaN             NaN        NaN
# 3     NaN        NaN                        NaN             NaN        NaN
# 4     NaN        NaN                        NaN             NaN        NaN
#
#    jobcontactpriorities5 stackoverflowjobsearch professionalcloud mgridiot  \
# 0                    NaN                    NaN               NaN      NaN
# 1                    NaN                    NaN               NaN      NaN
# 2                    NaN                    NaN               NaN      NaN
# 3                    NaN                    NaN               NaN      NaN
# 4                    NaN                    NaN               NaN      NaN
#
#   buildvsbuy opsysprofessional use stackoverflowhelpful  \
# 0        NaN                   NaN                  NaN
# 1        NaN                   NaN                  NaN
# 2        NaN                   NaN                  NaN
# 3        NaN                   NaN                  NaN
# 4        NaN                   NaN                  NaN
#
#   how many years of it/programming experience do you have? resumeprompted  \
# 0                                                       11            NaN
# 1                                                       11            NaN
# 2                                                       11            NaN
# 3                                                    41435            NaN
# 4                                                    41310            NaN
#
#   databaseworkedwith important_variety majorundergrad  \
# 0                NaN               NaN            NaN
# 1                NaN               NaN            NaN
# 2                NaN               NaN            NaN
# 3                NaN               NaN            NaN
# 4                NaN               NaN            NaN
#
#   what is your involvement in purchasing products or services for the company you work for? (you can choose more than one) (influencer)  \
# 0                                                                                                                                   NaN
# 1                                                                                                                                   NaN
# 2                                                                                                                                   NaN
# 3                                                                                                                                   NaN
# 4                                                                                                                                   NaN
#
#   aitoolcurrently partially ai officestackhaveentry kinshipdevelopers  \
# 0                          NaN                  NaN               NaN
# 1                          NaN                  NaN               NaN
# 2                          NaN                  NaN               NaN
# 3                          NaN                  NaN               NaN
# 4                          NaN                  NaN               NaN
#
#   enjoydebugging so_actions_15_text stackoverflownewquestion hourscomputer  \
# 0            NaN                NaN                      NaN           NaN
# 1            NaN                NaN                      NaN           NaN
# 2            NaN                NaN                      NaN           NaN
# 3            NaN                NaN                      NaN           NaN
# 4            NaN                NaN                      NaN           NaN
#
#   select all that apply (why answer: help a programmer in need)  \
# 0                                                           NaN
# 1                                                           NaN
# 2                                                           NaN
# 3                                                           NaN
# 4                                                           NaN
#
#   influencedepttech sovisitfreq  techendorse_9 importantbenefits  \
# 0               NaN         NaN            NaN               NaN
# 1               NaN         NaN            NaN               NaN
# 2               NaN         NaN            NaN               NaN
# 3               NaN         NaN            NaN               NaN
# 4               NaN         NaN            NaN               NaN
#
#    techendorse_4 importanthiringcommunication student techoppose_15_text  \
# 0            NaN                          NaN     NaN                NaN
# 1            NaN                          NaN     NaN                NaN
# 2            NaN                          NaN     NaN                NaN
# 3            NaN                          NaN     NaN                NaN
# 4            NaN                          NaN     NaN                NaN
#
#    techendorse_6 programhobby
# 0            NaN          NaN
# 1            NaN          NaN
# 2            NaN          NaN
# 3            NaN          NaN
# 4            NaN          NaN

# %%
# Find columns containing 'country'
country_columns = [col for col in df_use.columns if 'country' in str(col).lower()]

print("Columns containing 'country':")
for col in country_columns:
    try:
        # Select the column(s). If multiple columns share the same name this returns a DataFrame.
        selected = df_use.loc[:, col]
        # If a DataFrame is returned (duplicate column names), collapse to a single Series by taking
        # the first non-null value across duplicates for each row.
        if isinstance(selected, pd.DataFrame):
            if selected.shape[1] > 1:
                print(f"\nWarning: column name '{col}' is duplicated ({selected.shape[1]} columns). Combining duplicates by taking first non-null value.")
            series = selected.bfill(axis=1).iloc[:, 0]
        else:
            series = selected.squeeze()

        print(f"\nColumn: {col}")
        print("Top 5 most common values and their counts:")
        counts = series.fillna('NULL').value_counts().head()
        print(counts)

        # Get unique count excluding nulls
        unique_count = series.dropna().nunique()
        print(f"\nTotal unique values (excluding nulls): {unique_count}")
        print(f"Number of null values: {series.isnull().sum()}")
        print("-" * 50)
    except Exception as e:
        print(f"\nError processing column {col}: {str(e)}")
        print("-" * 50)
# Out:
# Columns containing 'country':
#
# Warning: column name 'country' is duplicated (2 columns). Combining duplicates by taking first non-null value.
#
# Column: country
# Top 5 most common values and their counts:
# country
# United States               15827
# NULL                        15330
# India                       14075
# United States of America    13283
# Germany                     10046
# Name: count, dtype: int64
#
# Total unique values (excluding nulls): 235
# Number of null values: 15330
# --------------------------------------------------
#
# Column: what country do you live in?
# Top 5 most common values and their counts:
# what country do you live in?
# NULL              152992
# United States        400
# India                166
# United Kingdom       143
# Germany               85
# Name: count, dtype: int64
#
# Total unique values (excluding nulls): 80
# Number of null values: 152992
# --------------------------------------------------
#
# Column: what country or region do you live in?
# Top 5 most common values and their counts:
# what country or region do you live in?
# NULL                        150762
# United States of America      1189
# Other Europe                   637
# United Kingdom                 386
# India                          292
# Name: count, dtype: int64
#
# Total unique values (excluding nulls): 20
# Number of null values: 150762
# --------------------------------------------------
#
# Warning: column name 'country' is duplicated (2 columns). Combining duplicates by taking first non-null value.
#
# Column: country
# Top 5 most common values and their counts:
# country
# United States               15827
# NULL                        15330
# India                       14075
# United States of America    13283
# Germany                     10046
# Name: count, dtype: int64
#
# Total unique values (excluding nulls): 235
# Number of null values: 15330
# --------------------------------------------------
#
# Column: uk_country
# Top 5 most common values and their counts:
# uk_country
# NULL                153633
# England                795
# Scotland                66
# Wales                   15
# Northern Ireland        12
# Name: count, dtype: int64
#
# Total unique values (excluding nulls): 4
# Number of null values: 153633
# --------------------------------------------------

# %%
# Dictionary of column groups to combine
column_groups = {
    'years_coding': ['yearscode', 'yearscodingprof', 'yearscodepro', 'work_experience', 'yearsprogram', 'yearscodedjob', 'how many years of it/programming experience do you have?'],
    'education': ['edlevel', 'education', 'formaleducation'],
    'employment': ['employment', 'employmentstatus', 'employment_status'],
    'company_size': ['companysize', 'company_size_range', 'orgsize', 'companyemployeesrange', 'how many people work for your company?', 'which best describes the size of your company?'],
    'salary': ['convertedsalary', 'convertedcomp', 'comptotal'],
    'job_satisfaction': ['jobsatisfaction', 'job_satisfaction', 'careersatisfaction', 'please rate your job/career satisfaction'],
    'job_title': ['jobtitle', 'currentjobtitle', 'jobprofile'],
    'developer_type': ['developertype', 'devtype'],
    'industry': ['industry', 'industrytype', 'companytype', 'how would you best describe the industry you work in?', 'how would you best describe the industry you currently work in?'],
    'country': ['country', 'location', 'countrycode', 'what country or region do you live in?', 'what country do you live in?'],
    'programming_experience': ['yearscode', 'yearscoding', 'codingexperience'],
    'database_worked_with': ['databaseworkedwith', 'dbworkedwith'],
    'dev_environment': ['ide', 'developmentenvironment', 'dev_environment', 'devenviron', 'devenvironment'],
    'operating_sys': ['opsys', 'operatingsystem', 'os', 'what operating system do you use the most?', 'which desktop operating system do you use the most?'],
    'dev_methodology': ['methodology', 'devmethodology', 'developmentmethodology'],
    'communication_tools': ['communicationtools', 'collaboration', 'collabtools'],
    'gender': ['gender', 'sex', 'what is your gender?'],
    'age': ['age', 'agerange','age_range','agegrouping', 'how old are you?'],
    'learning': ['learncode', 'learncodehow', 'learningmethod'],
    'work_experience': ['workexp', 'experience', 'yearsexperience'],
    'remote': ['remotework', 'workremote', 'remotestatus', 'do you work remotely?', 'homeremote', 'remote'],
    'team_size': ['teamsize', 'orgteamsize', 'developmentteamsize', 'how large is the team that you work on?'],
    'survey_easy': ['surveyease', 'surveyeasy', 'surveylong', 'surveytoolong', 'surveylength'],
    'version_control_sys': ['versioncontrol', 'versioncontrolsystem', 'vcs'],
    'currency': ['currency', 'currencydesc'],
    'hobby': ['hobby', 'hobbyist'],
    'race': ['race', 'raceethnicity', 'self_identification']
}

# %%
df_use_2 = df_use.copy()

# %%
# Identify and combine duplicate columns
def combine_duplicate_columns(df):
    """
    Identifies columns with the same name (case-insensitive), combines their data
    into a single column by taking the first non-null value, and removes the originals.

    Args:
        df: The input DataFrame.

    Returns:
        A new DataFrame with duplicate columns combined.
    """
    df_combined_duplicates = pd.DataFrame(index=df.index)
    processed_columns = set()

    for col_name in df.columns:
        col_name_lower = col_name.lower()

        if col_name_lower not in processed_columns:
            # Find all columns with this name (case-insensitive)
            duplicate_columns = [col for col in df.columns if col.lower() == col_name_lower]

            if len(duplicate_columns) > 1:
                print(f"Combining duplicate columns for '{col_name_lower}': {duplicate_columns}")
                # Select the duplicate columns
                selected_duplicates = df[duplicate_columns]
                # Combine by taking the first non-null value across rows
                combined_series = selected_duplicates.bfill(axis=1).iloc[:, 0]
                df_combined_duplicates[col_name_lower] = combined_series
                # Add to processed set
                processed_columns.add(col_name_lower)
            else:
                # Not a duplicate, just add the column
                df_combined_duplicates[col_name_lower] = df[col_name]
                processed_columns.add(col_name_lower)

    return df_combined_duplicates

# Apply the function to combine duplicate columns in df_use_2
df_use_combined_duplicates = combine_duplicate_columns(df_use_2)

print("\nOriginal DataFrame shape:", df_use_2.shape)
print("DataFrame shape after combining duplicates:", df_use_combined_duplicates.shape)
# Out:
# Combining duplicate columns for 'country': ['country', 'country']
# Combining duplicate columns for 'webframedesirenextyear': ['webframedesirenextyear', 'webframedesirenextyear']
# Combining duplicate columns for 'webframeworkedwith': ['webframeworkedwith', 'webframeworkedwith']
# Combining duplicate columns for 'industry': ['industry', 'industry']
# Combining duplicate columns for 'gender': ['gender', 'gender']
# Combining duplicate columns for 'hobby': ['hobby', 'hobby']
#
# Original DataFrame shape: (154521, 729)
# DataFrame shape after combining duplicates: (154521, 723)

# %%
def combine_columns(df, column_list):
    """
    Combines data from a list of columns into a single Series,
    taking the first non-null value across the columns for each row.

    Args:
        df: The input pandas DataFrame.
        column_list: A list of column names to combine.

    Returns:
        A pandas Series containing the combined data.
    """
    # Select the specified columns
    selected_columns = df[column_list]

    # Combine columns by taking the first non-null value across rows
    combined_series = selected_columns.bfill(axis=1).iloc[:, 0]

    return combined_series

# %%
# Initialize an empty dictionary to store consolidated columns
consolidated_columns_dict = {}

# Iterate through the column_groups dictionary
for group_name, column_list in column_groups.items():
    # Identify columns in df_use_combined_duplicates that are present in the current group's list
    present_columns = [col for col in column_list if col in df_use_combined_duplicates.columns]

    # If there are columns from the current group present in the DataFrame
    if present_columns:
        print(f"Processing group '{group_name}' with columns: {present_columns}")
        # Call the combine_columns function
        combined_series = combine_columns(df_use_combined_duplicates, present_columns)
        # Store the resulting combined Series in the dictionary
        consolidated_columns_dict[group_name] = combined_series
    else:
        print(f"No columns found for group '{group_name}' in the DataFrame.")

# Create a new DataFrame from the dictionary of consolidated columns
df_consolidated = pd.DataFrame(consolidated_columns_dict)

print("\nConsolidated DataFrame created.")
print(f"Shape of consolidated DataFrame: {df_consolidated.shape}")
df_consolidated.head()
# Out:
# Processing group 'years_coding' with columns: ['yearscode', 'yearscodingprof', 'yearscodepro', 'yearsprogram', 'yearscodedjob', 'how many years of it/programming experience do you have?']
# Processing group 'education' with columns: ['edlevel', 'education', 'formaleducation']
# Processing group 'employment' with columns: ['employment', 'employmentstatus', 'employment_status']
# Processing group 'company_size' with columns: ['companysize', 'company_size_range', 'orgsize', 'how many people work for your company?', 'which best describes the size of your company?']
# Processing group 'salary' with columns: ['convertedsalary', 'convertedcomp', 'comptotal']
# Processing group 'job_satisfaction' with columns: ['jobsatisfaction', 'job_satisfaction', 'careersatisfaction', 'please rate your job/career satisfaction']
# Processing group 'job_title' with columns: ['jobprofile']
# Processing group 'developer_type' with columns: ['developertype', 'devtype']
# Processing group 'industry' with columns: ['industry', 'companytype', 'how would you best describe the industry you work in?', 'how would you best describe the industry you currently work in?']
# Processing group 'country' with columns: ['country', 'what country or region do you live in?', 'what country do you live in?']
# Processing group 'programming_experience' with columns: ['yearscode', 'yearscoding']
# Processing group 'database_worked_with' with columns: ['databaseworkedwith']
# Processing group 'dev_environment' with columns: ['ide', 'dev_environment', 'devenviron']
# Processing group 'operating_sys' with columns: ['opsys', 'operatingsystem', 'what operating system do you use the most?', 'which desktop operating system do you use the most?']
# Processing group 'dev_methodology' with columns: ['methodology']
# Processing group 'communication_tools' with columns: ['communicationtools']
# Processing group 'gender' with columns: ['gender', 'what is your gender?']
# Processing group 'age' with columns: ['age', 'age_range', 'how old are you?']
# Processing group 'learning' with columns: ['learncode']
# Processing group 'work_experience' with columns: ['workexp']
# Processing group 'remote' with columns: ['remotework', 'workremote', 'do you work remotely?', 'homeremote', 'remote']
# Processing group 'team_size' with columns: ['how large is the team that you work on?']
# Processing group 'survey_easy' with columns: ['surveyease', 'surveyeasy', 'surveylong', 'surveytoolong', 'surveylength']
# Processing group 'version_control_sys' with columns: ['versioncontrol', 'versioncontrolsystem']
# Processing group 'currency' with columns: ['currency', 'currencydesc']
# Processing group 'hobby' with columns: ['hobby', 'hobbyist']
# Processing group 'race' with columns: ['race', 'raceethnicity', 'self_identification']
#
# Consolidated DataFrame created.
# Shape of consolidated DataFrame: (154521, 27)
#   years_coding education employment                           company_size  \
# 0           11       NaN        NaN                        Start Up (1-25)
# 1           11       NaN        NaN                        Start Up (1-25)
# 2           11       NaN        NaN         Mature Small Business (25-100)
# 3        41435       NaN        NaN                    Mid Sized (100-999)
# 4        41310       NaN        NaN  Other (not working, consultant, etc.)
#
#    salary       job_satisfaction job_title developer_type           industry  \
# 0     NaN      So happy it hurts       NaN            NaN       Web Services
# 1     NaN  I enjoy going to work       NaN            NaN  Software Products
# 2     NaN      So happy it hurts       NaN            NaN  Software Products
# 3     NaN                    FML       NaN            NaN         Healthcare
# 4     NaN  I enjoy going to work       NaN            NaN              Other
#
#                     country programming_experience database_worked_with  \
# 0  United States of America                    NaN                  NaN
# 1              Other Europe                    NaN                  NaN
# 2             South America                    NaN                  NaN
# 3                Other Asia                    NaN                  NaN
# 4              Other Europe                    NaN                  NaN
#
#   dev_environment operating_sys dev_methodology communication_tools gender  \
# 0             NaN         Linux             NaN                 NaN    NaN
# 1             NaN      Mac OS X             NaN                 NaN    NaN
# 2             NaN     Windows 7             NaN                 NaN    NaN
# 3             NaN      Mac OS X             NaN                 NaN    NaN
# 4             NaN         Linux             NaN                 NaN    NaN
#
#      age learning  work_experience remote team_size survey_easy  \
# 0  30-34      NaN              NaN    NaN       NaN         NaN
# 1  40-50      NaN              NaN    NaN       NaN         NaN
# 2  30-34      NaN              NaN    NaN       NaN         NaN
# 3  30-34      NaN              NaN    NaN       NaN         NaN
# 4  25-29      NaN              NaN    NaN       NaN         NaN
#
#   version_control_sys currency hobby race
# 0                 NaN      NaN   NaN  NaN
# 1                 NaN      NaN   NaN  NaN
# 2                 NaN      NaN   NaN  NaN
# 3                 NaN      NaN   NaN  NaN
# 4                 NaN      NaN   NaN  NaN

# %%
# Create a list of all original column names that were combined
original_columns_to_drop = []
for group_name, column_list in column_groups.items():
    # Identify columns in df_use_combined_duplicates that are present in the current group's list
    present_columns = [col for col in column_list if col in df_use_combined_duplicates.columns]
    original_columns_to_drop.extend(present_columns)

# Remove duplicates from the list of columns to drop
original_columns_to_drop = list(set(original_columns_to_drop))

# Drop these original columns from the df_use_combined_duplicates DataFrame
df_use_combined_duplicates_dropped = df_use_combined_duplicates.drop(columns=original_columns_to_drop, errors='ignore')

print("Original columns that were combined have been dropped.")
print(f"Shape of df_use_combined_duplicates after dropping original columns: {df_use_combined_duplicates_dropped.shape}")
# Out:
# Original columns that were combined have been dropped.
# Shape of df_use_combined_duplicates after dropping original columns: (154521, 651)

# %%
# Concatenate the remaining columns from df_use_combined_duplicates_dropped with the consolidated columns
df_all = pd.concat([df_use_combined_duplicates_dropped, df_consolidated], axis=1)

print("\nFinal DataFrame created by concatenating remaining original columns and consolidated columns.")
print(f"Shape of the final DataFrame: {df_all.shape}")

# Display the first few rows of the final dataframe
print("\nFirst 5 rows of the final DataFrame:")
display(df_all.head())
# Out:
# Final DataFrame created by concatenating remaining original columns and consolidated columns.
# Shape of the final DataFrame: (154521, 678)
#
# First 5 rows of the final DataFrame:
#   importanthiringrep equipmentsatisfiedram eduother  hoursperweek learncodeai  \
# 0                NaN                   NaN      NaN           NaN         NaN
# 1                NaN                   NaN      NaN           NaN         NaN
# 2                NaN                   NaN      NaN           NaN         NaN
# 3                NaN                   NaN      NaN           NaN         NaN
# 4                NaN                   NaN      NaN           NaN         NaN
#
#    jobsatpoints_16 webframewantentry assessjobcompensation  techoppose_2  \
# 0              NaN               NaN                   NaN           NaN
# 1              NaN               NaN                   NaN           NaN
# 2              NaN               NaN                   NaN           NaN
# 3              NaN               NaN                   NaN           NaN
# 4              NaN               NaN                   NaN           NaN
#
#   why_stack_overflow languagedesirenextyear ethicalimplications knowledge_6  \
# 0                NaN                    NaN                 NaN         NaN
# 1                NaN                    NaN                 NaN         NaN
# 2                NaN                    NaN                 NaN         NaN
# 3                NaN                    NaN                 NaN         NaN
# 4                NaN                    NaN                 NaN         NaN
#
#   aitooldon't plan to use ai for this task purchasehow dogs_vs_cats  \
# 0                                      NaN         NaN          NaN
# 1                                      NaN         NaN          NaN
# 2                                      NaN         NaN          NaN
# 3                                      NaN         NaN          NaN
# 4                                      NaN         NaN          NaN
#
#   agreedisagree2 equipmentsatisfiedmonitors  \
# 0            NaN                        NaN
# 1            NaN                        NaN
# 2            NaN                        NaN
# 3            NaN                        NaN
# 4            NaN                        NaN
#
#   please rate the advertising you've seen on stack overflow (the ads are relevant)  \
# 0                                                                              NaN
# 1                                                                              NaN
# 2                                                                              NaN
# 3                                                                              NaN
# 4                                                                              NaN
#
#   fizzbuzz influenceviztools stackoverflowmoderation haveworkedplatform  \
# 0      NaN               NaN                     NaN                NaN
# 1      NaN               NaN                     NaN                NaN
# 2      NaN               NaN                     NaN                NaN
# 3      NaN               NaN                     NaN                NaN
# 4      NaN               NaN                     NaN                NaN
#
#   interview_likelihood equipmentsatisfiedrw sovisit1st job_discovery  \
# 0                  NaN                  NaN        NaN           NaN
# 1                  NaN                  NaN        NaN           NaN
# 2                  NaN                  NaN        NaN           NaN
# 3                  NaN                  NaN        NaN           NaN
# 4                  NaN                  NaN        NaN           NaN
#
#   what types of purchases are you involved in? (hardware)  \
# 0                                                     NaN
# 1                                                     NaN
# 2                                                     NaN
# 3                                                     NaN
# 4                                                     NaN
#
#   databasedesirenextyear databasewanttoworkwith workchallenge icorpm  \
# 0                    NaN                    NaN           NaN    NaN
# 1                    NaN                    NaN           NaN    NaN
# 2                    NaN                    NaN           NaN    NaN
# 3                    NaN                    NaN           NaN    NaN
# 4                    NaN                    NaN           NaN    NaN
#
#   how likely is it that a recommendation you make will be acted upon?  \
# 0                                    Unless it's stoopid it gets done
# 1                                           It's been known to happen
# 2                                                 Once in a blue moon
# 3                                              Not in a million years
# 4                                                 Once in a blue moon
#
#   webframeadmired assessjobdiversity knowledge_8  adspriorities2 socomm  \
# 0             NaN                NaN         NaN             NaN    NaN
# 1             NaN                NaN         NaN             NaN    NaN
# 2             NaN                NaN         NaN             NaN    NaN
# 3             NaN                NaN         NaN             NaN    NaN
# 4             NaN                NaN         NaN             NaN    NaN
#
#   aiagentchallengesneutral aiselect problemsolving frustration  \
# 0                      NaN      NaN            NaN         NaN
# 1                      NaN      NaN            NaN         NaN
# 2                      NaN      NaN            NaN         NaN
# 3                      NaN      NaN            NaN         NaN
# 4                      NaN      NaN            NaN         NaN
#
#   platformworkedwith currencysymbol adsagreedisagree2 accessibility  \
# 0                NaN            NaN               NaN           NaN
# 1                NaN            NaN               NaN           NaN
# 2                NaN            NaN               NaN           NaN
# 3                NaN            NaN               NaN           NaN
# 4                NaN            NaN               NaN           NaN
#
#   you answered you don't have a careers profile, can you elaborate why?  \
# 0                                                                   NaN
# 1                                                                   NaN
# 2                                                                   NaN
# 3                                                                   NaN
# 4                                                                   NaN
#
#   wantworkdatabase which of our sites do you frequent most?  \
# 0              NaN                           Stack Overflow
# 1              NaN                           Stack Overflow
# 2              NaN                           Stack Overflow
# 3              NaN               Programmers Stack Exchange
# 4              NaN                           Stack Overflow
#
#   stackoverflowdevices questionsconfusing blockchainorg  salary_midpoint  \
# 0                  NaN                NaN           NaN              NaN
# 1                  NaN                NaN           NaN              NaN
# 2                  NaN                NaN           NaN              NaN
# 3                  NaN                NaN           NaN              NaN
# 4                  NaN                NaN           NaN              NaN
#
#   purchaseinfluence  \
# 0               NaN
# 1               NaN
# 2               NaN
# 3               NaN
# 4               NaN
#
#   how often do you find solutions to your programming problems on stack overflow without asking a new question?  \
# 0                                                                                                           NaN
# 1                                                                                                           NaN
# 2                                                                                                           NaN
# 3                                                                                                           NaN
# 4                                                                                                           NaN
#
#    big_mac_index  jobemailpriorities1 techendorse  techendorse_1  \
# 0            NaN                  NaN         NaN            NaN
# 1            NaN                  NaN         NaN            NaN
# 2            NaN                  NaN         NaN            NaN
# 3            NaN                  NaN         NaN            NaN
# 4            NaN                  NaN         NaN            NaN
#
#   languagechoice highesteducationparents tabsspaces stackoverflowrecommend  \
# 0            NaN                     NaN        NaN                    NaN
# 1            NaN                     NaN        NaN                    NaN
# 2            NaN                     NaN        NaN                    NaN
# 3            NaN                     NaN        NaN                    NaN
# 4            NaN                     NaN        NaN                    NaN
#
#   skipmeals  \
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN
#
#   how do you prefer to be contacted about job opportunities? (email)  \
# 0                                                                NaN
# 1                                                                NaN
# 2                                                                NaN
# 3                                                                NaN
# 4                                                                NaN
#
#   ethnicity timesearching assessjobindustry difficultcommunication  \
# 0       NaN           NaN               NaN                    NaN
# 1       NaN           NaN               NaN                    NaN
# 2       NaN           NaN               NaN                    NaN
# 3       NaN           NaN               NaN                    NaN
# 4       NaN           NaN               NaN                    NaN
#
#   languageworkedwith aisent platformwanttoworkwith cousineducation  \
# 0                NaN    NaN                    NaN             NaN
# 1                NaN    NaN                    NaN             NaN
# 2                NaN    NaN                    NaN             NaN
# 3                NaN    NaN                    NaN             NaN
# 4                NaN    NaN                    NaN             NaN
#
#   sotimesaved commplatformhaveentr agree_adblocker sojobs  \
# 0         NaN                  NaN             NaN    NaN
# 1         NaN                  NaN             NaN    NaN
# 2         NaN                  NaN             NaN    NaN
# 3         NaN                  NaN             NaN    NaN
# 4         NaN                  NaN             NaN    NaN
#
#   stackoverflowadsrelevant hypotheticaltools1 inthezone webframehaveentry  \
# 0                      NaN                NaN       NaN               NaN
# 1                      NaN                NaN       NaN               NaN
# 2                      NaN                NaN       NaN               NaN
# 3                      NaN                NaN       NaN               NaN
# 4                      NaN                NaN       NaN               NaN
#
#   knowledge_5 webframedesirenextyear  jobsatpoints_1  \
# 0         NaN                    NaN             NaN
# 1         NaN                    NaN             NaN
# 2         NaN                    NaN             NaN
# 3         NaN                    NaN             NaN
# 4         NaN                    NaN             NaN
#
#   do you have a stack overflow careers profile? exercise  \
# 0                                           NaN      NaN
# 1                                           NaN      NaN
# 2                                           NaN      NaN
# 3                                           NaN      NaN
# 4                                           NaN      NaN
#
#   how often do you visit job boards?  jobemailpriorities7  assessjob5  \
# 0                                NaN                  NaN         NaN
# 1                                NaN                  NaN         NaN
# 2                                NaN                  NaN         NaN
# 3                                NaN                  NaN         NaN
# 4                                NaN                  NaN         NaN
#
#   annoyingui databasewantentry tbranch aidevhaveworkedwith aiben  assessjob8  \
# 0        NaN               NaN     NaN                 NaN   NaN         NaN
# 1        NaN               NaN     NaN                 NaN   NaN         NaN
# 2        NaN               NaN     NaN                 NaN   NaN         NaN
# 3        NaN               NaN     NaN                 NaN   NaN         NaN
# 4        NaN               NaN     NaN                 NaN   NaN         NaN
#
#    assessjob4 webframeworkedwith influenceconsultants knowledge_4  \
# 0         NaN                NaN                  NaN         NaN
# 1         NaN                NaN                  NaN         NaN
# 2         NaN                NaN                  NaN         NaN
# 3         NaN                NaN                  NaN         NaN
# 4         NaN                NaN                  NaN         NaN
#
#    jobemailpriorities2 waketime aiexplain  \
# 0                  NaN      NaN       NaN
# 1                  NaN      NaN       NaN
# 2                  NaN      NaN       NaN
# 3                  NaN      NaN       NaN
# 4                  NaN      NaN       NaN
#
#   what is your budget for outside expenditures (hardware, software, consulting, etc) for 2014?  \
# 0                                                                                          NaN
# 1                                                                                          NaN
# 2                                                                                          NaN
# 3                                                                                          NaN
# 4                                                                                          NaN
#
#   aiagentorchwrite aihuman stackoverflowcompanypage  \
# 0              NaN     NaN                      NaN
# 1              NaN     NaN                      NaN
# 2              NaN     NaN                      NaN
# 3              NaN     NaN                      NaN
# 4              NaN     NaN                      NaN
#
#   officestacksyncwanttoworkwith updatecv important_wfh numbermonitors  \
# 0                           NaN      NaN           NaN            NaN
# 1                           NaN      NaN           NaN            NaN
# 2                           NaN      NaN           NaN            NaN
# 3                           NaN      NaN           NaN            NaN
# 4                           NaN      NaN           NaN            NaN
#
#   resumeupdate which us state or territory do you live in?  \
# 0          NaN                                  California
# 1          NaN                                         NaN
# 2          NaN                                         NaN
# 3          NaN                                         NaN
# 4          NaN                                         NaN
#
#   stackoverflowadsdistracting languageadmired importanthiringpmexp  \
# 0                         NaN             NaN                  NaN
# 1                         NaN             NaN                  NaN
# 2                         NaN             NaN                  NaN
# 3                         NaN             NaN                  NaN
# 4                         NaN             NaN                  NaN
#
#    assessbenefits4 embeddedhaveworkedwith  techoppose_7  \
# 0              NaN                    NaN           NaN
# 1              NaN                    NaN           NaN
# 2              NaN                    NaN           NaN
# 3              NaN                    NaN           NaN
# 4              NaN                    NaN           NaN
#
#   aiagentchallengessomewhat agree  adspriorities1  \
# 0                             NaN             NaN
# 1                             NaN             NaN
# 2                             NaN             NaN
# 3                             NaN             NaN
# 4                             NaN             NaN
#
#   which of the following best describes your occupation? mainbranch  \
# 0                                      Server Programmer        NaN
# 1                              Web Application Developer        NaN
# 2                          Desktop Application Developer        NaN
# 3                          Desktop Application Developer        NaN
# 4                                                Student        NaN
#
#    jobsatpoints_13  respondent important_ownoffice influencecloud  \
# 0              NaN         NaN                 NaN            NaN
# 1              NaN         NaN                 NaN            NaN
# 2              NaN         NaN                 NaN            NaN
# 3              NaN         NaN                 NaN            NaN
# 4              NaN         NaN                 NaN            NaN
#
#   aimodelswantentry team_size_range aidangerous embeddedadmired assessjobtech  \
# 0               NaN             NaN         NaN             NaN           NaN
# 1               NaN             NaN         NaN             NaN           NaN
# 2               NaN             NaN         NaN             NaN           NaN
# 3               NaN             NaN         NaN             NaN           NaN
# 4               NaN             NaN         NaN             NaN           NaN
#
#   hopefiveyears aitoolinterested in using ainextless integrated  \
# 0           NaN                       NaN                   NaN
# 1           NaN                       NaN                   NaN
# 2           NaN                       NaN                   NaN
# 3           NaN                       NaN                   NaN
# 4           NaN                       NaN                   NaN
#
#   devenvshaveworkedwith  jobsatpoints_10 assessjobproduct occupation_group  \
# 0                   NaN              NaN              NaN              NaN
# 1                   NaN              NaN              NaN              NaN
# 2                   NaN              NaN              NaN              NaN
# 3                   NaN              NaN              NaN              NaN
# 4                   NaN              NaN              NaN              NaN
#
#   important_promotion  techoppose_16 so_region databasechoice  \
# 0                 NaN            NaN       NaN            NaN
# 1                 NaN            NaN       NaN            NaN
# 2                 NaN            NaN       NaN            NaN
# 3                 NaN            NaN       NaN            NaN
# 4                 NaN            NaN       NaN            NaN
#
#   excoderwillnotcode welcomechange new_job_value competepeers aiethics  \
# 0                NaN           NaN           NaN          NaN      NaN
# 1                NaN           NaN           NaN          NaN      NaN
# 2                NaN           NaN           NaN          NaN      NaN
# 3                NaN           NaN           NaN          NaN      NaN
# 4                NaN           NaN           NaN          NaN      NaN
#
#    techoppose_13 newovertime  \
# 0            NaN         NaN
# 1            NaN         NaN
# 2            NaN         NaN
# 3            NaN         NaN
# 4            NaN         NaN
#
#   what other departments / roles do you interact with regularly? (system administrators)  \
# 0                                                                                    NaN
# 1                                                                                    NaN
# 2                                                                                    NaN
# 3                                                                                    NaN
# 4                                                                                    NaN
#
#   toolstechhaveworkedwith us_state  so_actions_10 stackoverflowdescribes  \
# 0                     NaN      NaN            NaN                    NaN
# 1                     NaN      NaN            NaN                    NaN
# 2                     NaN      NaN            NaN                    NaN
# 3                     NaN      NaN            NaN                    NaN
# 4                     NaN      NaN            NaN                    NaN
#
#   aimodelshaveentry excoderbelonged  assessjob2 important_control  \
# 0               NaN             NaN         NaN               NaN
# 1               NaN             NaN         NaN               NaN
# 2               NaN             NaN         NaN               NaN
# 3               NaN             NaN         NaN               NaN
# 4               NaN             NaN         NaN               NaN
#
#   agree_notice  assessjob6  \
# 0          NaN         NaN
# 1          NaN         NaN
# 2          NaN         NaN
# 3          NaN         NaN
# 4          NaN         NaN
#
#   select up to 3 (most annoying about job search: finding time)  \
# 0                                                           NaN
# 1                                                           NaN
# 2                                                           NaN
# 3                                                           NaN
# 4                                                           NaN
#
#   toolstechadmired  jobemailpriorities4 devenvswanttoworkwith  \
# 0              NaN                  NaN                   NaN
# 1              NaN                  NaN                   NaN
# 2              NaN                  NaN                   NaN
# 3              NaN                  NaN                   NaN
# 4              NaN                  NaN                   NaN
#
#   importanthiringtechexp collaborateremote importanthiringgettingthingsdone  \
# 0                    NaN               NaN                              NaN
# 1                    NaN               NaN                              NaN
# 2                    NaN               NaN                              NaN
# 3                    NaN               NaN                              NaN
# 4                    NaN               NaN                              NaN
#
#   agree_nightcode metricassess diversityimportant  vchostingprofessional use  \
# 0             NaN          NaN                NaN                        NaN
# 1             NaN          NaN                NaN                        NaN
# 2             NaN          NaN                NaN                        NaN
# 3             NaN          NaN                NaN                        NaN
# 4             NaN          NaN                NaN                        NaN
#
#   newstuck importanthiringopensource sohowmuchtime excoderskills  \
# 0      NaN                       NaN           NaN           NaN
# 1      NaN                       NaN           NaN           NaN
# 2      NaN                       NaN           NaN           NaN
# 3      NaN                       NaN           NaN           NaN
# 4      NaN                       NaN           NaN           NaN
#
#   what is your current stack overflow reputation? frequency_3 sotagshaveentry  \
# 0                                             NaN         NaN             NaN
# 1                                             NaN         NaN             NaN
# 2                                             NaN         NaN             NaN
# 3                                             NaN         NaN             NaN
# 4                                             NaN         NaN             NaN
#
#   purchasewhat which technologies are you excited about? (node.js)  \
# 0          NaN                                                 NaN
# 1          NaN                                                 NaN
# 2          NaN                                                 NaN
# 3          NaN                                                 NaN
# 4          NaN                                                 NaN
#
#   what type of project are you developing?  assessjob10  \
# 0                             Web Platform          NaN
# 1                               Enterprise          NaN
# 2                               Enterprise          NaN
# 3                                    Other          NaN
# 4                                    Other          NaN
#
#   webframehaveworkedwith sofindanswer influencetechstack  techendorse_3  \
# 0                    NaN          NaN                NaN            NaN
# 1                    NaN          NaN                NaN            NaN
# 2                    NaN          NaN                NaN            NaN
# 3                    NaN          NaN                NaN            NaN
# 4                    NaN          NaN                NaN            NaN
#
#   newcollabtoolshaveworkedwith officestacksynchaveworkedwith  \
# 0                          NaN                           NaN
# 1                          NaN                           NaN
# 2                          NaN                           NaN
# 3                          NaN                           NaN
# 4                          NaN                           NaN
#
#   languageshaveentry  techendorse_7 aiagents stackoverflowparticipate  \
# 0                NaN            NaN      NaN                      NaN
# 1                NaN            NaN      NaN                      NaN
# 2                NaN            NaN      NaN                      NaN
# 3                NaN            NaN      NaN                      NaN
# 4                NaN            NaN      NaN                      NaN
#
#   compfreq  vchostingpersonal use open_to_new_job workstart trans newofftopic  \
# 0      NaN                    NaN             NaN       NaN   NaN         NaN
# 1      NaN                    NaN             NaN       NaN   NaN         NaN
# 2      NaN                    NaN             NaN       NaN   NaN         NaN
# 3      NaN                    NaN             NaN       NaN   NaN         NaN
# 4      NaN                    NaN             NaN       NaN   NaN         NaN
#
#   stackoverflowcommunity desktop_os developer_challenges why_learn_new_tech  \
# 0                    NaN        NaN                  NaN                NaN
# 1                    NaN        NaN                  NaN                NaN
# 2                    NaN        NaN                  NaN                NaN
# 3                    NaN        NaN                  NaN                NaN
# 4                    NaN        NaN                  NaN                NaN
#
#   aisearchdevadmired aiagentchange buildingthings assessjoboffice  \
# 0                NaN           NaN            NaN             NaN
# 1                NaN           NaN            NaN             NaN
# 2                NaN           NaN            NaN             NaN
# 3                NaN           NaN            NaN             NaN
# 4                NaN           NaN            NaN             NaN
#
#    jobemailpriorities3 aiagentimpactstrongly disagree  \
# 0                  NaN                            NaN
# 1                  NaN                            NaN
# 2                  NaN                            NaN
# 3                  NaN                            NaN
# 4                  NaN                            NaN
#
#   aitoolplan to partially use ai  responseid  \
# 0                            NaN         NaN
# 1                            NaN         NaN
# 2                            NaN         NaN
# 3                            NaN         NaN
# 4                            NaN         NaN
#
#   what advertisers do you remember seeing on stack overflow? (open-ended response)  \
# 0                                                                              NaN
# 1                                                                              NaN
# 2                                                                              NaN
# 3                                                                              NaN
# 4                                                                              NaN
#
#   socialmedia platformhaveentry  surveyyear  jobsatpoints_8  \
# 0         NaN               NaN        2011             NaN
# 1         NaN               NaN        2011             NaN
# 2         NaN               NaN        2011             NaN
# 3         NaN               NaN        2011             NaN
# 4         NaN               NaN        2011             NaN
#
#   importanthiringalgorithms ethicsresponsible officestackasynchaveworkedwith  \
# 0                       NaN               NaN                            NaN
# 1                       NaN               NaN                            NaN
# 2                       NaN               NaN                            NaN
# 3                       NaN               NaN                            NaN
# 4                       NaN               NaN                            NaN
#
#   officestackasyncadmired officestackwantentry equipmentsatisfiedstorage  \
# 0                     NaN                  NaN                       NaN
# 1                     NaN                  NaN                       NaN
# 2                     NaN                  NaN                       NaN
# 3                     NaN                  NaN                       NaN
# 4                     NaN                  NaN                       NaN
#
#   buynewtool  so_actions_4 blockchain agree_tech unittests betterlife  \
# 0        NaN           NaN        NaN        NaN       NaN        NaN
# 1        NaN           NaN        NaN        NaN       NaN        NaN
# 2        NaN           NaN        NaN        NaN       NaN        NaN
# 3        NaN           NaN        NaN        NaN       NaN        NaN
# 4        NaN           NaN        NaN        NaN       NaN        NaN
#
#   hoursoutside  workweekhrs  adspriorities6 newjobhunt  \
# 0          NaN          NaN             NaN        NaN
# 1          NaN          NaN             NaN        NaN
# 2          NaN          NaN             NaN        NaN
# 3          NaN          NaN             NaN        NaN
# 4          NaN          NaN             NaN        NaN
#
#   commplatformwanttoworkwith sexualorientation knowledge_2 jobsecurity  \
# 0                        NaN               NaN         NaN         NaN
# 1                        NaN               NaN         NaN         NaN
# 2                        NaN               NaN         NaN         NaN
# 3                        NaN               NaN         NaN         NaN
# 4                        NaN               NaN         NaN         NaN
#
#   influenceservers stackoverflowanswer sopartfreq  assessbenefits7  \
# 0              NaN                 NaN        NaN              NaN
# 1              NaN                 NaN        NaN              NaN
# 2              NaN                 NaN        NaN              NaN
# 3              NaN                 NaN        NaN              NaN
# 4              NaN                 NaN        NaN              NaN
#
#   commit_frequency newcollabtoolsworkedwith newdevopsimpt jobseek  \
# 0              NaN                      NaN           NaN     NaN
# 1              NaN                      NaN           NaN     NaN
# 2              NaN                      NaN           NaN     NaN
# 3              NaN                      NaN           NaN     NaN
# 4              NaN                      NaN           NaN     NaN
#
#   commplatformhaveworkedwith  \
# 0                        NaN
# 1                        NaN
# 2                        NaN
# 3                        NaN
# 4                        NaN
#
#   select up to 3 (how can companies improve interview process: more live code)  \
# 0                                                                          NaN
# 1                                                                          NaN
# 2                                                                          NaN
# 3                                                                          NaN
# 4                                                                          NaN
#
#   learncodeonline adsactions misctechadmired importanthiringcompanies  \
# 0             NaN        NaN             NaN                      NaN
# 1             NaN        NaN             NaN                      NaN
# 2             NaN        NaN             NaN                      NaN
# 3             NaN        NaN             NaN                      NaN
# 4             NaN        NaN             NaN                      NaN
#
#    so_actions_16 commplatformwantentr understandcomputers assessjobremote  \
# 0            NaN                  NaN                 NaN             NaN
# 1            NaN                  NaN                 NaN             NaN
# 2            NaN                  NaN                 NaN             NaN
# 3            NaN                  NaN                 NaN             NaN
# 4            NaN                  NaN                 NaN             NaN
#
#   aifrustration aimodelschoice sotagswanttoworkwith salary_range  \
# 0           NaN            NaN                  NaN          NaN
# 1           NaN            NaN                  NaN          NaN
# 2           NaN            NaN                  NaN          NaN
# 3           NaN            NaN                  NaN          NaN
# 4           NaN            NaN                  NaN          NaN
#
#   challengemyself frequency_2  assessbenefits5  \
# 0             NaN         NaN              NaN
# 1             NaN         NaN              NaN
# 2             NaN         NaN              NaN
# 3             NaN         NaN              NaN
# 4             NaN         NaN              NaN
#
#   in an average week, how do you spend your time at work? (developing new features)  \
# 0                                                                               NaN
# 1                                                                               NaN
# 2                                                                               NaN
# 3                                                                               NaN
# 4                                                                               NaN
#
#   clickykeys stackoverflowdevstory assessjobexp techlist ainextvery similar  \
# 0        NaN                   NaN          NaN      NaN                NaN
# 1        NaN                   NaN          NaN      NaN                NaN
# 2        NaN                   NaN          NaN      NaN                NaN
# 3        NaN                   NaN          NaN      NaN                NaN
# 4        NaN                   NaN          NaN      NaN                NaN
#
#    so_actions_5 knowledge_7  stackoverflowsatisfaction  \
# 0           NaN         NaN                        NaN
# 1           NaN         NaN                        NaN
# 2           NaN         NaN                        NaN
# 3           NaN         NaN                        NaN
# 4           NaN         NaN                        NaN
#
#   what best describes your career / job satisfaction? stackoverflowbetter  \
# 0                                                 NaN                 NaN
# 1                                                 NaN                 NaN
# 2                                                 NaN                 NaN
# 3                                                 NaN                 NaN
# 4                                                 NaN                 NaN
#
#   stackoverflowvisit  assessbenefits8 jobsat influencedatabase  \
# 0                NaN              NaN    NaN               NaN
# 1                NaN              NaN    NaN               NaN
# 2                NaN              NaN    NaN               NaN
# 3                NaN              NaN    NaN               NaN
# 4                NaN              NaN    NaN               NaN
#
#   how often are you contacted by recruiters?  adspriorities4 coderev  \
# 0                                        NaN             NaN     NaN
# 1                                        NaN             NaN     NaN
# 2                                        NaN             NaN     NaN
# 3                                        NaN             NaN     NaN
# 4                                        NaN             NaN     NaN
#
#    assessbenefits3 newothercomms embeddedwanttoworkwith commplatformadmired  \
# 0              NaN           NaN                    NaN                 NaN
# 1              NaN           NaN                    NaN                 NaN
# 2              NaN           NaN                    NaN                 NaN
# 3              NaN           NaN                    NaN                 NaN
# 4              NaN           NaN                    NaN                 NaN
#
#   aimodelsadmired excodernotforme devenvschoice sonewcontent aithreat  \
# 0             NaN             NaN           NaN          NaN      NaN
# 1             NaN             NaN           NaN          NaN      NaN
# 2             NaN             NaN           NaN          NaN      NaN
# 3             NaN             NaN           NaN          NaN      NaN
# 4             NaN             NaN           NaN          NaN      NaN
#
#   platformadmired aimodelswanttoworkwith boringdetails sexuality  \
# 0             NaN                    NaN           NaN       NaN
# 1             NaN                    NaN           NaN       NaN
# 2             NaN                    NaN           NaN       NaN
# 3             NaN                    NaN           NaN       NaN
# 4             NaN                    NaN           NaN       NaN
#
#    adspriorities3 haveworkeddatabase  \
# 0             NaN                NaN
# 1             NaN                NaN
# 2             NaN                NaN
# 3             NaN                NaN
# 4             NaN                NaN
#
#   how did you find out about your current job? misctechhaveworkedwith  \
# 0                                          NaN                    NaN
# 1                                          NaN                    NaN
# 2                                          NaN                    NaN
# 3                                          NaN                    NaN
# 4                                          NaN                    NaN
#
#   salarytype important_buildexisting truefalse_3 adblockerdisable  \
# 0        NaN                     NaN         NaN              NaN
# 1        NaN                     NaN         NaN              NaN
# 2        NaN                     NaN         NaN              NaN
# 3        NaN                     NaN         NaN              NaN
# 4        NaN                     NaN         NaN              NaN
#
#   are you currently looking for a job or open to new opportunities?  \
# 0                                                               NaN
# 1                                                               NaN
# 2                                                               NaN
# 3                                                               NaN
# 4                                                               NaN
#
#   including bonus, what is your annual compensation in usd? assessjobleaders  \
# 0                                                       NaN              NaN
# 1                                         $40,000 - $60,000              NaN
# 2                                         $20,000 - $40,000              NaN
# 3                                         $60,000 - $80,000              NaN
# 4                                                  <$20,000              NaN
#
#    jobemailpriorities5  \
# 0                  NaN
# 1                  NaN
# 2                  NaN
# 3                  NaN
# 4                  NaN
#
#   select all that apply (training & education: no formal training) aiacc  \
# 0                                                              NaN   NaN
# 1                                                              NaN   NaN
# 2                                                              NaN   NaN
# 3                                                              NaN   NaN
# 4                                                              NaN   NaN
#
#   haveworkedframework platformchoice sohow important_sameend webframechoice  \
# 0                 NaN            NaN   NaN               NaN            NaN
# 1                 NaN            NaN   NaN               NaN            NaN
# 2                 NaN            NaN   NaN               NaN            NaN
# 3                 NaN            NaN   NaN               NaN            NaN
# 4                 NaN            NaN   NaN               NaN            NaN
#
#    so_actions_3 newcollabtoolsdesirenextyear databasehaveworkedwith  \
# 0           NaN                          NaN                    NaN
# 1           NaN                          NaN                    NaN
# 2           NaN                          NaN                    NaN
# 3           NaN                          NaN                    NaN
# 4           NaN                          NaN                    NaN
#
#   misctechworkedwith timeanswering languageswantentry stackoverflowjoblisting  \
# 0                NaN           NaN                NaN                     NaN
# 1                NaN           NaN                NaN                     NaN
# 2                NaN           NaN                NaN                     NaN
# 3                NaN           NaN                NaN                     NaN
# 4                NaN           NaN                NaN                     NaN
#
#   occupation webdevelopertype  jobcontactpriorities3 ainextsomewhat similar  \
# 0        NaN              NaN                    NaN                    NaN
# 1        NaN              NaN                    NaN                    NaN
# 2        NaN              NaN                    NaN                    NaN
# 3        NaN              NaN                    NaN                    NaN
# 4        NaN              NaN                    NaN                    NaN
#
#   sotagshaveworkedwith assessjobprojects aisearchdevwanttoworkwith  \
# 0                  NaN               NaN                       NaN
# 1                  NaN               NaN                       NaN
# 2                  NaN               NaN                       NaN
# 3                  NaN               NaN                       NaN
# 4                  NaN               NaN                       NaN
#
#    techoppose_5 women_on_team auditoryenvironment  \
# 0           NaN           NaN                 NaN
# 1           NaN           NaN                 NaN
# 2           NaN           NaN                 NaN
# 3           NaN           NaN                 NaN
# 4           NaN           NaN                 NaN
#
#   aiagentchallengesstrongly agree ethicschoice onboarding aichallenges  \
# 0                             NaN          NaN        NaN          NaN
# 1                             NaN          NaN        NaN          NaN
# 2                             NaN          NaN        NaN          NaN
# 3                             NaN          NaN        NaN          NaN
# 4                             NaN          NaN        NaN          NaN
#
#   rep_range learnedhiring stackoverflowjobs assessjobcommute sotagsadmired  \
# 0       NaN           NaN               NaN              NaN           NaN
# 1       NaN           NaN               NaN              NaN           NaN
# 2       NaN           NaN               NaN              NaN           NaN
# 3       NaN           NaN               NaN              NaN           NaN
# 4       NaN           NaN               NaN              NaN           NaN
#
#   wantworkplatform sovisitto  assessbenefits6 influenceinternet vcinteraction  \
# 0              NaN       NaN              NaN               NaN           NaN
# 1              NaN       NaN              NaN               NaN           NaN
# 2              NaN       NaN              NaN               NaN           NaN
# 3              NaN       NaN              NaN               NaN           NaN
# 4              NaN       NaN              NaN               NaN           NaN
#
#   knowledge_1 unit_testing professional ethicsreport techendorse_13_text  \
# 0         NaN          NaN          NaN          NaN                 NaN
# 1         NaN          NaN          NaN          NaN                 NaN
# 2         NaN          NaN          NaN          NaN                 NaN
# 3         NaN          NaN          NaN          NaN                 NaN
# 4         NaN          NaN          NaN          NaN                 NaN
#
#   ainextno change aidevwanttoworkwith  \
# 0             NaN                 NaN
# 1             NaN                 NaN
# 2             NaN                 NaN
# 3             NaN                 NaN
# 4             NaN                 NaN
#
#   select all that apply (why try stack overflow careers: no spam)  \
# 0                                                             NaN
# 1                                                             NaN
# 2                                                             NaN
# 3                                                             NaN
# 4                                                             NaN
#
#    jobsatpoints_14 adsagreedisagree1  assessjob1 hypotheticaltools4 newedimpt  \
# 0              NaN               NaN         NaN                NaN       NaN
# 1              NaN               NaN         NaN                NaN       NaN
# 2              NaN               NaN         NaN                NaN       NaN
# 3              NaN               NaN         NaN                NaN       NaN
# 4              NaN               NaN         NaN                NaN       NaN
#
#   newdevops frequency_1 excoderbalance hypotheticaltools5  \
# 0       NaN         NaN            NaN                NaN
# 1       NaN         NaN            NaN                NaN
# 2       NaN         NaN            NaN                NaN
# 3       NaN         NaN            NaN                NaN
# 4       NaN         NaN            NaN                NaN
#
#   influencerecruitment  adspriorities5 stackoverflowjobsrecommend  \
# 0                  NaN             NaN                        NaN
# 1                  NaN             NaN                        NaN
# 2                  NaN             NaN                        NaN
# 3                  NaN             NaN                        NaN
# 4                  NaN             NaN                        NaN
#
#   importanthiringtitles knowledge_3  \
# 0                   NaN         NaN
# 1                   NaN         NaN
# 2                   NaN         NaN
# 3                   NaN         NaN
# 4                   NaN         NaN
#
#   if your company has a native mobile app, what platforms do you support? (iphone)  \
# 0                                                                              NaN
# 1                                                                              NaN
# 2                                                                              NaN
# 3                                                                              NaN
# ...
#
#   hackathonreasons  toolcountwork aitoolcurrently using aiopen  \
# 0              NaN            NaN                   NaN    NaN
# 1              NaN            NaN                   NaN    NaN
# 2              NaN            NaN                   NaN    NaN
# 3              NaN            NaN                   NaN    NaN
# 4              NaN            NaN                   NaN    NaN
#
#   questionsinteresting sofriction  techoppose_11  so_actions_1  \
# 0                  NaN        NaN            NaN           NaN
# 1                  NaN        NaN            NaN           NaN
# 2                  NaN        NaN            NaN           NaN
# 3                  NaN        NaN            NaN           NaN
# 4                  NaN        NaN            NaN           NaN
#
#   equipmentsatisfiedcpu  experience_midpoint databaseadmired  \
# 0                   NaN                  NaN             NaN
# 1                   NaN                  NaN             NaN
# 2                   NaN                  NaN             NaN
# 3                   NaN                  NaN             NaN
# 4                   NaN                  NaN             NaN
#
#   aiagentimpactsomewhat disagree investtimetools mobiledevelopertype  \
# 0                            NaN             NaN                 NaN
# 1                            NaN             NaN                 NaN
# 2                            NaN             NaN                 NaN
# 3                            NaN             NaN                 NaN
# 4                            NaN             NaN                 NaN
#
#   workpaycare  techendorse_2 influenceworkstation influencecommunication  \
# 0         NaN            NaN                  NaN                    NaN
# 1         NaN            NaN                  NaN                    NaN
# 2         NaN            NaN                  NaN                    NaN
# 3         NaN            NaN                  NaN                    NaN
# 4         NaN            NaN                  NaN                    NaN
#
#   ainextsomewhat different jobsatpoints_15_text  so_actions_6  \
# 0                      NaN                  NaN           NaN
# 1                      NaN                  NaN           NaN
# 2                      NaN                  NaN           NaN
# 3                      NaN                  NaN           NaN
# 4                      NaN                  NaN           NaN
#
#   projectmanagement educationparents  jobsatpoints_7  age_midpoint  \
# 0               NaN              NaN             NaN           NaN
# 1               NaN              NaN             NaN           NaN
# 2               NaN              NaN             NaN           NaN
# 3               NaN              NaN             NaN           NaN
# 4               NaN              NaN             NaN           NaN
#
#    toolcountpersonal collector stackoverflowmetachat age1stcode  \
# 0                NaN       NaN                   NaN        NaN
# 1                NaN       NaN                   NaN        NaN
# 2                NaN       NaN                   NaN        NaN
# 3                NaN       NaN                   NaN        NaN
# 4                NaN       NaN                   NaN        NaN
#
#   stackoverflowcopiedcode newlearn important_companymission  \
# 0                     NaN      NaN                      NaN
# 1                     NaN      NaN                      NaN
# 2                     NaN      NaN                      NaN
# 3                     NaN      NaN                      NaN
# 4                     NaN      NaN                      NaN
#
#   how many developers are employed at your company?  \
# 0                                               NaN
# 1                                               NaN
# 2                                               NaN
# 3                                               NaN
# 4                                               NaN
#
#   stackoverflowconsidermember offon entteams platformhaveworkedwith  \
# 0                         NaN   NaN      NaN                    NaN
# 1                         NaN   NaN      NaN                    NaN
# 2                         NaN   NaN      NaN                    NaN
# 3                         NaN   NaN      NaN                    NaN
# 4                         NaN   NaN      NaN                    NaN
#
#   select all that apply (source control used: git)  \
# 0                                              NaN
# 1                                              NaN
# 2                                              NaN
# 3                                              NaN
# 4                                              NaN
#
#   which technology products do you own? (you can choose more than one) (iphone)  \
# 0                                                                        iPhone
# 1                                                                        iPhone
# 2                                                                        iPhone
# 3                                                                           NaN
# 4                                                                           NaN
#
#    assessjob7  jobcontactpriorities2 opensource blockchainis workplan  \
# 0         NaN                    NaN        NaN          NaN      NaN
# 1         NaN                    NaN        NaN          NaN      NaN
# 2         NaN                    NaN        NaN          NaN      NaN
# 3         NaN                    NaN        NaN          NaN      NaN
# 4         NaN                    NaN        NaN          NaN      NaN
#
#   educationtypes aiagentchallengessomewhat disagree stackoverflowwhatdo  \
# 0            NaN                                NaN                 NaN
# 1            NaN                                NaN                 NaN
# 2            NaN                                NaN                 NaN
# 3            NaN                                NaN                 NaN
# 4            NaN                                NaN                 NaN
#
#   ergonomicdevices adsagreedisagree3 learncodecoursescert hypotheticaltools2  \
# 0              NaN               NaN                  NaN                NaN
# 1              NaN               NaN                  NaN                NaN
# 2              NaN               NaN                  NaN                NaN
# 3              NaN               NaN                  NaN                NaN
# 4              NaN               NaN                  NaN                NaN
#
#   stackoverflowhasaccount aiagentknowwrite importanthiringeducation  \
# 0                     NaN              NaN                      NaN
# 1                     NaN              NaN                      NaN
# 2                     NaN              NaN                      NaN
# 3                     NaN              NaN                      NaN
# 4                     NaN              NaN                      NaN
#
#   visit_frequency select all that apply (future lang & tech: android)  \
# 0             NaN                                                 NaN
# 1             NaN                                                 NaN
# 2             NaN                                                 NaN
# 3             NaN                                                 NaN
# 4             NaN                                                 NaN
#
#   haveworkedlanguage jobfactors  \
# 0                NaN        NaN
# 1                NaN        NaN
# 2                NaN        NaN
# 3                NaN        NaN
# 4                NaN        NaN
#
#   in receiving an email about a job opportunity, what attributes of the message would make you more likely to respond? (message is personalized to me)  \
# 0                                                                                                                                                  NaN
# 1                                                                                                                                                  NaN
# 2                                                                                                                                                  NaN
# 3                                                                                                                                                  NaN
# 4                                                                                                                                                  NaN
#
#   workloc containers ainextmuch less integrated devenvwantentry lastnewjob  \
# 0     NaN        NaN                        NaN             NaN        NaN
# 1     NaN        NaN                        NaN             NaN        NaN
# 2     NaN        NaN                        NaN             NaN        NaN
# 3     NaN        NaN                        NaN             NaN        NaN
# 4     NaN        NaN                        NaN             NaN        NaN
#
#    jobcontactpriorities5 stackoverflowjobsearch professionalcloud mgridiot  \
# 0                    NaN                    NaN               NaN      NaN
# 1                    NaN                    NaN               NaN      NaN
# 2                    NaN                    NaN               NaN      NaN
# 3                    NaN                    NaN               NaN      NaN
# 4                    NaN                    NaN               NaN      NaN
#
#   buildvsbuy opsysprofessional use stackoverflowhelpful resumeprompted  \
# 0        NaN                   NaN                  NaN            NaN
# 1        NaN                   NaN                  NaN            NaN
# 2        NaN                   NaN                  NaN            NaN
# 3        NaN                   NaN                  NaN            NaN
# 4        NaN                   NaN                  NaN            NaN
#
#   important_variety majorundergrad  \
# 0               NaN            NaN
# 1               NaN            NaN
# 2               NaN            NaN
# 3               NaN            NaN
# 4               NaN            NaN
#
#   what is your involvement in purchasing products or services for the company you work for? (you can choose more than one) (influencer)  \
# 0                                                                                                                                   NaN
# 1                                                                                                                                   NaN
# 2                                                                                                                                   NaN
# 3                                                                                                                                   NaN
# 4                                                                                                                                   NaN
#
#   aitoolcurrently partially ai officestackhaveentry kinshipdevelopers  \
# 0                          NaN                  NaN               NaN
# 1                          NaN                  NaN               NaN
# 2                          NaN                  NaN               NaN
# 3                          NaN                  NaN               NaN
# 4                          NaN                  NaN               NaN
#
#   enjoydebugging so_actions_15_text stackoverflownewquestion hourscomputer  \
# 0            NaN                NaN                      NaN           NaN
# 1            NaN                NaN                      NaN           NaN
# 2            NaN                NaN                      NaN           NaN
# 3            NaN                NaN                      NaN           NaN
# 4            NaN                NaN                      NaN           NaN
#
#   select all that apply (why answer: help a programmer in need)  \
# 0                                                           NaN
# 1                                                           NaN
# 2                                                           NaN
# 3                                                           NaN
# 4                                                           NaN
#
#   influencedepttech sovisitfreq  techendorse_9 importantbenefits  \
# 0               NaN         NaN            NaN               NaN
# 1               NaN         NaN            NaN               NaN
# 2               NaN         NaN            NaN               NaN
# 3               NaN         NaN            NaN               NaN
# 4               NaN         NaN            NaN               NaN
#
#    techendorse_4 importanthiringcommunication student techoppose_15_text  \
# 0            NaN                          NaN     NaN                NaN
# 1            NaN                          NaN     NaN                NaN
# 2            NaN                          NaN     NaN                NaN
# 3            NaN                          NaN     NaN                NaN
# 4            NaN                          NaN     NaN                NaN
#
#    techendorse_6 programhobby years_coding education employment  \
# 0            NaN          NaN           11       NaN        NaN
# 1            NaN          NaN           11       NaN        NaN
# 2            NaN          NaN           11       NaN        NaN
# 3            NaN          NaN        41435       NaN        NaN
# 4            NaN          NaN        41310       NaN        NaN
#
#                             company_size  salary       job_satisfaction  \
# 0                        Start Up (1-25)     NaN      So happy it hurts
# 1                        Start Up (1-25)     NaN  I enjoy going to work
# 2         Mature Small Business (25-100)     NaN      So happy it hurts
# 3                    Mid Sized (100-999)     NaN                    FML
# 4  Other (not working, consultant, etc.)     NaN  I enjoy going to work
#
#   job_title developer_type           industry                   country  \
# 0       NaN            NaN       Web Services  United States of America
# 1       NaN            NaN  Software Products              Other Europe
# 2       NaN            NaN  Software Products             South America
# 3       NaN            NaN         Healthcare                Other Asia
# 4       NaN            NaN              Other              Other Europe
#
#   programming_experience database_worked_with dev_environment operating_sys  \
# 0                    NaN                  NaN             NaN         Linux
# 1                    NaN                  NaN             NaN      Mac OS X
# 2                    NaN                  NaN             NaN     Windows 7
# 3                    NaN                  NaN             NaN      Mac OS X
# 4                    NaN                  NaN             NaN         Linux
#
#   dev_methodology communication_tools gender    age learning  work_experience  \
# 0             NaN                 NaN    NaN  30-34      NaN              NaN
# 1             NaN                 NaN    NaN  40-50      NaN              NaN
# 2             NaN                 NaN    NaN  30-34      NaN              NaN
# 3             NaN                 NaN    NaN  30-34      NaN              NaN
# 4             NaN                 NaN    NaN  25-29      NaN              NaN
#
#   remote team_size survey_easy version_control_sys currency hobby race
# 0    NaN       NaN         NaN                 NaN      NaN   NaN  NaN
# 1    NaN       NaN         NaN                 NaN      NaN   NaN  NaN
# 2    NaN       NaN         NaN                 NaN      NaN   NaN  NaN
# 3    NaN       NaN         NaN                 NaN      NaN   NaN  NaN
# 4    NaN       NaN         NaN                 NaN      NaN   NaN  NaN

# %%
df_all.to_csv('df_final_population.csv')

# %%
df_2011 = df_all[df_all['surveyyear'] == 2011]

df_2011['country'].value_counts()
# Out:
# country
# United States of America    195
# Other Europe                 92
# United Kingdom               70
# Canada                       35
# Australia                    25
# Germany                      20
# India                        19
# Other Asia                   18
# Middle East                  18
# France                       14
# South America                12
# Russia                       12
# Netherlands                  11
# Italy                         6
# Africa                        5
# Australasia                   3
# Central America               3
# Mexico                        3
# North America (Other)         2
# Name: count, dtype: int64

# %%
combined_consolidated_df = df_all.copy()

# %%
# Mapping of variants -> canonical names (lowercased keys for matching)
country_map = {
    'united states': 'United States',
    'united states of america': 'United States',
    'united kingdom of great britain and northern ireland': 'United Kingdom',
    'united kingdom': 'United Kingdom',
    'trinidad and tobago': 'Trinidad and Tobago',
    'trinidad & tobago': 'Trinidad and Tobago',
    'syrian arab republic': 'Syria',
    'syria': 'Syria',
    'other country (not listed above)': 'Other',
    'other (please specify)': 'Other',
    'myanmar, {burma}': 'Myanmar',
    'myanmar': 'Myanmar',
    'libyan arab jamahiriya': 'Libya',
    'libya': 'Libya',
    'laos': 'Laos',
    "lao people's democratic republic": 'Laos',
    'korea south': 'South Korea',
    'republic of korea': 'South Korea',
    'south korea': 'South Korea',
    'korea north': 'North Korea',
    'north korea': 'North Korea',
    'ireland': 'Ireland',
    'ireland {republic}': 'Ireland',
    'hong kong (s.a.r.)': 'Hong Kong',
    'hong kong': 'Hong Kong',
    'guinea-bissau': 'Guinea',
    'guinea': 'Guinea',
    'bosnia herzegovina': 'Bosnia and Herzegovina',
    'bosnia and herzegovina': 'Bosnia and Herzegovina',
    'bosnia-herzegovina': 'Bosnia and Herzegovina',
    'vatican city state': 'Vatican',
    'vatican': 'Vatican',
    'viet nam': 'Vietnam',
    'vietnam': 'Vietnam'
}

# %%
# Standardize and map 'country' values in combined_consolidated_df
def standardize_country(val):
    # Preserve NaN/None as-is
    if pd.isna(val):
        return val
    # Normalize to lower-case stripped string for lookup
    key = str(val).strip().lower()
    # Return mapped canonical name if available, otherwise return original (preserve original casing)
    return country_map.get(key, val)

# Apply mapping (overwrites 'country' column if present)
if 'country' in combined_consolidated_df.columns:
    combined_consolidated_df['country'] = combined_consolidated_df['country'].apply(standardize_country)
    print("Mapped 'country' values using country_map. Sample counts:")
    # Print the top values (including NaN) to give a quick check
    print(combined_consolidated_df['country'].value_counts(dropna=False).head(20))
else:
    print("Warning: 'country' column not found in combined_consolidated_df")
# Out:
# Mapped 'country' values using country_map. Sample counts:
# country
# United States         30699
# India                 14533
# Germany               10309
# NaN                   10042
# United Kingdom         9382
# Canada                 5367
# France                 4451
# Brazil                 3344
# Poland                 3312
# Netherlands            3184
# Australia              3017
# Italy                  2742
# Spain                  2682
# Russian Federation     2564
# Sweden                 2163
# Ukraine                2019
# Switzerland            1672
# Israel                 1467
# Austria                1443
# Turkey                 1429
# Name: count, dtype: int64

# %%
# Remove columns from combined_consolidated_df with >70% null values
threshold = 0.7
null_pct = combined_consolidated_df.isna().mean()
cols_to_drop = null_pct[null_pct > threshold].index.tolist()
print(f"Dropping {len(cols_to_drop)} columns with >70% null values:")
print(cols_to_drop)
combined_consolidated_df.drop(columns=cols_to_drop, inplace=True)
print(f"New shape of combined_consolidated_df: {combined_consolidated_df.shape}")
# Out:
# Dropping 639 columns with >70% null values:
# ['importanthiringrep', 'equipmentsatisfiedram', 'eduother', 'hoursperweek', 'learncodeai', 'jobsatpoints_16', 'webframewantentry', 'assessjobcompensation', 'techoppose_2', 'why_stack_overflow', 'languagedesirenextyear', 'ethicalimplications', 'knowledge_6', "aitooldon't plan to use ai for this task", 'purchasehow', 'dogs_vs_cats', 'agreedisagree2', 'equipmentsatisfiedmonitors', "please rate the advertising you've seen on stack overflow (the ads are relevant)", 'fizzbuzz', 'influenceviztools', 'stackoverflowmoderation', 'haveworkedplatform', 'interview_likelihood', 'equipmentsatisfiedrw', 'sovisit1st', 'job_discovery', 'what types of purchases are you involved in? (hardware)', 'databasedesirenextyear', 'workchallenge', 'icorpm', 'how likely is it that a recommendation you make will be acted upon?', 'webframeadmired', 'assessjobdiversity', 'knowledge_8', 'adspriorities2', 'aiagentchallengesneutral', 'aiselect', 'problemsolving', 'frustration', 'platformworkedwith', 'currencysymbol', 'adsagreedisagree2', 'accessibility', "you answered you don't have a careers profile, can you elaborate why?", 'wantworkdatabase', 'which of our sites do you frequent most?', 'stackoverflowdevices', 'questionsconfusing', 'blockchainorg', 'salary_midpoint', 'purchaseinfluence', 'how often do you find solutions to your programming problems on stack overflow without asking a new question?', 'big_mac_index', 'jobemailpriorities1', 'techendorse', 'techendorse_1', 'languagechoice', 'highesteducationparents', 'tabsspaces', 'stackoverflowrecommend', 'skipmeals', 'how do you prefer to be contacted about job opportunities? (email)', 'timesearching', 'assessjobindustry', 'difficultcommunication', 'languageworkedwith', 'aisent', 'platformwanttoworkwith', 'cousineducation', 'sotimesaved', 'commplatformhaveentr', 'agree_adblocker', 'sojobs', 'stackoverflowadsrelevant', 'hypotheticaltools1', 'inthezone', 'webframehaveentry', 'knowledge_5', 'webframedesirenextyear', 'jobsatpoints_1', 'do you have a stack overflow careers profile?', 'exercise', 'how often do you visit job boards?', 'jobemailpriorities7', 'assessjob5', 'annoyingui', 'databasewantentry', 'tbranch', 'aidevhaveworkedwith', 'aiben', 'assessjob8', 'assessjob4', 'webframeworkedwith', 'influenceconsultants', 'knowledge_4', 'jobemailpriorities2', 'waketime', 'aiexplain', 'what is your budget for outside expenditures (hardware, software, consulting, etc) for 2014?', 'aiagentorchwrite', 'aihuman', 'stackoverflowcompanypage', 'officestacksyncwanttoworkwith', 'updatecv', 'important_wfh', 'numbermonitors', 'resumeupdate', 'which us state or territory do you live in?', 'stackoverflowadsdistracting', 'languageadmired', 'importanthiringpmexp', 'assessbenefits4', 'embeddedhaveworkedwith', 'techoppose_7', 'aiagentchallengessomewhat agree', 'adspriorities1', 'which of the following best describes your occupation?', 'jobsatpoints_13', 'important_ownoffice', 'influencecloud', 'aimodelswantentry', 'team_size_range', 'aidangerous', 'embeddedadmired', 'assessjobtech', 'hopefiveyears', 'aitoolinterested in using', 'ainextless integrated', 'devenvshaveworkedwith', 'jobsatpoints_10', 'assessjobproduct', 'occupation_group', 'important_promotion', 'techoppose_16', 'so_region', 'databasechoice', 'excoderwillnotcode', 'welcomechange', 'new_job_value', 'competepeers', 'aiethics', 'techoppose_13', 'newovertime', 'what other departments / roles do you interact with regularly? (system administrators)', 'us_state', 'so_actions_10', 'stackoverflowdescribes', 'aimodelshaveentry', 'excoderbelonged', 'assessjob2', 'important_control', 'agree_notice', 'assessjob6', 'select up to 3 (most annoying about job search: finding time)', 'toolstechadmired', 'jobemailpriorities4', 'devenvswanttoworkwith', 'importanthiringtechexp', 'collaborateremote', 'importanthiringgettingthingsdone', 'agree_nightcode', 'metricassess', 'diversityimportant', 'vchostingprofessional use', 'newstuck', 'importanthiringopensource', 'sohowmuchtime', 'excoderskills', 'what  ...
# New shape of combined_consolidated_df: (154521, 38)

# %%
# Detailed column stats sorted by non-null count (descending)
col_stats = pd.DataFrame({
    'non_null_count': combined_consolidated_df.notna().sum(),
    'null_count': combined_consolidated_df.isna().sum(),
    'unique_count': combined_consolidated_df.nunique(dropna=True)
}).sort_values('non_null_count', ascending=False)

# %%
# Add percent of total rows for nulls (rounded to 2 decimals)
total_rows = combined_consolidated_df.shape[0]
col_stats['null_pct'] = (col_stats['null_count'] / total_rows * 100).round(2)

# %%
col_stats
# Out:
#                               non_null_count  null_count  unique_count  \
# surveyyear                            154521           0            15
# country                               144479       10042           229
# employment                            140846       13675           151
# education                             137278       17243           554
# years_coding                          128780       25741           194
# age                                   125492       29029           175
# programming_experience                116643       37878           164
# developer_type                        113405       41116         14745
# company_size                          108436       46085            38
# survey_easy                           107361       47160            18
# mainbranch                            102584       51937             9
# soaccount                              95864       58657             4
# sovisitfreq                            95671       58850             8
# socomm                                 95425       59096             6
# currency                               92126       62395           301
# gender                                 90288       64233            50
# sopartfreq                             78453       76068             8
# remote                                 76487       78034            22
# newsosites                             72161       82360           100
# responseid                             72091       82430         42533
# learning                               67363       87158          3180
# languagehaveworkedwith                 66353       88168         27756
# operating_sys                          65228       89293            18
# languagewanttoworkwith                 61468       93053         25635
# respondent                             60718       93803         47730
# newcollabtoolshaveworkedwith           59030       95491         15531
# hobby                                  58530       95991             8
# trans                                  56849       97672             4
# databasehaveworkedwith                 55898       98623          8418
# ethnicity                              54384      100137           755
# newcollabtoolswanttoworkwith           53188      101333         10150
# sexuality                              52130      102391            38
# toolstechhaveworkedwith                51599      102922         13512
# webframehaveworkedwith                 50199      104322         12271
# opsyspersonal use                      49431      105090          2522
# dev_environment                        48894      105627          7735
# platformhaveworkedwith                 46681      107840          8024
# databasewanttoworkwith                 46496      108025          8066
#
#                               null_pct
# surveyyear                        0.00
# country                           6.50
# employment                        8.85
# education                        11.16
# years_coding                     16.66
# age                              18.79
# programming_experience           24.51
# developer_type                   26.61
# company_size                     29.82
# survey_easy                      30.52
# mainbranch                       33.61
# soaccount                        37.96
# sovisitfreq                      38.09
# socomm                           38.24
# currency                         40.38
# gender                           41.57
# sopartfreq                       49.23
# remote                           50.50
# newsosites                       53.30
# responseid                       53.35
# learning                         56.41
# languagehaveworkedwith           57.06
# operating_sys                    57.79
# languagewanttoworkwith           60.22
# respondent                       60.71
# newcollabtoolshaveworkedwith     61.80
# hobby                            62.12
# trans                            63.21
# databasehaveworkedwith           63.82
# ethnicity                        64.80
# newcollabtoolswanttoworkwith     65.58
# sexuality                        66.26
# toolstechhaveworkedwith          66.61
# webframehaveworkedwith           67.51
# opsyspersonal use                68.01
# dev_environment                  68.36
# platformhaveworkedwith           69.79
# databasewanttoworkwith           69.91

# %%
df_final = combined_consolidated_df.copy()

# %%
df_final.to_csv('df_final.csv')
